# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]
# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]
# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]
# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]
# data path info
environment = "local"
if environment == "local":
    train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = f"./target_state/"
if environment == "colab":
    from google.colab import drive
    drive.mount("/content/drive/")
    rive_path = "/content/drive/MyDrive/NQS4QEM/Bell"
    train_data_path = drive_path + f"/data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = drive_path + f"/target_state/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## caluculate ideal state

# %%
# calculate ideal state
is_ideal_state_file = os.path.exists(ideal_state_path)
if is_ideal_state_file:
    print("ideal state data is exsisted !")
else:
    print("caluculate ideal state data ...")
    subprocess.run("python caluculate_ideal_state.py", shell=True)
    print("ideal state data is ready !")
# Out:
# ideal state data is exsisted !

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path)
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    subprocess.run("python generate_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# train data is exsisted !

# %% [markdown]
# ## estimate observable expectation value

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XX():
    target_list = [0, 1]
    pauli_index = [1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZ():
    target_list = [0, 1]
    pauli_index = [1, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_XX_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "X"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_XZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

# %% [markdown]
# ## callback setting

# %%
def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "KL_Divergence": ts.KL,
        #"Observable_XX_ev": observable_XX_ev,
        #"Observable_XZ_ev": observable_XZ_ev,
    }

    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = ideal_rho,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    return callbacks

# %% [markdown]
# ## experiment

# %%
# experiment params
each_n_shot_list = [10, 50, 100, 500, 1000, 5000, 10000]
error_model_list = ["depolarizing", "unitary", "depolarizing&unitary"]

for error_model in error_model_list:
    for each_n_shot in each_n_shot_list:
        print(f"error_model : {error_model}, each_n_shot : {each_n_shot}")
        train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
        meas_pattern_path = train_data_path + "/measurement_pattern.txt"
        meas_label_path = train_data_path + "/measurement_label.txt"
        meas_result_path = train_data_path + "/measurement_result.txt"
        ideal_rho_re_path = ideal_state_path + "/rho_real.txt"
        ideal_rho_im_path = ideal_state_path + "/rho_imag.txt"
        meas_result, ideal_rho, meas_label, meas_pattern = data.load_data_DM(meas_result_path,
                                                                             ideal_rho_re_path,
                                                                             ideal_rho_im_path,
                                                                             meas_label_path,
                                                                             meas_pattern_path)
        
        nn_state_dm = DensityMatrix(num_visible = n_visible_unit, 
                                    num_hidden = n_hidden_unit, 
                                    num_aux = n_aux_unit, 
                                    unitary_dict = unitaries.create_dict(),
                                    gpu = False)
        
        callbacks = create_callback_dm(nn_state_dm)
        
        nn_state_dm.fit(data = meas_result,
                        input_bases = meas_label,
                        epochs = epoch,
                        pos_batch_size = pbs,
                        neg_batch_size = nbs,
                        lr = lr,
                        k = n_gibbs_step,
                        bases = meas_pattern,
                        callbacks = callbacks,
                        time = True,
                        optimizer = torch.optim.Adadelta,
                        scheduler = torch.optim.lr_scheduler.StepLR,
                        scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
                       )
        
        # save model
        nn_state_dm.save(f"./exp_mixed_state_varying_n_shot/model_n_pattern_shot={each_n_shot}_{error_model}.pt")
        # save train log
        train_log_df = pd.DataFrame()
        train_log_df["epoch"] = np.arange(period, epoch+1, period)
        train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
        train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
        #train_log_df["Observable_XX_ev"] = callbacks[0]["Observable_XX_ev"]
        #train_log_df["Observable_ZZ_ev"] = callbacks[0]["Observable_ZZ_ev"]
        train_log_df.to_csv(f"./exp_mixed_state_varying_n_shot/model_n_pattern_shot={each_n_shot}_{error_model}.csv", index=False)
# Out:
# error_model : depolarizing, each_n_shot : 10
# Epoch: 1	Fidelity = 0.401235	KL_Divergence = 0.606470
# Epoch: 2	Fidelity = 0.393706	KL_Divergence = 0.581701
# Epoch: 3	Fidelity = 0.369294	KL_Divergence = 0.564574
# Epoch: 4	Fidelity = 0.348492	KL_Divergence = 0.554220
# Epoch: 5	Fidelity = 0.339142	KL_Divergence = 0.549172
# Epoch: 6	Fidelity = 0.320670	KL_Divergence = 0.539904
# Epoch: 7	Fidelity = 0.306596	KL_Divergence = 0.532454
# Epoch: 8	Fidelity = 0.311075	KL_Divergence = 0.528982
# Epoch: 9	Fidelity = 0.308846	KL_Divergence = 0.523784
# Epoch: 10	Fidelity = 0.297016	KL_Divergence = 0.515966
# Epoch: 11	Fidelity = 0.294032	KL_Divergence = 0.509142
# Epoch: 12	Fidelity = 0.296378	KL_Divergence = 0.503757
# Epoch: 13	Fidelity = 0.289314	KL_Divergence = 0.496386
# Epoch: 14	Fidelity = 0.296002	KL_Divergence = 0.490283
# Epoch: 15	Fidelity = 0.305971	KL_Divergence = 0.487172
# Epoch: 16	Fidelity = 0.306148	KL_Divergence = 0.483075
# Epoch: 17	Fidelity = 0.303256	KL_Divergence = 0.473326
# Epoch: 18	Fidelity = 0.296681	KL_Divergence = 0.464228
# Epoch: 19	Fidelity = 0.292529	KL_Divergence = 0.457918
# Epoch: 20	Fidelity = 0.294014	KL_Divergence = 0.451159
# Epoch: 21	Fidelity = 0.295672	KL_Divergence = 0.443887
# Epoch: 22	Fidelity = 0.294771	KL_Divergence = 0.438193
# Epoch: 23	Fidelity = 0.298071	KL_Divergence = 0.432866
# Epoch: 24	Fidelity = 0.303527	KL_Divergence = 0.426616
# Epoch: 25	Fidelity = 0.299590	KL_Divergence = 0.420876
# Epoch: 26	Fidelity = 0.300545	KL_Divergence = 0.417142
# Epoch: 27	Fidelity = 0.309438	KL_Divergence = 0.410467
# Epoch: 28	Fidelity = 0.313216	KL_Divergence = 0.405574
# Epoch: 29	Fidelity = 0.318753	KL_Divergence = 0.401738
# Epoch: 30	Fidelity = 0.315763	KL_Divergence = 0.398369
# Epoch: 31	Fidelity = 0.314916	KL_Divergence = 0.392290
# Epoch: 32	Fidelity = 0.317016	KL_Divergence = 0.387071
# Epoch: 33	Fidelity = 0.320787	KL_Divergence = 0.386198
# Epoch: 34	Fidelity = 0.320639	KL_Divergence = 0.378845
# Epoch: 35	Fidelity = 0.329174	KL_Divergence = 0.374718
# Epoch: 36	Fidelity = 0.328648	KL_Divergence = 0.367915
# Epoch: 37	Fidelity = 0.334777	KL_Divergence = 0.364973
# Epoch: 38	Fidelity = 0.337824	KL_Divergence = 0.363805
# Epoch: 39	Fidelity = 0.338621	KL_Divergence = 0.358339
# Epoch: 40	Fidelity = 0.342247	KL_Divergence = 0.352022
# Epoch: 41	Fidelity = 0.346498	KL_Divergence = 0.348471
# Epoch: 42	Fidelity = 0.349576	KL_Divergence = 0.343578
# Epoch: 43	Fidelity = 0.351509	KL_Divergence = 0.341525
# Epoch: 44	Fidelity = 0.352892	KL_Divergence = 0.340361
# Epoch: 45	Fidelity = 0.352674	KL_Divergence = 0.341104
# Epoch: 46	Fidelity = 0.351885	KL_Divergence = 0.333223
# Epoch: 47	Fidelity = 0.359523	KL_Divergence = 0.326998
# Epoch: 48	Fidelity = 0.359395	KL_Divergence = 0.327134
# Epoch: 49	Fidelity = 0.359215	KL_Divergence = 0.325091
# Epoch: 50	Fidelity = 0.365960	KL_Divergence = 0.317488
# Epoch: 51	Fidelity = 0.369685	KL_Divergence = 0.319601
# Epoch: 52	Fidelity = 0.373183	KL_Divergence = 0.316926
# Epoch: 53	Fidelity = 0.375188	KL_Divergence = 0.323265
# Epoch: 54	Fidelity = 0.373760	KL_Divergence = 0.308402
# Epoch: 55	Fidelity = 0.380203	KL_Divergence = 0.303646
# Epoch: 56	Fidelity = 0.381043	KL_Divergence = 0.304492
# Epoch: 57	Fidelity = 0.383501	KL_Divergence = 0.300913
# Epoch: 58	Fidelity = 0.378914	KL_Divergence = 0.300236
# Epoch: 59	Fidelity = 0.379198	KL_Divergence = 0.295283
# Epoch: 60	Fidelity = 0.378039	KL_Divergence = 0.298314
# Epoch: 61	Fidelity = 0.384360	KL_Divergence = 0.293756
# Epoch: 62	Fidelity = 0.384441	KL_Divergence = 0.292882
# Epoch: 63	Fidelity = 0.386743	KL_Divergence = 0.285869
# Epoch: 64	Fidelity = 0.387116	KL_Divergence = 0.281737
# Epoch: 65	Fidelity = 0.390062	KL_Divergence = 0.281078
# Epoch: 66	Fidelity = 0.397786	KL_Divergence = 0.273705
# Epoch: 67	Fidelity = 0.396270	KL_Divergence = 0.280922
# Epoch: 68	Fidelity = 0.397616	KL_Divergence = 0.278847
# Epoch: 69	Fidelity = 0.397283	KL_Divergence = 0.269969
# Epoch: 70	Fidelity = 0.400657	KL_Divergence = 0.270965
# Epoch: 71	Fidelity = 0.402609	KL_Divergence = 0.268350
# Epoch: 72	Fidelity = 0.408239	KL_Divergence = 0.269912
# Epoch: 73	Fidelity = 0.409451	KL_Divergence = 0.263343
# Epoch: 74	Fidelity = 0.411816	KL_Divergence = 0.261926
# Epoch: 75	Fidelity = 0.411886	KL_Divergence = 0.258302
# Epoch: 76	Fidelity = 0.413427	KL_Divergence = 0.255801
# Epoch: 77	Fidelity = 0.419790	KL_Divergence = 0.252645
# Epoch: 78	Fidelity = 0.421884	KL_Divergence = 0.259945
# Epoch: 79	Fidelity = 0.422631	KL_Divergence = 0.249863
# Epoch: 80	Fidelity = 0.423168	KL_Divergence = 0.249380
# Epoch: 81	Fidelity = 0.422195	KL_Divergence = 0.246837
# Epoch: 82	Fidelity = 0.423885	KL_Divergence = 0.243479
# Epoch: 83	Fidelity = 0.426454	KL_Divergence = 0.242310
# Epoch: 84	Fidelity = 0.428785	KL_Divergence = 0.243811
# Epoch: 85	Fidelity = 0.431233	KL_Divergence = 0.244575
# Epoch: 86	Fidelity = 0.431904	KL_Divergence = 0.238210
# Epoch: 87	Fidelity = 0.435498	KL_Divergence = 0.233107
# Epoch: 88	Fidelity = 0.435766	KL_Divergence = 0.234691
# Epoch: 89	Fidelity = 0.438580	KL_Divergence = 0.228034
# Epoch: 90	Fidelity = 0.440127	KL_Divergence = 0.230039
# Epoch: 91	Fidelity = 0.439289	KL_Divergence = 0.225978
# Epoch: 92	Fidelity = 0.440760	KL_Divergence = 0.226775
# Epoch: 93	Fidelity = 0.440320	KL_Divergence = 0.228079
# Epoch: 94	Fidelity = 0.443933	KL_Divergence = 0.225602
# Epoch: 95	Fidelity = 0.444720	KL_Divergence = 0.222397
# Epoch: 96	Fidelity = 0.449517	KL_Divergence = 0.219131
# Epoch: 97	Fidelity = 0.449037	KL_Divergence = 0.216649
# Epoch: 98	Fidelity = 0.449367	KL_Divergence = 0.218679
# Epoch: 99	Fidelity = 0.449704	KL_Divergence = 0.217361
# Epoch: 100	Fidelity = 0.450870	KL_Divergence = 0.217000
# Epoch: 101	Fidelity = 0.450311	KL_Divergence = 0.216028
# Epoch: 102	Fidelity = 0.449180	KL_Divergence = 0.219660
# Epoch: 103	Fidelity = 0.452628	KL_Divergence = 0.220841
# Epoch: 104	Fidelity = 0.451361	KL_Divergence = 0.224125
# Epoch: 105	Fidelity = 0.455724	KL_Divergence = 0.218771
# Epoch: 106	Fidelity = 0.453158	KL_Divergence = 0.214321
# Epoch: 107	Fidelity = 0.454258	KL_Divergence = 0.222105
# Epoch: 108	Fidelity = 0.454765	KL_Divergence = 0.221283
# Epoch: 109	Fidelity = 0.456402	KL_Divergence = 0.213100
# Epoch: 110	Fidelity = 0.459622	KL_Divergence = 0.212219
# Epoch: 111	Fidelity = 0.458973	KL_Divergence = 0.206474
# Epoch: 112	Fidelity = 0.459790	KL_Divergence = 0.209521
# Epoch: 113	Fidelity = 0.462619	KL_Divergence = 0.207484
# Epoch: 114	Fidelity = 0.464767	KL_Divergence = 0.205658
# Epoch: 115	Fidelity = 0.465511	KL_Divergence = 0.201854
# Epoch: 116	Fidelity = 0.464243	KL_Divergence = 0.201716
# Epoch: 117	Fidelity = 0.463937	KL_Divergence = 0.201776
# Epoch: 118	Fidelity = 0.465314	KL_Divergence = 0.202390
# Epoch: 119	Fidelity = 0.466489	KL_Divergence = 0.203820
# Epoch: 120	Fidelity = 0.467351	KL_Divergence = 0.201572
# Epoch: 121	Fidelity = 0.468086	KL_Divergence = 0.199876
# Epoch: 122	Fidelity = 0.466305	KL_Divergence = 0.199526
# Epoch: 123	Fidelity = 0.469087	KL_Divergence = 0.198327
# Epoch: 124	Fidelity = 0.471314	KL_Divergence = 0.198014
# Epoch: 125	Fidelity = 0.470733	KL_Divergence = 0.196879
# Epoch: 126	Fidelity = 0.472621	KL_Divergence = 0.197308
# Epoch: 127	Fidelity = 0.475902	KL_Divergence = 0.196547
# Epoch: 128	Fidelity = 0.474803	KL_Divergence = 0.194496
# Epoch: 129	Fidelity = 0.476025	KL_Divergence = 0.196460
# Epoch: 130	Fidelity = 0.477808	KL_Divergence = 0.193166
# Epoch: 131	Fidelity = 0.477559	KL_Divergence = 0.191798
# Epoch: 132	Fidelity = 0.478418	KL_Divergence = 0.191978
# Epoch: 133	Fidelity = 0.478260	KL_Divergence = 0.194088
# Epoch: 134	Fidelity = 0.480257	KL_Divergence = 0.195199
# Epoch: 135	Fidelity = 0.481580	KL_Divergence = 0.191368
# Epoch: 136	Fidelity = 0.484013	KL_Divergence = 0.190366
# Epoch: 137	Fidelity = 0.485207	KL_Divergence = 0.189328
# Epoch: 138	Fidelity = 0.484442	KL_Divergence = 0.187945
# Epoch: 139	Fidelity = 0.484963	KL_Divergence = 0.188485
# Epoch: 140	Fidelity = 0.485094	KL_Divergence = 0.193453
# Epoch: 141	Fidelity = 0.483258	KL_Divergence = 0.190882
# Epoch: 142	Fidelity = 0.483047	KL_Divergence = 0.192146
# Epoch: 143	Fidelity = 0.483472	KL_Divergence = 0.191891
# Epoch: 144	Fidelity = 0.484017	KL_Divergence = 0.190090
# Epoch: 145	Fidelity = 0.483384	KL_Divergence = 0.186642
# Epoch: 146	Fidelity = 0.484479	KL_Divergence = 0.189223
# Epoch: 147	Fidelity = 0.485823	KL_Divergence = 0.189768
# Epoch: 148	Fidelity = 0.486327	KL_Divergence = 0.187999
# Epoch: 149	Fidelity = 0.488545	KL_Divergence = 0.186526
# Epoch: 150	Fidelity = 0.490027	KL_Divergence = 0.189731
# Epoch: 151	Fidelity = 0.490361	KL_Divergence = 0.184864
# Epoch: 152	Fidelity = 0.490246	KL_Divergence = 0.184512
# Epoch: 153	Fidelity = 0.491526	KL_Divergence = 0.184088
# Epoch: 154	Fidelity = 0.491516	KL_Divergence = 0.181311
# Epoch: 155	Fidelity = 0.492139	KL_Divergence = 0.182201
# Epoch: 156	Fidelity = 0.492298	KL_Divergence = 0.181889
# Epoch: 157	Fidelity = 0.492925	KL_Divergence = 0.180226
# Epoch: 158	Fidelity = 0.493397	KL_Divergence = 0.179100
# Epoch: 159	Fidelity = 0.494851	KL_Divergence = 0.177520
# Epoch: 160	Fidelity = 0.494648	KL_Divergence = 0.178333
# Epoch: 161	Fidelity = 0.495202	KL_Divergence = 0.179976
# Epoch: 162	Fidelity = 0.495793	KL_Divergence = 0.180228
# Epoch: 163	Fidelity = 0.497480	KL_Divergence = 0.178883
# Epoch: 164	Fidelity = 0.497113	KL_Divergence = 0.176951
# Epoch: 165	Fidelity = 0.495556	KL_Divergence = 0.177676
# Epoch: 166	Fidelity = 0.496764	KL_Divergence = 0.177643
# Epoch: 167	Fidelity = 0.496994	KL_Divergence = 0.176203
# Epoch: 168	Fidelity = 0.498145	KL_Divergence = 0.177328
# Epoch: 169	Fidelity = 0.498469	KL_Divergence = 0.178222
# Epoch: 170	Fidelity = 0.499688	KL_Divergence = 0.175524
# Epoch: 171	Fidelity = 0.500202	KL_Divergence = 0.176076
# Epoch: 172	Fidelity = 0.500497	KL_Divergence = 0.175328
# Epoch: 173	Fidelity = 0.502539	KL_Divergence = 0.176434
# Epoch: 174	Fidelity = 0.503034	KL_Divergence = 0.174973
# Epoch: 175	Fidelity = 0.503217	KL_Divergence = 0.175310
# Epoch: 176	Fidelity = 0.503360	KL_Divergence = 0.179991
# Epoch: 177	Fidelity = 0.503328	KL_Divergence = 0.175784
# Epoch: 178	Fidelity = 0.504139	KL_Divergence = 0.174260
# Epoch: 179	Fidelity = 0.504576	KL_Divergence = 0.174035
# Epoch: 180	Fidelity = 0.505485	KL_Divergence = 0.176490
# Epoch: 181	Fidelity = 0.506246	KL_Divergence = 0.178752
# Epoch: 182	Fidelity = 0.506504	KL_Divergence = 0.175771
# Epoch: 183	Fidelity = 0.507842	KL_Divergence = 0.174731
# Epoch: 184	Fidelity = 0.508821	KL_Divergence = 0.173466
# Epoch: 185	Fidelity = 0.509352	KL_Divergence = 0.173972
# Epoch: 186	Fidelity = 0.509562	KL_Divergence = 0.176783
# Epoch: 187	Fidelity = 0.509996	KL_Divergence = 0.172682
# Epoch: 188	Fidelity = 0.510281	KL_Divergence = 0.175150
# Epoch: 189	Fidelity = 0.510313	KL_Divergence = 0.173813
# Epoch: 190	Fidelity = 0.511111	KL_Divergence = 0.172823
# Epoch: 191	Fidelity = 0.511867	KL_Divergence = 0.170695
# Epoch: 192	Fidelity = 0.512804	KL_Divergence = 0.170390
# Epoch: 193	Fidelity = 0.512208	KL_Divergence = 0.168722
# Epoch: 194	Fidelity = 0.511974	KL_Divergence = 0.168608
# Epoch: 195	Fidelity = 0.512612	KL_Divergence = 0.168667
# Epoch: 196	Fidelity = 0.512761	KL_Divergence = 0.168662
# Epoch: 197	Fidelity = 0.512712	KL_Divergence = 0.169169
# Epoch: 198	Fidelity = 0.512707	KL_Divergence = 0.170847
# Epoch: 199	Fidelity = 0.513566	KL_Divergence = 0.171235
# Epoch: 200	Fidelity = 0.514178	KL_Divergence = 0.169956
# Epoch: 201	Fidelity = 0.514822	KL_Divergence = 0.169053
# Epoch: 202	Fidelity = 0.514990	KL_Divergence = 0.168074
# Epoch: 203	Fidelity = 0.515733	KL_Divergence = 0.166797
# Epoch: 204	Fidelity = 0.515873	KL_Divergence = 0.165441
# Epoch: 205	Fidelity = 0.516062	KL_Divergence = 0.166024
# Epoch: 206	Fidelity = 0.516522	KL_Divergence = 0.167400
# Epoch: 207	Fidelity = 0.516763	KL_Divergence = 0.165758
# Epoch: 208	Fidelity = 0.517001	KL_Divergence = 0.168403
# Epoch: 209	Fidelity = 0.517131	KL_Divergence = 0.168502
# Epoch: 210	Fidelity = 0.517302	KL_Divergence = 0.167471
# Epoch: 211	Fidelity = 0.517947	KL_Divergence = 0.168711
# Epoch: 212	Fidelity = 0.517971	KL_Divergence = 0.167155
# Epoch: 213	Fidelity = 0.517816	KL_Divergence = 0.166086
# Epoch: 214	Fidelity = 0.517783	KL_Divergence = 0.164914
# Epoch: 215	Fidelity = 0.517920	KL_Divergence = 0.165075
# Epoch: 216	Fidelity = 0.518250	KL_Divergence = 0.163400
# Epoch: 217	Fidelity = 0.518573	KL_Divergence = 0.163881
# Epoch: 218	Fidelity = 0.519350	KL_Divergence = 0.164113
# Epoch: 219	Fidelity = 0.519407	KL_Divergence = 0.163911
# Epoch: 220	Fidelity = 0.519994	KL_Divergence = 0.165958
# Epoch: 221	Fidelity = 0.520465	KL_Divergence = 0.166678
# Epoch: 222	Fidelity = 0.520183	KL_Divergence = 0.165758
# Epoch: 223	Fidelity = 0.520508	KL_Divergence = 0.165791
# Epoch: 224	Fidelity = 0.520697	KL_Divergence = 0.166390
# Epoch: 225	Fidelity = 0.520902	KL_Divergence = 0.165791
# Epoch: 226	Fidelity = 0.520977	KL_Divergence = 0.163844
# Epoch: 227	Fidelity = 0.520640	KL_Divergence = 0.164072
# Epoch: 228	Fidelity = 0.520633	KL_Divergence = 0.164174
# Epoch: 229	Fidelity = 0.521307	KL_Divergence = 0.164897
# Epoch: 230	Fidelity = 0.521920	KL_Divergence = 0.164311
# Epoch: 231	Fidelity = 0.522167	KL_Divergence = 0.163589
# Epoch: 232	Fidelity = 0.522387	KL_Divergence = 0.162187
# Epoch: 233	Fidelity = 0.522721	KL_Divergence = 0.161764
# Epoch: 234	Fidelity = 0.523441	KL_Divergence = 0.162024
# Epoch: 235	Fidelity = 0.523703	KL_Divergence = 0.161810
# Epoch: 236	Fidelity = 0.523549	KL_Divergence = 0.162017
# Epoch: 237	Fidelity = 0.523653	KL_Divergence = 0.162656
# Epoch: 238	Fidelity = 0.524236	KL_Divergence = 0.163805
# Epoch: 239	Fidelity = 0.524285	KL_Divergence = 0.162948
# Epoch: 240	Fidelity = 0.524250	KL_Divergence = 0.163221
# Epoch: 241	Fidelity = 0.524352	KL_Divergence = 0.163218
# Epoch: 242	Fidelity = 0.524553	KL_Divergence = 0.162477
# Epoch: 243	Fidelity = 0.524817	KL_Divergence = 0.161404
# Epoch: 244	Fidelity = 0.525182	KL_Divergence = 0.160478
# Epoch: 245	Fidelity = 0.525237	KL_Divergence = 0.160641
# Epoch: 246	Fidelity = 0.525608	KL_Divergence = 0.159911
# Epoch: 247	Fidelity = 0.525406	KL_Divergence = 0.160496
# Epoch: 248	Fidelity = 0.525517	KL_Divergence = 0.160768
# Epoch: 249	Fidelity = 0.525524	KL_Divergence = 0.160954
# Epoch: 250	Fidelity = 0.525301	KL_Divergence = 0.161444
# Epoch: 251	Fidelity = 0.525813	KL_Divergence = 0.161856
# Epoch: 252	Fidelity = 0.525735	KL_Divergence = 0.161903
# Epoch: 253	Fidelity = 0.525594	KL_Divergence = 0.161813
# Epoch: 254	Fidelity = 0.526038	KL_Divergence = 0.161695
# Epoch: 255	Fidelity = 0.526250	KL_Divergence = 0.161180
# Epoch: 256	Fidelity = 0.526476	KL_Divergence = 0.160594
# Epoch: 257	Fidelity = 0.526376	KL_Divergence = 0.160052
# Epoch: 258	Fidelity = 0.526451	KL_Divergence = 0.159650
# Epoch: 259	Fidelity = 0.526559	KL_Divergence = 0.160445
# Epoch: 260	Fidelity = 0.526907	KL_Divergence = 0.159826
# Epoch: 261	Fidelity = 0.527605	KL_Divergence = 0.159758
# Epoch: 262	Fidelity = 0.527848	KL_Divergence = 0.159587
# Epoch: 263	Fidelity = 0.528134	KL_Divergence = 0.159698
# Epoch: 264	Fidelity = 0.528574	KL_Divergence = 0.160137
# Epoch: 265	Fidelity = 0.528658	KL_Divergence = 0.158876
# Epoch: 266	Fidelity = 0.528764	KL_Divergence = 0.158376
# Epoch: 267	Fidelity = 0.528943	KL_Divergence = 0.158249
# Epoch: 268	Fidelity = 0.529145	KL_Divergence = 0.158084
# Epoch: 269	Fidelity = 0.529285	KL_Divergence = 0.157777
# Epoch: 270	Fidelity = 0.529746	KL_Divergence = 0.157419
# Epoch: 271	Fidelity = 0.529891	KL_Divergence = 0.157714
# Epoch: 272	Fidelity = 0.530235	KL_Divergence = 0.157848
# Epoch: 273	Fidelity = 0.530318	KL_Divergence = 0.157056
# Epoch: 274	Fidelity = 0.530318	KL_Divergence = 0.156856
# Epoch: 275	Fidelity = 0.530460	KL_Divergence = 0.157046
# Epoch: 276	Fidelity = 0.530500	KL_Divergence = 0.156699
# Epoch: 277	Fidelity = 0.530573	KL_Divergence = 0.156636
# Epoch: 278	Fidelity = 0.530691	KL_Divergence = 0.156250
# Epoch: 279	Fidelity = 0.531106	KL_Divergence = 0.156024
# Epoch: 280	Fidelity = 0.531617	KL_Divergence = 0.156006
# Epoch: 281	Fidelity = 0.531480	KL_Divergence = 0.156542
# Epoch: 282	Fidelity = 0.531566	KL_Divergence = 0.156686
# Epoch: 283	Fidelity = 0.531761	KL_Divergence = 0.156469
# Epoch: 284	Fidelity = 0.531901	KL_Divergence = 0.156289
# Epoch: 285	Fidelity = 0.532157	KL_Divergence = 0.156091
# Epoch: 286	Fidelity = 0.532531	KL_Divergence = 0.156239
# Epoch: 287	Fidelity = 0.532771	KL_Divergence = 0.156446
# Epoch: 288	Fidelity = 0.532628	KL_Divergence = 0.156676
# Epoch: 289	Fidelity = 0.532817	KL_Divergence = 0.156605
# Epoch: 290	Fidelity = 0.532577	KL_Divergence = 0.156578
# Epoch: 291	Fidelity = 0.532703	KL_Divergence = 0.157278
# Epoch: 292	Fidelity = 0.532963	KL_Divergence = 0.157056
# Epoch: 293	Fidelity = 0.533042	KL_Divergence = 0.157556
# Epoch: 294	Fidelity = 0.533317	KL_Divergence = 0.157125
# Epoch: 295	Fidelity = 0.533333	KL_Divergence = 0.156557
# Epoch: 296	Fidelity = 0.533217	KL_Divergence = 0.156341
# Epoch: 297	Fidelity = 0.533349	KL_Divergence = 0.155642
# Epoch: 298	Fidelity = 0.533156	KL_Divergence = 0.155886
# Epoch: 299	Fidelity = 0.533412	KL_Divergence = 0.156448
# Epoch: 300	Fidelity = 0.533530	KL_Divergence = 0.156418
# Epoch: 301	Fidelity = 0.533764	KL_Divergence = 0.156284
# Epoch: 302	Fidelity = 0.533966	KL_Divergence = 0.155844
# Epoch: 303	Fidelity = 0.533927	KL_Divergence = 0.156364
# Epoch: 304	Fidelity = 0.533889	KL_Divergence = 0.155513
# Epoch: 305	Fidelity = 0.534268	KL_Divergence = 0.155282
# Epoch: 306	Fidelity = 0.534588	KL_Divergence = 0.155043
# Epoch: 307	Fidelity = 0.534702	KL_Divergence = 0.155064
# Epoch: 308	Fidelity = 0.534861	KL_Divergence = 0.154702
# Epoch: 309	Fidelity = 0.534797	KL_Divergence = 0.155499
# Epoch: 310	Fidelity = 0.535005	KL_Divergence = 0.155807
# Epoch: 311	Fidelity = 0.535121	KL_Divergence = 0.156200
# Epoch: 312	Fidelity = 0.535258	KL_Divergence = 0.156062
# Epoch: 313	Fidelity = 0.535277	KL_Divergence = 0.155605
# Epoch: 314	Fidelity = 0.535299	KL_Divergence = 0.155330
# Epoch: 315	Fidelity = 0.535565	KL_Divergence = 0.155140
# Epoch: 316	Fidelity = 0.535693	KL_Divergence = 0.154880
# Epoch: 317	Fidelity = 0.535823	KL_Divergence = 0.154471
# Epoch: 318	Fidelity = 0.535811	KL_Divergence = 0.154659
# Epoch: 319	Fidelity = 0.535923	KL_Divergence = 0.154762
# Epoch: 320	Fidelity = 0.536003	KL_Divergence = 0.154501
# Epoch: 321	Fidelity = 0.536239	KL_Divergence = 0.154184
# Epoch: 322	Fidelity = 0.536262	KL_Divergence = 0.154262
# Epoch: 323	Fidelity = 0.536371	KL_Divergence = 0.154501
# Epoch: 324	Fidelity = 0.536415	KL_Divergence = 0.154780
# Epoch: 325	Fidelity = 0.536557	KL_Divergence = 0.154292
# Epoch: 326	Fidelity = 0.536721	KL_Divergence = 0.154440
# Epoch: 327	Fidelity = 0.536875	KL_Divergence = 0.154373
# Epoch: 328	Fidelity = 0.536880	KL_Divergence = 0.154382
# Epoch: 329	Fidelity = 0.537004	KL_Divergence = 0.154378
# Epoch: 330	Fidelity = 0.537138	KL_Divergence = 0.154496
# Epoch: 331	Fidelity = 0.537303	KL_Divergence = 0.154603
# Epoch: 332	Fidelity = 0.537363	KL_Divergence = 0.154851
# Epoch: 333	Fidelity = 0.537480	KL_Divergence = 0.154836
# Epoch: 334	Fidelity = 0.537480	KL_Divergence = 0.155175
# Epoch: 335	Fidelity = 0.537749	KL_Divergence = 0.155184
# Epoch: 336	Fidelity = 0.537839	KL_Divergence = 0.154523
# Epoch: 337	Fidelity = 0.538006	KL_Divergence = 0.154257
# Epoch: 338	Fidelity = 0.538158	KL_Divergence = 0.154267
# Epoch: 339	Fidelity = 0.538213	KL_Divergence = 0.154566
# Epoch: 340	Fidelity = 0.538412	KL_Divergence = 0.154572
# Epoch: 341	Fidelity = 0.538356	KL_Divergence = 0.154390
# Epoch: 342	Fidelity = 0.538327	KL_Divergence = 0.154208
# Epoch: 343	Fidelity = 0.538560	KL_Divergence = 0.154049
# Epoch: 344	Fidelity = 0.538828	KL_Divergence = 0.154166
# Epoch: 345	Fidelity = 0.538885	KL_Divergence = 0.153894
# Epoch: 346	Fidelity = 0.538985	KL_Divergence = 0.154073
# Epoch: 347	Fidelity = 0.538979	KL_Divergence = 0.154031
# Epoch: 348	Fidelity = 0.539082	KL_Divergence = 0.154380
# Epoch: 349	Fidelity = 0.539316	KL_Divergence = 0.154348
# Epoch: 350	Fidelity = 0.539278	KL_Divergence = 0.154512
# Epoch: 351	Fidelity = 0.539258	KL_Divergence = 0.154893
# Epoch: 352	Fidelity = 0.539291	KL_Divergence = 0.154622
# Epoch: 353	Fidelity = 0.539239	KL_Divergence = 0.154473
# Epoch: 354	Fidelity = 0.539276	KL_Divergence = 0.154155
# Epoch: 355	Fidelity = 0.539417	KL_Divergence = 0.153722
# Epoch: 356	Fidelity = 0.539363	KL_Divergence = 0.153715
# Epoch: 357	Fidelity = 0.539376	KL_Divergence = 0.153962
# Epoch: 358	Fidelity = 0.539476	KL_Divergence = 0.154081
# Epoch: 359	Fidelity = 0.539437	KL_Divergence = 0.154351
# Epoch: 360	Fidelity = 0.539366	KL_Divergence = 0.154209
# Epoch: 361	Fidelity = 0.539377	KL_Divergence = 0.154102
# Epoch: 362	Fidelity = 0.539422	KL_Divergence = 0.154126
# Epoch: 363	Fidelity = 0.539524	KL_Divergence = 0.154056
# Epoch: 364	Fidelity = 0.539532	KL_Divergence = 0.154354
# Epoch: 365	Fidelity = 0.539588	KL_Divergence = 0.154605
# Epoch: 366	Fidelity = 0.539626	KL_Divergence = 0.154010
# Epoch: 367	Fidelity = 0.539690	KL_Divergence = 0.154468
# Epoch: 368	Fidelity = 0.539713	KL_Divergence = 0.154310
# Epoch: 369	Fidelity = 0.539795	KL_Divergence = 0.154021
# Epoch: 370	Fidelity = 0.539881	KL_Divergence = 0.154025
# Epoch: 371	Fidelity = 0.539846	KL_Divergence = 0.154008
# Epoch: 372	Fidelity = 0.539810	KL_Divergence = 0.154143
# Epoch: 373	Fidelity = 0.539814	KL_Divergence = 0.154135
# Epoch: 374	Fidelity = 0.539991	KL_Divergence = 0.154260
# Epoch: 375	Fidelity = 0.540129	KL_Divergence = 0.154420
# Epoch: 376	Fidelity = 0.540189	KL_Divergence = 0.154742
# Epoch: 377	Fidelity = 0.540213	KL_Divergence = 0.154426
# Epoch: 378	Fidelity = 0.540196	KL_Divergence = 0.154436
# Epoch: 379	Fidelity = 0.540150	KL_Divergence = 0.154347
# Epoch: 380	Fidelity = 0.540271	KL_Divergence = 0.154497
# Epoch: 381	Fidelity = 0.540286	KL_Divergence = 0.154654
# Epoch: 382	Fidelity = 0.540335	KL_Divergence = 0.154536
# Epoch: 383	Fidelity = 0.540434	KL_Divergence = 0.154374
# Epoch: 384	Fidelity = 0.540473	KL_Divergence = 0.154111
# Epoch: 385	Fidelity = 0.540484	KL_Divergence = 0.154404
# Epoch: 386	Fidelity = 0.540723	KL_Divergence = 0.154171
# Epoch: 387	Fidelity = 0.540713	KL_Divergence = 0.153690
# Epoch: 388	Fidelity = 0.540725	KL_Divergence = 0.153960
# Epoch: 389	Fidelity = 0.540806	KL_Divergence = 0.153934
# Epoch: 390	Fidelity = 0.540801	KL_Divergence = 0.153931
# Epoch: 391	Fidelity = 0.540879	KL_Divergence = 0.153810
# Epoch: 392	Fidelity = 0.540963	KL_Divergence = 0.153425
# Epoch: 393	Fidelity = 0.540925	KL_Divergence = 0.153311
# Epoch: 394	Fidelity = 0.540905	KL_Divergence = 0.153287
# Epoch: 395	Fidelity = 0.540879	KL_Divergence = 0.153570
# Epoch: 396	Fidelity = 0.541017	KL_Divergence = 0.153286
# Epoch: 397	Fidelity = 0.541038	KL_Divergence = 0.153331
# Epoch: 398	Fidelity = 0.541048	KL_Divergence = 0.153167
# Epoch: 399	Fidelity = 0.541143	KL_Divergence = 0.153141
# Epoch: 400	Fidelity = 0.541153	KL_Divergence = 0.153188
# Epoch: 401	Fidelity = 0.541114	KL_Divergence = 0.152962
# Epoch: 402	Fidelity = 0.541130	KL_Divergence = 0.152980
# Epoch: 403	Fidelity = 0.541139	KL_Divergence = 0.153160
# Epoch: 404	Fidelity = 0.541259	KL_Divergence = 0.153080
# Epoch: 405	Fidelity = 0.541347	KL_Divergence = 0.153006
# Epoch: 406	Fidelity = 0.541399	KL_Divergence = 0.152972
# Epoch: 407	Fidelity = 0.541457	KL_Divergence = 0.153040
# Epoch: 408	Fidelity = 0.541473	KL_Divergence = 0.152999
# Epoch: 409	Fidelity = 0.541500	KL_Divergence = 0.152620
# Epoch: 410	Fidelity = 0.541484	KL_Divergence = 0.152600
# Epoch: 411	Fidelity = 0.541472	KL_Divergence = 0.152659
# Epoch: 412	Fidelity = 0.541475	KL_Divergence = 0.152845
# Epoch: 413	Fidelity = 0.541534	KL_Divergence = 0.152953
# Epoch: 414	Fidelity = 0.541583	KL_Divergence = 0.152835
# Epoch: 415	Fidelity = 0.541578	KL_Divergence = 0.152750
# Epoch: 416	Fidelity = 0.541651	KL_Divergence = 0.152793
# Epoch: 417	Fidelity = 0.541706	KL_Divergence = 0.153000
# Epoch: 418	Fidelity = 0.541787	KL_Divergence = 0.152847
# Epoch: 419	Fidelity = 0.541814	KL_Divergence = 0.152745
# Epoch: 420	Fidelity = 0.541792	KL_Divergence = 0.152698
# Epoch: 421	Fidelity = 0.541852	KL_Divergence = 0.152678
# Epoch: 422	Fidelity = 0.541845	KL_Divergence = 0.152664
# Epoch: 423	Fidelity = 0.541872	KL_Divergence = 0.152680
# Epoch: 424	Fidelity = 0.541892	KL_Divergence = 0.152825
# Epoch: 425	Fidelity = 0.541988	KL_Divergence = 0.152767
# Epoch: 426	Fidelity = 0.542015	KL_Divergence = 0.152800
# Epoch: 427	Fidelity = 0.542022	KL_Divergence = 0.152759
# Epoch: 428	Fidelity = 0.542045	KL_Divergence = 0.152617
# Epoch: 429	Fidelity = 0.542069	KL_Divergence = 0.152541
# Epoch: 430	Fidelity = 0.542060	KL_Divergence = 0.152514
# Epoch: 431	Fidelity = 0.542071	KL_Divergence = 0.152455
# Epoch: 432	Fidelity = 0.542116	KL_Divergence = 0.152565
# Epoch: 433	Fidelity = 0.542205	KL_Divergence = 0.152507
# Epoch: 434	Fidelity = 0.542231	KL_Divergence = 0.152488
# Epoch: 435	Fidelity = 0.542207	KL_Divergence = 0.152450
# Epoch: 436	Fidelity = 0.542191	KL_Divergence = 0.152347
# Epoch: 437	Fidelity = 0.542174	KL_Divergence = 0.152278
# Epoch: 438	Fidelity = 0.542153	KL_Divergence = 0.152192
# Epoch: 439	Fidelity = 0.542104	KL_Divergence = 0.152287
# Epoch: 440	Fidelity = 0.542118	KL_Divergence = 0.152173
# Epoch: 441	Fidelity = 0.542135	KL_Divergence = 0.152265
# Epoch: 442	Fidelity = 0.542152	KL_Divergence = 0.152342
# Epoch: 443	Fidelity = 0.542191	KL_Divergence = 0.152452
# Epoch: 444	Fidelity = 0.542162	KL_Divergence = 0.152466
# Epoch: 445	Fidelity = 0.542180	KL_Divergence = 0.152452
# Epoch: 446	Fidelity = 0.542188	KL_Divergence = 0.152398
# Epoch: 447	Fidelity = 0.542219	KL_Divergence = 0.152396
# Epoch: 448	Fidelity = 0.542185	KL_Divergence = 0.152341
# Epoch: 449	Fidelity = 0.542193	KL_Divergence = 0.152280
# Epoch: 450	Fidelity = 0.542132	KL_Divergence = 0.152344
# Epoch: 451	Fidelity = 0.542173	KL_Divergence = 0.152417
# Epoch: 452	Fidelity = 0.542236	KL_Divergence = 0.152348
# Epoch: 453	Fidelity = 0.542252	KL_Divergence = 0.152251
# Epoch: 454	Fidelity = 0.542298	KL_Divergence = 0.152190
# Epoch: 455	Fidelity = 0.542302	KL_Divergence = 0.152050
# Epoch: 456	Fidelity = 0.542333	KL_Divergence = 0.152053
# Epoch: 457	Fidelity = 0.542337	KL_Divergence = 0.152177
# Epoch: 458	Fidelity = 0.542315	KL_Divergence = 0.152208
# Epoch: 459	Fidelity = 0.542368	KL_Divergence = 0.152197
# Epoch: 460	Fidelity = 0.542370	KL_Divergence = 0.152088
# Epoch: 461	Fidelity = 0.542390	KL_Divergence = 0.152110
# Epoch: 462	Fidelity = 0.542403	KL_Divergence = 0.152054
# Epoch: 463	Fidelity = 0.542443	KL_Divergence = 0.152026
# Epoch: 464	Fidelity = 0.542475	KL_Divergence = 0.152038
# Epoch: 465	Fidelity = 0.542476	KL_Divergence = 0.151957
# Epoch: 466	Fidelity = 0.542496	KL_Divergence = 0.152023
# Epoch: 467	Fidelity = 0.542569	KL_Divergence = 0.151959
# Epoch: 468	Fidelity = 0.542576	KL_Divergence = 0.151902
# Epoch: 469	Fidelity = 0.542605	KL_Divergence = 0.151841
# Epoch: 470	Fidelity = 0.542565	KL_Divergence = 0.151842
# Epoch: 471	Fidelity = 0.542586	KL_Divergence = 0.151840
# Epoch: 472	Fidelity = 0.542639	KL_Divergence = 0.151791
# Epoch: 473	Fidelity = 0.542653	KL_Divergence = 0.151869
# Epoch: 474	Fidelity = 0.542705	KL_Divergence = 0.151855
# Epoch: 475	Fidelity = 0.542724	KL_Divergence = 0.151929
# Epoch: 476	Fidelity = 0.542788	KL_Divergence = 0.151843
# Epoch: 477	Fidelity = 0.542856	KL_Divergence = 0.151771
# Epoch: 478	Fidelity = 0.542881	KL_Divergence = 0.151636
# Epoch: 479	Fidelity = 0.542907	KL_Divergence = 0.151669
# Epoch: 480	Fidelity = 0.542909	KL_Divergence = 0.151680
# Epoch: 481	Fidelity = 0.542915	KL_Divergence = 0.151773
# Epoch: 482	Fidelity = 0.542944	KL_Divergence = 0.151746
# Epoch: 483	Fidelity = 0.542936	KL_Divergence = 0.151774
# Epoch: 484	Fidelity = 0.542963	KL_Divergence = 0.151858
# Epoch: 485	Fidelity = 0.542992	KL_Divergence = 0.151713
# Epoch: 486	Fidelity = 0.543001	KL_Divergence = 0.151726
# Epoch: 487	Fidelity = 0.542993	KL_Divergence = 0.151858
# Epoch: 488	Fidelity = 0.543010	KL_Divergence = 0.151805
# Epoch: 489	Fidelity = 0.542961	KL_Divergence = 0.151807
# Epoch: 490	Fidelity = 0.542951	KL_Divergence = 0.151746
# Epoch: 491	Fidelity = 0.542983	KL_Divergence = 0.151745
# Epoch: 492	Fidelity = 0.543015	KL_Divergence = 0.151777
# Epoch: 493	Fidelity = 0.543035	KL_Divergence = 0.151796
# Epoch: 494	Fidelity = 0.543032	KL_Divergence = 0.151755
# Epoch: 495	Fidelity = 0.543056	KL_Divergence = 0.151802
# Epoch: 496	Fidelity = 0.543067	KL_Divergence = 0.151844
# Epoch: 497	Fidelity = 0.543123	KL_Divergence = 0.151770
# Epoch: 498	Fidelity = 0.543152	KL_Divergence = 0.151768
# Epoch: 499	Fidelity = 0.543188	KL_Divergence = 0.151756
# Epoch: 500	Fidelity = 0.543194	KL_Divergence = 0.151811
# Total time elapsed during training: 394.350 s
# error_model : depolarizing, each_n_shot : 50
# Epoch: 1	Fidelity = 0.400340	KL_Divergence = 0.531119
# Epoch: 2	Fidelity = 0.392774	KL_Divergence = 0.503120
# Epoch: 3	Fidelity = 0.386641	KL_Divergence = 0.487977
# Epoch: 4	Fidelity = 0.387573	KL_Divergence = 0.481444
# Epoch: 5	Fidelity = 0.400326	KL_Divergence = 0.476054
# Epoch: 6	Fidelity = 0.395003	KL_Divergence = 0.477766
# Epoch: 7	Fidelity = 0.383632	KL_Divergence = 0.472564
# Epoch: 8	Fidelity = 0.384549	KL_Divergence = 0.465233
# Epoch: 9	Fidelity = 0.387576	KL_Divergence = 0.464183
# Epoch: 10	Fidelity = 0.387133	KL_Divergence = 0.457747
# Epoch: 11	Fidelity = 0.388319	KL_Divergence = 0.452350
# Epoch: 12	Fidelity = 0.405234	KL_Divergence = 0.451264
# Epoch: 13	Fidelity = 0.403967	KL_Divergence = 0.444040
# Epoch: 14	Fidelity = 0.405658	KL_Divergence = 0.439068
# Epoch: 15	Fidelity = 0.416371	KL_Divergence = 0.425249
# Epoch: 16	Fidelity = 0.426245	KL_Divergence = 0.419091
# Epoch: 17	Fidelity = 0.427336	KL_Divergence = 0.422132
# Epoch: 18	Fidelity = 0.420234	KL_Divergence = 0.410974
# Epoch: 19	Fidelity = 0.424172	KL_Divergence = 0.415628
# Epoch: 20	Fidelity = 0.425024	KL_Divergence = 0.398230
# Epoch: 21	Fidelity = 0.421653	KL_Divergence = 0.391869
# Epoch: 22	Fidelity = 0.421203	KL_Divergence = 0.389239
# Epoch: 23	Fidelity = 0.428680	KL_Divergence = 0.378194
# Epoch: 24	Fidelity = 0.427971	KL_Divergence = 0.374813
# Epoch: 25	Fidelity = 0.422056	KL_Divergence = 0.371623
# Epoch: 26	Fidelity = 0.432643	KL_Divergence = 0.371624
# Epoch: 27	Fidelity = 0.430425	KL_Divergence = 0.356809
# Epoch: 28	Fidelity = 0.438168	KL_Divergence = 0.354039
# Epoch: 29	Fidelity = 0.446564	KL_Divergence = 0.349877
# Epoch: 30	Fidelity = 0.452221	KL_Divergence = 0.335973
# Epoch: 31	Fidelity = 0.453434	KL_Divergence = 0.337889
# Epoch: 32	Fidelity = 0.458396	KL_Divergence = 0.325084
# Epoch: 33	Fidelity = 0.460958	KL_Divergence = 0.320936
# Epoch: 34	Fidelity = 0.463755	KL_Divergence = 0.309788
# Epoch: 35	Fidelity = 0.465804	KL_Divergence = 0.316293
# Epoch: 36	Fidelity = 0.465349	KL_Divergence = 0.306329
# Epoch: 37	Fidelity = 0.468674	KL_Divergence = 0.305939
# Epoch: 38	Fidelity = 0.469898	KL_Divergence = 0.297143
# Epoch: 39	Fidelity = 0.474224	KL_Divergence = 0.293285
# Epoch: 40	Fidelity = 0.478521	KL_Divergence = 0.284299
# Epoch: 41	Fidelity = 0.483735	KL_Divergence = 0.275128
# Epoch: 42	Fidelity = 0.483341	KL_Divergence = 0.275150
# Epoch: 43	Fidelity = 0.487788	KL_Divergence = 0.267561
# Epoch: 44	Fidelity = 0.491300	KL_Divergence = 0.263077
# Epoch: 45	Fidelity = 0.494684	KL_Divergence = 0.257703
# Epoch: 46	Fidelity = 0.499090	KL_Divergence = 0.252161
# Epoch: 47	Fidelity = 0.501733	KL_Divergence = 0.250969
# Epoch: 48	Fidelity = 0.500977	KL_Divergence = 0.260911
# Epoch: 49	Fidelity = 0.503984	KL_Divergence = 0.254057
# Epoch: 50	Fidelity = 0.505755	KL_Divergence = 0.241757
# Epoch: 51	Fidelity = 0.508858	KL_Divergence = 0.239262
# Epoch: 52	Fidelity = 0.511525	KL_Divergence = 0.234769
# Epoch: 53	Fidelity = 0.513841	KL_Divergence = 0.233494
# Epoch: 54	Fidelity = 0.516916	KL_Divergence = 0.229892
# Epoch: 55	Fidelity = 0.517605	KL_Divergence = 0.227275
# Epoch: 56	Fidelity = 0.520572	KL_Divergence = 0.221475
# Epoch: 57	Fidelity = 0.521445	KL_Divergence = 0.224186
# Epoch: 58	Fidelity = 0.526605	KL_Divergence = 0.215488
# Epoch: 59	Fidelity = 0.528064	KL_Divergence = 0.215784
# Epoch: 60	Fidelity = 0.530375	KL_Divergence = 0.222412
# Epoch: 61	Fidelity = 0.534046	KL_Divergence = 0.207682
# Epoch: 62	Fidelity = 0.533242	KL_Divergence = 0.209439
# Epoch: 63	Fidelity = 0.536611	KL_Divergence = 0.203312
# Epoch: 64	Fidelity = 0.540137	KL_Divergence = 0.206749
# Epoch: 65	Fidelity = 0.541547	KL_Divergence = 0.198938
# Epoch: 66	Fidelity = 0.543624	KL_Divergence = 0.198117
# Epoch: 67	Fidelity = 0.542929	KL_Divergence = 0.202896
# Epoch: 68	Fidelity = 0.546482	KL_Divergence = 0.195955
# Epoch: 69	Fidelity = 0.551333	KL_Divergence = 0.190329
# Epoch: 70	Fidelity = 0.554348	KL_Divergence = 0.187426
# Epoch: 71	Fidelity = 0.556217	KL_Divergence = 0.185611
# Epoch: 72	Fidelity = 0.556766	KL_Divergence = 0.187115
# Epoch: 73	Fidelity = 0.558305	KL_Divergence = 0.186065
# Epoch: 74	Fidelity = 0.561802	KL_Divergence = 0.180823
# Epoch: 75	Fidelity = 0.563802	KL_Divergence = 0.178472
# Epoch: 76	Fidelity = 0.565785	KL_Divergence = 0.178478
# Epoch: 77	Fidelity = 0.568568	KL_Divergence = 0.174511
# Epoch: 78	Fidelity = 0.569297	KL_Divergence = 0.178785
# Epoch: 79	Fidelity = 0.572238	KL_Divergence = 0.173624
# Epoch: 80	Fidelity = 0.575048	KL_Divergence = 0.169321
# Epoch: 81	Fidelity = 0.576331	KL_Divergence = 0.169950
# Epoch: 82	Fidelity = 0.578184	KL_Divergence = 0.167085
# Epoch: 83	Fidelity = 0.581202	KL_Divergence = 0.164455
# Epoch: 84	Fidelity = 0.582444	KL_Divergence = 0.164730
# Epoch: 85	Fidelity = 0.585162	KL_Divergence = 0.161347
# Epoch: 86	Fidelity = 0.584645	KL_Divergence = 0.168260
# Epoch: 87	Fidelity = 0.587759	KL_Divergence = 0.159551
# Epoch: 88	Fidelity = 0.588806	KL_Divergence = 0.161048
# Epoch: 89	Fidelity = 0.590999	KL_Divergence = 0.157773
# Epoch: 90	Fidelity = 0.592109	KL_Divergence = 0.158145
# Epoch: 91	Fidelity = 0.593553	KL_Divergence = 0.156661
# Epoch: 92	Fidelity = 0.594764	KL_Divergence = 0.156532
# Epoch: 93	Fidelity = 0.595525	KL_Divergence = 0.155898
# Epoch: 94	Fidelity = 0.596635	KL_Divergence = 0.154509
# Epoch: 95	Fidelity = 0.598028	KL_Divergence = 0.152666
# Epoch: 96	Fidelity = 0.600601	KL_Divergence = 0.151838
# Epoch: 97	Fidelity = 0.600995	KL_Divergence = 0.154242
# Epoch: 98	Fidelity = 0.600640	KL_Divergence = 0.162590
# Epoch: 99	Fidelity = 0.603222	KL_Divergence = 0.157530
# Epoch: 100	Fidelity = 0.605345	KL_Divergence = 0.155811
# Epoch: 101	Fidelity = 0.608406	KL_Divergence = 0.148030
# Epoch: 102	Fidelity = 0.610857	KL_Divergence = 0.143783
# Epoch: 103	Fidelity = 0.610643	KL_Divergence = 0.147901
# Epoch: 104	Fidelity = 0.613058	KL_Divergence = 0.143764
# Epoch: 105	Fidelity = 0.613912	KL_Divergence = 0.144250
# Epoch: 106	Fidelity = 0.616135	KL_Divergence = 0.140403
# Epoch: 107	Fidelity = 0.615770	KL_Divergence = 0.144190
# Epoch: 108	Fidelity = 0.618159	KL_Divergence = 0.140165
# Epoch: 109	Fidelity = 0.619042	KL_Divergence = 0.140686
# Epoch: 110	Fidelity = 0.620610	KL_Divergence = 0.138597
# Epoch: 111	Fidelity = 0.621614	KL_Divergence = 0.138599
# Epoch: 112	Fidelity = 0.622195	KL_Divergence = 0.140441
# Epoch: 113	Fidelity = 0.624234	KL_Divergence = 0.136492
# Epoch: 114	Fidelity = 0.625260	KL_Divergence = 0.136038
# Epoch: 115	Fidelity = 0.626863	KL_Divergence = 0.134644
# Epoch: 116	Fidelity = 0.628478	KL_Divergence = 0.133527
# Epoch: 117	Fidelity = 0.629340	KL_Divergence = 0.133201
# Epoch: 118	Fidelity = 0.629531	KL_Divergence = 0.133407
# Epoch: 119	Fidelity = 0.630090	KL_Divergence = 0.132604
# Epoch: 120	Fidelity = 0.628607	KL_Divergence = 0.139793
# Epoch: 121	Fidelity = 0.631184	KL_Divergence = 0.135790
# Epoch: 122	Fidelity = 0.633798	KL_Divergence = 0.131167
# Epoch: 123	Fidelity = 0.634917	KL_Divergence = 0.131020
# Epoch: 124	Fidelity = 0.635003	KL_Divergence = 0.133163
# Epoch: 125	Fidelity = 0.632138	KL_Divergence = 0.144509
# Epoch: 126	Fidelity = 0.636144	KL_Divergence = 0.133535
# Epoch: 127	Fidelity = 0.637901	KL_Divergence = 0.130825
# Epoch: 128	Fidelity = 0.637753	KL_Divergence = 0.133242
# Epoch: 129	Fidelity = 0.639552	KL_Divergence = 0.130407
# Epoch: 130	Fidelity = 0.642266	KL_Divergence = 0.125621
# Epoch: 131	Fidelity = 0.642041	KL_Divergence = 0.127325
# Epoch: 132	Fidelity = 0.643464	KL_Divergence = 0.125512
# Epoch: 133	Fidelity = 0.643026	KL_Divergence = 0.128466
# Epoch: 134	Fidelity = 0.643084	KL_Divergence = 0.129278
# Epoch: 135	Fidelity = 0.645274	KL_Divergence = 0.125983
# Epoch: 136	Fidelity = 0.646204	KL_Divergence = 0.125443
# Epoch: 137	Fidelity = 0.647266	KL_Divergence = 0.125938
# Epoch: 138	Fidelity = 0.649382	KL_Divergence = 0.122429
# Epoch: 139	Fidelity = 0.649684	KL_Divergence = 0.124494
# Epoch: 140	Fidelity = 0.651522	KL_Divergence = 0.120946
# Epoch: 141	Fidelity = 0.651633	KL_Divergence = 0.123432
# Epoch: 142	Fidelity = 0.653038	KL_Divergence = 0.120977
# Epoch: 143	Fidelity = 0.653465	KL_Divergence = 0.122410
# Epoch: 144	Fidelity = 0.653570	KL_Divergence = 0.122539
# Epoch: 145	Fidelity = 0.655875	KL_Divergence = 0.118871
# Epoch: 146	Fidelity = 0.656385	KL_Divergence = 0.119795
# Epoch: 147	Fidelity = 0.657329	KL_Divergence = 0.119336
# Epoch: 148	Fidelity = 0.659240	KL_Divergence = 0.117737
# Epoch: 149	Fidelity = 0.660491	KL_Divergence = 0.116540
# Epoch: 150	Fidelity = 0.660056	KL_Divergence = 0.120297
# Epoch: 151	Fidelity = 0.660706	KL_Divergence = 0.120828
# Epoch: 152	Fidelity = 0.661797	KL_Divergence = 0.119280
# Epoch: 153	Fidelity = 0.662983	KL_Divergence = 0.117176
# Epoch: 154	Fidelity = 0.664311	KL_Divergence = 0.115871
# Epoch: 155	Fidelity = 0.665477	KL_Divergence = 0.114940
# Epoch: 156	Fidelity = 0.667032	KL_Divergence = 0.113531
# Epoch: 157	Fidelity = 0.667226	KL_Divergence = 0.114441
# Epoch: 158	Fidelity = 0.667045	KL_Divergence = 0.115545
# Epoch: 159	Fidelity = 0.667377	KL_Divergence = 0.115198
# Epoch: 160	Fidelity = 0.668720	KL_Divergence = 0.113556
# Epoch: 161	Fidelity = 0.670145	KL_Divergence = 0.112444
# Epoch: 162	Fidelity = 0.670707	KL_Divergence = 0.112899
# Epoch: 163	Fidelity = 0.671868	KL_Divergence = 0.111519
# Epoch: 164	Fidelity = 0.672500	KL_Divergence = 0.111264
# Epoch: 165	Fidelity = 0.673312	KL_Divergence = 0.110805
# Epoch: 166	Fidelity = 0.673904	KL_Divergence = 0.110555
# Epoch: 167	Fidelity = 0.674852	KL_Divergence = 0.109964
# Epoch: 168	Fidelity = 0.676119	KL_Divergence = 0.108754
# Epoch: 169	Fidelity = 0.676365	KL_Divergence = 0.109101
# Epoch: 170	Fidelity = 0.677271	KL_Divergence = 0.108208
# Epoch: 171	Fidelity = 0.677805	KL_Divergence = 0.108160
# Epoch: 172	Fidelity = 0.678362	KL_Divergence = 0.108345
# Epoch: 173	Fidelity = 0.678019	KL_Divergence = 0.109850
# Epoch: 174	Fidelity = 0.679417	KL_Divergence = 0.107812
# Epoch: 175	Fidelity = 0.679532	KL_Divergence = 0.108391
# Epoch: 176	Fidelity = 0.679581	KL_Divergence = 0.109060
# Epoch: 177	Fidelity = 0.680927	KL_Divergence = 0.107797
# Epoch: 178	Fidelity = 0.681232	KL_Divergence = 0.108369
# Epoch: 179	Fidelity = 0.682017	KL_Divergence = 0.106767
# Epoch: 180	Fidelity = 0.682805	KL_Divergence = 0.106445
# Epoch: 181	Fidelity = 0.683078	KL_Divergence = 0.106733
# Epoch: 182	Fidelity = 0.683103	KL_Divergence = 0.107715
# Epoch: 183	Fidelity = 0.683317	KL_Divergence = 0.108262
# Epoch: 184	Fidelity = 0.684146	KL_Divergence = 0.107108
# Epoch: 185	Fidelity = 0.683836	KL_Divergence = 0.107677
# Epoch: 186	Fidelity = 0.684947	KL_Divergence = 0.107207
# Epoch: 187	Fidelity = 0.685921	KL_Divergence = 0.106474
# Epoch: 188	Fidelity = 0.686789	KL_Divergence = 0.105689
# Epoch: 189	Fidelity = 0.687547	KL_Divergence = 0.105349
# Epoch: 190	Fidelity = 0.688211	KL_Divergence = 0.104888
# Epoch: 191	Fidelity = 0.687962	KL_Divergence = 0.106672
# Epoch: 192	Fidelity = 0.688916	KL_Divergence = 0.105720
# Epoch: 193	Fidelity = 0.690081	KL_Divergence = 0.104118
# Epoch: 194	Fidelity = 0.691248	KL_Divergence = 0.103095
# Epoch: 195	Fidelity = 0.691695	KL_Divergence = 0.103075
# Epoch: 196	Fidelity = 0.692756	KL_Divergence = 0.101944
# Epoch: 197	Fidelity = 0.693867	KL_Divergence = 0.101166
# Epoch: 198	Fidelity = 0.694154	KL_Divergence = 0.101389
# Epoch: 199	Fidelity = 0.694505	KL_Divergence = 0.101307
# Epoch: 200	Fidelity = 0.695052	KL_Divergence = 0.101186
# Epoch: 201	Fidelity = 0.695086	KL_Divergence = 0.101520
# Epoch: 202	Fidelity = 0.695462	KL_Divergence = 0.101927
# Epoch: 203	Fidelity = 0.696672	KL_Divergence = 0.100309
# Epoch: 204	Fidelity = 0.695990	KL_Divergence = 0.102205
# Epoch: 205	Fidelity = 0.696959	KL_Divergence = 0.100960
# Epoch: 206	Fidelity = 0.697478	KL_Divergence = 0.100772
# Epoch: 207	Fidelity = 0.698295	KL_Divergence = 0.100047
# Epoch: 208	Fidelity = 0.698646	KL_Divergence = 0.099935
# Epoch: 209	Fidelity = 0.699161	KL_Divergence = 0.099387
# Epoch: 210	Fidelity = 0.700065	KL_Divergence = 0.098916
# Epoch: 211	Fidelity = 0.700435	KL_Divergence = 0.099080
# Epoch: 212	Fidelity = 0.700968	KL_Divergence = 0.099046
# Epoch: 213	Fidelity = 0.701761	KL_Divergence = 0.098092
# Epoch: 214	Fidelity = 0.701639	KL_Divergence = 0.098388
# Epoch: 215	Fidelity = 0.701714	KL_Divergence = 0.098805
# Epoch: 216	Fidelity = 0.702699	KL_Divergence = 0.097863
# Epoch: 217	Fidelity = 0.703317	KL_Divergence = 0.097652
# Epoch: 218	Fidelity = 0.703370	KL_Divergence = 0.098369
# Epoch: 219	Fidelity = 0.704086	KL_Divergence = 0.097590
# Epoch: 220	Fidelity = 0.703750	KL_Divergence = 0.098921
# Epoch: 221	Fidelity = 0.704226	KL_Divergence = 0.098704
# Epoch: 222	Fidelity = 0.704909	KL_Divergence = 0.098309
# Epoch: 223	Fidelity = 0.704951	KL_Divergence = 0.098640
# Epoch: 224	Fidelity = 0.705282	KL_Divergence = 0.098855
# Epoch: 225	Fidelity = 0.705630	KL_Divergence = 0.098493
# Epoch: 226	Fidelity = 0.706763	KL_Divergence = 0.096761
# Epoch: 227	Fidelity = 0.706361	KL_Divergence = 0.098102
# Epoch: 228	Fidelity = 0.706099	KL_Divergence = 0.099254
# Epoch: 229	Fidelity = 0.707108	KL_Divergence = 0.097740
# Epoch: 230	Fidelity = 0.706632	KL_Divergence = 0.099452
# Epoch: 231	Fidelity = 0.707037	KL_Divergence = 0.099172
# Epoch: 232	Fidelity = 0.708256	KL_Divergence = 0.097079
# Epoch: 233	Fidelity = 0.708945	KL_Divergence = 0.096244
# Epoch: 234	Fidelity = 0.709124	KL_Divergence = 0.096552
# Epoch: 235	Fidelity = 0.709854	KL_Divergence = 0.095678
# Epoch: 236	Fidelity = 0.709904	KL_Divergence = 0.095942
# Epoch: 237	Fidelity = 0.710276	KL_Divergence = 0.095924
# Epoch: 238	Fidelity = 0.710256	KL_Divergence = 0.096335
# Epoch: 239	Fidelity = 0.710947	KL_Divergence = 0.095486
# Epoch: 240	Fidelity = 0.711855	KL_Divergence = 0.094363
# Epoch: 241	Fidelity = 0.712135	KL_Divergence = 0.094254
# Epoch: 242	Fidelity = 0.712364	KL_Divergence = 0.094415
# Epoch: 243	Fidelity = 0.712910	KL_Divergence = 0.094135
# Epoch: 244	Fidelity = 0.713066	KL_Divergence = 0.094304
# Epoch: 245	Fidelity = 0.713583	KL_Divergence = 0.093733
# Epoch: 246	Fidelity = 0.713534	KL_Divergence = 0.094337
# Epoch: 247	Fidelity = 0.713532	KL_Divergence = 0.094929
# Epoch: 248	Fidelity = 0.713931	KL_Divergence = 0.094419
# Epoch: 249	Fidelity = 0.714419	KL_Divergence = 0.094322
# Epoch: 250	Fidelity = 0.714583	KL_Divergence = 0.094635
# Epoch: 251	Fidelity = 0.714851	KL_Divergence = 0.094551
# Epoch: 252	Fidelity = 0.715708	KL_Divergence = 0.093196
# Epoch: 253	Fidelity = 0.716077	KL_Divergence = 0.093075
# Epoch: 254	Fidelity = 0.716123	KL_Divergence = 0.093506
# Epoch: 255	Fidelity = 0.716721	KL_Divergence = 0.092938
# Epoch: 256	Fidelity = 0.717048	KL_Divergence = 0.092711
# Epoch: 257	Fidelity = 0.717151	KL_Divergence = 0.092989
# Epoch: 258	Fidelity = 0.717379	KL_Divergence = 0.093078
# Epoch: 259	Fidelity = 0.717622	KL_Divergence = 0.093050
# Epoch: 260	Fidelity = 0.718096	KL_Divergence = 0.092842
# Epoch: 261	Fidelity = 0.717887	KL_Divergence = 0.093717
# Epoch: 262	Fidelity = 0.718066	KL_Divergence = 0.093899
# Epoch: 263	Fidelity = 0.718339	KL_Divergence = 0.093867
# Epoch: 264	Fidelity = 0.718141	KL_Divergence = 0.094691
# Epoch: 265	Fidelity = 0.718956	KL_Divergence = 0.093267
# Epoch: 266	Fidelity = 0.718796	KL_Divergence = 0.094114
# Epoch: 267	Fidelity = 0.719173	KL_Divergence = 0.093976
# Epoch: 268	Fidelity = 0.719556	KL_Divergence = 0.093645
# Epoch: 269	Fidelity = 0.720231	KL_Divergence = 0.092617
# Epoch: 270	Fidelity = 0.720795	KL_Divergence = 0.091919
# Epoch: 271	Fidelity = 0.720890	KL_Divergence = 0.092087
# Epoch: 272	Fidelity = 0.721130	KL_Divergence = 0.091974
# Epoch: 273	Fidelity = 0.721621	KL_Divergence = 0.091405
# Epoch: 274	Fidelity = 0.721653	KL_Divergence = 0.091650
# Epoch: 275	Fidelity = 0.721746	KL_Divergence = 0.091978
# Epoch: 276	Fidelity = 0.721986	KL_Divergence = 0.091732
# Epoch: 277	Fidelity = 0.722239	KL_Divergence = 0.091495
# Epoch: 278	Fidelity = 0.722753	KL_Divergence = 0.090779
# Epoch: 279	Fidelity = 0.722859	KL_Divergence = 0.090958
# Epoch: 280	Fidelity = 0.723331	KL_Divergence = 0.090425
# Epoch: 281	Fidelity = 0.723792	KL_Divergence = 0.089928
# Epoch: 282	Fidelity = 0.724005	KL_Divergence = 0.089894
# Epoch: 283	Fidelity = 0.723892	KL_Divergence = 0.090302
# Epoch: 284	Fidelity = 0.724478	KL_Divergence = 0.089496
# Epoch: 285	Fidelity = 0.724268	KL_Divergence = 0.090152
# Epoch: 286	Fidelity = 0.724767	KL_Divergence = 0.089630
# Epoch: 287	Fidelity = 0.725166	KL_Divergence = 0.089393
# Epoch: 288	Fidelity = 0.725488	KL_Divergence = 0.089155
# Epoch: 289	Fidelity = 0.725823	KL_Divergence = 0.088958
# Epoch: 290	Fidelity = 0.725823	KL_Divergence = 0.089203
# Epoch: 291	Fidelity = 0.725708	KL_Divergence = 0.089641
# Epoch: 292	Fidelity = 0.725636	KL_Divergence = 0.090117
# Epoch: 293	Fidelity = 0.725388	KL_Divergence = 0.090922
# Epoch: 294	Fidelity = 0.726017	KL_Divergence = 0.089919
# Epoch: 295	Fidelity = 0.726712	KL_Divergence = 0.088826
# Epoch: 296	Fidelity = 0.726801	KL_Divergence = 0.088985
# Epoch: 297	Fidelity = 0.726907	KL_Divergence = 0.089209
# Epoch: 298	Fidelity = 0.727006	KL_Divergence = 0.089364
# Epoch: 299	Fidelity = 0.727363	KL_Divergence = 0.088969
# Epoch: 300	Fidelity = 0.727479	KL_Divergence = 0.089088
# Epoch: 301	Fidelity = 0.727942	KL_Divergence = 0.088508
# Epoch: 302	Fidelity = 0.728106	KL_Divergence = 0.088378
# Epoch: 303	Fidelity = 0.728305	KL_Divergence = 0.088216
# Epoch: 304	Fidelity = 0.728556	KL_Divergence = 0.087932
# Epoch: 305	Fidelity = 0.728448	KL_Divergence = 0.088186
# Epoch: 306	Fidelity = 0.728710	KL_Divergence = 0.088078
# Epoch: 307	Fidelity = 0.728592	KL_Divergence = 0.088604
# Epoch: 308	Fidelity = 0.728508	KL_Divergence = 0.089062
# Epoch: 309	Fidelity = 0.728907	KL_Divergence = 0.088538
# Epoch: 310	Fidelity = 0.729102	KL_Divergence = 0.088525
# Epoch: 311	Fidelity = 0.729473	KL_Divergence = 0.088065
# Epoch: 312	Fidelity = 0.729885	KL_Divergence = 0.087519
# Epoch: 313	Fidelity = 0.729908	KL_Divergence = 0.087742
# Epoch: 314	Fidelity = 0.730252	KL_Divergence = 0.087337
# Epoch: 315	Fidelity = 0.730378	KL_Divergence = 0.087305
# Epoch: 316	Fidelity = 0.730433	KL_Divergence = 0.087424
# Epoch: 317	Fidelity = 0.730750	KL_Divergence = 0.087078
# Epoch: 318	Fidelity = 0.730752	KL_Divergence = 0.087267
# Epoch: 319	Fidelity = 0.730872	KL_Divergence = 0.087254
# Epoch: 320	Fidelity = 0.730911	KL_Divergence = 0.087469
# Epoch: 321	Fidelity = 0.730942	KL_Divergence = 0.087675
# Epoch: 322	Fidelity = 0.731212	KL_Divergence = 0.087314
# Epoch: 323	Fidelity = 0.731420	KL_Divergence = 0.087099
# Epoch: 324	Fidelity = 0.731531	KL_Divergence = 0.087165
# Epoch: 325	Fidelity = 0.731737	KL_Divergence = 0.086926
# Epoch: 326	Fidelity = 0.732073	KL_Divergence = 0.086478
# Epoch: 327	Fidelity = 0.732186	KL_Divergence = 0.086367
# Epoch: 328	Fidelity = 0.732367	KL_Divergence = 0.086182
# Epoch: 329	Fidelity = 0.732404	KL_Divergence = 0.086381
# Epoch: 330	Fidelity = 0.732410	KL_Divergence = 0.086533
# Epoch: 331	Fidelity = 0.732616	KL_Divergence = 0.086305
# Epoch: 332	Fidelity = 0.732582	KL_Divergence = 0.086556
# Epoch: 333	Fidelity = 0.732748	KL_Divergence = 0.086387
# Epoch: 334	Fidelity = 0.732870	KL_Divergence = 0.086385
# Epoch: 335	Fidelity = 0.733005	KL_Divergence = 0.086323
# Epoch: 336	Fidelity = 0.733223	KL_Divergence = 0.086116
# Epoch: 337	Fidelity = 0.733265	KL_Divergence = 0.086298
# Epoch: 338	Fidelity = 0.733554	KL_Divergence = 0.085977
# Epoch: 339	Fidelity = 0.733742	KL_Divergence = 0.085832
# Epoch: 340	Fidelity = 0.734002	KL_Divergence = 0.085556
# Epoch: 341	Fidelity = 0.734074	KL_Divergence = 0.085596
# Epoch: 342	Fidelity = 0.734146	KL_Divergence = 0.085634
# Epoch: 343	Fidelity = 0.734165	KL_Divergence = 0.085772
# Epoch: 344	Fidelity = 0.734193	KL_Divergence = 0.085931
# Epoch: 345	Fidelity = 0.734133	KL_Divergence = 0.086182
# Epoch: 346	Fidelity = 0.734250	KL_Divergence = 0.086238
# Epoch: 347	Fidelity = 0.734232	KL_Divergence = 0.086392
# Epoch: 348	Fidelity = 0.734451	KL_Divergence = 0.086239
# Epoch: 349	Fidelity = 0.734365	KL_Divergence = 0.086598
# Epoch: 350	Fidelity = 0.734312	KL_Divergence = 0.086944
# Epoch: 351	Fidelity = 0.734447	KL_Divergence = 0.086855
# Epoch: 352	Fidelity = 0.734523	KL_Divergence = 0.086962
# Epoch: 353	Fidelity = 0.734546	KL_Divergence = 0.087123
# Epoch: 354	Fidelity = 0.734651	KL_Divergence = 0.087092
# Epoch: 355	Fidelity = 0.734986	KL_Divergence = 0.086582
# Epoch: 356	Fidelity = 0.735091	KL_Divergence = 0.086467
# Epoch: 357	Fidelity = 0.735244	KL_Divergence = 0.086331
# Epoch: 358	Fidelity = 0.735417	KL_Divergence = 0.086176
# ...
# Epoch: 217	Fidelity = 0.951731	KL_Divergence = 0.019811
# Epoch: 218	Fidelity = 0.956469	KL_Divergence = 0.014060
# Epoch: 219	Fidelity = 0.955764	KL_Divergence = 0.015174
# Epoch: 220	Fidelity = 0.955754	KL_Divergence = 0.015169
# Epoch: 221	Fidelity = 0.957015	KL_Divergence = 0.013690
# Epoch: 222	Fidelity = 0.953096	KL_Divergence = 0.018210
# Epoch: 223	Fidelity = 0.955070	KL_Divergence = 0.015323
# Epoch: 224	Fidelity = 0.954871	KL_Divergence = 0.015747
# Epoch: 225	Fidelity = 0.954337	KL_Divergence = 0.016333
# Epoch: 226	Fidelity = 0.955821	KL_Divergence = 0.014498
# Epoch: 227	Fidelity = 0.951955	KL_Divergence = 0.019816
# Epoch: 228	Fidelity = 0.952593	KL_Divergence = 0.019066
# Epoch: 229	Fidelity = 0.955804	KL_Divergence = 0.014851
# Epoch: 230	Fidelity = 0.956133	KL_Divergence = 0.014340
# Epoch: 231	Fidelity = 0.953389	KL_Divergence = 0.017841
# Epoch: 232	Fidelity = 0.954621	KL_Divergence = 0.016581
# Epoch: 233	Fidelity = 0.955171	KL_Divergence = 0.015631
# Epoch: 234	Fidelity = 0.952106	KL_Divergence = 0.019454
# Epoch: 235	Fidelity = 0.955662	KL_Divergence = 0.014218
# Epoch: 236	Fidelity = 0.955381	KL_Divergence = 0.014826
# Epoch: 237	Fidelity = 0.953072	KL_Divergence = 0.018093
# Epoch: 238	Fidelity = 0.953065	KL_Divergence = 0.018348
# Epoch: 239	Fidelity = 0.955714	KL_Divergence = 0.015068
# Epoch: 240	Fidelity = 0.955450	KL_Divergence = 0.015414
# Epoch: 241	Fidelity = 0.943285	KL_Divergence = 0.031794
# Epoch: 242	Fidelity = 0.955945	KL_Divergence = 0.015174
# Epoch: 243	Fidelity = 0.953822	KL_Divergence = 0.017628
# Epoch: 244	Fidelity = 0.955380	KL_Divergence = 0.015472
# Epoch: 245	Fidelity = 0.956979	KL_Divergence = 0.013647
# Epoch: 246	Fidelity = 0.952250	KL_Divergence = 0.019528
# Epoch: 247	Fidelity = 0.954260	KL_Divergence = 0.016916
# Epoch: 248	Fidelity = 0.956734	KL_Divergence = 0.013921
# Epoch: 249	Fidelity = 0.957131	KL_Divergence = 0.013614
# Epoch: 250	Fidelity = 0.952649	KL_Divergence = 0.019294
# Epoch: 251	Fidelity = 0.953329	KL_Divergence = 0.018197
# Epoch: 252	Fidelity = 0.956078	KL_Divergence = 0.014778
# Epoch: 253	Fidelity = 0.955686	KL_Divergence = 0.015177
# Epoch: 254	Fidelity = 0.952837	KL_Divergence = 0.018835
# Epoch: 255	Fidelity = 0.955686	KL_Divergence = 0.014822
# Epoch: 256	Fidelity = 0.953444	KL_Divergence = 0.017735
# Epoch: 257	Fidelity = 0.954360	KL_Divergence = 0.017164
# Epoch: 258	Fidelity = 0.957374	KL_Divergence = 0.013562
# Epoch: 259	Fidelity = 0.955279	KL_Divergence = 0.015799
# Epoch: 260	Fidelity = 0.956925	KL_Divergence = 0.014016
# Epoch: 261	Fidelity = 0.955158	KL_Divergence = 0.015774
# Epoch: 262	Fidelity = 0.954631	KL_Divergence = 0.016406
# Epoch: 263	Fidelity = 0.954977	KL_Divergence = 0.015833
# Epoch: 264	Fidelity = 0.954339	KL_Divergence = 0.016247
# Epoch: 265	Fidelity = 0.953233	KL_Divergence = 0.017919
# Epoch: 266	Fidelity = 0.954196	KL_Divergence = 0.016593
# Epoch: 267	Fidelity = 0.956852	KL_Divergence = 0.013713
# Epoch: 268	Fidelity = 0.955701	KL_Divergence = 0.014866
# Epoch: 269	Fidelity = 0.955146	KL_Divergence = 0.015742
# Epoch: 270	Fidelity = 0.954531	KL_Divergence = 0.016206
# Epoch: 271	Fidelity = 0.953640	KL_Divergence = 0.017000
# Epoch: 272	Fidelity = 0.953900	KL_Divergence = 0.016773
# Epoch: 273	Fidelity = 0.956791	KL_Divergence = 0.013752
# Epoch: 274	Fidelity = 0.954895	KL_Divergence = 0.015532
# Epoch: 275	Fidelity = 0.954784	KL_Divergence = 0.015880
# Epoch: 276	Fidelity = 0.954247	KL_Divergence = 0.016018
# Epoch: 277	Fidelity = 0.954846	KL_Divergence = 0.015528
# Epoch: 278	Fidelity = 0.954020	KL_Divergence = 0.016725
# Epoch: 279	Fidelity = 0.955910	KL_Divergence = 0.014688
# Epoch: 280	Fidelity = 0.954163	KL_Divergence = 0.016628
# Epoch: 281	Fidelity = 0.955836	KL_Divergence = 0.014773
# Epoch: 282	Fidelity = 0.954408	KL_Divergence = 0.016641
# Epoch: 283	Fidelity = 0.956170	KL_Divergence = 0.014203
# Epoch: 284	Fidelity = 0.956060	KL_Divergence = 0.014432
# Epoch: 285	Fidelity = 0.954623	KL_Divergence = 0.016193
# Epoch: 286	Fidelity = 0.950701	KL_Divergence = 0.021226
# Epoch: 287	Fidelity = 0.954248	KL_Divergence = 0.016370
# Epoch: 288	Fidelity = 0.954620	KL_Divergence = 0.016006
# Epoch: 289	Fidelity = 0.950023	KL_Divergence = 0.021973
# Epoch: 290	Fidelity = 0.953721	KL_Divergence = 0.017204
# Epoch: 291	Fidelity = 0.954171	KL_Divergence = 0.016802
# Epoch: 292	Fidelity = 0.955679	KL_Divergence = 0.015049
# Epoch: 293	Fidelity = 0.955491	KL_Divergence = 0.015229
# Epoch: 294	Fidelity = 0.953893	KL_Divergence = 0.016962
# Epoch: 295	Fidelity = 0.953668	KL_Divergence = 0.016984
# Epoch: 296	Fidelity = 0.954103	KL_Divergence = 0.016867
# Epoch: 297	Fidelity = 0.953052	KL_Divergence = 0.018317
# Epoch: 298	Fidelity = 0.954812	KL_Divergence = 0.016123
# Epoch: 299	Fidelity = 0.956728	KL_Divergence = 0.013953
# Epoch: 300	Fidelity = 0.955807	KL_Divergence = 0.015176
# Epoch: 301	Fidelity = 0.956910	KL_Divergence = 0.013936
# Epoch: 302	Fidelity = 0.957022	KL_Divergence = 0.013878
# Epoch: 303	Fidelity = 0.956748	KL_Divergence = 0.014174
# Epoch: 304	Fidelity = 0.956539	KL_Divergence = 0.014536
# Epoch: 305	Fidelity = 0.955609	KL_Divergence = 0.015594
# Epoch: 306	Fidelity = 0.954303	KL_Divergence = 0.016999
# Epoch: 307	Fidelity = 0.954233	KL_Divergence = 0.017092
# Epoch: 308	Fidelity = 0.955945	KL_Divergence = 0.014750
# Epoch: 309	Fidelity = 0.955689	KL_Divergence = 0.015171
# Epoch: 310	Fidelity = 0.954208	KL_Divergence = 0.017091
# Epoch: 311	Fidelity = 0.954603	KL_Divergence = 0.016433
# Epoch: 312	Fidelity = 0.952899	KL_Divergence = 0.018532
# Epoch: 313	Fidelity = 0.953283	KL_Divergence = 0.017951
# Epoch: 314	Fidelity = 0.953476	KL_Divergence = 0.017471
# Epoch: 315	Fidelity = 0.953461	KL_Divergence = 0.017604
# Epoch: 316	Fidelity = 0.954265	KL_Divergence = 0.016372
# Epoch: 317	Fidelity = 0.953819	KL_Divergence = 0.017170
# Epoch: 318	Fidelity = 0.954801	KL_Divergence = 0.015965
# Epoch: 319	Fidelity = 0.953846	KL_Divergence = 0.017066
# Epoch: 320	Fidelity = 0.955370	KL_Divergence = 0.015066
# Epoch: 321	Fidelity = 0.956343	KL_Divergence = 0.014101
# Epoch: 322	Fidelity = 0.955764	KL_Divergence = 0.014743
# Epoch: 323	Fidelity = 0.956315	KL_Divergence = 0.014071
# Epoch: 324	Fidelity = 0.955634	KL_Divergence = 0.014837
# Epoch: 325	Fidelity = 0.954433	KL_Divergence = 0.016335
# Epoch: 326	Fidelity = 0.953764	KL_Divergence = 0.017308
# Epoch: 327	Fidelity = 0.953337	KL_Divergence = 0.017859
# Epoch: 328	Fidelity = 0.951229	KL_Divergence = 0.020583
# Epoch: 329	Fidelity = 0.954035	KL_Divergence = 0.016832
# Epoch: 330	Fidelity = 0.954398	KL_Divergence = 0.016467
# Epoch: 331	Fidelity = 0.952742	KL_Divergence = 0.018519
# Epoch: 332	Fidelity = 0.954567	KL_Divergence = 0.016209
# Epoch: 333	Fidelity = 0.955062	KL_Divergence = 0.015552
# Epoch: 334	Fidelity = 0.954396	KL_Divergence = 0.016519
# Epoch: 335	Fidelity = 0.954116	KL_Divergence = 0.016817
# Epoch: 336	Fidelity = 0.952525	KL_Divergence = 0.018854
# Epoch: 337	Fidelity = 0.954078	KL_Divergence = 0.016761
# Epoch: 338	Fidelity = 0.955767	KL_Divergence = 0.014753
# Epoch: 339	Fidelity = 0.956009	KL_Divergence = 0.014551
# Epoch: 340	Fidelity = 0.955112	KL_Divergence = 0.015708
# Epoch: 341	Fidelity = 0.954322	KL_Divergence = 0.016685
# Epoch: 342	Fidelity = 0.954078	KL_Divergence = 0.016801
# Epoch: 343	Fidelity = 0.954396	KL_Divergence = 0.016466
# Epoch: 344	Fidelity = 0.953805	KL_Divergence = 0.017168
# Epoch: 345	Fidelity = 0.952523	KL_Divergence = 0.018867
# Epoch: 346	Fidelity = 0.953296	KL_Divergence = 0.017723
# Epoch: 347	Fidelity = 0.954739	KL_Divergence = 0.016074
# Epoch: 348	Fidelity = 0.955171	KL_Divergence = 0.015605
# Epoch: 349	Fidelity = 0.954682	KL_Divergence = 0.016075
# Epoch: 350	Fidelity = 0.953376	KL_Divergence = 0.017570
# Epoch: 351	Fidelity = 0.953523	KL_Divergence = 0.017425
# Epoch: 352	Fidelity = 0.954729	KL_Divergence = 0.016136
# Epoch: 353	Fidelity = 0.954377	KL_Divergence = 0.016540
# Epoch: 354	Fidelity = 0.954704	KL_Divergence = 0.016123
# Epoch: 355	Fidelity = 0.954290	KL_Divergence = 0.016591
# Epoch: 356	Fidelity = 0.951497	KL_Divergence = 0.020052
# Epoch: 357	Fidelity = 0.955068	KL_Divergence = 0.015571
# Epoch: 358	Fidelity = 0.955334	KL_Divergence = 0.015319
# Epoch: 359	Fidelity = 0.955884	KL_Divergence = 0.014683
# Epoch: 360	Fidelity = 0.954857	KL_Divergence = 0.015941
# Epoch: 361	Fidelity = 0.953768	KL_Divergence = 0.017371
# Epoch: 362	Fidelity = 0.954568	KL_Divergence = 0.016336
# Epoch: 363	Fidelity = 0.955479	KL_Divergence = 0.015205
# Epoch: 364	Fidelity = 0.955431	KL_Divergence = 0.015250
# Epoch: 365	Fidelity = 0.954977	KL_Divergence = 0.015825
# Epoch: 366	Fidelity = 0.954549	KL_Divergence = 0.016384
# Epoch: 367	Fidelity = 0.954729	KL_Divergence = 0.016303
# Epoch: 368	Fidelity = 0.955401	KL_Divergence = 0.015404
# Epoch: 369	Fidelity = 0.954427	KL_Divergence = 0.016640
# Epoch: 370	Fidelity = 0.955215	KL_Divergence = 0.015703
# Epoch: 371	Fidelity = 0.954205	KL_Divergence = 0.016854
# Epoch: 372	Fidelity = 0.953010	KL_Divergence = 0.018373
# Epoch: 373	Fidelity = 0.954654	KL_Divergence = 0.016235
# Epoch: 374	Fidelity = 0.954835	KL_Divergence = 0.016075
# Epoch: 375	Fidelity = 0.953540	KL_Divergence = 0.017576
# Epoch: 376	Fidelity = 0.954542	KL_Divergence = 0.016322
# Epoch: 377	Fidelity = 0.954630	KL_Divergence = 0.016090
# Epoch: 378	Fidelity = 0.955008	KL_Divergence = 0.015762
# Epoch: 379	Fidelity = 0.954267	KL_Divergence = 0.016674
# Epoch: 380	Fidelity = 0.954244	KL_Divergence = 0.016658
# Epoch: 381	Fidelity = 0.954382	KL_Divergence = 0.016521
# Epoch: 382	Fidelity = 0.954759	KL_Divergence = 0.016004
# Epoch: 383	Fidelity = 0.955265	KL_Divergence = 0.015438
# Epoch: 384	Fidelity = 0.956289	KL_Divergence = 0.014268
# Epoch: 385	Fidelity = 0.954358	KL_Divergence = 0.016567
# Epoch: 386	Fidelity = 0.955109	KL_Divergence = 0.015738
# Epoch: 387	Fidelity = 0.955411	KL_Divergence = 0.015309
# Epoch: 388	Fidelity = 0.955366	KL_Divergence = 0.015403
# Epoch: 389	Fidelity = 0.955171	KL_Divergence = 0.015622
# Epoch: 390	Fidelity = 0.954514	KL_Divergence = 0.016393
# Epoch: 391	Fidelity = 0.954847	KL_Divergence = 0.016033
# Epoch: 392	Fidelity = 0.954426	KL_Divergence = 0.016498
# Epoch: 393	Fidelity = 0.954867	KL_Divergence = 0.015971
# Epoch: 394	Fidelity = 0.954735	KL_Divergence = 0.016095
# Epoch: 395	Fidelity = 0.955594	KL_Divergence = 0.015044
# Epoch: 396	Fidelity = 0.955898	KL_Divergence = 0.014610
# Epoch: 397	Fidelity = 0.955612	KL_Divergence = 0.014987
# Epoch: 398	Fidelity = 0.956321	KL_Divergence = 0.014155
# Epoch: 399	Fidelity = 0.955670	KL_Divergence = 0.014911
# Epoch: 400	Fidelity = 0.955911	KL_Divergence = 0.014626
# Epoch: 401	Fidelity = 0.956039	KL_Divergence = 0.014499
# Epoch: 402	Fidelity = 0.955377	KL_Divergence = 0.015285
# Epoch: 403	Fidelity = 0.955576	KL_Divergence = 0.015033
# Epoch: 404	Fidelity = 0.955723	KL_Divergence = 0.014836
# Epoch: 405	Fidelity = 0.954857	KL_Divergence = 0.015807
# Epoch: 406	Fidelity = 0.954912	KL_Divergence = 0.015717
# Epoch: 407	Fidelity = 0.955075	KL_Divergence = 0.015527
# Epoch: 408	Fidelity = 0.954206	KL_Divergence = 0.016594
# Epoch: 409	Fidelity = 0.955182	KL_Divergence = 0.015372
# Epoch: 410	Fidelity = 0.954124	KL_Divergence = 0.016602
# Epoch: 411	Fidelity = 0.954492	KL_Divergence = 0.016188
# Epoch: 412	Fidelity = 0.954491	KL_Divergence = 0.016206
# Epoch: 413	Fidelity = 0.954700	KL_Divergence = 0.015975
# Epoch: 414	Fidelity = 0.954932	KL_Divergence = 0.015644
# Epoch: 415	Fidelity = 0.954793	KL_Divergence = 0.015823
# Epoch: 416	Fidelity = 0.954479	KL_Divergence = 0.016180
# Epoch: 417	Fidelity = 0.954312	KL_Divergence = 0.016409
# Epoch: 418	Fidelity = 0.954486	KL_Divergence = 0.016187
# Epoch: 419	Fidelity = 0.954068	KL_Divergence = 0.016722
# Epoch: 420	Fidelity = 0.953581	KL_Divergence = 0.017274
# Epoch: 421	Fidelity = 0.953449	KL_Divergence = 0.017374
# Epoch: 422	Fidelity = 0.953866	KL_Divergence = 0.016895
# Epoch: 423	Fidelity = 0.954010	KL_Divergence = 0.016690
# Epoch: 424	Fidelity = 0.954416	KL_Divergence = 0.016205
# Epoch: 425	Fidelity = 0.954471	KL_Divergence = 0.016201
# Epoch: 426	Fidelity = 0.954209	KL_Divergence = 0.016575
# Epoch: 427	Fidelity = 0.954349	KL_Divergence = 0.016397
# Epoch: 428	Fidelity = 0.954829	KL_Divergence = 0.015745
# Epoch: 429	Fidelity = 0.955278	KL_Divergence = 0.015176
# Epoch: 430	Fidelity = 0.955339	KL_Divergence = 0.015174
# Epoch: 431	Fidelity = 0.955010	KL_Divergence = 0.015594
# Epoch: 432	Fidelity = 0.955217	KL_Divergence = 0.015403
# Epoch: 433	Fidelity = 0.954775	KL_Divergence = 0.015921
# Epoch: 434	Fidelity = 0.955246	KL_Divergence = 0.015342
# Epoch: 435	Fidelity = 0.955435	KL_Divergence = 0.015124
# Epoch: 436	Fidelity = 0.955614	KL_Divergence = 0.014896
# Epoch: 437	Fidelity = 0.955635	KL_Divergence = 0.014890
# Epoch: 438	Fidelity = 0.955863	KL_Divergence = 0.014674
# Epoch: 439	Fidelity = 0.955129	KL_Divergence = 0.015569
# Epoch: 440	Fidelity = 0.955591	KL_Divergence = 0.014982
# Epoch: 441	Fidelity = 0.955490	KL_Divergence = 0.015173
# Epoch: 442	Fidelity = 0.955376	KL_Divergence = 0.015328
# Epoch: 443	Fidelity = 0.955363	KL_Divergence = 0.015354
# Epoch: 444	Fidelity = 0.955192	KL_Divergence = 0.015585
# Epoch: 445	Fidelity = 0.955115	KL_Divergence = 0.015695
# Epoch: 446	Fidelity = 0.954738	KL_Divergence = 0.016204
# Epoch: 447	Fidelity = 0.954869	KL_Divergence = 0.016054
# Epoch: 448	Fidelity = 0.954499	KL_Divergence = 0.016487
# Epoch: 449	Fidelity = 0.954418	KL_Divergence = 0.016567
# Epoch: 450	Fidelity = 0.954628	KL_Divergence = 0.016355
# Epoch: 451	Fidelity = 0.954762	KL_Divergence = 0.016174
# Epoch: 452	Fidelity = 0.954730	KL_Divergence = 0.016205
# Epoch: 453	Fidelity = 0.955195	KL_Divergence = 0.015636
# Epoch: 454	Fidelity = 0.954724	KL_Divergence = 0.016248
# Epoch: 455	Fidelity = 0.955375	KL_Divergence = 0.015452
# Epoch: 456	Fidelity = 0.955174	KL_Divergence = 0.015729
# Epoch: 457	Fidelity = 0.954833	KL_Divergence = 0.016177
# Epoch: 458	Fidelity = 0.954543	KL_Divergence = 0.016547
# Epoch: 459	Fidelity = 0.954893	KL_Divergence = 0.016093
# Epoch: 460	Fidelity = 0.954584	KL_Divergence = 0.016471
# Epoch: 461	Fidelity = 0.955023	KL_Divergence = 0.015856
# Epoch: 462	Fidelity = 0.955371	KL_Divergence = 0.015414
# Epoch: 463	Fidelity = 0.955400	KL_Divergence = 0.015391
# Epoch: 464	Fidelity = 0.955428	KL_Divergence = 0.015341
# Epoch: 465	Fidelity = 0.955368	KL_Divergence = 0.015407
# Epoch: 466	Fidelity = 0.955167	KL_Divergence = 0.015621
# Epoch: 467	Fidelity = 0.955198	KL_Divergence = 0.015582
# Epoch: 468	Fidelity = 0.954843	KL_Divergence = 0.015983
# Epoch: 469	Fidelity = 0.954916	KL_Divergence = 0.015923
# Epoch: 470	Fidelity = 0.955289	KL_Divergence = 0.015456
# Epoch: 471	Fidelity = 0.955116	KL_Divergence = 0.015644
# Epoch: 472	Fidelity = 0.954913	KL_Divergence = 0.015904
# Epoch: 473	Fidelity = 0.954542	KL_Divergence = 0.016411
# Epoch: 474	Fidelity = 0.954170	KL_Divergence = 0.016837
# Epoch: 475	Fidelity = 0.953904	KL_Divergence = 0.017200
# Epoch: 476	Fidelity = 0.954286	KL_Divergence = 0.016743
# Epoch: 477	Fidelity = 0.953558	KL_Divergence = 0.017686
# Epoch: 478	Fidelity = 0.953639	KL_Divergence = 0.017559
# Epoch: 479	Fidelity = 0.954189	KL_Divergence = 0.016832
# Epoch: 480	Fidelity = 0.954039	KL_Divergence = 0.016997
# Epoch: 481	Fidelity = 0.954110	KL_Divergence = 0.016876
# Epoch: 482	Fidelity = 0.954213	KL_Divergence = 0.016762
# Epoch: 483	Fidelity = 0.954497	KL_Divergence = 0.016375
# Epoch: 484	Fidelity = 0.954995	KL_Divergence = 0.015764
# Epoch: 485	Fidelity = 0.955101	KL_Divergence = 0.015637
# Epoch: 486	Fidelity = 0.954606	KL_Divergence = 0.016217
# Epoch: 487	Fidelity = 0.954654	KL_Divergence = 0.016165
# Epoch: 488	Fidelity = 0.954875	KL_Divergence = 0.015927
# Epoch: 489	Fidelity = 0.954792	KL_Divergence = 0.015991
# Epoch: 490	Fidelity = 0.954717	KL_Divergence = 0.016076
# Epoch: 491	Fidelity = 0.954814	KL_Divergence = 0.015931
# Epoch: 492	Fidelity = 0.954841	KL_Divergence = 0.015890
# Epoch: 493	Fidelity = 0.954562	KL_Divergence = 0.016229
# Epoch: 494	Fidelity = 0.954351	KL_Divergence = 0.016502
# Epoch: 495	Fidelity = 0.954437	KL_Divergence = 0.016409
# Epoch: 496	Fidelity = 0.954272	KL_Divergence = 0.016611
# Epoch: 497	Fidelity = 0.954756	KL_Divergence = 0.015995
# Epoch: 498	Fidelity = 0.954811	KL_Divergence = 0.015917
# Epoch: 499	Fidelity = 0.955063	KL_Divergence = 0.015569
# Epoch: 500	Fidelity = 0.955322	KL_Divergence = 0.015226
# Total time elapsed during training: 74470.995 s
