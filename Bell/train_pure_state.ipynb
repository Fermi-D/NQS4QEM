# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]
# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]
# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]
# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]
# data path info
environment = "local"
if environment == "local":
    train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = f"./target_state/"
if environment == "colab":
    from google.colab import drive
    drive.mount("/content/drive/")
    rive_path = "/content/drive/MyDrive/NQS4QEM/Bell"
    train_data_path = drive_path + f"/data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = drive_path + f"/target_state/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## caluculate ideal state

# %%
# calculate ideal state
is_ideal_state_file = os.path.exists(ideal_state_path)
if is_ideal_state_file:
    print("ideal state data is exsisted !")
else:
    print("caluculate ideal state data ...")
    subprocess.run("python caluculate_ideal_state.py", shell=True)
    print("ideal state data is ready !")
# Out:
# ideal state data is exsisted !

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path)
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    subprocess.run("python generate_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# train data is exsisted !

# %% [markdown]
# ## estimate observable expectation value

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XX():
    target_list = [0, 1]
    pauli_index = [1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZ():
    target_list = [0, 1]
    pauli_index = [1, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_XX_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "X"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_XZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

# %% [markdown]
# ## callback setting

# %%
def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "KL_Divergence": ts.KL,
        #"Observable_XX_ev": observable_XX_ev,
        #"Observable_XZ_ev": observable_XZ_ev,
    }

    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = ideal_vec,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    return callbacks

# %% [markdown]
# ## experiment

# %%
# experiment params
each_n_shot_list = [10, 50, 100, 500, 1000, 5000, 10000]
error_model_list = ["depolarizing", "unitary", "depolarizing&unitary"]

for error_model in error_model_list:
    for each_n_shot in each_n_shot_list:
        print(f"error_model : {error_model}, each_n_shot : {each_n_shot}")
        train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
        meas_pattern_path = train_data_path + "/measurement_pattern.txt"
        meas_label_path = train_data_path + "/measurement_label.txt"
        meas_result_path = train_data_path + "/measurement_result.txt"
        #ideal_rho_re_path = ideal_state_path + "/rho_real.txt"
        #ideal_rho_im_path = ideal_state_path + "/rho_imag.txt"
        ideal_state_vector_path = ideal_state_path + "/state_vector.txt"
        meas_result, ideal_vec, meas_label, meas_pattern = data.load_data(meas_result_path,
                                                                          ideal_state_vector_path,
                                                                          meas_label_path,
                                                                          meas_pattern_path)
        
        nn_state_sv = ComplexWaveFunction(num_visible = n_visible_unit, 
                                          num_hidden = n_hidden_unit, 
                                          unitary_dict = unitaries.create_dict(),
                                          gpu = False)
        
        callbacks = create_callback_dm(nn_state_sv)
        
        nn_state_sv.fit(data = meas_result,
                        input_bases = meas_label,
                        epochs = epoch,
                        pos_batch_size = pbs,
                        neg_batch_size = nbs,
                        lr = lr,
                        k = n_gibbs_step,
                        bases = meas_pattern,
                        callbacks = callbacks,
                        time = True,
                        optimizer = torch.optim.Adadelta,
                        scheduler = torch.optim.lr_scheduler.StepLR,
                        scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
                       )
        
        # save model
        nn_state_sv.save(f"./exp_pure_state_varying_n_shot/model_n_pattern_shot={each_n_shot}_{error_model}.pt")
        # save train log
        train_log_df = pd.DataFrame()
        train_log_df["epoch"] = np.arange(period, epoch+1, period)
        train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
        train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
        #train_log_df["Observable_XX_ev"] = callbacks[0]["Observable_XX_ev"]
        #train_log_df["Observable_ZZ_ev"] = callbacks[0]["Observable_ZZ_ev"]
        train_log_df.to_csv(f"./exp_pure_state_varying_n_shot/model_n_pattern_shot={each_n_shot}_{error_model}.csv", index=False)
# Out:
# error_model : depolarizing, each_n_shot : 10
# Epoch: 1	Fidelity = 0.407650	KL_Divergence = 0.863049
# Epoch: 2	Fidelity = 0.407554	KL_Divergence = 0.861890
# Epoch: 3	Fidelity = 0.407469	KL_Divergence = 0.860782
# Epoch: 4	Fidelity = 0.407406	KL_Divergence = 0.859617
# Epoch: 5	Fidelity = 0.407321	KL_Divergence = 0.858480
# Epoch: 6	Fidelity = 0.407209	KL_Divergence = 0.857328
# Epoch: 7	Fidelity = 0.407073	KL_Divergence = 0.856101
# Epoch: 8	Fidelity = 0.406976	KL_Divergence = 0.854930
# Epoch: 9	Fidelity = 0.406855	KL_Divergence = 0.853736
# Epoch: 10	Fidelity = 0.406816	KL_Divergence = 0.852596
# Epoch: 11	Fidelity = 0.406721	KL_Divergence = 0.851518
# Epoch: 12	Fidelity = 0.406646	KL_Divergence = 0.850509
# Epoch: 13	Fidelity = 0.406504	KL_Divergence = 0.849464
# Epoch: 14	Fidelity = 0.406420	KL_Divergence = 0.848422
# Epoch: 15	Fidelity = 0.406308	KL_Divergence = 0.847386
# Epoch: 16	Fidelity = 0.406198	KL_Divergence = 0.846300
# Epoch: 17	Fidelity = 0.406093	KL_Divergence = 0.845267
# Epoch: 18	Fidelity = 0.406025	KL_Divergence = 0.844306
# Epoch: 19	Fidelity = 0.405906	KL_Divergence = 0.843265
# Epoch: 20	Fidelity = 0.405770	KL_Divergence = 0.842224
# Epoch: 21	Fidelity = 0.405678	KL_Divergence = 0.841314
# Epoch: 22	Fidelity = 0.405573	KL_Divergence = 0.840343
# Epoch: 23	Fidelity = 0.405516	KL_Divergence = 0.839473
# Epoch: 24	Fidelity = 0.405450	KL_Divergence = 0.838518
# Epoch: 25	Fidelity = 0.405412	KL_Divergence = 0.837652
# Epoch: 26	Fidelity = 0.405356	KL_Divergence = 0.836729
# Epoch: 27	Fidelity = 0.405286	KL_Divergence = 0.835846
# Epoch: 28	Fidelity = 0.405206	KL_Divergence = 0.834912
# Epoch: 29	Fidelity = 0.405152	KL_Divergence = 0.834042
# Epoch: 30	Fidelity = 0.405078	KL_Divergence = 0.833176
# Epoch: 31	Fidelity = 0.404983	KL_Divergence = 0.832306
# Epoch: 32	Fidelity = 0.404908	KL_Divergence = 0.831500
# Epoch: 33	Fidelity = 0.404843	KL_Divergence = 0.830678
# Epoch: 34	Fidelity = 0.404760	KL_Divergence = 0.829869
# Epoch: 35	Fidelity = 0.404701	KL_Divergence = 0.829101
# Epoch: 36	Fidelity = 0.404628	KL_Divergence = 0.828355
# Epoch: 37	Fidelity = 0.404580	KL_Divergence = 0.827608
# Epoch: 38	Fidelity = 0.404512	KL_Divergence = 0.826803
# Epoch: 39	Fidelity = 0.404441	KL_Divergence = 0.826018
# Epoch: 40	Fidelity = 0.404363	KL_Divergence = 0.825230
# Epoch: 41	Fidelity = 0.404323	KL_Divergence = 0.824551
# Epoch: 42	Fidelity = 0.404281	KL_Divergence = 0.823865
# Epoch: 43	Fidelity = 0.404212	KL_Divergence = 0.823150
# Epoch: 44	Fidelity = 0.404124	KL_Divergence = 0.822432
# Epoch: 45	Fidelity = 0.404061	KL_Divergence = 0.821750
# Epoch: 46	Fidelity = 0.404008	KL_Divergence = 0.821032
# Epoch: 47	Fidelity = 0.403983	KL_Divergence = 0.820359
# Epoch: 48	Fidelity = 0.403931	KL_Divergence = 0.819671
# Epoch: 49	Fidelity = 0.403867	KL_Divergence = 0.818978
# Epoch: 50	Fidelity = 0.403792	KL_Divergence = 0.818263
# Epoch: 51	Fidelity = 0.403701	KL_Divergence = 0.817593
# Epoch: 52	Fidelity = 0.403642	KL_Divergence = 0.816968
# Epoch: 53	Fidelity = 0.403597	KL_Divergence = 0.816299
# Epoch: 54	Fidelity = 0.403521	KL_Divergence = 0.815614
# Epoch: 55	Fidelity = 0.403460	KL_Divergence = 0.814969
# Epoch: 56	Fidelity = 0.403387	KL_Divergence = 0.814317
# Epoch: 57	Fidelity = 0.403308	KL_Divergence = 0.813691
# Epoch: 58	Fidelity = 0.403251	KL_Divergence = 0.813078
# Epoch: 59	Fidelity = 0.403203	KL_Divergence = 0.812495
# Epoch: 60	Fidelity = 0.403149	KL_Divergence = 0.811881
# Epoch: 61	Fidelity = 0.403096	KL_Divergence = 0.811349
# Epoch: 62	Fidelity = 0.403034	KL_Divergence = 0.810763
# Epoch: 63	Fidelity = 0.402977	KL_Divergence = 0.810206
# Epoch: 64	Fidelity = 0.402917	KL_Divergence = 0.809614
# Epoch: 65	Fidelity = 0.402862	KL_Divergence = 0.809064
# Epoch: 66	Fidelity = 0.402798	KL_Divergence = 0.808464
# Epoch: 67	Fidelity = 0.402754	KL_Divergence = 0.807896
# Epoch: 68	Fidelity = 0.402704	KL_Divergence = 0.807332
# Epoch: 69	Fidelity = 0.402640	KL_Divergence = 0.806762
# Epoch: 70	Fidelity = 0.402571	KL_Divergence = 0.806190
# Epoch: 71	Fidelity = 0.402529	KL_Divergence = 0.805681
# Epoch: 72	Fidelity = 0.402486	KL_Divergence = 0.805178
# Epoch: 73	Fidelity = 0.402441	KL_Divergence = 0.804700
# Epoch: 74	Fidelity = 0.402373	KL_Divergence = 0.804209
# Epoch: 75	Fidelity = 0.402313	KL_Divergence = 0.803667
# Epoch: 76	Fidelity = 0.402265	KL_Divergence = 0.803141
# Epoch: 77	Fidelity = 0.402202	KL_Divergence = 0.802654
# Epoch: 78	Fidelity = 0.402133	KL_Divergence = 0.802122
# Epoch: 79	Fidelity = 0.402079	KL_Divergence = 0.801615
# Epoch: 80	Fidelity = 0.402032	KL_Divergence = 0.801140
# Epoch: 81	Fidelity = 0.401995	KL_Divergence = 0.800706
# Epoch: 82	Fidelity = 0.401933	KL_Divergence = 0.800274
# Epoch: 83	Fidelity = 0.401878	KL_Divergence = 0.799812
# Epoch: 84	Fidelity = 0.401822	KL_Divergence = 0.799379
# Epoch: 85	Fidelity = 0.401776	KL_Divergence = 0.798920
# Epoch: 86	Fidelity = 0.401741	KL_Divergence = 0.798472
# Epoch: 87	Fidelity = 0.401677	KL_Divergence = 0.798026
# Epoch: 88	Fidelity = 0.401623	KL_Divergence = 0.797575
# Epoch: 89	Fidelity = 0.401567	KL_Divergence = 0.797131
# Epoch: 90	Fidelity = 0.401512	KL_Divergence = 0.796669
# Epoch: 91	Fidelity = 0.401477	KL_Divergence = 0.796278
# Epoch: 92	Fidelity = 0.401449	KL_Divergence = 0.795875
# Epoch: 93	Fidelity = 0.401406	KL_Divergence = 0.795456
# Epoch: 94	Fidelity = 0.401379	KL_Divergence = 0.795048
# Epoch: 95	Fidelity = 0.401345	KL_Divergence = 0.794676
# Epoch: 96	Fidelity = 0.401305	KL_Divergence = 0.794261
# Epoch: 97	Fidelity = 0.401276	KL_Divergence = 0.793855
# Epoch: 98	Fidelity = 0.401240	KL_Divergence = 0.793455
# Epoch: 99	Fidelity = 0.401196	KL_Divergence = 0.793081
# Epoch: 100	Fidelity = 0.401160	KL_Divergence = 0.792690
# Epoch: 101	Fidelity = 0.401129	KL_Divergence = 0.792362
# Epoch: 102	Fidelity = 0.401095	KL_Divergence = 0.792012
# Epoch: 103	Fidelity = 0.401052	KL_Divergence = 0.791667
# Epoch: 104	Fidelity = 0.401004	KL_Divergence = 0.791288
# Epoch: 105	Fidelity = 0.400971	KL_Divergence = 0.790925
# Epoch: 106	Fidelity = 0.400918	KL_Divergence = 0.790556
# Epoch: 107	Fidelity = 0.400875	KL_Divergence = 0.790190
# Epoch: 108	Fidelity = 0.400840	KL_Divergence = 0.789810
# Epoch: 109	Fidelity = 0.400801	KL_Divergence = 0.789416
# Epoch: 110	Fidelity = 0.400746	KL_Divergence = 0.789053
# Epoch: 111	Fidelity = 0.400711	KL_Divergence = 0.788739
# Epoch: 112	Fidelity = 0.400681	KL_Divergence = 0.788427
# Epoch: 113	Fidelity = 0.400635	KL_Divergence = 0.788109
# Epoch: 114	Fidelity = 0.400607	KL_Divergence = 0.787767
# Epoch: 115	Fidelity = 0.400568	KL_Divergence = 0.787448
# Epoch: 116	Fidelity = 0.400522	KL_Divergence = 0.787126
# Epoch: 117	Fidelity = 0.400483	KL_Divergence = 0.786829
# Epoch: 118	Fidelity = 0.400443	KL_Divergence = 0.786478
# Epoch: 119	Fidelity = 0.400408	KL_Divergence = 0.786139
# Epoch: 120	Fidelity = 0.400369	KL_Divergence = 0.785823
# Epoch: 121	Fidelity = 0.400337	KL_Divergence = 0.785538
# Epoch: 122	Fidelity = 0.400286	KL_Divergence = 0.785256
# Epoch: 123	Fidelity = 0.400259	KL_Divergence = 0.784950
# Epoch: 124	Fidelity = 0.400223	KL_Divergence = 0.784666
# Epoch: 125	Fidelity = 0.400173	KL_Divergence = 0.784389
# Epoch: 126	Fidelity = 0.400138	KL_Divergence = 0.784105
# Epoch: 127	Fidelity = 0.400103	KL_Divergence = 0.783813
# Epoch: 128	Fidelity = 0.400068	KL_Divergence = 0.783543
# Epoch: 129	Fidelity = 0.400037	KL_Divergence = 0.783268
# Epoch: 130	Fidelity = 0.400002	KL_Divergence = 0.782972
# Epoch: 131	Fidelity = 0.399971	KL_Divergence = 0.782707
# Epoch: 132	Fidelity = 0.399942	KL_Divergence = 0.782426
# Epoch: 133	Fidelity = 0.399913	KL_Divergence = 0.782153
# Epoch: 134	Fidelity = 0.399888	KL_Divergence = 0.781883
# Epoch: 135	Fidelity = 0.399866	KL_Divergence = 0.781620
# Epoch: 136	Fidelity = 0.399829	KL_Divergence = 0.781344
# Epoch: 137	Fidelity = 0.399800	KL_Divergence = 0.781103
# Epoch: 138	Fidelity = 0.399776	KL_Divergence = 0.780852
# Epoch: 139	Fidelity = 0.399743	KL_Divergence = 0.780573
# Epoch: 140	Fidelity = 0.399699	KL_Divergence = 0.780316
# Epoch: 141	Fidelity = 0.399667	KL_Divergence = 0.780095
# Epoch: 142	Fidelity = 0.399635	KL_Divergence = 0.779860
# Epoch: 143	Fidelity = 0.399609	KL_Divergence = 0.779618
# Epoch: 144	Fidelity = 0.399579	KL_Divergence = 0.779388
# Epoch: 145	Fidelity = 0.399553	KL_Divergence = 0.779143
# Epoch: 146	Fidelity = 0.399524	KL_Divergence = 0.778914
# Epoch: 147	Fidelity = 0.399497	KL_Divergence = 0.778686
# Epoch: 148	Fidelity = 0.399463	KL_Divergence = 0.778443
# Epoch: 149	Fidelity = 0.399436	KL_Divergence = 0.778216
# Epoch: 150	Fidelity = 0.399402	KL_Divergence = 0.777989
# Epoch: 151	Fidelity = 0.399376	KL_Divergence = 0.777796
# Epoch: 152	Fidelity = 0.399346	KL_Divergence = 0.777574
# Epoch: 153	Fidelity = 0.399321	KL_Divergence = 0.777363
# Epoch: 154	Fidelity = 0.399291	KL_Divergence = 0.777130
# Epoch: 155	Fidelity = 0.399263	KL_Divergence = 0.776914
# Epoch: 156	Fidelity = 0.399234	KL_Divergence = 0.776688
# Epoch: 157	Fidelity = 0.399206	KL_Divergence = 0.776457
# Epoch: 158	Fidelity = 0.399171	KL_Divergence = 0.776251
# Epoch: 159	Fidelity = 0.399147	KL_Divergence = 0.776044
# Epoch: 160	Fidelity = 0.399124	KL_Divergence = 0.775830
# Epoch: 161	Fidelity = 0.399095	KL_Divergence = 0.775644
# Epoch: 162	Fidelity = 0.399072	KL_Divergence = 0.775454
# Epoch: 163	Fidelity = 0.399045	KL_Divergence = 0.775268
# Epoch: 164	Fidelity = 0.399018	KL_Divergence = 0.775073
# Epoch: 165	Fidelity = 0.398990	KL_Divergence = 0.774866
# Epoch: 166	Fidelity = 0.398960	KL_Divergence = 0.774684
# Epoch: 167	Fidelity = 0.398936	KL_Divergence = 0.774488
# Epoch: 168	Fidelity = 0.398909	KL_Divergence = 0.774307
# Epoch: 169	Fidelity = 0.398877	KL_Divergence = 0.774133
# Epoch: 170	Fidelity = 0.398853	KL_Divergence = 0.773939
# Epoch: 171	Fidelity = 0.398833	KL_Divergence = 0.773762
# Epoch: 172	Fidelity = 0.398815	KL_Divergence = 0.773579
# Epoch: 173	Fidelity = 0.398794	KL_Divergence = 0.773400
# Epoch: 174	Fidelity = 0.398766	KL_Divergence = 0.773227
# Epoch: 175	Fidelity = 0.398737	KL_Divergence = 0.773045
# Epoch: 176	Fidelity = 0.398711	KL_Divergence = 0.772886
# Epoch: 177	Fidelity = 0.398692	KL_Divergence = 0.772708
# Epoch: 178	Fidelity = 0.398675	KL_Divergence = 0.772526
# Epoch: 179	Fidelity = 0.398647	KL_Divergence = 0.772348
# Epoch: 180	Fidelity = 0.398627	KL_Divergence = 0.772174
# Epoch: 181	Fidelity = 0.398601	KL_Divergence = 0.772012
# Epoch: 182	Fidelity = 0.398580	KL_Divergence = 0.771857
# Epoch: 183	Fidelity = 0.398556	KL_Divergence = 0.771700
# Epoch: 184	Fidelity = 0.398534	KL_Divergence = 0.771536
# Epoch: 185	Fidelity = 0.398512	KL_Divergence = 0.771377
# Epoch: 186	Fidelity = 0.398493	KL_Divergence = 0.771225
# Epoch: 187	Fidelity = 0.398472	KL_Divergence = 0.771066
# Epoch: 188	Fidelity = 0.398449	KL_Divergence = 0.770898
# Epoch: 189	Fidelity = 0.398425	KL_Divergence = 0.770745
# Epoch: 190	Fidelity = 0.398397	KL_Divergence = 0.770580
# Epoch: 191	Fidelity = 0.398382	KL_Divergence = 0.770443
# Epoch: 192	Fidelity = 0.398362	KL_Divergence = 0.770305
# Epoch: 193	Fidelity = 0.398345	KL_Divergence = 0.770155
# Epoch: 194	Fidelity = 0.398325	KL_Divergence = 0.770015
# Epoch: 195	Fidelity = 0.398307	KL_Divergence = 0.769872
# Epoch: 196	Fidelity = 0.398288	KL_Divergence = 0.769727
# Epoch: 197	Fidelity = 0.398268	KL_Divergence = 0.769580
# Epoch: 198	Fidelity = 0.398244	KL_Divergence = 0.769432
# Epoch: 199	Fidelity = 0.398223	KL_Divergence = 0.769282
# Epoch: 200	Fidelity = 0.398202	KL_Divergence = 0.769131
# Epoch: 201	Fidelity = 0.398182	KL_Divergence = 0.769006
# Epoch: 202	Fidelity = 0.398163	KL_Divergence = 0.768875
# Epoch: 203	Fidelity = 0.398142	KL_Divergence = 0.768749
# Epoch: 204	Fidelity = 0.398120	KL_Divergence = 0.768615
# Epoch: 205	Fidelity = 0.398099	KL_Divergence = 0.768492
# Epoch: 206	Fidelity = 0.398083	KL_Divergence = 0.768352
# Epoch: 207	Fidelity = 0.398067	KL_Divergence = 0.768219
# Epoch: 208	Fidelity = 0.398050	KL_Divergence = 0.768095
# Epoch: 209	Fidelity = 0.398031	KL_Divergence = 0.767962
# Epoch: 210	Fidelity = 0.398010	KL_Divergence = 0.767829
# Epoch: 211	Fidelity = 0.397990	KL_Divergence = 0.767713
# Epoch: 212	Fidelity = 0.397970	KL_Divergence = 0.767593
# Epoch: 213	Fidelity = 0.397955	KL_Divergence = 0.767470
# Epoch: 214	Fidelity = 0.397937	KL_Divergence = 0.767348
# Epoch: 215	Fidelity = 0.397919	KL_Divergence = 0.767228
# Epoch: 216	Fidelity = 0.397898	KL_Divergence = 0.767108
# Epoch: 217	Fidelity = 0.397879	KL_Divergence = 0.766996
# Epoch: 218	Fidelity = 0.397862	KL_Divergence = 0.766874
# Epoch: 219	Fidelity = 0.397847	KL_Divergence = 0.766751
# Epoch: 220	Fidelity = 0.397829	KL_Divergence = 0.766630
# Epoch: 221	Fidelity = 0.397810	KL_Divergence = 0.766527
# Epoch: 222	Fidelity = 0.397795	KL_Divergence = 0.766421
# Epoch: 223	Fidelity = 0.397781	KL_Divergence = 0.766312
# Epoch: 224	Fidelity = 0.397766	KL_Divergence = 0.766198
# Epoch: 225	Fidelity = 0.397752	KL_Divergence = 0.766092
# Epoch: 226	Fidelity = 0.397732	KL_Divergence = 0.765986
# Epoch: 227	Fidelity = 0.397718	KL_Divergence = 0.765874
# Epoch: 228	Fidelity = 0.397700	KL_Divergence = 0.765761
# Epoch: 229	Fidelity = 0.397687	KL_Divergence = 0.765652
# Epoch: 230	Fidelity = 0.397669	KL_Divergence = 0.765548
# Epoch: 231	Fidelity = 0.397655	KL_Divergence = 0.765447
# Epoch: 232	Fidelity = 0.397639	KL_Divergence = 0.765351
# Epoch: 233	Fidelity = 0.397627	KL_Divergence = 0.765255
# Epoch: 234	Fidelity = 0.397611	KL_Divergence = 0.765151
# Epoch: 235	Fidelity = 0.397592	KL_Divergence = 0.765051
# Epoch: 236	Fidelity = 0.397577	KL_Divergence = 0.764963
# Epoch: 237	Fidelity = 0.397560	KL_Divergence = 0.764864
# Epoch: 238	Fidelity = 0.397545	KL_Divergence = 0.764771
# Epoch: 239	Fidelity = 0.397530	KL_Divergence = 0.764671
# Epoch: 240	Fidelity = 0.397514	KL_Divergence = 0.764579
# Epoch: 241	Fidelity = 0.397500	KL_Divergence = 0.764488
# Epoch: 242	Fidelity = 0.397487	KL_Divergence = 0.764396
# Epoch: 243	Fidelity = 0.397471	KL_Divergence = 0.764308
# Epoch: 244	Fidelity = 0.397459	KL_Divergence = 0.764216
# Epoch: 245	Fidelity = 0.397447	KL_Divergence = 0.764117
# Epoch: 246	Fidelity = 0.397434	KL_Divergence = 0.764030
# Epoch: 247	Fidelity = 0.397421	KL_Divergence = 0.763937
# Epoch: 248	Fidelity = 0.397408	KL_Divergence = 0.763848
# Epoch: 249	Fidelity = 0.397394	KL_Divergence = 0.763760
# Epoch: 250	Fidelity = 0.397381	KL_Divergence = 0.763674
# Epoch: 251	Fidelity = 0.397370	KL_Divergence = 0.763595
# Epoch: 252	Fidelity = 0.397356	KL_Divergence = 0.763513
# Epoch: 253	Fidelity = 0.397341	KL_Divergence = 0.763434
# Epoch: 254	Fidelity = 0.397329	KL_Divergence = 0.763352
# Epoch: 255	Fidelity = 0.397320	KL_Divergence = 0.763271
# Epoch: 256	Fidelity = 0.397307	KL_Divergence = 0.763189
# Epoch: 257	Fidelity = 0.397294	KL_Divergence = 0.763109
# Epoch: 258	Fidelity = 0.397282	KL_Divergence = 0.763030
# Epoch: 259	Fidelity = 0.397271	KL_Divergence = 0.762946
# Epoch: 260	Fidelity = 0.397259	KL_Divergence = 0.762863
# Epoch: 261	Fidelity = 0.397248	KL_Divergence = 0.762789
# Epoch: 262	Fidelity = 0.397235	KL_Divergence = 0.762720
# Epoch: 263	Fidelity = 0.397223	KL_Divergence = 0.762645
# Epoch: 264	Fidelity = 0.397211	KL_Divergence = 0.762570
# Epoch: 265	Fidelity = 0.397200	KL_Divergence = 0.762494
# Epoch: 266	Fidelity = 0.397190	KL_Divergence = 0.762418
# Epoch: 267	Fidelity = 0.397180	KL_Divergence = 0.762341
# Epoch: 268	Fidelity = 0.397167	KL_Divergence = 0.762265
# Epoch: 269	Fidelity = 0.397155	KL_Divergence = 0.762192
# Epoch: 270	Fidelity = 0.397145	KL_Divergence = 0.762116
# Epoch: 271	Fidelity = 0.397135	KL_Divergence = 0.762053
# Epoch: 272	Fidelity = 0.397124	KL_Divergence = 0.761990
# Epoch: 273	Fidelity = 0.397112	KL_Divergence = 0.761924
# Epoch: 274	Fidelity = 0.397103	KL_Divergence = 0.761860
# Epoch: 275	Fidelity = 0.397091	KL_Divergence = 0.761790
# Epoch: 276	Fidelity = 0.397082	KL_Divergence = 0.761724
# Epoch: 277	Fidelity = 0.397072	KL_Divergence = 0.761657
# Epoch: 278	Fidelity = 0.397061	KL_Divergence = 0.761585
# Epoch: 279	Fidelity = 0.397053	KL_Divergence = 0.761516
# Epoch: 280	Fidelity = 0.397042	KL_Divergence = 0.761449
# Epoch: 281	Fidelity = 0.397032	KL_Divergence = 0.761389
# Epoch: 282	Fidelity = 0.397024	KL_Divergence = 0.761323
# Epoch: 283	Fidelity = 0.397012	KL_Divergence = 0.761263
# Epoch: 284	Fidelity = 0.397004	KL_Divergence = 0.761203
# Epoch: 285	Fidelity = 0.396995	KL_Divergence = 0.761138
# Epoch: 286	Fidelity = 0.396982	KL_Divergence = 0.761080
# Epoch: 287	Fidelity = 0.396971	KL_Divergence = 0.761024
# Epoch: 288	Fidelity = 0.396960	KL_Divergence = 0.760959
# Epoch: 289	Fidelity = 0.396952	KL_Divergence = 0.760897
# Epoch: 290	Fidelity = 0.396942	KL_Divergence = 0.760837
# Epoch: 291	Fidelity = 0.396935	KL_Divergence = 0.760781
# Epoch: 292	Fidelity = 0.396926	KL_Divergence = 0.760728
# Epoch: 293	Fidelity = 0.396918	KL_Divergence = 0.760676
# Epoch: 294	Fidelity = 0.396909	KL_Divergence = 0.760621
# Epoch: 295	Fidelity = 0.396900	KL_Divergence = 0.760564
# Epoch: 296	Fidelity = 0.396892	KL_Divergence = 0.760508
# Epoch: 297	Fidelity = 0.396883	KL_Divergence = 0.760450
# Epoch: 298	Fidelity = 0.396874	KL_Divergence = 0.760395
# Epoch: 299	Fidelity = 0.396865	KL_Divergence = 0.760338
# Epoch: 300	Fidelity = 0.396858	KL_Divergence = 0.760283
# Epoch: 301	Fidelity = 0.396849	KL_Divergence = 0.760229
# Epoch: 302	Fidelity = 0.396839	KL_Divergence = 0.760181
# Epoch: 303	Fidelity = 0.396831	KL_Divergence = 0.760133
# Epoch: 304	Fidelity = 0.396822	KL_Divergence = 0.760082
# Epoch: 305	Fidelity = 0.396815	KL_Divergence = 0.760032
# Epoch: 306	Fidelity = 0.396807	KL_Divergence = 0.759982
# Epoch: 307	Fidelity = 0.396800	KL_Divergence = 0.759932
# Epoch: 308	Fidelity = 0.396793	KL_Divergence = 0.759881
# Epoch: 309	Fidelity = 0.396784	KL_Divergence = 0.759828
# Epoch: 310	Fidelity = 0.396775	KL_Divergence = 0.759779
# Epoch: 311	Fidelity = 0.396767	KL_Divergence = 0.759731
# Epoch: 312	Fidelity = 0.396759	KL_Divergence = 0.759682
# Epoch: 313	Fidelity = 0.396752	KL_Divergence = 0.759637
# Epoch: 314	Fidelity = 0.396743	KL_Divergence = 0.759592
# Epoch: 315	Fidelity = 0.396735	KL_Divergence = 0.759545
# Epoch: 316	Fidelity = 0.396726	KL_Divergence = 0.759504
# Epoch: 317	Fidelity = 0.396718	KL_Divergence = 0.759460
# Epoch: 318	Fidelity = 0.396709	KL_Divergence = 0.759416
# Epoch: 319	Fidelity = 0.396701	KL_Divergence = 0.759369
# Epoch: 320	Fidelity = 0.396693	KL_Divergence = 0.759326
# Epoch: 321	Fidelity = 0.396687	KL_Divergence = 0.759284
# Epoch: 322	Fidelity = 0.396679	KL_Divergence = 0.759241
# Epoch: 323	Fidelity = 0.396672	KL_Divergence = 0.759199
# Epoch: 324	Fidelity = 0.396665	KL_Divergence = 0.759157
# Epoch: 325	Fidelity = 0.396657	KL_Divergence = 0.759115
# Epoch: 326	Fidelity = 0.396649	KL_Divergence = 0.759076
# Epoch: 327	Fidelity = 0.396641	KL_Divergence = 0.759033
# Epoch: 328	Fidelity = 0.396634	KL_Divergence = 0.758990
# Epoch: 329	Fidelity = 0.396628	KL_Divergence = 0.758947
# Epoch: 330	Fidelity = 0.396622	KL_Divergence = 0.758906
# Epoch: 331	Fidelity = 0.396616	KL_Divergence = 0.758870
# Epoch: 332	Fidelity = 0.396610	KL_Divergence = 0.758830
# Epoch: 333	Fidelity = 0.396604	KL_Divergence = 0.758793
# Epoch: 334	Fidelity = 0.396596	KL_Divergence = 0.758758
# Epoch: 335	Fidelity = 0.396590	KL_Divergence = 0.758720
# Epoch: 336	Fidelity = 0.396583	KL_Divergence = 0.758681
# Epoch: 337	Fidelity = 0.396576	KL_Divergence = 0.758642
# Epoch: 338	Fidelity = 0.396570	KL_Divergence = 0.758606
# Epoch: 339	Fidelity = 0.396564	KL_Divergence = 0.758569
# Epoch: 340	Fidelity = 0.396557	KL_Divergence = 0.758531
# Epoch: 341	Fidelity = 0.396551	KL_Divergence = 0.758496
# Epoch: 342	Fidelity = 0.396546	KL_Divergence = 0.758461
# Epoch: 343	Fidelity = 0.396542	KL_Divergence = 0.758424
# Epoch: 344	Fidelity = 0.396536	KL_Divergence = 0.758386
# Epoch: 345	Fidelity = 0.396529	KL_Divergence = 0.758350
# Epoch: 346	Fidelity = 0.396522	KL_Divergence = 0.758318
# Epoch: 347	Fidelity = 0.396517	KL_Divergence = 0.758282
# Epoch: 348	Fidelity = 0.396513	KL_Divergence = 0.758246
# Epoch: 349	Fidelity = 0.396508	KL_Divergence = 0.758209
# Epoch: 350	Fidelity = 0.396503	KL_Divergence = 0.758172
# Epoch: 351	Fidelity = 0.396498	KL_Divergence = 0.758140
# Epoch: 352	Fidelity = 0.396492	KL_Divergence = 0.758109
# Epoch: 353	Fidelity = 0.396487	KL_Divergence = 0.758079
# Epoch: 354	Fidelity = 0.396482	KL_Divergence = 0.758048
# Epoch: 355	Fidelity = 0.396477	KL_Divergence = 0.758016
# Epoch: 356	Fidelity = 0.396471	KL_Divergence = 0.757985
# Epoch: 357	Fidelity = 0.396466	KL_Divergence = 0.757954
# Epoch: 358	Fidelity = 0.396461	KL_Divergence = 0.757922
# Epoch: 359	Fidelity = 0.396456	KL_Divergence = 0.757888
# Epoch: 360	Fidelity = 0.396450	KL_Divergence = 0.757855
# Epoch: 361	Fidelity = 0.396445	KL_Divergence = 0.757828
# Epoch: 362	Fidelity = 0.396441	KL_Divergence = 0.757798
# Epoch: 363	Fidelity = 0.396436	KL_Divergence = 0.757770
# Epoch: 364	Fidelity = 0.396431	KL_Divergence = 0.757740
# Epoch: 365	Fidelity = 0.396426	KL_Divergence = 0.757711
# Epoch: 366	Fidelity = 0.396421	KL_Divergence = 0.757683
# Epoch: 367	Fidelity = 0.396416	KL_Divergence = 0.757653
# Epoch: 368	Fidelity = 0.396411	KL_Divergence = 0.757625
# Epoch: 369	Fidelity = 0.396406	KL_Divergence = 0.757595
# Epoch: 370	Fidelity = 0.396401	KL_Divergence = 0.757566
# Epoch: 371	Fidelity = 0.396396	KL_Divergence = 0.757541
# Epoch: 372	Fidelity = 0.396392	KL_Divergence = 0.757514
# Epoch: 373	Fidelity = 0.396387	KL_Divergence = 0.757488
# Epoch: 374	Fidelity = 0.396383	KL_Divergence = 0.757463
# Epoch: 375	Fidelity = 0.396379	KL_Divergence = 0.757436
# Epoch: 376	Fidelity = 0.396374	KL_Divergence = 0.757410
# Epoch: 377	Fidelity = 0.396369	KL_Divergence = 0.757382
# Epoch: 378	Fidelity = 0.396365	KL_Divergence = 0.757354
# Epoch: 379	Fidelity = 0.396360	KL_Divergence = 0.757328
# Epoch: 380	Fidelity = 0.396356	KL_Divergence = 0.757302
# Epoch: 381	Fidelity = 0.396351	KL_Divergence = 0.757279
# Epoch: 382	Fidelity = 0.396348	KL_Divergence = 0.757255
# Epoch: 383	Fidelity = 0.396344	KL_Divergence = 0.757232
# Epoch: 384	Fidelity = 0.396339	KL_Divergence = 0.757210
# Epoch: 385	Fidelity = 0.396335	KL_Divergence = 0.757185
# Epoch: 386	Fidelity = 0.396331	KL_Divergence = 0.757161
# Epoch: 387	Fidelity = 0.396327	KL_Divergence = 0.757138
# Epoch: 388	Fidelity = 0.396323	KL_Divergence = 0.757114
# Epoch: 389	Fidelity = 0.396319	KL_Divergence = 0.757090
# Epoch: 390	Fidelity = 0.396315	KL_Divergence = 0.757066
# Epoch: 391	Fidelity = 0.396311	KL_Divergence = 0.757045
# Epoch: 392	Fidelity = 0.396308	KL_Divergence = 0.757023
# Epoch: 393	Fidelity = 0.396305	KL_Divergence = 0.757000
# Epoch: 394	Fidelity = 0.396301	KL_Divergence = 0.756977
# Epoch: 395	Fidelity = 0.396297	KL_Divergence = 0.756956
# Epoch: 396	Fidelity = 0.396293	KL_Divergence = 0.756936
# Epoch: 397	Fidelity = 0.396289	KL_Divergence = 0.756915
# Epoch: 398	Fidelity = 0.396286	KL_Divergence = 0.756892
# Epoch: 399	Fidelity = 0.396282	KL_Divergence = 0.756870
# Epoch: 400	Fidelity = 0.396278	KL_Divergence = 0.756848
# Epoch: 401	Fidelity = 0.396275	KL_Divergence = 0.756829
# Epoch: 402	Fidelity = 0.396271	KL_Divergence = 0.756809
# Epoch: 403	Fidelity = 0.396268	KL_Divergence = 0.756789
# Epoch: 404	Fidelity = 0.396265	KL_Divergence = 0.756769
# Epoch: 405	Fidelity = 0.396261	KL_Divergence = 0.756749
# Epoch: 406	Fidelity = 0.396258	KL_Divergence = 0.756729
# Epoch: 407	Fidelity = 0.396255	KL_Divergence = 0.756708
# Epoch: 408	Fidelity = 0.396251	KL_Divergence = 0.756689
# Epoch: 409	Fidelity = 0.396248	KL_Divergence = 0.756669
# Epoch: 410	Fidelity = 0.396244	KL_Divergence = 0.756651
# Epoch: 411	Fidelity = 0.396241	KL_Divergence = 0.756633
# Epoch: 412	Fidelity = 0.396237	KL_Divergence = 0.756616
# Epoch: 413	Fidelity = 0.396234	KL_Divergence = 0.756599
# Epoch: 414	Fidelity = 0.396231	KL_Divergence = 0.756582
# Epoch: 415	Fidelity = 0.396227	KL_Divergence = 0.756565
# Epoch: 416	Fidelity = 0.396224	KL_Divergence = 0.756549
# Epoch: 417	Fidelity = 0.396221	KL_Divergence = 0.756531
# Epoch: 418	Fidelity = 0.396218	KL_Divergence = 0.756514
# Epoch: 419	Fidelity = 0.396214	KL_Divergence = 0.756496
# Epoch: 420	Fidelity = 0.396211	KL_Divergence = 0.756478
# Epoch: 421	Fidelity = 0.396208	KL_Divergence = 0.756463
# Epoch: 422	Fidelity = 0.396205	KL_Divergence = 0.756446
# Epoch: 423	Fidelity = 0.396203	KL_Divergence = 0.756430
# Epoch: 424	Fidelity = 0.396200	KL_Divergence = 0.756415
# Epoch: 425	Fidelity = 0.396197	KL_Divergence = 0.756399
# Epoch: 426	Fidelity = 0.396195	KL_Divergence = 0.756382
# Epoch: 427	Fidelity = 0.396192	KL_Divergence = 0.756366
# Epoch: 428	Fidelity = 0.396189	KL_Divergence = 0.756351
# Epoch: 429	Fidelity = 0.396186	KL_Divergence = 0.756334
# Epoch: 430	Fidelity = 0.396183	KL_Divergence = 0.756316
# Epoch: 431	Fidelity = 0.396180	KL_Divergence = 0.756302
# Epoch: 432	Fidelity = 0.396177	KL_Divergence = 0.756287
# Epoch: 433	Fidelity = 0.396175	KL_Divergence = 0.756272
# Epoch: 434	Fidelity = 0.396173	KL_Divergence = 0.756257
# Epoch: 435	Fidelity = 0.396170	KL_Divergence = 0.756241
# Epoch: 436	Fidelity = 0.396167	KL_Divergence = 0.756227
# Epoch: 437	Fidelity = 0.396165	KL_Divergence = 0.756213
# Epoch: 438	Fidelity = 0.396162	KL_Divergence = 0.756198
# Epoch: 439	Fidelity = 0.396159	KL_Divergence = 0.756184
# Epoch: 440	Fidelity = 0.396156	KL_Divergence = 0.756170
# Epoch: 441	Fidelity = 0.396154	KL_Divergence = 0.756157
# Epoch: 442	Fidelity = 0.396152	KL_Divergence = 0.756143
# Epoch: 443	Fidelity = 0.396149	KL_Divergence = 0.756129
# Epoch: 444	Fidelity = 0.396147	KL_Divergence = 0.756115
# Epoch: 445	Fidelity = 0.396145	KL_Divergence = 0.756101
# Epoch: 446	Fidelity = 0.396142	KL_Divergence = 0.756088
# Epoch: 447	Fidelity = 0.396139	KL_Divergence = 0.756075
# Epoch: 448	Fidelity = 0.396137	KL_Divergence = 0.756062
# Epoch: 449	Fidelity = 0.396135	KL_Divergence = 0.756048
# Epoch: 450	Fidelity = 0.396132	KL_Divergence = 0.756036
# Epoch: 451	Fidelity = 0.396130	KL_Divergence = 0.756024
# Epoch: 452	Fidelity = 0.396127	KL_Divergence = 0.756012
# Epoch: 453	Fidelity = 0.396124	KL_Divergence = 0.756001
# Epoch: 454	Fidelity = 0.396122	KL_Divergence = 0.755989
# Epoch: 455	Fidelity = 0.396120	KL_Divergence = 0.755977
# Epoch: 456	Fidelity = 0.396118	KL_Divergence = 0.755965
# Epoch: 457	Fidelity = 0.396115	KL_Divergence = 0.755952
# Epoch: 458	Fidelity = 0.396113	KL_Divergence = 0.755940
# Epoch: 459	Fidelity = 0.396111	KL_Divergence = 0.755929
# Epoch: 460	Fidelity = 0.396109	KL_Divergence = 0.755917
# Epoch: 461	Fidelity = 0.396107	KL_Divergence = 0.755906
# Epoch: 462	Fidelity = 0.396105	KL_Divergence = 0.755895
# Epoch: 463	Fidelity = 0.396103	KL_Divergence = 0.755883
# Epoch: 464	Fidelity = 0.396101	KL_Divergence = 0.755872
# Epoch: 465	Fidelity = 0.396099	KL_Divergence = 0.755861
# Epoch: 466	Fidelity = 0.396097	KL_Divergence = 0.755849
# Epoch: 467	Fidelity = 0.396095	KL_Divergence = 0.755838
# Epoch: 468	Fidelity = 0.396093	KL_Divergence = 0.755827
# Epoch: 469	Fidelity = 0.396091	KL_Divergence = 0.755816
# Epoch: 470	Fidelity = 0.396089	KL_Divergence = 0.755805
# Epoch: 471	Fidelity = 0.396087	KL_Divergence = 0.755795
# Epoch: 472	Fidelity = 0.396085	KL_Divergence = 0.755785
# Epoch: 473	Fidelity = 0.396083	KL_Divergence = 0.755775
# Epoch: 474	Fidelity = 0.396081	KL_Divergence = 0.755765
# Epoch: 475	Fidelity = 0.396080	KL_Divergence = 0.755755
# Epoch: 476	Fidelity = 0.396078	KL_Divergence = 0.755745
# Epoch: 477	Fidelity = 0.396076	KL_Divergence = 0.755735
# Epoch: 478	Fidelity = 0.396074	KL_Divergence = 0.755724
# Epoch: 479	Fidelity = 0.396072	KL_Divergence = 0.755714
# Epoch: 480	Fidelity = 0.396070	KL_Divergence = 0.755705
# Epoch: 481	Fidelity = 0.396069	KL_Divergence = 0.755695
# Epoch: 482	Fidelity = 0.396067	KL_Divergence = 0.755686
# Epoch: 483	Fidelity = 0.396066	KL_Divergence = 0.755677
# Epoch: 484	Fidelity = 0.396064	KL_Divergence = 0.755668
# Epoch: 485	Fidelity = 0.396062	KL_Divergence = 0.755659
# Epoch: 486	Fidelity = 0.396061	KL_Divergence = 0.755650
# Epoch: 487	Fidelity = 0.396059	KL_Divergence = 0.755641
# Epoch: 488	Fidelity = 0.396058	KL_Divergence = 0.755632
# Epoch: 489	Fidelity = 0.396056	KL_Divergence = 0.755623
# Epoch: 490	Fidelity = 0.396054	KL_Divergence = 0.755614
# Epoch: 491	Fidelity = 0.396053	KL_Divergence = 0.755605
# Epoch: 492	Fidelity = 0.396051	KL_Divergence = 0.755597
# Epoch: 493	Fidelity = 0.396050	KL_Divergence = 0.755588
# Epoch: 494	Fidelity = 0.396049	KL_Divergence = 0.755580
# Epoch: 495	Fidelity = 0.396047	KL_Divergence = 0.755572
# Epoch: 496	Fidelity = 0.396045	KL_Divergence = 0.755564
# Epoch: 497	Fidelity = 0.396044	KL_Divergence = 0.755556
# Epoch: 498	Fidelity = 0.396042	KL_Divergence = 0.755548
# Epoch: 499	Fidelity = 0.396040	KL_Divergence = 0.755540
# Epoch: 500	Fidelity = 0.396039	KL_Divergence = 0.755532
# Total time elapsed during training: 341.467 s
# error_model : depolarizing, each_n_shot : 50
# Epoch: 1	Fidelity = 0.236865	KL_Divergence = 0.729075
# Epoch: 2	Fidelity = 0.236835	KL_Divergence = 0.728728
# Epoch: 3	Fidelity = 0.236844	KL_Divergence = 0.728407
# Epoch: 4	Fidelity = 0.236817	KL_Divergence = 0.728053
# Epoch: 5	Fidelity = 0.236786	KL_Divergence = 0.727690
# Epoch: 6	Fidelity = 0.236753	KL_Divergence = 0.727333
# Epoch: 7	Fidelity = 0.236732	KL_Divergence = 0.726988
# Epoch: 8	Fidelity = 0.236727	KL_Divergence = 0.726652
# Epoch: 9	Fidelity = 0.236707	KL_Divergence = 0.726303
# Epoch: 10	Fidelity = 0.236680	KL_Divergence = 0.725959
# Epoch: 11	Fidelity = 0.236670	KL_Divergence = 0.725654
# Epoch: 12	Fidelity = 0.236631	KL_Divergence = 0.725329
# Epoch: 13	Fidelity = 0.236600	KL_Divergence = 0.725011
# Epoch: 14	Fidelity = 0.236583	KL_Divergence = 0.724699
# Epoch: 15	Fidelity = 0.236566	KL_Divergence = 0.724387
# Epoch: 16	Fidelity = 0.236570	KL_Divergence = 0.724101
# Epoch: 17	Fidelity = 0.236545	KL_Divergence = 0.723797
# Epoch: 18	Fidelity = 0.236556	KL_Divergence = 0.723515
# Epoch: 19	Fidelity = 0.236535	KL_Divergence = 0.723208
# Epoch: 20	Fidelity = 0.236511	KL_Divergence = 0.722900
# Epoch: 21	Fidelity = 0.236467	KL_Divergence = 0.722602
# Epoch: 22	Fidelity = 0.236454	KL_Divergence = 0.722329
# Epoch: 23	Fidelity = 0.236471	KL_Divergence = 0.722083
# Epoch: 24	Fidelity = 0.236452	KL_Divergence = 0.721815
# Epoch: 25	Fidelity = 0.236445	KL_Divergence = 0.721556
# Epoch: 26	Fidelity = 0.236456	KL_Divergence = 0.721307
# Epoch: 27	Fidelity = 0.236441	KL_Divergence = 0.721047
# Epoch: 28	Fidelity = 0.236424	KL_Divergence = 0.720772
# Epoch: 29	Fidelity = 0.236424	KL_Divergence = 0.720511
# Epoch: 30	Fidelity = 0.236406	KL_Divergence = 0.720250
# Epoch: 31	Fidelity = 0.236401	KL_Divergence = 0.720020
# Epoch: 32	Fidelity = 0.236377	KL_Divergence = 0.719779
# Epoch: 33	Fidelity = 0.236348	KL_Divergence = 0.719533
# Epoch: 34	Fidelity = 0.236351	KL_Divergence = 0.719310
# Epoch: 35	Fidelity = 0.236328	KL_Divergence = 0.719075
# Epoch: 36	Fidelity = 0.236333	KL_Divergence = 0.718852
# Epoch: 37	Fidelity = 0.236347	KL_Divergence = 0.718638
# Epoch: 38	Fidelity = 0.236334	KL_Divergence = 0.718408
# Epoch: 39	Fidelity = 0.236296	KL_Divergence = 0.718163
# Epoch: 40	Fidelity = 0.236286	KL_Divergence = 0.717937
# Epoch: 41	Fidelity = 0.236276	KL_Divergence = 0.717733
# Epoch: 42	Fidelity = 0.236257	KL_Divergence = 0.717525
# Epoch: 43	Fidelity = 0.236272	KL_Divergence = 0.717337
# Epoch: 44	Fidelity = 0.236247	KL_Divergence = 0.717126
# Epoch: 45	Fidelity = 0.236204	KL_Divergence = 0.716901
# Epoch: 46	Fidelity = 0.236165	KL_Divergence = 0.716679
# Epoch: 47	Fidelity = 0.236145	KL_Divergence = 0.716470
# Epoch: 48	Fidelity = 0.236146	KL_Divergence = 0.716280
# Epoch: 49	Fidelity = 0.236166	KL_Divergence = 0.716099
# Epoch: 50	Fidelity = 0.236176	KL_Divergence = 0.715914
# Epoch: 51	Fidelity = 0.236151	KL_Divergence = 0.715722
# Epoch: 52	Fidelity = 0.236126	KL_Divergence = 0.715532
# Epoch: 53	Fidelity = 0.236114	KL_Divergence = 0.715347
# Epoch: 54	Fidelity = 0.236116	KL_Divergence = 0.715172
# Epoch: 55	Fidelity = 0.236128	KL_Divergence = 0.715006
# Epoch: 56	Fidelity = 0.236151	KL_Divergence = 0.714852
# Epoch: 57	Fidelity = 0.236153	KL_Divergence = 0.714681
# Epoch: 58	Fidelity = 0.236175	KL_Divergence = 0.714525
# Epoch: 59	Fidelity = 0.236179	KL_Divergence = 0.714355
# Epoch: 60	Fidelity = 0.236194	KL_Divergence = 0.714200
# Epoch: 61	Fidelity = 0.236185	KL_Divergence = 0.714040
# Epoch: 62	Fidelity = 0.236178	KL_Divergence = 0.713883
# Epoch: 63	Fidelity = 0.236167	KL_Divergence = 0.713721
# Epoch: 64	Fidelity = 0.236167	KL_Divergence = 0.713567
# Epoch: 65	Fidelity = 0.236173	KL_Divergence = 0.713417
# Epoch: 66	Fidelity = 0.236159	KL_Divergence = 0.713261
# Epoch: 67	Fidelity = 0.236128	KL_Divergence = 0.713090
# Epoch: 68	Fidelity = 0.236094	KL_Divergence = 0.712925
# Epoch: 69	Fidelity = 0.236089	KL_Divergence = 0.712767
# Epoch: 70	Fidelity = 0.236077	KL_Divergence = 0.712612
# Epoch: 71	Fidelity = 0.236078	KL_Divergence = 0.712477
# Epoch: 72	Fidelity = 0.236057	KL_Divergence = 0.712331
# Epoch: 73	Fidelity = 0.236057	KL_Divergence = 0.712196
# Epoch: 74	Fidelity = 0.236054	KL_Divergence = 0.712060
# Epoch: 75	Fidelity = 0.236063	KL_Divergence = 0.711928
# Epoch: 76	Fidelity = 0.236057	KL_Divergence = 0.711788
# Epoch: 77	Fidelity = 0.236074	KL_Divergence = 0.711662
# Epoch: 78	Fidelity = 0.236071	KL_Divergence = 0.711530
# Epoch: 79	Fidelity = 0.236055	KL_Divergence = 0.711387
# Epoch: 80	Fidelity = 0.236073	KL_Divergence = 0.711261
# Epoch: 81	Fidelity = 0.236073	KL_Divergence = 0.711139
# Epoch: 82	Fidelity = 0.236083	KL_Divergence = 0.711025
# Epoch: 83	Fidelity = 0.236091	KL_Divergence = 0.710911
# Epoch: 84	Fidelity = 0.236079	KL_Divergence = 0.710786
# Epoch: 85	Fidelity = 0.236071	KL_Divergence = 0.710660
# Epoch: 86	Fidelity = 0.236075	KL_Divergence = 0.710540
# Epoch: 87	Fidelity = 0.236074	KL_Divergence = 0.710418
# Epoch: 88	Fidelity = 0.236076	KL_Divergence = 0.710299
# Epoch: 89	Fidelity = 0.236072	KL_Divergence = 0.710181
# Epoch: 90	Fidelity = 0.236053	KL_Divergence = 0.710058
# Epoch: 91	Fidelity = 0.236050	KL_Divergence = 0.709953
# Epoch: 92	Fidelity = 0.236051	KL_Divergence = 0.709846
# Epoch: 93	Fidelity = 0.236024	KL_Divergence = 0.709726
# Epoch: 94	Fidelity = 0.236009	KL_Divergence = 0.709613
# Epoch: 95	Fidelity = 0.235992	KL_Divergence = 0.709498
# Epoch: 96	Fidelity = 0.236012	KL_Divergence = 0.709400
# Epoch: 97	Fidelity = 0.235998	KL_Divergence = 0.709284
# Epoch: 98	Fidelity = 0.236005	KL_Divergence = 0.709186
# Epoch: 99	Fidelity = 0.236002	KL_Divergence = 0.709077
# Epoch: 100	Fidelity = 0.235995	KL_Divergence = 0.708968
# Epoch: 101	Fidelity = 0.236008	KL_Divergence = 0.708881
# Epoch: 102	Fidelity = 0.235981	KL_Divergence = 0.708771
# Epoch: 103	Fidelity = 0.235985	KL_Divergence = 0.708679
# Epoch: 104	Fidelity = 0.236001	KL_Divergence = 0.708594
# Epoch: 105	Fidelity = 0.236002	KL_Divergence = 0.708499
# Epoch: 106	Fidelity = 0.236005	KL_Divergence = 0.708408
# Epoch: 107	Fidelity = 0.236000	KL_Divergence = 0.708316
# Epoch: 108	Fidelity = 0.235978	KL_Divergence = 0.708214
# Epoch: 109	Fidelity = 0.235956	KL_Divergence = 0.708109
# Epoch: 110	Fidelity = 0.235948	KL_Divergence = 0.708013
# Epoch: 111	Fidelity = 0.235934	KL_Divergence = 0.707923
# Epoch: 112	Fidelity = 0.235929	KL_Divergence = 0.707838
# Epoch: 113	Fidelity = 0.235922	KL_Divergence = 0.707748
# Epoch: 114	Fidelity = 0.235910	KL_Divergence = 0.707659
# Epoch: 115	Fidelity = 0.235889	KL_Divergence = 0.707568
# Epoch: 116	Fidelity = 0.235869	KL_Divergence = 0.707480
# Epoch: 117	Fidelity = 0.235857	KL_Divergence = 0.707393
# Epoch: 118	Fidelity = 0.235857	KL_Divergence = 0.707309
# Epoch: 119	Fidelity = 0.235854	KL_Divergence = 0.707222
# Epoch: 120	Fidelity = 0.235860	KL_Divergence = 0.707145
# Epoch: 121	Fidelity = 0.235850	KL_Divergence = 0.707068
# Epoch: 122	Fidelity = 0.235843	KL_Divergence = 0.706992
# Epoch: 123	Fidelity = 0.235844	KL_Divergence = 0.706917
# Epoch: 124	Fidelity = 0.235848	KL_Divergence = 0.706845
# Epoch: 125	Fidelity = 0.235848	KL_Divergence = 0.706773
# Epoch: 126	Fidelity = 0.235851	KL_Divergence = 0.706700
# Epoch: 127	Fidelity = 0.235838	KL_Divergence = 0.706620
# Epoch: 128	Fidelity = 0.235827	KL_Divergence = 0.706539
# Epoch: 129	Fidelity = 0.235815	KL_Divergence = 0.706461
# Epoch: 130	Fidelity = 0.235824	KL_Divergence = 0.706391
# Epoch: 131	Fidelity = 0.235826	KL_Divergence = 0.706324
# Epoch: 132	Fidelity = 0.235829	KL_Divergence = 0.706259
# Epoch: 133	Fidelity = 0.235813	KL_Divergence = 0.706188
# Epoch: 134	Fidelity = 0.235805	KL_Divergence = 0.706118
# Epoch: 135	Fidelity = 0.235801	KL_Divergence = 0.706051
# Epoch: 136	Fidelity = 0.235810	KL_Divergence = 0.705986
# Epoch: 137	Fidelity = 0.235803	KL_Divergence = 0.705918
# Epoch: 138	Fidelity = 0.235802	KL_Divergence = 0.705851
# Epoch: 139	Fidelity = 0.235808	KL_Divergence = 0.705787
# Epoch: 140	Fidelity = 0.235800	KL_Divergence = 0.705716
# Epoch: 141	Fidelity = 0.235784	KL_Divergence = 0.705649
# Epoch: 142	Fidelity = 0.235777	KL_Divergence = 0.705587
# Epoch: 143	Fidelity = 0.235770	KL_Divergence = 0.705524
# Epoch: 144	Fidelity = 0.235771	KL_Divergence = 0.705463
# Epoch: 145	Fidelity = 0.235768	KL_Divergence = 0.705402
# Epoch: 146	Fidelity = 0.235767	KL_Divergence = 0.705343
# Epoch: 147	Fidelity = 0.235773	KL_Divergence = 0.705289
# Epoch: 148	Fidelity = 0.235773	KL_Divergence = 0.705227
# Epoch: 149	Fidelity = 0.235768	KL_Divergence = 0.705164
# Epoch: 150	Fidelity = 0.235750	KL_Divergence = 0.705097
# Epoch: 151	Fidelity = 0.235737	KL_Divergence = 0.705038
# Epoch: 152	Fidelity = 0.235728	KL_Divergence = 0.704980
# Epoch: 153	Fidelity = 0.235730	KL_Divergence = 0.704927
# Epoch: 154	Fidelity = 0.235731	KL_Divergence = 0.704871
# Epoch: 155	Fidelity = 0.235722	KL_Divergence = 0.704814
# Epoch: 156	Fidelity = 0.235721	KL_Divergence = 0.704758
# Epoch: 157	Fidelity = 0.235729	KL_Divergence = 0.704706
# Epoch: 158	Fidelity = 0.235721	KL_Divergence = 0.704652
# Epoch: 159	Fidelity = 0.235710	KL_Divergence = 0.704596
# Epoch: 160	Fidelity = 0.235708	KL_Divergence = 0.704542
# Epoch: 161	Fidelity = 0.235696	KL_Divergence = 0.704490
# Epoch: 162	Fidelity = 0.235691	KL_Divergence = 0.704442
# Epoch: 163	Fidelity = 0.235684	KL_Divergence = 0.704390
# Epoch: 164	Fidelity = 0.235675	KL_Divergence = 0.704338
# Epoch: 165	Fidelity = 0.235670	KL_Divergence = 0.704289
# Epoch: 166	Fidelity = 0.235645	KL_Divergence = 0.704232
# Epoch: 167	Fidelity = 0.235635	KL_Divergence = 0.704184
# Epoch: 168	Fidelity = 0.235635	KL_Divergence = 0.704138
# Epoch: 169	Fidelity = 0.235635	KL_Divergence = 0.704090
# Epoch: 170	Fidelity = 0.235639	KL_Divergence = 0.704042
# Epoch: 171	Fidelity = 0.235637	KL_Divergence = 0.703999
# Epoch: 172	Fidelity = 0.235621	KL_Divergence = 0.703950
# Epoch: 173	Fidelity = 0.235617	KL_Divergence = 0.703907
# Epoch: 174	Fidelity = 0.235618	KL_Divergence = 0.703865
# Epoch: 175	Fidelity = 0.235620	KL_Divergence = 0.703822
# Epoch: 176	Fidelity = 0.235626	KL_Divergence = 0.703781
# Epoch: 177	Fidelity = 0.235622	KL_Divergence = 0.703738
# Epoch: 178	Fidelity = 0.235631	KL_Divergence = 0.703699
# Epoch: 179	Fidelity = 0.235613	KL_Divergence = 0.703650
# Epoch: 180	Fidelity = 0.235613	KL_Divergence = 0.703607
# Epoch: 181	Fidelity = 0.235597	KL_Divergence = 0.703564
# Epoch: 182	Fidelity = 0.235596	KL_Divergence = 0.703524
# Epoch: 183	Fidelity = 0.235601	KL_Divergence = 0.703486
# Epoch: 184	Fidelity = 0.235589	KL_Divergence = 0.703444
# Epoch: 185	Fidelity = 0.235572	KL_Divergence = 0.703401
# Epoch: 186	Fidelity = 0.235571	KL_Divergence = 0.703362
# Epoch: 187	Fidelity = 0.235572	KL_Divergence = 0.703325
# Epoch: 188	Fidelity = 0.235574	KL_Divergence = 0.703287
# Epoch: 189	Fidelity = 0.235577	KL_Divergence = 0.703247
# Epoch: 190	Fidelity = 0.235569	KL_Divergence = 0.703205
# Epoch: 191	Fidelity = 0.235569	KL_Divergence = 0.703171
# Epoch: 192	Fidelity = 0.235564	KL_Divergence = 0.703136
# Epoch: 193	Fidelity = 0.235553	KL_Divergence = 0.703099
# Epoch: 194	Fidelity = 0.235553	KL_Divergence = 0.703064
# Epoch: 195	Fidelity = 0.235544	KL_Divergence = 0.703026
# Epoch: 196	Fidelity = 0.235533	KL_Divergence = 0.702989
# Epoch: 197	Fidelity = 0.235540	KL_Divergence = 0.702957
# Epoch: 198	Fidelity = 0.235540	KL_Divergence = 0.702921
# Epoch: 199	Fidelity = 0.235526	KL_Divergence = 0.702884
# Epoch: 200	Fidelity = 0.235529	KL_Divergence = 0.702850
# Epoch: 201	Fidelity = 0.235527	KL_Divergence = 0.702819
# Epoch: 202	Fidelity = 0.235531	KL_Divergence = 0.702788
# Epoch: 203	Fidelity = 0.235534	KL_Divergence = 0.702757
# Epoch: 204	Fidelity = 0.235530	KL_Divergence = 0.702724
# Epoch: 205	Fidelity = 0.235517	KL_Divergence = 0.702689
# Epoch: 206	Fidelity = 0.235510	KL_Divergence = 0.702654
# Epoch: 207	Fidelity = 0.235508	KL_Divergence = 0.702621
# Epoch: 208	Fidelity = 0.235517	KL_Divergence = 0.702592
# Epoch: 209	Fidelity = 0.235517	KL_Divergence = 0.702560
# Epoch: 210	Fidelity = 0.235513	KL_Divergence = 0.702528
# Epoch: 211	Fidelity = 0.235510	KL_Divergence = 0.702499
# Epoch: 212	Fidelity = 0.235498	KL_Divergence = 0.702467
# Epoch: 213	Fidelity = 0.235498	KL_Divergence = 0.702439
# Epoch: 214	Fidelity = 0.235488	KL_Divergence = 0.702408
# Epoch: 215	Fidelity = 0.235500	KL_Divergence = 0.702382
# Epoch: 216	Fidelity = 0.235504	KL_Divergence = 0.702354
# Epoch: 217	Fidelity = 0.235499	KL_Divergence = 0.702324
# Epoch: 218	Fidelity = 0.235501	KL_Divergence = 0.702296
# Epoch: 219	Fidelity = 0.235486	KL_Divergence = 0.702262
# Epoch: 220	Fidelity = 0.235477	KL_Divergence = 0.702232
# Epoch: 221	Fidelity = 0.235478	KL_Divergence = 0.702207
# Epoch: 222	Fidelity = 0.235477	KL_Divergence = 0.702180
# Epoch: 223	Fidelity = 0.235469	KL_Divergence = 0.702152
# Epoch: 224	Fidelity = 0.235466	KL_Divergence = 0.702126
# Epoch: 225	Fidelity = 0.235468	KL_Divergence = 0.702101
# Epoch: 226	Fidelity = 0.235456	KL_Divergence = 0.702072
# Epoch: 227	Fidelity = 0.235452	KL_Divergence = 0.702044
# Epoch: 228	Fidelity = 0.235447	KL_Divergence = 0.702017
# Epoch: 229	Fidelity = 0.235446	KL_Divergence = 0.701992
# Epoch: 230	Fidelity = 0.235435	KL_Divergence = 0.701963
# Epoch: 231	Fidelity = 0.235437	KL_Divergence = 0.701941
# Epoch: 232	Fidelity = 0.235438	KL_Divergence = 0.701918
# Epoch: 233	Fidelity = 0.235434	KL_Divergence = 0.701894
# Epoch: 234	Fidelity = 0.235437	KL_Divergence = 0.701872
# Epoch: 235	Fidelity = 0.235437	KL_Divergence = 0.701848
# Epoch: 236	Fidelity = 0.235428	KL_Divergence = 0.701821
# Epoch: 237	Fidelity = 0.235429	KL_Divergence = 0.701799
# Epoch: 238	Fidelity = 0.235427	KL_Divergence = 0.701775
# Epoch: 239	Fidelity = 0.235427	KL_Divergence = 0.701751
# Epoch: 240	Fidelity = 0.235425	KL_Divergence = 0.701726
# Epoch: 241	Fidelity = 0.235426	KL_Divergence = 0.701706
# Epoch: 242	Fidelity = 0.235426	KL_Divergence = 0.701684
# Epoch: 243	Fidelity = 0.235425	KL_Divergence = 0.701663
# Epoch: 244	Fidelity = 0.235424	KL_Divergence = 0.701642
# Epoch: 245	Fidelity = 0.235427	KL_Divergence = 0.701622
# Epoch: 246	Fidelity = 0.235420	KL_Divergence = 0.701599
# Epoch: 247	Fidelity = 0.235421	KL_Divergence = 0.701578
# Epoch: 248	Fidelity = 0.235418	KL_Divergence = 0.701557
# Epoch: 249	Fidelity = 0.235414	KL_Divergence = 0.701535
# Epoch: 250	Fidelity = 0.235409	KL_Divergence = 0.701513
# Epoch: 251	Fidelity = 0.235405	KL_Divergence = 0.701494
# Epoch: 252	Fidelity = 0.235411	KL_Divergence = 0.701476
# Epoch: 253	Fidelity = 0.235414	KL_Divergence = 0.701457
# Epoch: 254	Fidelity = 0.235410	KL_Divergence = 0.701437
# Epoch: 255	Fidelity = 0.235402	KL_Divergence = 0.701416
# Epoch: 256	Fidelity = 0.235400	KL_Divergence = 0.701398
# Epoch: 257	Fidelity = 0.235402	KL_Divergence = 0.701379
# Epoch: 258	Fidelity = 0.235394	KL_Divergence = 0.701358
# Epoch: 259	Fidelity = 0.235389	KL_Divergence = 0.701338
# Epoch: 260	Fidelity = 0.235384	KL_Divergence = 0.701316
# Epoch: 261	Fidelity = 0.235377	KL_Divergence = 0.701298
# Epoch: 262	Fidelity = 0.235370	KL_Divergence = 0.701280
# Epoch: 263	Fidelity = 0.235369	KL_Divergence = 0.701262
# Epoch: 264	Fidelity = 0.235370	KL_Divergence = 0.701245
# Epoch: 265	Fidelity = 0.235370	KL_Divergence = 0.701228
# Epoch: 266	Fidelity = 0.235369	KL_Divergence = 0.701211
# Epoch: 267	Fidelity = 0.235363	KL_Divergence = 0.701192
# Epoch: 268	Fidelity = 0.235360	KL_Divergence = 0.701175
# Epoch: 269	Fidelity = 0.235351	KL_Divergence = 0.701155
# Epoch: 270	Fidelity = 0.235349	KL_Divergence = 0.701137
# Epoch: 271	Fidelity = 0.235350	KL_Divergence = 0.701121
# Epoch: 272	Fidelity = 0.235351	KL_Divergence = 0.701106
# Epoch: 273	Fidelity = 0.235350	KL_Divergence = 0.701090
# Epoch: 274	Fidelity = 0.235347	KL_Divergence = 0.701074
# Epoch: 275	Fidelity = 0.235347	KL_Divergence = 0.701060
# Epoch: 276	Fidelity = 0.235346	KL_Divergence = 0.701044
# Epoch: 277	Fidelity = 0.235345	KL_Divergence = 0.701029
# Epoch: 278	Fidelity = 0.235341	KL_Divergence = 0.701013
# Epoch: 279	Fidelity = 0.235346	KL_Divergence = 0.700998
# Epoch: 280	Fidelity = 0.235341	KL_Divergence = 0.700982
# Epoch: 281	Fidelity = 0.235338	KL_Divergence = 0.700967
# Epoch: 282	Fidelity = 0.235337	KL_Divergence = 0.700954
# Epoch: 283	Fidelity = 0.235332	KL_Divergence = 0.700938
# Epoch: 284	Fidelity = 0.235330	KL_Divergence = 0.700923
# Epoch: 285	Fidelity = 0.235323	KL_Divergence = 0.700908
# Epoch: 286	Fidelity = 0.235325	KL_Divergence = 0.700894
# Epoch: 287	Fidelity = 0.235323	KL_Divergence = 0.700879
# Epoch: 288	Fidelity = 0.235321	KL_Divergence = 0.700865
# Epoch: 289	Fidelity = 0.235316	KL_Divergence = 0.700850
# Epoch: 290	Fidelity = 0.235316	KL_Divergence = 0.700835
# Epoch: 291	Fidelity = 0.235315	KL_Divergence = 0.700823
# Epoch: 292	Fidelity = 0.235314	KL_Divergence = 0.700811
# Epoch: 293	Fidelity = 0.235312	KL_Divergence = 0.700797
# Epoch: 294	Fidelity = 0.235314	KL_Divergence = 0.700784
# Epoch: 295	Fidelity = 0.235311	KL_Divergence = 0.700771
# Epoch: 296	Fidelity = 0.235309	KL_Divergence = 0.700759
# Epoch: 297	Fidelity = 0.235305	KL_Divergence = 0.700745
# Epoch: 298	Fidelity = 0.235303	KL_Divergence = 0.700732
# Epoch: 299	Fidelity = 0.235304	KL_Divergence = 0.700721
# Epoch: 300	Fidelity = 0.235307	KL_Divergence = 0.700708
# Epoch: 301	Fidelity = 0.235304	KL_Divergence = 0.700697
# Epoch: 302	Fidelity = 0.235302	KL_Divergence = 0.700685
# Epoch: 303	Fidelity = 0.235301	KL_Divergence = 0.700674
# Epoch: 304	Fidelity = 0.235300	KL_Divergence = 0.700662
# Epoch: 305	Fidelity = 0.235297	KL_Divergence = 0.700650
# Epoch: 306	Fidelity = 0.235294	KL_Divergence = 0.700638
# Epoch: 307	Fidelity = 0.235289	KL_Divergence = 0.700625
# Epoch: 308	Fidelity = 0.235289	KL_Divergence = 0.700614
# Epoch: 309	Fidelity = 0.235290	KL_Divergence = 0.700603
# Epoch: 310	Fidelity = 0.235290	KL_Divergence = 0.700591
# Epoch: 311	Fidelity = 0.235288	KL_Divergence = 0.700580
# Epoch: 312	Fidelity = 0.235287	KL_Divergence = 0.700570
# Epoch: 313	Fidelity = 0.235285	KL_Divergence = 0.700559
# Epoch: 314	Fidelity = 0.235282	KL_Divergence = 0.700548
# Epoch: 315	Fidelity = 0.235278	KL_Divergence = 0.700537
# Epoch: 316	Fidelity = 0.235278	KL_Divergence = 0.700526
# Epoch: 317	Fidelity = 0.235276	KL_Divergence = 0.700516
# Epoch: 318	Fidelity = 0.235272	KL_Divergence = 0.700505
# Epoch: 319	Fidelity = 0.235268	KL_Divergence = 0.700493
# Epoch: 320	Fidelity = 0.235269	KL_Divergence = 0.700483
# Epoch: 321	Fidelity = 0.235270	KL_Divergence = 0.700474
# Epoch: 322	Fidelity = 0.235266	KL_Divergence = 0.700464
# Epoch: 323	Fidelity = 0.235268	KL_Divergence = 0.700455
# Epoch: 324	Fidelity = 0.235267	KL_Divergence = 0.700445
# Epoch: 325	Fidelity = 0.235263	KL_Divergence = 0.700435
# Epoch: 326	Fidelity = 0.235263	KL_Divergence = 0.700425
# Epoch: 327	Fidelity = 0.235255	KL_Divergence = 0.700414
# Epoch: 328	Fidelity = 0.235254	KL_Divergence = 0.700405
# Epoch: 329	Fidelity = 0.235251	KL_Divergence = 0.700395
# Epoch: 330	Fidelity = 0.235248	KL_Divergence = 0.700384
# Epoch: 331	Fidelity = 0.235244	KL_Divergence = 0.700374
# Epoch: 332	Fidelity = 0.235241	KL_Divergence = 0.700365
# Epoch: 333	Fidelity = 0.235234	KL_Divergence = 0.700354
# Epoch: 334	Fidelity = 0.235232	KL_Divergence = 0.700345
# Epoch: 335	Fidelity = 0.235228	KL_Divergence = 0.700336
# Epoch: 336	Fidelity = 0.235229	KL_Divergence = 0.700328
# Epoch: 337	Fidelity = 0.235224	KL_Divergence = 0.700318
# Epoch: 338	Fidelity = 0.235221	KL_Divergence = 0.700309
# Epoch: 339	Fidelity = 0.235220	KL_Divergence = 0.700300
# Epoch: 340	Fidelity = 0.235215	KL_Divergence = 0.700290
# Epoch: 341	Fidelity = 0.235214	KL_Divergence = 0.700282
# Epoch: 342	Fidelity = 0.235214	KL_Divergence = 0.700274
# Epoch: 343	Fidelity = 0.235212	KL_Divergence = 0.700266
# Epoch: 344	Fidelity = 0.235211	KL_Divergence = 0.700258
# Epoch: 345	Fidelity = 0.235210	KL_Divergence = 0.700250
# Epoch: 346	Fidelity = 0.235208	KL_Divergence = 0.700242
# Epoch: 347	Fidelity = 0.235207	KL_Divergence = 0.700234
# Epoch: 348	Fidelity = 0.235204	KL_Divergence = 0.700225
# Epoch: 349	Fidelity = 0.235202	KL_Divergence = 0.700217
# Epoch: 350	Fidelity = 0.235199	KL_Divergence = 0.700208
# Epoch: 351	Fidelity = 0.235199	KL_Divergence = 0.700201
# Epoch: 352	Fidelity = 0.235203	KL_Divergence = 0.700195
# Epoch: 353	Fidelity = 0.235200	KL_Divergence = 0.700187
# Epoch: 354	Fidelity = 0.235198	KL_Divergence = 0.700180
# Epoch: 355	Fidelity = 0.235197	KL_Divergence = 0.700173
# Epoch: 356	Fidelity = 0.235196	KL_Divergence = 0.700166
# Epoch: 357	Fidelity = 0.235196	KL_Divergence = 0.700159
# Epoch: 358	Fidelity = 0.235198	KL_Divergence = 0.700152
# ...
# Epoch: 217	Fidelity = 0.579279	KL_Divergence = 0.345751
# Epoch: 218	Fidelity = 0.579709	KL_Divergence = 0.345483
# Epoch: 219	Fidelity = 0.580118	KL_Divergence = 0.345230
# Epoch: 220	Fidelity = 0.580554	KL_Divergence = 0.344960
# Epoch: 221	Fidelity = 0.580951	KL_Divergence = 0.344714
# Epoch: 222	Fidelity = 0.581347	KL_Divergence = 0.344461
# Epoch: 223	Fidelity = 0.581745	KL_Divergence = 0.344211
# Epoch: 224	Fidelity = 0.582154	KL_Divergence = 0.343961
# Epoch: 225	Fidelity = 0.582549	KL_Divergence = 0.343711
# Epoch: 226	Fidelity = 0.582956	KL_Divergence = 0.343450
# Epoch: 227	Fidelity = 0.583366	KL_Divergence = 0.343194
# Epoch: 228	Fidelity = 0.583779	KL_Divergence = 0.342939
# Epoch: 229	Fidelity = 0.584183	KL_Divergence = 0.342681
# Epoch: 230	Fidelity = 0.584617	KL_Divergence = 0.342404
# Epoch: 231	Fidelity = 0.585012	KL_Divergence = 0.342147
# Epoch: 232	Fidelity = 0.585400	KL_Divergence = 0.341898
# Epoch: 233	Fidelity = 0.585774	KL_Divergence = 0.341662
# Epoch: 234	Fidelity = 0.586158	KL_Divergence = 0.341419
# Epoch: 235	Fidelity = 0.586550	KL_Divergence = 0.341167
# Epoch: 236	Fidelity = 0.586933	KL_Divergence = 0.340923
# Epoch: 237	Fidelity = 0.587309	KL_Divergence = 0.340679
# Epoch: 238	Fidelity = 0.587713	KL_Divergence = 0.340409
# Epoch: 239	Fidelity = 0.588110	KL_Divergence = 0.340147
# Epoch: 240	Fidelity = 0.588502	KL_Divergence = 0.339896
# Epoch: 241	Fidelity = 0.588845	KL_Divergence = 0.339666
# Epoch: 242	Fidelity = 0.589217	KL_Divergence = 0.339411
# Epoch: 243	Fidelity = 0.589592	KL_Divergence = 0.339162
# Epoch: 244	Fidelity = 0.589961	KL_Divergence = 0.338927
# Epoch: 245	Fidelity = 0.590337	KL_Divergence = 0.338680
# Epoch: 246	Fidelity = 0.590706	KL_Divergence = 0.338433
# Epoch: 247	Fidelity = 0.591074	KL_Divergence = 0.338190
# Epoch: 248	Fidelity = 0.591449	KL_Divergence = 0.337939
# Epoch: 249	Fidelity = 0.591825	KL_Divergence = 0.337685
# Epoch: 250	Fidelity = 0.592192	KL_Divergence = 0.337443
# Epoch: 251	Fidelity = 0.592518	KL_Divergence = 0.337226
# Epoch: 252	Fidelity = 0.592848	KL_Divergence = 0.337012
# Epoch: 253	Fidelity = 0.593190	KL_Divergence = 0.336784
# Epoch: 254	Fidelity = 0.593526	KL_Divergence = 0.336561
# Epoch: 255	Fidelity = 0.593867	KL_Divergence = 0.336336
# Epoch: 256	Fidelity = 0.594212	KL_Divergence = 0.336104
# Epoch: 257	Fidelity = 0.594547	KL_Divergence = 0.335874
# Epoch: 258	Fidelity = 0.594900	KL_Divergence = 0.335633
# Epoch: 259	Fidelity = 0.595245	KL_Divergence = 0.335403
# Epoch: 260	Fidelity = 0.595592	KL_Divergence = 0.335171
# Epoch: 261	Fidelity = 0.595895	KL_Divergence = 0.334969
# Epoch: 262	Fidelity = 0.596190	KL_Divergence = 0.334774
# Epoch: 263	Fidelity = 0.596483	KL_Divergence = 0.334575
# Epoch: 264	Fidelity = 0.596787	KL_Divergence = 0.334370
# Epoch: 265	Fidelity = 0.597093	KL_Divergence = 0.334155
# Epoch: 266	Fidelity = 0.597408	KL_Divergence = 0.333939
# Epoch: 267	Fidelity = 0.597721	KL_Divergence = 0.333728
# Epoch: 268	Fidelity = 0.598027	KL_Divergence = 0.333519
# Epoch: 269	Fidelity = 0.598350	KL_Divergence = 0.333305
# Epoch: 270	Fidelity = 0.598667	KL_Divergence = 0.333089
# Epoch: 271	Fidelity = 0.598948	KL_Divergence = 0.332895
# Epoch: 272	Fidelity = 0.599230	KL_Divergence = 0.332708
# Epoch: 273	Fidelity = 0.599520	KL_Divergence = 0.332503
# Epoch: 274	Fidelity = 0.599810	KL_Divergence = 0.332306
# Epoch: 275	Fidelity = 0.600111	KL_Divergence = 0.332098
# Epoch: 276	Fidelity = 0.600410	KL_Divergence = 0.331894
# Epoch: 277	Fidelity = 0.600705	KL_Divergence = 0.331690
# Epoch: 278	Fidelity = 0.600997	KL_Divergence = 0.331488
# Epoch: 279	Fidelity = 0.601289	KL_Divergence = 0.331282
# Epoch: 280	Fidelity = 0.601578	KL_Divergence = 0.331082
# Epoch: 281	Fidelity = 0.601843	KL_Divergence = 0.330898
# Epoch: 282	Fidelity = 0.602100	KL_Divergence = 0.330722
# Epoch: 283	Fidelity = 0.602362	KL_Divergence = 0.330543
# Epoch: 284	Fidelity = 0.602627	KL_Divergence = 0.330363
# Epoch: 285	Fidelity = 0.602886	KL_Divergence = 0.330183
# Epoch: 286	Fidelity = 0.603157	KL_Divergence = 0.329992
# Epoch: 287	Fidelity = 0.603430	KL_Divergence = 0.329800
# Epoch: 288	Fidelity = 0.603718	KL_Divergence = 0.329600
# Epoch: 289	Fidelity = 0.603996	KL_Divergence = 0.329409
# Epoch: 290	Fidelity = 0.604268	KL_Divergence = 0.329216
# Epoch: 291	Fidelity = 0.604517	KL_Divergence = 0.329044
# Epoch: 292	Fidelity = 0.604758	KL_Divergence = 0.328872
# Epoch: 293	Fidelity = 0.605004	KL_Divergence = 0.328697
# Epoch: 294	Fidelity = 0.605259	KL_Divergence = 0.328514
# Epoch: 295	Fidelity = 0.605504	KL_Divergence = 0.328340
# Epoch: 296	Fidelity = 0.605753	KL_Divergence = 0.328163
# Epoch: 297	Fidelity = 0.606005	KL_Divergence = 0.327983
# Epoch: 298	Fidelity = 0.606254	KL_Divergence = 0.327806
# Epoch: 299	Fidelity = 0.606502	KL_Divergence = 0.327632
# Epoch: 300	Fidelity = 0.606751	KL_Divergence = 0.327457
# Epoch: 301	Fidelity = 0.606980	KL_Divergence = 0.327297
# Epoch: 302	Fidelity = 0.607206	KL_Divergence = 0.327139
# Epoch: 303	Fidelity = 0.607437	KL_Divergence = 0.326969
# Epoch: 304	Fidelity = 0.607670	KL_Divergence = 0.326800
# Epoch: 305	Fidelity = 0.607896	KL_Divergence = 0.326643
# Epoch: 306	Fidelity = 0.608123	KL_Divergence = 0.326482
# Epoch: 307	Fidelity = 0.608354	KL_Divergence = 0.326316
# Epoch: 308	Fidelity = 0.608569	KL_Divergence = 0.326162
# Epoch: 309	Fidelity = 0.608800	KL_Divergence = 0.325997
# Epoch: 310	Fidelity = 0.609026	KL_Divergence = 0.325837
# Epoch: 311	Fidelity = 0.609230	KL_Divergence = 0.325692
# Epoch: 312	Fidelity = 0.609439	KL_Divergence = 0.325544
# Epoch: 313	Fidelity = 0.609648	KL_Divergence = 0.325396
# Epoch: 314	Fidelity = 0.609864	KL_Divergence = 0.325241
# Epoch: 315	Fidelity = 0.610076	KL_Divergence = 0.325087
# Epoch: 316	Fidelity = 0.610288	KL_Divergence = 0.324935
# Epoch: 317	Fidelity = 0.610503	KL_Divergence = 0.324782
# Epoch: 318	Fidelity = 0.610718	KL_Divergence = 0.324627
# Epoch: 319	Fidelity = 0.610931	KL_Divergence = 0.324477
# Epoch: 320	Fidelity = 0.611142	KL_Divergence = 0.324329
# Epoch: 321	Fidelity = 0.611328	KL_Divergence = 0.324196
# Epoch: 322	Fidelity = 0.611518	KL_Divergence = 0.324059
# Epoch: 323	Fidelity = 0.611714	KL_Divergence = 0.323918
# Epoch: 324	Fidelity = 0.611910	KL_Divergence = 0.323776
# Epoch: 325	Fidelity = 0.612100	KL_Divergence = 0.323639
# Epoch: 326	Fidelity = 0.612288	KL_Divergence = 0.323501
# Epoch: 327	Fidelity = 0.612478	KL_Divergence = 0.323364
# Epoch: 328	Fidelity = 0.612666	KL_Divergence = 0.323226
# Epoch: 329	Fidelity = 0.612850	KL_Divergence = 0.323095
# Epoch: 330	Fidelity = 0.613037	KL_Divergence = 0.322961
# Epoch: 331	Fidelity = 0.613211	KL_Divergence = 0.322836
# Epoch: 332	Fidelity = 0.613378	KL_Divergence = 0.322716
# Epoch: 333	Fidelity = 0.613549	KL_Divergence = 0.322590
# Epoch: 334	Fidelity = 0.613723	KL_Divergence = 0.322464
# Epoch: 335	Fidelity = 0.613898	KL_Divergence = 0.322336
# Epoch: 336	Fidelity = 0.614072	KL_Divergence = 0.322210
# Epoch: 337	Fidelity = 0.614240	KL_Divergence = 0.322087
# Epoch: 338	Fidelity = 0.614412	KL_Divergence = 0.321962
# Epoch: 339	Fidelity = 0.614588	KL_Divergence = 0.321836
# Epoch: 340	Fidelity = 0.614767	KL_Divergence = 0.321707
# Epoch: 341	Fidelity = 0.614929	KL_Divergence = 0.321589
# Epoch: 342	Fidelity = 0.615084	KL_Divergence = 0.321479
# Epoch: 343	Fidelity = 0.615239	KL_Divergence = 0.321364
# Epoch: 344	Fidelity = 0.615397	KL_Divergence = 0.321246
# Epoch: 345	Fidelity = 0.615558	KL_Divergence = 0.321129
# Epoch: 346	Fidelity = 0.615718	KL_Divergence = 0.321011
# Epoch: 347	Fidelity = 0.615878	KL_Divergence = 0.320894
# Epoch: 348	Fidelity = 0.616039	KL_Divergence = 0.320777
# Epoch: 349	Fidelity = 0.616198	KL_Divergence = 0.320661
# Epoch: 350	Fidelity = 0.616351	KL_Divergence = 0.320548
# Epoch: 351	Fidelity = 0.616488	KL_Divergence = 0.320450
# Epoch: 352	Fidelity = 0.616630	KL_Divergence = 0.320347
# Epoch: 353	Fidelity = 0.616777	KL_Divergence = 0.320237
# Epoch: 354	Fidelity = 0.616922	KL_Divergence = 0.320132
# Epoch: 355	Fidelity = 0.617065	KL_Divergence = 0.320025
# Epoch: 356	Fidelity = 0.617213	KL_Divergence = 0.319916
# Epoch: 357	Fidelity = 0.617355	KL_Divergence = 0.319812
# Epoch: 358	Fidelity = 0.617501	KL_Divergence = 0.319705
# Epoch: 359	Fidelity = 0.617643	KL_Divergence = 0.319602
# Epoch: 360	Fidelity = 0.617787	KL_Divergence = 0.319496
# Epoch: 361	Fidelity = 0.617918	KL_Divergence = 0.319399
# Epoch: 362	Fidelity = 0.618052	KL_Divergence = 0.319300
# Epoch: 363	Fidelity = 0.618187	KL_Divergence = 0.319202
# Epoch: 364	Fidelity = 0.618317	KL_Divergence = 0.319106
# Epoch: 365	Fidelity = 0.618451	KL_Divergence = 0.319008
# Epoch: 366	Fidelity = 0.618586	KL_Divergence = 0.318908
# Epoch: 367	Fidelity = 0.618724	KL_Divergence = 0.318807
# Epoch: 368	Fidelity = 0.618863	KL_Divergence = 0.318703
# Epoch: 369	Fidelity = 0.618995	KL_Divergence = 0.318607
# Epoch: 370	Fidelity = 0.619137	KL_Divergence = 0.318502
# Epoch: 371	Fidelity = 0.619260	KL_Divergence = 0.318411
# Epoch: 372	Fidelity = 0.619379	KL_Divergence = 0.318323
# Epoch: 373	Fidelity = 0.619500	KL_Divergence = 0.318233
# Epoch: 374	Fidelity = 0.619623	KL_Divergence = 0.318143
# Epoch: 375	Fidelity = 0.619746	KL_Divergence = 0.318053
# Epoch: 376	Fidelity = 0.619868	KL_Divergence = 0.317962
# Epoch: 377	Fidelity = 0.619992	KL_Divergence = 0.317870
# Epoch: 378	Fidelity = 0.620115	KL_Divergence = 0.317779
# Epoch: 379	Fidelity = 0.620237	KL_Divergence = 0.317687
# Epoch: 380	Fidelity = 0.620358	KL_Divergence = 0.317598
# Epoch: 381	Fidelity = 0.620467	KL_Divergence = 0.317518
# Epoch: 382	Fidelity = 0.620575	KL_Divergence = 0.317438
# Epoch: 383	Fidelity = 0.620686	KL_Divergence = 0.317356
# Epoch: 384	Fidelity = 0.620793	KL_Divergence = 0.317277
# Epoch: 385	Fidelity = 0.620902	KL_Divergence = 0.317195
# Epoch: 386	Fidelity = 0.621014	KL_Divergence = 0.317111
# Epoch: 387	Fidelity = 0.621122	KL_Divergence = 0.317030
# Epoch: 388	Fidelity = 0.621226	KL_Divergence = 0.316954
# Epoch: 389	Fidelity = 0.621330	KL_Divergence = 0.316877
# Epoch: 390	Fidelity = 0.621437	KL_Divergence = 0.316797
# Epoch: 391	Fidelity = 0.621536	KL_Divergence = 0.316723
# Epoch: 392	Fidelity = 0.621632	KL_Divergence = 0.316651
# Epoch: 393	Fidelity = 0.621730	KL_Divergence = 0.316577
# Epoch: 394	Fidelity = 0.621824	KL_Divergence = 0.316508
# Epoch: 395	Fidelity = 0.621919	KL_Divergence = 0.316439
# Epoch: 396	Fidelity = 0.622015	KL_Divergence = 0.316368
# Epoch: 397	Fidelity = 0.622113	KL_Divergence = 0.316295
# Epoch: 398	Fidelity = 0.622213	KL_Divergence = 0.316221
# Epoch: 399	Fidelity = 0.622313	KL_Divergence = 0.316147
# Epoch: 400	Fidelity = 0.622411	KL_Divergence = 0.316074
# Epoch: 401	Fidelity = 0.622501	KL_Divergence = 0.316007
# Epoch: 402	Fidelity = 0.622590	KL_Divergence = 0.315941
# Epoch: 403	Fidelity = 0.622679	KL_Divergence = 0.315874
# Epoch: 404	Fidelity = 0.622770	KL_Divergence = 0.315807
# Epoch: 405	Fidelity = 0.622860	KL_Divergence = 0.315740
# Epoch: 406	Fidelity = 0.622948	KL_Divergence = 0.315674
# Epoch: 407	Fidelity = 0.623039	KL_Divergence = 0.315606
# Epoch: 408	Fidelity = 0.623129	KL_Divergence = 0.315539
# Epoch: 409	Fidelity = 0.623220	KL_Divergence = 0.315469
# Epoch: 410	Fidelity = 0.623308	KL_Divergence = 0.315403
# Epoch: 411	Fidelity = 0.623390	KL_Divergence = 0.315342
# Epoch: 412	Fidelity = 0.623474	KL_Divergence = 0.315280
# Epoch: 413	Fidelity = 0.623557	KL_Divergence = 0.315217
# Epoch: 414	Fidelity = 0.623641	KL_Divergence = 0.315154
# Epoch: 415	Fidelity = 0.623722	KL_Divergence = 0.315094
# Epoch: 416	Fidelity = 0.623800	KL_Divergence = 0.315036
# Epoch: 417	Fidelity = 0.623881	KL_Divergence = 0.314976
# Epoch: 418	Fidelity = 0.623959	KL_Divergence = 0.314916
# Epoch: 419	Fidelity = 0.624041	KL_Divergence = 0.314855
# Epoch: 420	Fidelity = 0.624122	KL_Divergence = 0.314795
# Epoch: 421	Fidelity = 0.624194	KL_Divergence = 0.314740
# Epoch: 422	Fidelity = 0.624267	KL_Divergence = 0.314685
# Epoch: 423	Fidelity = 0.624341	KL_Divergence = 0.314630
# Epoch: 424	Fidelity = 0.624414	KL_Divergence = 0.314575
# Epoch: 425	Fidelity = 0.624485	KL_Divergence = 0.314522
# Epoch: 426	Fidelity = 0.624560	KL_Divergence = 0.314467
# Epoch: 427	Fidelity = 0.624634	KL_Divergence = 0.314411
# Epoch: 428	Fidelity = 0.624708	KL_Divergence = 0.314356
# Epoch: 429	Fidelity = 0.624781	KL_Divergence = 0.314301
# Epoch: 430	Fidelity = 0.624856	KL_Divergence = 0.314244
# Epoch: 431	Fidelity = 0.624924	KL_Divergence = 0.314193
# Epoch: 432	Fidelity = 0.624992	KL_Divergence = 0.314142
# Epoch: 433	Fidelity = 0.625063	KL_Divergence = 0.314088
# Epoch: 434	Fidelity = 0.625130	KL_Divergence = 0.314037
# Epoch: 435	Fidelity = 0.625198	KL_Divergence = 0.313986
# Epoch: 436	Fidelity = 0.625265	KL_Divergence = 0.313936
# Epoch: 437	Fidelity = 0.625333	KL_Divergence = 0.313885
# Epoch: 438	Fidelity = 0.625402	KL_Divergence = 0.313834
# Epoch: 439	Fidelity = 0.625471	KL_Divergence = 0.313783
# Epoch: 440	Fidelity = 0.625538	KL_Divergence = 0.313733
# Epoch: 441	Fidelity = 0.625599	KL_Divergence = 0.313688
# Epoch: 442	Fidelity = 0.625658	KL_Divergence = 0.313643
# Epoch: 443	Fidelity = 0.625717	KL_Divergence = 0.313599
# Epoch: 444	Fidelity = 0.625775	KL_Divergence = 0.313555
# Epoch: 445	Fidelity = 0.625833	KL_Divergence = 0.313510
# Epoch: 446	Fidelity = 0.625891	KL_Divergence = 0.313467
# Epoch: 447	Fidelity = 0.625949	KL_Divergence = 0.313423
# Epoch: 448	Fidelity = 0.626008	KL_Divergence = 0.313378
# Epoch: 449	Fidelity = 0.626066	KL_Divergence = 0.313335
# Epoch: 450	Fidelity = 0.626128	KL_Divergence = 0.313288
# Epoch: 451	Fidelity = 0.626183	KL_Divergence = 0.313246
# Epoch: 452	Fidelity = 0.626237	KL_Divergence = 0.313205
# Epoch: 453	Fidelity = 0.626288	KL_Divergence = 0.313166
# Epoch: 454	Fidelity = 0.626344	KL_Divergence = 0.313125
# Epoch: 455	Fidelity = 0.626396	KL_Divergence = 0.313086
# Epoch: 456	Fidelity = 0.626450	KL_Divergence = 0.313045
# Epoch: 457	Fidelity = 0.626506	KL_Divergence = 0.313003
# Epoch: 458	Fidelity = 0.626559	KL_Divergence = 0.312963
# Epoch: 459	Fidelity = 0.626614	KL_Divergence = 0.312922
# Epoch: 460	Fidelity = 0.626667	KL_Divergence = 0.312882
# Epoch: 461	Fidelity = 0.626715	KL_Divergence = 0.312845
# Epoch: 462	Fidelity = 0.626763	KL_Divergence = 0.312809
# Epoch: 463	Fidelity = 0.626809	KL_Divergence = 0.312774
# Epoch: 464	Fidelity = 0.626857	KL_Divergence = 0.312737
# Epoch: 465	Fidelity = 0.626904	KL_Divergence = 0.312702
# Epoch: 466	Fidelity = 0.626951	KL_Divergence = 0.312666
# Epoch: 467	Fidelity = 0.626999	KL_Divergence = 0.312630
# Epoch: 468	Fidelity = 0.627048	KL_Divergence = 0.312593
# Epoch: 469	Fidelity = 0.627096	KL_Divergence = 0.312556
# Epoch: 470	Fidelity = 0.627144	KL_Divergence = 0.312520
# Epoch: 471	Fidelity = 0.627187	KL_Divergence = 0.312488
# Epoch: 472	Fidelity = 0.627230	KL_Divergence = 0.312455
# Epoch: 473	Fidelity = 0.627272	KL_Divergence = 0.312424
# Epoch: 474	Fidelity = 0.627316	KL_Divergence = 0.312390
# Epoch: 475	Fidelity = 0.627360	KL_Divergence = 0.312356
# Epoch: 476	Fidelity = 0.627404	KL_Divergence = 0.312323
# Epoch: 477	Fidelity = 0.627449	KL_Divergence = 0.312289
# Epoch: 478	Fidelity = 0.627493	KL_Divergence = 0.312257
# Epoch: 479	Fidelity = 0.627537	KL_Divergence = 0.312223
# Epoch: 480	Fidelity = 0.627581	KL_Divergence = 0.312189
# Epoch: 481	Fidelity = 0.627621	KL_Divergence = 0.312159
# Epoch: 482	Fidelity = 0.627661	KL_Divergence = 0.312129
# Epoch: 483	Fidelity = 0.627701	KL_Divergence = 0.312099
# Epoch: 484	Fidelity = 0.627740	KL_Divergence = 0.312069
# Epoch: 485	Fidelity = 0.627778	KL_Divergence = 0.312040
# Epoch: 486	Fidelity = 0.627817	KL_Divergence = 0.312011
# Epoch: 487	Fidelity = 0.627857	KL_Divergence = 0.311980
# Epoch: 488	Fidelity = 0.627896	KL_Divergence = 0.311951
# Epoch: 489	Fidelity = 0.627935	KL_Divergence = 0.311922
# Epoch: 490	Fidelity = 0.627974	KL_Divergence = 0.311892
# Epoch: 491	Fidelity = 0.628009	KL_Divergence = 0.311866
# Epoch: 492	Fidelity = 0.628043	KL_Divergence = 0.311840
# Epoch: 493	Fidelity = 0.628076	KL_Divergence = 0.311815
# Epoch: 494	Fidelity = 0.628111	KL_Divergence = 0.311789
# Epoch: 495	Fidelity = 0.628144	KL_Divergence = 0.311764
# Epoch: 496	Fidelity = 0.628179	KL_Divergence = 0.311737
# Epoch: 497	Fidelity = 0.628214	KL_Divergence = 0.311711
# Epoch: 498	Fidelity = 0.628249	KL_Divergence = 0.311684
# Epoch: 499	Fidelity = 0.628285	KL_Divergence = 0.311657
# Epoch: 500	Fidelity = 0.628320	KL_Divergence = 0.311631
# Total time elapsed during training: 27671.934 s
