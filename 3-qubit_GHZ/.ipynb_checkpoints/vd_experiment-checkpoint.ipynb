# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]
# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]
# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]
# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]
# data path info
train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
ideal_state_path = f"./target_state/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## caluculate ideal state

# %%
# calculate ideal state
is_ideal_state_file = os.path.exists(ideal_state_path)
if is_ideal_state_file:
    print("ideal state data is exsisted !")
else:
    print("caluculate ideal state data ...")
    os.makedirs(ideal_state_path, exist_ok = True)
    subprocess.run("python caluculate_ideal_state.py", shell=True)
    print("ideal state data is ready !")
# Out:
# ideal state data is exsisted !

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path)
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    subprocess.run("python generate_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# train data is exsisted !

# %% [markdown]
# ## load dataset

# %%
meas_pattern_path = train_data_path + "/measurement_pattern.txt"
meas_label_path = train_data_path + "/measurement_label.txt"
meas_result_path = train_data_path + "/measurement_result.txt"
ideal_rho_re_path = ideal_state_path + "/rho_real.txt"
ideal_rho_im_path = ideal_state_path + "/rho_imag.txt"
meas_result, ideal_rho, meas_label, meas_pattern = data.load_data_DM(meas_result_path,
                                                                     ideal_rho_re_path,
                                                                     ideal_rho_im_path,
                                                                     meas_label_path,
                                                                     meas_pattern_path)

# %% [markdown]
# ## build RBM architecture

# %%
nn_state_dm = DensityMatrix(
    num_visible = n_visible_unit, 
    num_hidden = n_hidden_unit, 
    num_aux = n_aux_unit, 
    unitary_dict = unitaries.create_dict(),
    gpu = False
)

# %% [markdown]
# ## estimate observable expectation value

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XXX():
    target_list = [0, 1, 2]
    pauli_index = [1, 1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZZ():
    target_list = [0, 1, 2]
    pauli_index = [1, 3, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_XXX_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "X", 2: "X"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_XZZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "Z", 2: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

# %% [markdown]
# ## callback setting

# %%
def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "KL_Divergence": ts.KL,
        "Observable_XXX_ev": observable_XXX_ev,
        "Observable_XZZ_ev": observable_XZZ_ev,
    }

    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = ideal_rho,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    return callbacks

callbacks = create_callback_dm(nn_state_dm)

# %% [markdown]
# ## train

# %%
nn_state_dm.fit(
    data = meas_result,
    input_bases = meas_label,
    epochs = epoch,
    pos_batch_size = pbs,
    neg_batch_size = nbs,
    lr = lr,
    k = n_gibbs_step,
    bases = meas_pattern,
    callbacks = callbacks,
    time = True,
    optimizer = torch.optim.Adadelta,
    scheduler = torch.optim.lr_scheduler.StepLR,
    scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
)
# Out:
# Epoch: 1	Fidelity = 0.376080	KL_Divergence = 0.387473	Observable_XXX_ev = 0.168953	Observable_XZZ_ev = 0.044451
# Epoch: 2	Fidelity = 0.388134	KL_Divergence = 0.287615	Observable_XXX_ev = 0.214322	Observable_XZZ_ev = 0.171458
# Epoch: 3	Fidelity = 0.422312	KL_Divergence = 0.269586	Observable_XXX_ev = 0.138395	Observable_XZZ_ev = 0.073644
# Epoch: 4	Fidelity = 0.416232	KL_Divergence = 0.228160	Observable_XXX_ev = 0.139947	Observable_XZZ_ev = 0.215918
# Epoch: 5	Fidelity = 0.436874	KL_Divergence = 0.171824	Observable_XXX_ev = 0.143496	Observable_XZZ_ev = 0.021570
# Epoch: 6	Fidelity = 0.445480	KL_Divergence = 0.214242	Observable_XXX_ev = 0.136846	Observable_XZZ_ev = 0.174271
# Epoch: 7	Fidelity = 0.462774	KL_Divergence = 0.125114	Observable_XXX_ev = 0.146178	Observable_XZZ_ev = 0.038640
# Epoch: 8	Fidelity = 0.469768	KL_Divergence = 0.177168	Observable_XXX_ev = 0.116016	Observable_XZZ_ev = 0.066087
# Epoch: 9	Fidelity = 0.478106	KL_Divergence = 0.130385	Observable_XXX_ev = 0.129604	Observable_XZZ_ev = 0.079262
# Epoch: 10	Fidelity = 0.484788	KL_Divergence = 0.117432	Observable_XXX_ev = 0.145979	Observable_XZZ_ev = 0.015168
# Epoch: 11	Fidelity = 0.487686	KL_Divergence = 0.119862	Observable_XXX_ev = 0.193982	Observable_XZZ_ev = 0.034207
# Epoch: 12	Fidelity = 0.492643	KL_Divergence = 0.110575	Observable_XXX_ev = 0.173409	Observable_XZZ_ev = 0.027340
# Epoch: 13	Fidelity = 0.495493	KL_Divergence = 0.109796	Observable_XXX_ev = 0.195081	Observable_XZZ_ev = 0.034141
# Epoch: 14	Fidelity = 0.498790	KL_Divergence = 0.107702	Observable_XXX_ev = 0.186795	Observable_XZZ_ev = 0.022806
# Epoch: 15	Fidelity = 0.501993	KL_Divergence = 0.107636	Observable_XXX_ev = 0.203238	Observable_XZZ_ev = 0.003129
# Epoch: 16	Fidelity = 0.505837	KL_Divergence = 0.105822	Observable_XXX_ev = 0.185539	Observable_XZZ_ev = 0.003760
# Epoch: 17	Fidelity = 0.510766	KL_Divergence = 0.106616	Observable_XXX_ev = 0.212861	Observable_XZZ_ev = 0.004971
# Epoch: 18	Fidelity = 0.517764	KL_Divergence = 0.103433	Observable_XXX_ev = 0.243351	Observable_XZZ_ev = 0.011548
# Epoch: 19	Fidelity = 0.526320	KL_Divergence = 0.108367	Observable_XXX_ev = 0.314378	Observable_XZZ_ev = -0.013261
# Epoch: 20	Fidelity = 0.535195	KL_Divergence = 0.113855	Observable_XXX_ev = 0.341816	Observable_XZZ_ev = 0.005656
# Epoch: 21	Fidelity = 0.545909	KL_Divergence = 0.130854	Observable_XXX_ev = 0.367186	Observable_XZZ_ev = -0.003229
# Epoch: 22	Fidelity = 0.564848	KL_Divergence = 0.121771	Observable_XXX_ev = 0.586035	Observable_XZZ_ev = -0.015152
# Epoch: 23	Fidelity = 0.590439	KL_Divergence = 0.091935	Observable_XXX_ev = 0.452812	Observable_XZZ_ev = -0.019000
# Epoch: 24	Fidelity = 0.621858	KL_Divergence = 0.080654	Observable_XXX_ev = 0.806724	Observable_XZZ_ev = -0.028574
# Epoch: 25	Fidelity = 0.643431	KL_Divergence = 0.085814	Observable_XXX_ev = 0.575363	Observable_XZZ_ev = -0.032074
# Epoch: 26	Fidelity = 0.681953	KL_Divergence = 0.069391	Observable_XXX_ev = 0.694812	Observable_XZZ_ev = -0.027127
# Epoch: 27	Fidelity = 0.704138	KL_Divergence = 0.082751	Observable_XXX_ev = 0.709826	Observable_XZZ_ev = -0.029074
# Epoch: 28	Fidelity = 0.735614	KL_Divergence = 0.063624	Observable_XXX_ev = 0.805513	Observable_XZZ_ev = -0.060575
# Epoch: 29	Fidelity = 0.750727	KL_Divergence = 0.078577	Observable_XXX_ev = 0.928105	Observable_XZZ_ev = -0.037893
# Epoch: 30	Fidelity = 0.755445	KL_Divergence = 0.058704	Observable_XXX_ev = 0.923768	Observable_XZZ_ev = -0.045757
# Epoch: 31	Fidelity = 0.784969	KL_Divergence = 0.058983	Observable_XXX_ev = 0.949129	Observable_XZZ_ev = -0.036131
# Epoch: 32	Fidelity = 0.824357	KL_Divergence = 0.042988	Observable_XXX_ev = 1.003372	Observable_XZZ_ev = -0.022558
# Epoch: 33	Fidelity = 0.838105	KL_Divergence = 0.044197	Observable_XXX_ev = 0.938922	Observable_XZZ_ev = -0.046711
# Epoch: 34	Fidelity = 0.826621	KL_Divergence = 0.071102	Observable_XXX_ev = 0.870693	Observable_XZZ_ev = -0.016107
# Epoch: 35	Fidelity = 0.865734	KL_Divergence = 0.032384	Observable_XXX_ev = 0.998070	Observable_XZZ_ev = -0.024143
# Epoch: 36	Fidelity = 0.867419	KL_Divergence = 0.056166	Observable_XXX_ev = 0.814295	Observable_XZZ_ev = -0.011334
# Epoch: 37	Fidelity = 0.889797	KL_Divergence = 0.030296	Observable_XXX_ev = 1.027017	Observable_XZZ_ev = -0.017016
# Epoch: 38	Fidelity = 0.868549	KL_Divergence = 0.070752	Observable_XXX_ev = 0.748609	Observable_XZZ_ev = -0.034544
# Epoch: 39	Fidelity = 0.905384	KL_Divergence = 0.025522	Observable_XXX_ev = 0.954562	Observable_XZZ_ev = -0.038655
# Epoch: 40	Fidelity = 0.916963	KL_Divergence = 0.019959	Observable_XXX_ev = 1.011376	Observable_XZZ_ev = -0.032840
# Epoch: 41	Fidelity = 0.916849	KL_Divergence = 0.026198	Observable_XXX_ev = 1.003417	Observable_XZZ_ev = -0.017613
# Epoch: 42	Fidelity = 0.922022	KL_Divergence = 0.021560	Observable_XXX_ev = 1.108801	Observable_XZZ_ev = -0.030614
# Epoch: 43	Fidelity = 0.912682	KL_Divergence = 0.045072	Observable_XXX_ev = 1.098095	Observable_XZZ_ev = -0.026164
# Epoch: 44	Fidelity = 0.885254	KL_Divergence = 0.096636	Observable_XXX_ev = 0.810022	Observable_XZZ_ev = -0.041576
# Epoch: 45	Fidelity = 0.926600	KL_Divergence = 0.023131	Observable_XXX_ev = 0.967402	Observable_XZZ_ev = -0.038140
# Epoch: 46	Fidelity = 0.929788	KL_Divergence = 0.017682	Observable_XXX_ev = 0.980439	Observable_XZZ_ev = -0.016634
# Epoch: 47	Fidelity = 0.867634	KL_Divergence = 0.132080	Observable_XXX_ev = 0.700524	Observable_XZZ_ev = -0.010376
# Epoch: 48	Fidelity = 0.918859	KL_Divergence = 0.028874	Observable_XXX_ev = 1.004118	Observable_XZZ_ev = -0.015177
# Epoch: 49	Fidelity = 0.923180	KL_Divergence = 0.038536	Observable_XXX_ev = 1.022698	Observable_XZZ_ev = -0.015311
# Epoch: 50	Fidelity = 0.926861	KL_Divergence = 0.026367	Observable_XXX_ev = 0.983634	Observable_XZZ_ev = -0.025056
# Epoch: 51	Fidelity = 0.859138	KL_Divergence = 0.152316	Observable_XXX_ev = 0.817514	Observable_XZZ_ev = -0.024676
# Epoch: 52	Fidelity = 0.898778	KL_Divergence = 0.079781	Observable_XXX_ev = 0.929772	Observable_XZZ_ev = -0.020117
# Epoch: 53	Fidelity = 0.929954	KL_Divergence = 0.019313	Observable_XXX_ev = 0.893317	Observable_XZZ_ev = -0.008760
# Epoch: 54	Fidelity = 0.902501	KL_Divergence = 0.069704	Observable_XXX_ev = 0.890797	Observable_XZZ_ev = -0.018955
# Epoch: 55	Fidelity = 0.884278	KL_Divergence = 0.096552	Observable_XXX_ev = 0.956271	Observable_XZZ_ev = -0.014455
# Epoch: 56	Fidelity = 0.921325	KL_Divergence = 0.047859	Observable_XXX_ev = 0.954748	Observable_XZZ_ev = -0.025438
# Epoch: 57	Fidelity = 0.938696	KL_Divergence = 0.018668	Observable_XXX_ev = 1.002803	Observable_XZZ_ev = -0.008187
# Epoch: 58	Fidelity = 0.931682	KL_Divergence = 0.031919	Observable_XXX_ev = 1.023270	Observable_XZZ_ev = -0.015963
# Epoch: 59	Fidelity = 0.934842	KL_Divergence = 0.025092	Observable_XXX_ev = 0.959579	Observable_XZZ_ev = -0.007965
# Epoch: 60	Fidelity = 0.932711	KL_Divergence = 0.018696	Observable_XXX_ev = 1.028420	Observable_XZZ_ev = -0.007948
# Epoch: 61	Fidelity = 0.924310	KL_Divergence = 0.040617	Observable_XXX_ev = 1.011467	Observable_XZZ_ev = -0.020315
# Epoch: 62	Fidelity = 0.930953	KL_Divergence = 0.033768	Observable_XXX_ev = 0.940345	Observable_XZZ_ev = -0.027947
# Epoch: 63	Fidelity = 0.878173	KL_Divergence = 0.128430	Observable_XXX_ev = 0.845420	Observable_XZZ_ev = -0.012426
# Epoch: 64	Fidelity = 0.925215	KL_Divergence = 0.044370	Observable_XXX_ev = 0.968064	Observable_XZZ_ev = -0.008326
# Epoch: 65	Fidelity = 0.906898	KL_Divergence = 0.075138	Observable_XXX_ev = 0.781035	Observable_XZZ_ev = -0.007526
# Epoch: 66	Fidelity = 0.939283	KL_Divergence = 0.017342	Observable_XXX_ev = 0.985731	Observable_XZZ_ev = -0.015483
# Epoch: 67	Fidelity = 0.920986	KL_Divergence = 0.042596	Observable_XXX_ev = 0.911676	Observable_XZZ_ev = -0.023184
# Epoch: 68	Fidelity = 0.903095	KL_Divergence = 0.080908	Observable_XXX_ev = 0.889173	Observable_XZZ_ev = -0.007050
# Epoch: 69	Fidelity = 0.939026	KL_Divergence = 0.020893	Observable_XXX_ev = 0.922810	Observable_XZZ_ev = -0.006972
# Epoch: 70	Fidelity = 0.908331	KL_Divergence = 0.073876	Observable_XXX_ev = 0.954610	Observable_XZZ_ev = -0.014952
# Epoch: 71	Fidelity = 0.910963	KL_Divergence = 0.067367	Observable_XXX_ev = 1.022152	Observable_XZZ_ev = -0.009915
# Epoch: 72	Fidelity = 0.923758	KL_Divergence = 0.047116	Observable_XXX_ev = 0.917517	Observable_XZZ_ev = -0.010472
# Epoch: 73	Fidelity = 0.942693	KL_Divergence = 0.016197	Observable_XXX_ev = 0.918019	Observable_XZZ_ev = -0.012920
# Epoch: 74	Fidelity = 0.882112	KL_Divergence = 0.125631	Observable_XXX_ev = 0.788865	Observable_XZZ_ev = -0.006428
# Epoch: 75	Fidelity = 0.883784	KL_Divergence = 0.118787	Observable_XXX_ev = 0.817334	Observable_XZZ_ev = -0.021666
# Epoch: 76	Fidelity = 0.917339	KL_Divergence = 0.057930	Observable_XXX_ev = 0.969245	Observable_XZZ_ev = -0.006727
# Epoch: 77	Fidelity = 0.934384	KL_Divergence = 0.030763	Observable_XXX_ev = 1.027651	Observable_XZZ_ev = -0.012927
# Epoch: 78	Fidelity = 0.931563	KL_Divergence = 0.034871	Observable_XXX_ev = 0.865438	Observable_XZZ_ev = -0.013455
# Epoch: 79	Fidelity = 0.871490	KL_Divergence = 0.141825	Observable_XXX_ev = 0.856749	Observable_XZZ_ev = -0.015276
# Epoch: 80	Fidelity = 0.890937	KL_Divergence = 0.104004	Observable_XXX_ev = 0.887340	Observable_XZZ_ev = -0.017383
# Epoch: 81	Fidelity = 0.941907	KL_Divergence = 0.015516	Observable_XXX_ev = 1.085961	Observable_XZZ_ev = -0.005805
# Epoch: 82	Fidelity = 0.910199	KL_Divergence = 0.069105	Observable_XXX_ev = 0.924993	Observable_XZZ_ev = -0.013413
# Epoch: 83	Fidelity = 0.935899	KL_Divergence = 0.028129	Observable_XXX_ev = 0.984361	Observable_XZZ_ev = -0.015930
# Epoch: 84	Fidelity = 0.940261	KL_Divergence = 0.019648	Observable_XXX_ev = 0.980077	Observable_XZZ_ev = -0.007594
# Epoch: 85	Fidelity = 0.873979	KL_Divergence = 0.138496	Observable_XXX_ev = 0.814716	Observable_XZZ_ev = -0.008420
# Epoch: 86	Fidelity = 0.941973	KL_Divergence = 0.015811	Observable_XXX_ev = 1.016425	Observable_XZZ_ev = -0.010483
# Epoch: 87	Fidelity = 0.931515	KL_Divergence = 0.036299	Observable_XXX_ev = 0.976572	Observable_XZZ_ev = -0.037540
# Epoch: 88	Fidelity = 0.943452	KL_Divergence = 0.016792	Observable_XXX_ev = 1.035810	Observable_XZZ_ev = -0.006899
# Epoch: 89	Fidelity = 0.937103	KL_Divergence = 0.026298	Observable_XXX_ev = 0.982930	Observable_XZZ_ev = -0.011078
# Epoch: 90	Fidelity = 0.944480	KL_Divergence = 0.016797	Observable_XXX_ev = 1.070718	Observable_XZZ_ev = -0.013972
# Epoch: 91	Fidelity = 0.922873	KL_Divergence = 0.044078	Observable_XXX_ev = 0.947178	Observable_XZZ_ev = -0.011693
# Epoch: 92	Fidelity = 0.927259	KL_Divergence = 0.044164	Observable_XXX_ev = 0.950751	Observable_XZZ_ev = -0.008613
# Epoch: 93	Fidelity = 0.933491	KL_Divergence = 0.033382	Observable_XXX_ev = 0.907657	Observable_XZZ_ev = -0.006108
# Epoch: 94	Fidelity = 0.927934	KL_Divergence = 0.041579	Observable_XXX_ev = 0.934527	Observable_XZZ_ev = -0.008394
# Epoch: 95	Fidelity = 0.946826	KL_Divergence = 0.013600	Observable_XXX_ev = 1.022759	Observable_XZZ_ev = -0.008421
# Epoch: 96	Fidelity = 0.943338	KL_Divergence = 0.015434	Observable_XXX_ev = 1.019207	Observable_XZZ_ev = -0.007492
# Epoch: 97	Fidelity = 0.870461	KL_Divergence = 0.148612	Observable_XXX_ev = 0.807002	Observable_XZZ_ev = -0.003344
# Epoch: 98	Fidelity = 0.942708	KL_Divergence = 0.017468	Observable_XXX_ev = 1.018542	Observable_XZZ_ev = -0.005528
# Epoch: 99	Fidelity = 0.940672	KL_Divergence = 0.020806	Observable_XXX_ev = 0.983120	Observable_XZZ_ev = -0.007151
# Epoch: 100	Fidelity = 0.923033	KL_Divergence = 0.047601	Observable_XXX_ev = 0.896330	Observable_XZZ_ev = -0.004989
# Epoch: 101	Fidelity = 0.943399	KL_Divergence = 0.016803	Observable_XXX_ev = 0.950054	Observable_XZZ_ev = -0.003966
# Epoch: 102	Fidelity = 0.940241	KL_Divergence = 0.018149	Observable_XXX_ev = 0.928800	Observable_XZZ_ev = -0.003830
# Epoch: 103	Fidelity = 0.936759	KL_Divergence = 0.027445	Observable_XXX_ev = 1.090532	Observable_XZZ_ev = -0.003587
# Epoch: 104	Fidelity = 0.935285	KL_Divergence = 0.031455	Observable_XXX_ev = 1.090778	Observable_XZZ_ev = -0.010402
# Epoch: 105	Fidelity = 0.921965	KL_Divergence = 0.053326	Observable_XXX_ev = 0.978845	Observable_XZZ_ev = -0.006423
# Epoch: 106	Fidelity = 0.942478	KL_Divergence = 0.018610	Observable_XXX_ev = 0.941512	Observable_XZZ_ev = -0.003227
# Epoch: 107	Fidelity = 0.945360	KL_Divergence = 0.014273	Observable_XXX_ev = 0.989942	Observable_XZZ_ev = -0.003675
# Epoch: 108	Fidelity = 0.943850	KL_Divergence = 0.015976	Observable_XXX_ev = 0.991206	Observable_XZZ_ev = -0.007542
# Epoch: 109	Fidelity = 0.923098	KL_Divergence = 0.044207	Observable_XXX_ev = 0.843450	Observable_XZZ_ev = -0.002965
# Epoch: 110	Fidelity = 0.925484	KL_Divergence = 0.037445	Observable_XXX_ev = 1.021708	Observable_XZZ_ev = -0.004069
# Epoch: 111	Fidelity = 0.944574	KL_Divergence = 0.015083	Observable_XXX_ev = 0.898795	Observable_XZZ_ev = -0.003989
# Epoch: 112	Fidelity = 0.944056	KL_Divergence = 0.016327	Observable_XXX_ev = 1.034638	Observable_XZZ_ev = -0.007124
# Epoch: 113	Fidelity = 0.922301	KL_Divergence = 0.051377	Observable_XXX_ev = 0.922269	Observable_XZZ_ev = -0.005049
# Epoch: 114	Fidelity = 0.909871	KL_Divergence = 0.074983	Observable_XXX_ev = 0.899424	Observable_XZZ_ev = -0.004771
# Epoch: 115	Fidelity = 0.936561	KL_Divergence = 0.028450	Observable_XXX_ev = 0.889711	Observable_XZZ_ev = -0.004119
# Epoch: 116	Fidelity = 0.941918	KL_Divergence = 0.019685	Observable_XXX_ev = 1.015449	Observable_XZZ_ev = -0.005153
# Epoch: 117	Fidelity = 0.944685	KL_Divergence = 0.015246	Observable_XXX_ev = 0.989357	Observable_XZZ_ev = -0.003217
# Epoch: 118	Fidelity = 0.922150	KL_Divergence = 0.053687	Observable_XXX_ev = 0.960780	Observable_XZZ_ev = -0.004681
# Epoch: 119	Fidelity = 0.930113	KL_Divergence = 0.037190	Observable_XXX_ev = 0.988853	Observable_XZZ_ev = -0.002896
# Epoch: 120	Fidelity = 0.926634	KL_Divergence = 0.042580	Observable_XXX_ev = 0.895253	Observable_XZZ_ev = -0.003838
# Epoch: 121	Fidelity = 0.942133	KL_Divergence = 0.017424	Observable_XXX_ev = 1.006552	Observable_XZZ_ev = -0.003561
# Epoch: 122	Fidelity = 0.935488	KL_Divergence = 0.030195	Observable_XXX_ev = 0.935607	Observable_XZZ_ev = -0.011347
# Epoch: 123	Fidelity = 0.939307	KL_Divergence = 0.023603	Observable_XXX_ev = 1.100860	Observable_XZZ_ev = -0.003734
# Epoch: 124	Fidelity = 0.943640	KL_Divergence = 0.017000	Observable_XXX_ev = 0.947238	Observable_XZZ_ev = -0.003403
# Epoch: 125	Fidelity = 0.938715	KL_Divergence = 0.024617	Observable_XXX_ev = 1.099628	Observable_XZZ_ev = -0.002537
# Epoch: 126	Fidelity = 0.923759	KL_Divergence = 0.049211	Observable_XXX_ev = 0.914806	Observable_XZZ_ev = -0.003016
# Epoch: 127	Fidelity = 0.923683	KL_Divergence = 0.050221	Observable_XXX_ev = 1.092501	Observable_XZZ_ev = -0.008906
# Epoch: 128	Fidelity = 0.932835	KL_Divergence = 0.035094	Observable_XXX_ev = 0.958487	Observable_XZZ_ev = -0.006527
# Epoch: 129	Fidelity = 0.940404	KL_Divergence = 0.021196	Observable_XXX_ev = 1.054081	Observable_XZZ_ev = -0.002640
# Epoch: 130	Fidelity = 0.931098	KL_Divergence = 0.034773	Observable_XXX_ev = 0.995054	Observable_XZZ_ev = -0.002220
# Epoch: 131	Fidelity = 0.944574	KL_Divergence = 0.015949	Observable_XXX_ev = 1.001327	Observable_XZZ_ev = -0.009178
# Epoch: 132	Fidelity = 0.915555	KL_Divergence = 0.064680	Observable_XXX_ev = 0.822135	Observable_XZZ_ev = -0.004400
# Epoch: 133	Fidelity = 0.938828	KL_Divergence = 0.019748	Observable_XXX_ev = 1.046962	Observable_XZZ_ev = -0.003159
# Epoch: 134	Fidelity = 0.932879	KL_Divergence = 0.033551	Observable_XXX_ev = 0.974013	Observable_XZZ_ev = -0.002377
# Epoch: 135	Fidelity = 0.935889	KL_Divergence = 0.029569	Observable_XXX_ev = 1.010957	Observable_XZZ_ev = -0.002018
# Epoch: 136	Fidelity = 0.922394	KL_Divergence = 0.053610	Observable_XXX_ev = 0.888295	Observable_XZZ_ev = -0.005024
# Epoch: 137	Fidelity = 0.915017	KL_Divergence = 0.066199	Observable_XXX_ev = 1.096988	Observable_XZZ_ev = -0.003475
# Epoch: 138	Fidelity = 0.944959	KL_Divergence = 0.015782	Observable_XXX_ev = 0.971437	Observable_XZZ_ev = -0.008800
# Epoch: 139	Fidelity = 0.941338	KL_Divergence = 0.021726	Observable_XXX_ev = 0.937323	Observable_XZZ_ev = -0.002735
# Epoch: 140	Fidelity = 0.931033	KL_Divergence = 0.031602	Observable_XXX_ev = 1.036459	Observable_XZZ_ev = -0.002317
# Epoch: 141	Fidelity = 0.907010	KL_Divergence = 0.076712	Observable_XXX_ev = 0.891653	Observable_XZZ_ev = -0.006025
# Epoch: 142	Fidelity = 0.933377	KL_Divergence = 0.027371	Observable_XXX_ev = 0.907471	Observable_XZZ_ev = -0.002357
# Epoch: 143	Fidelity = 0.905690	KL_Divergence = 0.081600	Observable_XXX_ev = 0.871737	Observable_XZZ_ev = -0.002117
# Epoch: 144	Fidelity = 0.939675	KL_Divergence = 0.024676	Observable_XXX_ev = 0.947231	Observable_XZZ_ev = -0.002705
# Epoch: 145	Fidelity = 0.871916	KL_Divergence = 0.145196	Observable_XXX_ev = 0.754338	Observable_XZZ_ev = -0.001894
# Epoch: 146	Fidelity = 0.928103	KL_Divergence = 0.041073	Observable_XXX_ev = 0.954788	Observable_XZZ_ev = -0.002017
# Epoch: 147	Fidelity = 0.945389	KL_Divergence = 0.015359	Observable_XXX_ev = 1.064511	Observable_XZZ_ev = -0.002139
# Epoch: 148	Fidelity = 0.940436	KL_Divergence = 0.024343	Observable_XXX_ev = 0.987043	Observable_XZZ_ev = -0.002780
# Epoch: 149	Fidelity = 0.919569	KL_Divergence = 0.058888	Observable_XXX_ev = 0.977339	Observable_XZZ_ev = -0.001658
# Epoch: 150	Fidelity = 0.931762	KL_Divergence = 0.038925	Observable_XXX_ev = 0.908366	Observable_XZZ_ev = -0.002086
# Epoch: 151	Fidelity = 0.934196	KL_Divergence = 0.034816	Observable_XXX_ev = 0.930220	Observable_XZZ_ev = -0.002299
# Epoch: 152	Fidelity = 0.932433	KL_Divergence = 0.036880	Observable_XXX_ev = 1.014523	Observable_XZZ_ev = -0.005816
# Epoch: 153	Fidelity = 0.947808	KL_Divergence = 0.013469	Observable_XXX_ev = 0.958100	Observable_XZZ_ev = -0.001236
# Epoch: 154	Fidelity = 0.946939	KL_Divergence = 0.014797	Observable_XXX_ev = 1.157031	Observable_XZZ_ev = -0.007568
# Epoch: 155	Fidelity = 0.947584	KL_Divergence = 0.013695	Observable_XXX_ev = 1.018353	Observable_XZZ_ev = -0.001408
# Epoch: 156	Fidelity = 0.944044	KL_Divergence = 0.020297	Observable_XXX_ev = 1.023644	Observable_XZZ_ev = -0.002146
# Epoch: 157	Fidelity = 0.931611	KL_Divergence = 0.040188	Observable_XXX_ev = 0.898210	Observable_XZZ_ev = -0.001524
# Epoch: 158	Fidelity = 0.943215	KL_Divergence = 0.017777	Observable_XXX_ev = 1.136955	Observable_XZZ_ev = -0.001626
# Epoch: 159	Fidelity = 0.938854	KL_Divergence = 0.024040	Observable_XXX_ev = 0.977614	Observable_XZZ_ev = -0.001234
# Epoch: 160	Fidelity = 0.941746	KL_Divergence = 0.023084	Observable_XXX_ev = 0.937763	Observable_XZZ_ev = -0.002112
# Epoch: 161	Fidelity = 0.943309	KL_Divergence = 0.020280	Observable_XXX_ev = 0.954075	Observable_XZZ_ev = -0.001385
# Epoch: 162	Fidelity = 0.916598	KL_Divergence = 0.065326	Observable_XXX_ev = 1.031383	Observable_XZZ_ev = -0.000868
# Epoch: 163	Fidelity = 0.923219	KL_Divergence = 0.053074	Observable_XXX_ev = 0.953554	Observable_XZZ_ev = -0.000951
# Epoch: 164	Fidelity = 0.917726	KL_Divergence = 0.059838	Observable_XXX_ev = 0.951148	Observable_XZZ_ev = -0.001352
# Epoch: 165	Fidelity = 0.932522	KL_Divergence = 0.036769	Observable_XXX_ev = 0.939746	Observable_XZZ_ev = -0.001341
# Epoch: 166	Fidelity = 0.926679	KL_Divergence = 0.045976	Observable_XXX_ev = 0.883603	Observable_XZZ_ev = -0.009130
# Epoch: 167	Fidelity = 0.943613	KL_Divergence = 0.018970	Observable_XXX_ev = 1.072071	Observable_XZZ_ev = -0.001435
# Epoch: 168	Fidelity = 0.916619	KL_Divergence = 0.064320	Observable_XXX_ev = 0.955191	Observable_XZZ_ev = -0.001377
# Epoch: 169	Fidelity = 0.924053	KL_Divergence = 0.051317	Observable_XXX_ev = 0.968057	Observable_XZZ_ev = -0.001394
# Epoch: 170	Fidelity = 0.899939	KL_Divergence = 0.092299	Observable_XXX_ev = 0.948918	Observable_XZZ_ev = -0.001082
# Epoch: 171	Fidelity = 0.929199	KL_Divergence = 0.042234	Observable_XXX_ev = 0.994575	Observable_XZZ_ev = -0.001519
# Epoch: 172	Fidelity = 0.864771	KL_Divergence = 0.157644	Observable_XXX_ev = 0.807227	Observable_XZZ_ev = -0.000515
# Epoch: 173	Fidelity = 0.930822	KL_Divergence = 0.035025	Observable_XXX_ev = 0.890721	Observable_XZZ_ev = -0.001257
# Epoch: 174	Fidelity = 0.933005	KL_Divergence = 0.034298	Observable_XXX_ev = 0.944608	Observable_XZZ_ev = -0.001856
# Epoch: 175	Fidelity = 0.907121	KL_Divergence = 0.078623	Observable_XXX_ev = 0.968013	Observable_XZZ_ev = -0.004202
# Epoch: 176	Fidelity = 0.932340	KL_Divergence = 0.034624	Observable_XXX_ev = 1.181962	Observable_XZZ_ev = -0.001326
# Epoch: 177	Fidelity = 0.930242	KL_Divergence = 0.037422	Observable_XXX_ev = 0.942462	Observable_XZZ_ev = -0.005085
# Epoch: 178	Fidelity = 0.934391	KL_Divergence = 0.029373	Observable_XXX_ev = 1.043050	Observable_XZZ_ev = -0.000805
# Epoch: 179	Fidelity = 0.940750	KL_Divergence = 0.018623	Observable_XXX_ev = 1.013354	Observable_XZZ_ev = -0.001372
# Epoch: 180	Fidelity = 0.926679	KL_Divergence = 0.043327	Observable_XXX_ev = 1.006520	Observable_XZZ_ev = -0.004481
# Epoch: 181	Fidelity = 0.927820	KL_Divergence = 0.040991	Observable_XXX_ev = 0.906817	Observable_XZZ_ev = -0.007871
# Epoch: 182	Fidelity = 0.944729	KL_Divergence = 0.014475	Observable_XXX_ev = 0.913641	Observable_XZZ_ev = -0.001697
# Epoch: 183	Fidelity = 0.933351	KL_Divergence = 0.031669	Observable_XXX_ev = 0.994264	Observable_XZZ_ev = -0.005376
# Epoch: 184	Fidelity = 0.935894	KL_Divergence = 0.029647	Observable_XXX_ev = 0.933226	Observable_XZZ_ev = -0.004980
# Epoch: 185	Fidelity = 0.937192	KL_Divergence = 0.025916	Observable_XXX_ev = 0.949820	Observable_XZZ_ev = -0.004766
# Epoch: 186	Fidelity = 0.945998	KL_Divergence = 0.014128	Observable_XXX_ev = 0.959419	Observable_XZZ_ev = -0.000983
# Epoch: 187	Fidelity = 0.933381	KL_Divergence = 0.033157	Observable_XXX_ev = 0.955568	Observable_XZZ_ev = -0.001058
# Epoch: 188	Fidelity = 0.940346	KL_Divergence = 0.023331	Observable_XXX_ev = 1.013899	Observable_XZZ_ev = -0.001167
# Epoch: 189	Fidelity = 0.946590	KL_Divergence = 0.013919	Observable_XXX_ev = 0.951943	Observable_XZZ_ev = -0.001180
# Epoch: 190	Fidelity = 0.932233	KL_Divergence = 0.037093	Observable_XXX_ev = 1.074228	Observable_XZZ_ev = -0.000881
# Epoch: 191	Fidelity = 0.922424	KL_Divergence = 0.052651	Observable_XXX_ev = 1.135854	Observable_XZZ_ev = -0.004047
# Epoch: 192	Fidelity = 0.924084	KL_Divergence = 0.051030	Observable_XXX_ev = 1.001778	Observable_XZZ_ev = -0.000905
# Epoch: 193	Fidelity = 0.943137	KL_Divergence = 0.019158	Observable_XXX_ev = 1.039459	Observable_XZZ_ev = -0.000513
# Epoch: 194	Fidelity = 0.917855	KL_Divergence = 0.060751	Observable_XXX_ev = 0.844141	Observable_XZZ_ev = -0.000358
# Epoch: 195	Fidelity = 0.902310	KL_Divergence = 0.089426	Observable_XXX_ev = 0.831248	Observable_XZZ_ev = -0.003384
# Epoch: 196	Fidelity = 0.913425	KL_Divergence = 0.069402	Observable_XXX_ev = 0.961456	Observable_XZZ_ev = -0.004013
# Epoch: 197	Fidelity = 0.941510	KL_Divergence = 0.022023	Observable_XXX_ev = 1.011901	Observable_XZZ_ev = -0.000856
# Epoch: 198	Fidelity = 0.926848	KL_Divergence = 0.044253	Observable_XXX_ev = 0.887439	Observable_XZZ_ev = -0.000925
# Epoch: 199	Fidelity = 0.912543	KL_Divergence = 0.071255	Observable_XXX_ev = 0.896590	Observable_XZZ_ev = -0.000516
# Epoch: 200	Fidelity = 0.945744	KL_Divergence = 0.014332	Observable_XXX_ev = 1.027816	Observable_XZZ_ev = -0.000396
# Epoch: 201	Fidelity = 0.942897	KL_Divergence = 0.016228	Observable_XXX_ev = 1.051912	Observable_XZZ_ev = -0.000813
# Epoch: 202	Fidelity = 0.939597	KL_Divergence = 0.025272	Observable_XXX_ev = 1.115034	Observable_XZZ_ev = -0.000575
# Epoch: 203	Fidelity = 0.924935	KL_Divergence = 0.048209	Observable_XXX_ev = 0.840567	Observable_XZZ_ev = -0.000614
# Epoch: 204	Fidelity = 0.931451	KL_Divergence = 0.038816	Observable_XXX_ev = 0.919386	Observable_XZZ_ev = -0.000671
# Epoch: 205	Fidelity = 0.932070	KL_Divergence = 0.037552	Observable_XXX_ev = 0.930654	Observable_XZZ_ev = -0.000572
# Epoch: 206	Fidelity = 0.929724	KL_Divergence = 0.041563	Observable_XXX_ev = 1.100209	Observable_XZZ_ev = -0.000563
# Epoch: 207	Fidelity = 0.936693	KL_Divergence = 0.029881	Observable_XXX_ev = 1.006683	Observable_XZZ_ev = -0.000675
# Epoch: 208	Fidelity = 0.933289	KL_Divergence = 0.033760	Observable_XXX_ev = 0.847419	Observable_XZZ_ev = -0.004086
# Epoch: 209	Fidelity = 0.934062	KL_Divergence = 0.033566	Observable_XXX_ev = 1.060919	Observable_XZZ_ev = -0.000319
# Epoch: 210	Fidelity = 0.933431	KL_Divergence = 0.035611	Observable_XXX_ev = 0.899421	Observable_XZZ_ev = -0.000406
# Epoch: 211	Fidelity = 0.917592	KL_Divergence = 0.062018	Observable_XXX_ev = 1.011224	Observable_XZZ_ev = -0.000399
# Epoch: 212	Fidelity = 0.925912	KL_Divergence = 0.048283	Observable_XXX_ev = 0.980302	Observable_XZZ_ev = -0.000483
# Epoch: 213	Fidelity = 0.930374	KL_Divergence = 0.040283	Observable_XXX_ev = 0.871005	Observable_XZZ_ev = -0.000625
# Epoch: 214	Fidelity = 0.942610	KL_Divergence = 0.020502	Observable_XXX_ev = 0.928873	Observable_XZZ_ev = -0.000638
# Epoch: 215	Fidelity = 0.937436	KL_Divergence = 0.028106	Observable_XXX_ev = 1.068710	Observable_XZZ_ev = -0.000206
# Epoch: 216	Fidelity = 0.943972	KL_Divergence = 0.018647	Observable_XXX_ev = 0.960537	Observable_XZZ_ev = -0.000181
# Epoch: 217	Fidelity = 0.937965	KL_Divergence = 0.028018	Observable_XXX_ev = 0.946074	Observable_XZZ_ev = -0.000037
# Epoch: 218	Fidelity = 0.943326	KL_Divergence = 0.018944	Observable_XXX_ev = 0.941009	Observable_XZZ_ev = -0.000949
# Epoch: 219	Fidelity = 0.938345	KL_Divergence = 0.025601	Observable_XXX_ev = 1.085995	Observable_XZZ_ev = -0.000666
# Epoch: 220	Fidelity = 0.932973	KL_Divergence = 0.036515	Observable_XXX_ev = 0.873507	Observable_XZZ_ev = -0.000740
# Epoch: 221	Fidelity = 0.938209	KL_Divergence = 0.027811	Observable_XXX_ev = 0.979062	Observable_XZZ_ev = -0.000492
# Epoch: 222	Fidelity = 0.935672	KL_Divergence = 0.031860	Observable_XXX_ev = 1.029352	Observable_XZZ_ev = -0.000427
# Epoch: 223	Fidelity = 0.923544	KL_Divergence = 0.052003	Observable_XXX_ev = 0.816501	Observable_XZZ_ev = -0.000444
# Epoch: 224	Fidelity = 0.918497	KL_Divergence = 0.060659	Observable_XXX_ev = 1.044926	Observable_XZZ_ev = -0.000198
# Epoch: 225	Fidelity = 0.921811	KL_Divergence = 0.054127	Observable_XXX_ev = 0.963086	Observable_XZZ_ev = -0.002576
# Epoch: 226	Fidelity = 0.917308	KL_Divergence = 0.062408	Observable_XXX_ev = 0.977243	Observable_XZZ_ev = -0.000533
# Epoch: 227	Fidelity = 0.928900	KL_Divergence = 0.042037	Observable_XXX_ev = 1.019472	Observable_XZZ_ev = -0.000416
# Epoch: 228	Fidelity = 0.926387	KL_Divergence = 0.045592	Observable_XXX_ev = 0.984820	Observable_XZZ_ev = -0.000604
# Epoch: 229	Fidelity = 0.929113	KL_Divergence = 0.041325	Observable_XXX_ev = 0.870705	Observable_XZZ_ev = -0.000699
# Epoch: 230	Fidelity = 0.930693	KL_Divergence = 0.039646	Observable_XXX_ev = 1.038021	Observable_XZZ_ev = -0.003595
# Epoch: 231	Fidelity = 0.924585	KL_Divergence = 0.044473	Observable_XXX_ev = 0.924760	Observable_XZZ_ev = -0.000511
# Epoch: 232	Fidelity = 0.933722	KL_Divergence = 0.034119	Observable_XXX_ev = 1.014771	Observable_XZZ_ev = -0.000637
# Epoch: 233	Fidelity = 0.919965	KL_Divergence = 0.057028	Observable_XXX_ev = 1.060860	Observable_XZZ_ev = -0.000271
# Epoch: 234	Fidelity = 0.928656	KL_Divergence = 0.041801	Observable_XXX_ev = 1.041990	Observable_XZZ_ev = -0.000366
# Epoch: 235	Fidelity = 0.930091	KL_Divergence = 0.039612	Observable_XXX_ev = 0.945359	Observable_XZZ_ev = 0.000329
# Epoch: 236	Fidelity = 0.933963	KL_Divergence = 0.032112	Observable_XXX_ev = 1.027678	Observable_XZZ_ev = -0.000537
# Epoch: 237	Fidelity = 0.930676	KL_Divergence = 0.038640	Observable_XXX_ev = 0.924205	Observable_XZZ_ev = -0.000159
# Epoch: 238	Fidelity = 0.926504	KL_Divergence = 0.046757	Observable_XXX_ev = 0.918516	Observable_XZZ_ev = 0.000177
# Epoch: 239	Fidelity = 0.935768	KL_Divergence = 0.031329	Observable_XXX_ev = 0.944350	Observable_XZZ_ev = -0.006374
# Epoch: 240	Fidelity = 0.926142	KL_Divergence = 0.047099	Observable_XXX_ev = 0.963130	Observable_XZZ_ev = -0.003115
# Epoch: 241	Fidelity = 0.936199	KL_Divergence = 0.029974	Observable_XXX_ev = 1.032284	Observable_XZZ_ev = -0.003031
# Epoch: 242	Fidelity = 0.940454	KL_Divergence = 0.023544	Observable_XXX_ev = 1.058716	Observable_XZZ_ev = -0.000604
# Epoch: 243	Fidelity = 0.928949	KL_Divergence = 0.043229	Observable_XXX_ev = 1.097457	Observable_XZZ_ev = -0.000202
# Epoch: 244	Fidelity = 0.934001	KL_Divergence = 0.034697	Observable_XXX_ev = 0.765149	Observable_XZZ_ev = -0.000200
# Epoch: 245	Fidelity = 0.943305	KL_Divergence = 0.019869	Observable_XXX_ev = 1.092584	Observable_XZZ_ev = -0.000903
# Epoch: 246	Fidelity = 0.945729	KL_Divergence = 0.016086	Observable_XXX_ev = 1.045266	Observable_XZZ_ev = -0.000508
# Epoch: 247	Fidelity = 0.939800	KL_Divergence = 0.024395	Observable_XXX_ev = 1.044942	Observable_XZZ_ev = -0.000239
# Epoch: 248	Fidelity = 0.928651	KL_Divergence = 0.044091	Observable_XXX_ev = 0.898110	Observable_XZZ_ev = -0.002297
# Epoch: 249	Fidelity = 0.924614	KL_Divergence = 0.050903	Observable_XXX_ev = 0.892518	Observable_XZZ_ev = 0.000975
# Epoch: 250	Fidelity = 0.926589	KL_Divergence = 0.047686	Observable_XXX_ev = 0.887996	Observable_XZZ_ev = -0.002978
# Epoch: 251	Fidelity = 0.930581	KL_Divergence = 0.040490	Observable_XXX_ev = 0.892591	Observable_XZZ_ev = -0.000047
# Epoch: 252	Fidelity = 0.928468	KL_Divergence = 0.044325	Observable_XXX_ev = 0.914823	Observable_XZZ_ev = -0.000216
# Epoch: 253	Fidelity = 0.915115	KL_Divergence = 0.067184	Observable_XXX_ev = 0.922948	Observable_XZZ_ev = 0.000265
# Epoch: 254	Fidelity = 0.933613	KL_Divergence = 0.035730	Observable_XXX_ev = 1.020017	Observable_XZZ_ev = -0.000317
# Epoch: 255	Fidelity = 0.927649	KL_Divergence = 0.044451	Observable_XXX_ev = 0.921331	Observable_XZZ_ev = -0.000084
# Epoch: 256	Fidelity = 0.939430	KL_Divergence = 0.026197	Observable_XXX_ev = 1.016538	Observable_XZZ_ev = -0.000494
# Epoch: 257	Fidelity = 0.936946	KL_Divergence = 0.030128	Observable_XXX_ev = 0.994020	Observable_XZZ_ev = -0.000258
# Epoch: 258	Fidelity = 0.939015	KL_Divergence = 0.027280	Observable_XXX_ev = 0.945932	Observable_XZZ_ev = -0.000334
# Epoch: 259	Fidelity = 0.921878	KL_Divergence = 0.055503	Observable_XXX_ev = 0.931946	Observable_XZZ_ev = -0.000290
# Epoch: 260	Fidelity = 0.910873	KL_Divergence = 0.074292	Observable_XXX_ev = 0.925048	Observable_XZZ_ev = 0.000447
# Epoch: 261	Fidelity = 0.919561	KL_Divergence = 0.058837	Observable_XXX_ev = 0.923307	Observable_XZZ_ev = 0.000062
# Epoch: 262	Fidelity = 0.926486	KL_Divergence = 0.047729	Observable_XXX_ev = 0.938956	Observable_XZZ_ev = 0.000227
# Epoch: 263	Fidelity = 0.929786	KL_Divergence = 0.041516	Observable_XXX_ev = 1.020789	Observable_XZZ_ev = 0.000046
# Epoch: 264	Fidelity = 0.936842	KL_Divergence = 0.030501	Observable_XXX_ev = 0.902767	Observable_XZZ_ev = -0.000229
# Epoch: 265	Fidelity = 0.944116	KL_Divergence = 0.017409	Observable_XXX_ev = 0.972713	Observable_XZZ_ev = -0.003455
# Epoch: 266	Fidelity = 0.943065	KL_Divergence = 0.019241	Observable_XXX_ev = 1.058114	Observable_XZZ_ev = -0.000047
# Epoch: 267	Fidelity = 0.931983	KL_Divergence = 0.038364	Observable_XXX_ev = 1.005567	Observable_XZZ_ev = -0.002676
# Epoch: 268	Fidelity = 0.927003	KL_Divergence = 0.046236	Observable_XXX_ev = 0.903072	Observable_XZZ_ev = -0.000025
# Epoch: 269	Fidelity = 0.935170	KL_Divergence = 0.033296	Observable_XXX_ev = 0.928634	Observable_XZZ_ev = -0.003058
# Epoch: 270	Fidelity = 0.939046	KL_Divergence = 0.026388	Observable_XXX_ev = 1.026322	Observable_XZZ_ev = -0.000284
# Epoch: 271	Fidelity = 0.940197	KL_Divergence = 0.025180	Observable_XXX_ev = 1.164531	Observable_XZZ_ev = -0.002432
# Epoch: 272	Fidelity = 0.927562	KL_Divergence = 0.045310	Observable_XXX_ev = 0.947646	Observable_XZZ_ev = -0.000087
# Epoch: 273	Fidelity = 0.927438	KL_Divergence = 0.045932	Observable_XXX_ev = 1.039723	Observable_XZZ_ev = -0.000438
# Epoch: 274	Fidelity = 0.933064	KL_Divergence = 0.035673	Observable_XXX_ev = 0.923811	Observable_XZZ_ev = -0.002807
# Epoch: 275	Fidelity = 0.936965	KL_Divergence = 0.029897	Observable_XXX_ev = 1.024541	Observable_XZZ_ev = -0.006173
# Epoch: 276	Fidelity = 0.925432	KL_Divergence = 0.048440	Observable_XXX_ev = 1.193091	Observable_XZZ_ev = 0.000179
# Epoch: 277	Fidelity = 0.932131	KL_Divergence = 0.037339	Observable_XXX_ev = 0.978808	Observable_XZZ_ev = -0.000093
# Epoch: 278	Fidelity = 0.929879	KL_Divergence = 0.041290	Observable_XXX_ev = 1.025277	Observable_XZZ_ev = 0.000383
# Epoch: 279	Fidelity = 0.927798	KL_Divergence = 0.044335	Observable_XXX_ev = 0.915778	Observable_XZZ_ev = 0.000006
# Epoch: 280	Fidelity = 0.917146	KL_Divergence = 0.062778	Observable_XXX_ev = 0.872208	Observable_XZZ_ev = 0.000559
# Epoch: 281	Fidelity = 0.928569	KL_Divergence = 0.043804	Observable_XXX_ev = 0.942305	Observable_XZZ_ev = 0.000185
# Epoch: 282	Fidelity = 0.928198	KL_Divergence = 0.044512	Observable_XXX_ev = 1.121898	Observable_XZZ_ev = -0.003030
# Epoch: 283	Fidelity = 0.924970	KL_Divergence = 0.049873	Observable_XXX_ev = 0.931026	Observable_XZZ_ev = 0.000008
# Epoch: 284	Fidelity = 0.925678	KL_Divergence = 0.048562	Observable_XXX_ev = 1.128770	Observable_XZZ_ev = -0.004615
# Epoch: 285	Fidelity = 0.927157	KL_Divergence = 0.044855	Observable_XXX_ev = 1.003879	Observable_XZZ_ev = -0.002280
# Epoch: 286	Fidelity = 0.921493	KL_Divergence = 0.054737	Observable_XXX_ev = 0.955014	Observable_XZZ_ev = 0.000099
# Epoch: 287	Fidelity = 0.936679	KL_Divergence = 0.029610	Observable_XXX_ev = 0.895851	Observable_XZZ_ev = -0.000124
# Epoch: 288	Fidelity = 0.935012	KL_Divergence = 0.032891	Observable_XXX_ev = 0.964188	Observable_XZZ_ev = -0.002778
# Epoch: 289	Fidelity = 0.934585	KL_Divergence = 0.033971	Observable_XXX_ev = 1.031089	Observable_XZZ_ev = -0.000241
# Epoch: 290	Fidelity = 0.941593	KL_Divergence = 0.022103	Observable_XXX_ev = 0.899389	Observable_XZZ_ev = -0.000031
# Epoch: 291	Fidelity = 0.940462	KL_Divergence = 0.024186	Observable_XXX_ev = 1.057320	Observable_XZZ_ev = -0.000054
# Epoch: 292	Fidelity = 0.938358	KL_Divergence = 0.027245	Observable_XXX_ev = 0.949358	Observable_XZZ_ev = -0.000210
# Epoch: 293	Fidelity = 0.935650	KL_Divergence = 0.030933	Observable_XXX_ev = 0.924177	Observable_XZZ_ev = 0.000294
# Epoch: 294	Fidelity = 0.936173	KL_Divergence = 0.031297	Observable_XXX_ev = 0.909595	Observable_XZZ_ev = 0.000319
# Epoch: 295	Fidelity = 0.933330	KL_Divergence = 0.035861	Observable_XXX_ev = 0.916796	Observable_XZZ_ev = 0.000600
# Epoch: 296	Fidelity = 0.939601	KL_Divergence = 0.025475	Observable_XXX_ev = 0.966446	Observable_XZZ_ev = -0.000039
# Epoch: 297	Fidelity = 0.935218	KL_Divergence = 0.033045	Observable_XXX_ev = 0.993650	Observable_XZZ_ev = -0.000223
# Epoch: 298	Fidelity = 0.939340	KL_Divergence = 0.025972	Observable_XXX_ev = 1.044642	Observable_XZZ_ev = -0.000152
# Epoch: 299	Fidelity = 0.938331	KL_Divergence = 0.027478	Observable_XXX_ev = 0.928521	Observable_XZZ_ev = -0.002020
# Epoch: 300	Fidelity = 0.932328	KL_Divergence = 0.037401	Observable_XXX_ev = 0.922320	Observable_XZZ_ev = 0.000369
# Epoch: 301	Fidelity = 0.936422	KL_Divergence = 0.030975	Observable_XXX_ev = 1.027159	Observable_XZZ_ev = -0.000151
# Epoch: 302	Fidelity = 0.933509	KL_Divergence = 0.035241	Observable_XXX_ev = 0.901860	Observable_XZZ_ev = -0.000174
# Epoch: 303	Fidelity = 0.936796	KL_Divergence = 0.029566	Observable_XXX_ev = 0.954336	Observable_XZZ_ev = 0.000644
# Epoch: 304	Fidelity = 0.938968	KL_Divergence = 0.026502	Observable_XXX_ev = 0.999263	Observable_XZZ_ev = -0.002936
# Epoch: 305	Fidelity = 0.942864	KL_Divergence = 0.020268	Observable_XXX_ev = 1.084564	Observable_XZZ_ev = 0.000027
# Epoch: 306	Fidelity = 0.941659	KL_Divergence = 0.022619	Observable_XXX_ev = 1.010618	Observable_XZZ_ev = -0.000158
# Epoch: 307	Fidelity = 0.937167	KL_Divergence = 0.029544	Observable_XXX_ev = 1.010899	Observable_XZZ_ev = -0.001509
# Epoch: 308	Fidelity = 0.933710	KL_Divergence = 0.035253	Observable_XXX_ev = 0.951831	Observable_XZZ_ev = -0.000192
# Epoch: 309	Fidelity = 0.934702	KL_Divergence = 0.033606	Observable_XXX_ev = 1.012087	Observable_XZZ_ev = -0.000095
# Epoch: 310	Fidelity = 0.936518	KL_Divergence = 0.030326	Observable_XXX_ev = 1.041726	Observable_XZZ_ev = 0.000594
# Epoch: 311	Fidelity = 0.926894	KL_Divergence = 0.046040	Observable_XXX_ev = 0.990627	Observable_XZZ_ev = 0.000238
# Epoch: 312	Fidelity = 0.932211	KL_Divergence = 0.037622	Observable_XXX_ev = 1.038274	Observable_XZZ_ev = -0.000057
# Epoch: 313	Fidelity = 0.931105	KL_Divergence = 0.039695	Observable_XXX_ev = 0.930669	Observable_XZZ_ev = 0.000398
# Epoch: 314	Fidelity = 0.928092	KL_Divergence = 0.044233	Observable_XXX_ev = 0.945899	Observable_XZZ_ev = 0.000396
# Epoch: 315	Fidelity = 0.928192	KL_Divergence = 0.044475	Observable_XXX_ev = 0.942417	Observable_XZZ_ev = 0.000601
# Epoch: 316	Fidelity = 0.921478	KL_Divergence = 0.055360	Observable_XXX_ev = 0.904087	Observable_XZZ_ev = 0.001031
# Epoch: 317	Fidelity = 0.923541	KL_Divergence = 0.051478	Observable_XXX_ev = 0.939255	Observable_XZZ_ev = -0.000113
# Epoch: 318	Fidelity = 0.928291	KL_Divergence = 0.044291	Observable_XXX_ev = 0.929191	Observable_XZZ_ev = 0.001046
# Epoch: 319	Fidelity = 0.934951	KL_Divergence = 0.032640	Observable_XXX_ev = 1.047503	Observable_XZZ_ev = -0.002348
# Epoch: 320	Fidelity = 0.933531	KL_Divergence = 0.034850	Observable_XXX_ev = 0.881071	Observable_XZZ_ev = 0.000388
# Epoch: 321	Fidelity = 0.936346	KL_Divergence = 0.030600	Observable_XXX_ev = 1.019171	Observable_XZZ_ev = -0.002515
# Epoch: 322	Fidelity = 0.931840	KL_Divergence = 0.038374	Observable_XXX_ev = 0.799222	Observable_XZZ_ev = -0.000216
# Epoch: 323	Fidelity = 0.934020	KL_Divergence = 0.034238	Observable_XXX_ev = 0.928770	Observable_XZZ_ev = 0.000939
# Epoch: 324	Fidelity = 0.933066	KL_Divergence = 0.035947	Observable_XXX_ev = 1.085866	Observable_XZZ_ev = -0.000320
# Epoch: 325	Fidelity = 0.934942	KL_Divergence = 0.032797	Observable_XXX_ev = 0.947352	Observable_XZZ_ev = 0.000563
# Epoch: 326	Fidelity = 0.935092	KL_Divergence = 0.032718	Observable_XXX_ev = 0.961485	Observable_XZZ_ev = -0.000230
# Epoch: 327	Fidelity = 0.935519	KL_Divergence = 0.032196	Observable_XXX_ev = 0.900985	Observable_XZZ_ev = -0.002048
# Epoch: 328	Fidelity = 0.934003	KL_Divergence = 0.035019	Observable_XXX_ev = 1.008035	Observable_XZZ_ev = -0.001653
# Epoch: 329	Fidelity = 0.936452	KL_Divergence = 0.030543	Observable_XXX_ev = 1.102417	Observable_XZZ_ev = 0.000070
# Epoch: 330	Fidelity = 0.929997	KL_Divergence = 0.041034	Observable_XXX_ev = 0.954987	Observable_XZZ_ev = -0.000230
# Epoch: 331	Fidelity = 0.936022	KL_Divergence = 0.030941	Observable_XXX_ev = 0.956845	Observable_XZZ_ev = 0.000706
# Epoch: 332	Fidelity = 0.933396	KL_Divergence = 0.035833	Observable_XXX_ev = 0.925426	Observable_XZZ_ev = 0.000365
# Epoch: 333	Fidelity = 0.932833	KL_Divergence = 0.036844	Observable_XXX_ev = 1.018016	Observable_XZZ_ev = 0.000785
# Epoch: 334	Fidelity = 0.933135	KL_Divergence = 0.036099	Observable_XXX_ev = 0.941044	Observable_XZZ_ev = 0.000504
# Epoch: 335	Fidelity = 0.934841	KL_Divergence = 0.033704	Observable_XXX_ev = 0.864012	Observable_XZZ_ev = -0.000166
# Epoch: 336	Fidelity = 0.936391	KL_Divergence = 0.030660	Observable_XXX_ev = 0.977574	Observable_XZZ_ev = -0.003281
# Epoch: 337	Fidelity = 0.936358	KL_Divergence = 0.030370	Observable_XXX_ev = 1.041867	Observable_XZZ_ev = -0.001165
# Epoch: 338	Fidelity = 0.931838	KL_Divergence = 0.038198	Observable_XXX_ev = 0.803459	Observable_XZZ_ev = 0.000583
# Epoch: 339	Fidelity = 0.921344	KL_Divergence = 0.055843	Observable_XXX_ev = 1.046440	Observable_XZZ_ev = 0.000636
# Epoch: 340	Fidelity = 0.924367	KL_Divergence = 0.050175	Observable_XXX_ev = 0.915323	Observable_XZZ_ev = -0.000114
# Epoch: 341	Fidelity = 0.921858	KL_Divergence = 0.054725	Observable_XXX_ev = 0.987515	Observable_XZZ_ev = 0.000232
# Epoch: 342	Fidelity = 0.925872	KL_Divergence = 0.047976	Observable_XXX_ev = 0.939583	Observable_XZZ_ev = -0.000027
# Epoch: 343	Fidelity = 0.924693	KL_Divergence = 0.049909	Observable_XXX_ev = 0.842328	Observable_XZZ_ev = 0.000029
# Epoch: 344	Fidelity = 0.929220	KL_Divergence = 0.042554	Observable_XXX_ev = 1.019425	Observable_XZZ_ev = 0.000529
# Epoch: 345	Fidelity = 0.934044	KL_Divergence = 0.034436	Observable_XXX_ev = 0.933085	Observable_XZZ_ev = -0.000056
# Epoch: 346	Fidelity = 0.935880	KL_Divergence = 0.031614	Observable_XXX_ev = 0.981687	Observable_XZZ_ev = 0.000077
# Epoch: 347	Fidelity = 0.929635	KL_Divergence = 0.041624	Observable_XXX_ev = 0.972821	Observable_XZZ_ev = -0.001869
# Epoch: 348	Fidelity = 0.928871	KL_Divergence = 0.043113	Observable_XXX_ev = 1.054339	Observable_XZZ_ev = 0.000788
# Epoch: 349	Fidelity = 0.930528	KL_Divergence = 0.040343	Observable_XXX_ev = 0.988290	Observable_XZZ_ev = 0.000431
# Epoch: 350	Fidelity = 0.929262	KL_Divergence = 0.042175	Observable_XXX_ev = 1.044510	Observable_XZZ_ev = 0.000001
# Epoch: 351	Fidelity = 0.927911	KL_Divergence = 0.044634	Observable_XXX_ev = 0.974034	Observable_XZZ_ev = 0.000402
# Epoch: 352	Fidelity = 0.928422	KL_Divergence = 0.043612	Observable_XXX_ev = 0.935539	Observable_XZZ_ev = 0.000494
# Epoch: 353	Fidelity = 0.927293	KL_Divergence = 0.045787	Observable_XXX_ev = 0.868862	Observable_XZZ_ev = -0.000073
# Epoch: 354	Fidelity = 0.923225	KL_Divergence = 0.052509	Observable_XXX_ev = 0.962026	Observable_XZZ_ev = 0.000570
# Epoch: 355	Fidelity = 0.924827	KL_Divergence = 0.049951	Observable_XXX_ev = 0.882227	Observable_XZZ_ev = 0.000262
# Epoch: 356	Fidelity = 0.928874	KL_Divergence = 0.042795	Observable_XXX_ev = 0.988339	Observable_XZZ_ev = -0.000392
# Epoch: 357	Fidelity = 0.929933	KL_Divergence = 0.041177	Observable_XXX_ev = 1.006385	Observable_XZZ_ev = -0.000102
# Epoch: 358	Fidelity = 0.931762	KL_Divergence = 0.038058	Observable_XXX_ev = 0.939159	Observable_XZZ_ev = -0.000162
# Epoch: 359	Fidelity = 0.929817	KL_Divergence = 0.041414	Observable_XXX_ev = 0.906047	Observable_XZZ_ev = -0.000060
# Epoch: 360	Fidelity = 0.931457	KL_Divergence = 0.038377	Observable_XXX_ev = 0.906953	Observable_XZZ_ev = 0.001309
# Epoch: 361	Fidelity = 0.928056	KL_Divergence = 0.044129	Observable_XXX_ev = 1.052497	Observable_XZZ_ev = 0.000372
# Epoch: 362	Fidelity = 0.927566	KL_Divergence = 0.044983	Observable_XXX_ev = 0.865315	Observable_XZZ_ev = 0.000423
# Epoch: 363	Fidelity = 0.932031	KL_Divergence = 0.037707	Observable_XXX_ev = 0.941276	Observable_XZZ_ev = 0.000080
# Epoch: 364	Fidelity = 0.932966	KL_Divergence = 0.036060	Observable_XXX_ev = 1.014662	Observable_XZZ_ev = -0.000176
# Epoch: 365	Fidelity = 0.931939	KL_Divergence = 0.038008	Observable_XXX_ev = 0.992924	Observable_XZZ_ev = -0.000040
# Epoch: 366	Fidelity = 0.924754	KL_Divergence = 0.049770	Observable_XXX_ev = 0.999983	Observable_XZZ_ev = 0.001245
# Epoch: 367	Fidelity = 0.932460	KL_Divergence = 0.036925	Observable_XXX_ev = 0.878266	Observable_XZZ_ev = 0.000138
# Epoch: 368	Fidelity = 0.929102	KL_Divergence = 0.042314	Observable_XXX_ev = 0.991224	Observable_XZZ_ev = -0.000942
# Epoch: 369	Fidelity = 0.930329	KL_Divergence = 0.040480	Observable_XXX_ev = 0.882472	Observable_XZZ_ev = 0.000309
# Epoch: 370	Fidelity = 0.927628	KL_Divergence = 0.045351	Observable_XXX_ev = 0.948581	Observable_XZZ_ev = -0.002196
# Epoch: 371	Fidelity = 0.925628	KL_Divergence = 0.048251	Observable_XXX_ev = 0.928729	Observable_XZZ_ev = -0.001349
# Epoch: 372	Fidelity = 0.930658	KL_Divergence = 0.039847	Observable_XXX_ev = 1.012807	Observable_XZZ_ev = 0.000382
# Epoch: 373	Fidelity = 0.932874	KL_Divergence = 0.036038	Observable_XXX_ev = 1.062748	Observable_XZZ_ev = -0.000072
# Epoch: 374	Fidelity = 0.933730	KL_Divergence = 0.034870	Observable_XXX_ev = 0.971920	Observable_XZZ_ev = 0.000392
# Epoch: 375	Fidelity = 0.930958	KL_Divergence = 0.039293	Observable_XXX_ev = 0.911417	Observable_XZZ_ev = 0.000707
# Epoch: 376	Fidelity = 0.931322	KL_Divergence = 0.038740	Observable_XXX_ev = 0.844214	Observable_XZZ_ev = 0.000791
# Epoch: 377	Fidelity = 0.928984	KL_Divergence = 0.042510	Observable_XXX_ev = 0.977479	Observable_XZZ_ev = 0.000746
# Epoch: 378	Fidelity = 0.928533	KL_Divergence = 0.043099	Observable_XXX_ev = 0.974874	Observable_XZZ_ev = 0.000115
# Epoch: 379	Fidelity = 0.925799	KL_Divergence = 0.048032	Observable_XXX_ev = 0.922657	Observable_XZZ_ev = -0.000967
# Epoch: 380	Fidelity = 0.927350	KL_Divergence = 0.045410	Observable_XXX_ev = 0.938412	Observable_XZZ_ev = 0.000551
# Epoch: 381	Fidelity = 0.928586	KL_Divergence = 0.043300	Observable_XXX_ev = 1.039639	Observable_XZZ_ev = -0.002351
# Epoch: 382	Fidelity = 0.926877	KL_Divergence = 0.046258	Observable_XXX_ev = 0.954130	Observable_XZZ_ev = -0.000119
# Epoch: 383	Fidelity = 0.924541	KL_Divergence = 0.050062	Observable_XXX_ev = 0.956281	Observable_XZZ_ev = -0.003966
# Epoch: 384	Fidelity = 0.929697	KL_Divergence = 0.041619	Observable_XXX_ev = 0.921129	Observable_XZZ_ev = 0.000664
# Epoch: 385	Fidelity = 0.932834	KL_Divergence = 0.036382	Observable_XXX_ev = 1.027613	Observable_XZZ_ev = 0.000758
# Epoch: 386	Fidelity = 0.933465	KL_Divergence = 0.035349	Observable_XXX_ev = 0.905667	Observable_XZZ_ev = -0.000098
# Epoch: 387	Fidelity = 0.933880	KL_Divergence = 0.034626	Observable_XXX_ev = 0.801889	Observable_XZZ_ev = 0.000978
# Epoch: 388	Fidelity = 0.931497	KL_Divergence = 0.038506	Observable_XXX_ev = 0.951153	Observable_XZZ_ev = 0.000904
# Epoch: 389	Fidelity = 0.932837	KL_Divergence = 0.036150	Observable_XXX_ev = 0.940756	Observable_XZZ_ev = 0.001450
# Epoch: 390	Fidelity = 0.932590	KL_Divergence = 0.036554	Observable_XXX_ev = 1.042228	Observable_XZZ_ev = 0.000633
# Epoch: 391	Fidelity = 0.933218	KL_Divergence = 0.035388	Observable_XXX_ev = 0.997686	Observable_XZZ_ev = 0.000003
# Epoch: 392	Fidelity = 0.932118	KL_Divergence = 0.037400	Observable_XXX_ev = 0.948772	Observable_XZZ_ev = 0.000662
# Epoch: 393	Fidelity = 0.929261	KL_Divergence = 0.042150	Observable_XXX_ev = 1.035695	Observable_XZZ_ev = 0.001100
# Epoch: 394	Fidelity = 0.928520	KL_Divergence = 0.043327	Observable_XXX_ev = 1.010011	Observable_XZZ_ev = -0.001390
# Epoch: 395	Fidelity = 0.929516	KL_Divergence = 0.041561	Observable_XXX_ev = 1.013453	Observable_XZZ_ev = 0.000276
# Epoch: 396	Fidelity = 0.929280	KL_Divergence = 0.041848	Observable_XXX_ev = 1.033435	Observable_XZZ_ev = -0.001035
# Epoch: 397	Fidelity = 0.933859	KL_Divergence = 0.034350	Observable_XXX_ev = 0.934889	Observable_XZZ_ev = -0.000091
# Epoch: 398	Fidelity = 0.932072	KL_Divergence = 0.037370	Observable_XXX_ev = 1.012239	Observable_XZZ_ev = -0.000160
# Epoch: 399	Fidelity = 0.933672	KL_Divergence = 0.034689	Observable_XXX_ev = 0.998697	Observable_XZZ_ev = -0.000189
# Epoch: 400	Fidelity = 0.936922	KL_Divergence = 0.029432	Observable_XXX_ev = 1.045281	Observable_XZZ_ev = 0.000168
# Epoch: 401	Fidelity = 0.938971	KL_Divergence = 0.026044	Observable_XXX_ev = 0.987497	Observable_XZZ_ev = 0.000283
# Epoch: 402	Fidelity = 0.938361	KL_Divergence = 0.027020	Observable_XXX_ev = 1.094331	Observable_XZZ_ev = -0.000251
# Epoch: 403	Fidelity = 0.936926	KL_Divergence = 0.029427	Observable_XXX_ev = 1.007603	Observable_XZZ_ev = 0.000110
# Epoch: 404	Fidelity = 0.937499	KL_Divergence = 0.028722	Observable_XXX_ev = 1.071041	Observable_XZZ_ev = 0.000153
# Epoch: 405	Fidelity = 0.937774	KL_Divergence = 0.028247	Observable_XXX_ev = 0.984406	Observable_XZZ_ev = -0.002323
# Epoch: 406	Fidelity = 0.936929	KL_Divergence = 0.029505	Observable_XXX_ev = 1.006392	Observable_XZZ_ev = -0.002378
# Epoch: 407	Fidelity = 0.932575	KL_Divergence = 0.036658	Observable_XXX_ev = 0.920009	Observable_XZZ_ev = 0.000271
# Epoch: 408	Fidelity = 0.930682	KL_Divergence = 0.039795	Observable_XXX_ev = 1.099717	Observable_XZZ_ev = 0.000011
# Epoch: 409	Fidelity = 0.933622	KL_Divergence = 0.034988	Observable_XXX_ev = 0.938436	Observable_XZZ_ev = 0.000449
# Epoch: 410	Fidelity = 0.929370	KL_Divergence = 0.042079	Observable_XXX_ev = 0.969695	Observable_XZZ_ev = -0.000120
# Epoch: 411	Fidelity = 0.930260	KL_Divergence = 0.040531	Observable_XXX_ev = 0.937418	Observable_XZZ_ev = 0.000325
# Epoch: 412	Fidelity = 0.932122	KL_Divergence = 0.037457	Observable_XXX_ev = 0.909628	Observable_XZZ_ev = 0.000253
# Epoch: 413	Fidelity = 0.932297	KL_Divergence = 0.037137	Observable_XXX_ev = 0.966258	Observable_XZZ_ev = -0.001613
# Epoch: 414	Fidelity = 0.935648	KL_Divergence = 0.031765	Observable_XXX_ev = 1.019660	Observable_XZZ_ev = 0.000112
# Epoch: 415	Fidelity = 0.934629	KL_Divergence = 0.033275	Observable_XXX_ev = 1.020995	Observable_XZZ_ev = -0.002245
# Epoch: 416	Fidelity = 0.935831	KL_Divergence = 0.031208	Observable_XXX_ev = 1.004084	Observable_XZZ_ev = 0.000451
# Epoch: 417	Fidelity = 0.935299	KL_Divergence = 0.032164	Observable_XXX_ev = 0.793296	Observable_XZZ_ev = -0.000194
# Epoch: 418	Fidelity = 0.934192	KL_Divergence = 0.034106	Observable_XXX_ev = 0.841966	Observable_XZZ_ev = -0.000006
# Epoch: 419	Fidelity = 0.932942	KL_Divergence = 0.036168	Observable_XXX_ev = 0.947051	Observable_XZZ_ev = 0.000270
# Epoch: 420	Fidelity = 0.933825	KL_Divergence = 0.034870	Observable_XXX_ev = 0.997905	Observable_XZZ_ev = -0.000266
# Epoch: 421	Fidelity = 0.932017	KL_Divergence = 0.037670	Observable_XXX_ev = 0.931505	Observable_XZZ_ev = 0.000136
# Epoch: 422	Fidelity = 0.928252	KL_Divergence = 0.043855	Observable_XXX_ev = 0.984954	Observable_XZZ_ev = 0.000017
# Epoch: 423	Fidelity = 0.927334	KL_Divergence = 0.045334	Observable_XXX_ev = 0.867414	Observable_XZZ_ev = 0.000531
# Epoch: 424	Fidelity = 0.929030	KL_Divergence = 0.042614	Observable_XXX_ev = 0.949058	Observable_XZZ_ev = -0.001691
# Epoch: 425	Fidelity = 0.928516	KL_Divergence = 0.043422	Observable_XXX_ev = 0.954887	Observable_XZZ_ev = 0.000312
# Epoch: 426	Fidelity = 0.929326	KL_Divergence = 0.042064	Observable_XXX_ev = 0.926382	Observable_XZZ_ev = -0.000048
# Epoch: 427	Fidelity = 0.926809	KL_Divergence = 0.046310	Observable_XXX_ev = 0.877170	Observable_XZZ_ev = 0.000388
# Epoch: 428	Fidelity = 0.928100	KL_Divergence = 0.044139	Observable_XXX_ev = 0.959401	Observable_XZZ_ev = 0.000376
# Epoch: 429	Fidelity = 0.929410	KL_Divergence = 0.041899	Observable_XXX_ev = 0.922296	Observable_XZZ_ev = 0.000826
# Epoch: 430	Fidelity = 0.932426	KL_Divergence = 0.036903	Observable_XXX_ev = 1.003698	Observable_XZZ_ev = -0.000116
# Epoch: 431	Fidelity = 0.931677	KL_Divergence = 0.038158	Observable_XXX_ev = 1.128793	Observable_XZZ_ev = 0.000358
# Epoch: 432	Fidelity = 0.932070	KL_Divergence = 0.037487	Observable_XXX_ev = 1.049925	Observable_XZZ_ev = 0.000254
# Epoch: 433	Fidelity = 0.930071	KL_Divergence = 0.040844	Observable_XXX_ev = 0.989332	Observable_XZZ_ev = -0.000007
# Epoch: 434	Fidelity = 0.929014	KL_Divergence = 0.042691	Observable_XXX_ev = 0.909921	Observable_XZZ_ev = 0.000658
# Epoch: 435	Fidelity = 0.928796	KL_Divergence = 0.043051	Observable_XXX_ev = 0.958391	Observable_XZZ_ev = -0.000010
# Epoch: 436	Fidelity = 0.930153	KL_Divergence = 0.040691	Observable_XXX_ev = 0.969303	Observable_XZZ_ev = 0.000969
# Epoch: 437	Fidelity = 0.929428	KL_Divergence = 0.041812	Observable_XXX_ev = 0.872591	Observable_XZZ_ev = -0.001376
# Epoch: 438	Fidelity = 0.929100	KL_Divergence = 0.042402	Observable_XXX_ev = 1.090507	Observable_XZZ_ev = 0.000358
# Epoch: 439	Fidelity = 0.929669	KL_Divergence = 0.041428	Observable_XXX_ev = 0.916399	Observable_XZZ_ev = -0.003512
# Epoch: 440	Fidelity = 0.927560	KL_Divergence = 0.044972	Observable_XXX_ev = 0.990691	Observable_XZZ_ev = 0.000074
# Epoch: 441	Fidelity = 0.926429	KL_Divergence = 0.046751	Observable_XXX_ev = 0.871000	Observable_XZZ_ev = -0.000219
# Epoch: 442	Fidelity = 0.927223	KL_Divergence = 0.045393	Observable_XXX_ev = 1.017366	Observable_XZZ_ev = 0.000365
# Epoch: 443	Fidelity = 0.928738	KL_Divergence = 0.042848	Observable_XXX_ev = 1.096945	Observable_XZZ_ev = 0.000020
# Epoch: 444	Fidelity = 0.928503	KL_Divergence = 0.043324	Observable_XXX_ev = 0.961597	Observable_XZZ_ev = -0.004120
# Epoch: 445	Fidelity = 0.928956	KL_Divergence = 0.042567	Observable_XXX_ev = 1.004063	Observable_XZZ_ev = 0.000040
# Epoch: 446	Fidelity = 0.929377	KL_Divergence = 0.041848	Observable_XXX_ev = 1.048231	Observable_XZZ_ev = 0.000078
# Epoch: 447	Fidelity = 0.927080	KL_Divergence = 0.045728	Observable_XXX_ev = 0.950723	Observable_XZZ_ev = -0.001675
# Epoch: 448	Fidelity = 0.927241	KL_Divergence = 0.045411	Observable_XXX_ev = 1.037443	Observable_XZZ_ev = 0.001039
# Epoch: 449	Fidelity = 0.929415	KL_Divergence = 0.041799	Observable_XXX_ev = 1.074548	Observable_XZZ_ev = 0.000705
# Epoch: 450	Fidelity = 0.927768	KL_Divergence = 0.044579	Observable_XXX_ev = 0.974481	Observable_XZZ_ev = 0.001264
# Epoch: 451	Fidelity = 0.927278	KL_Divergence = 0.045408	Observable_XXX_ev = 0.993384	Observable_XZZ_ev = 0.001451
# Epoch: 452	Fidelity = 0.927817	KL_Divergence = 0.044519	Observable_XXX_ev = 0.914371	Observable_XZZ_ev = 0.001560
# Epoch: 453	Fidelity = 0.926348	KL_Divergence = 0.046917	Observable_XXX_ev = 0.926298	Observable_XZZ_ev = 0.000394
# Epoch: 454	Fidelity = 0.928531	KL_Divergence = 0.043246	Observable_XXX_ev = 1.061187	Observable_XZZ_ev = 0.000536
# Epoch: 455	Fidelity = 0.929249	KL_Divergence = 0.042055	Observable_XXX_ev = 0.904913	Observable_XZZ_ev = -0.001869
# Epoch: 456	Fidelity = 0.930023	KL_Divergence = 0.040855	Observable_XXX_ev = 1.021016	Observable_XZZ_ev = 0.000287
# Epoch: 457	Fidelity = 0.930780	KL_Divergence = 0.039574	Observable_XXX_ev = 1.143427	Observable_XZZ_ev = -0.000089
# Epoch: 458	Fidelity = 0.929919	KL_Divergence = 0.041069	Observable_XXX_ev = 0.953988	Observable_XZZ_ev = -0.000044
# Epoch: 459	Fidelity = 0.929476	KL_Divergence = 0.041804	Observable_XXX_ev = 0.867472	Observable_XZZ_ev = 0.000362
# Epoch: 460	Fidelity = 0.930803	KL_Divergence = 0.039598	Observable_XXX_ev = 0.916721	Observable_XZZ_ev = -0.000049
# Epoch: 461	Fidelity = 0.932515	KL_Divergence = 0.036741	Observable_XXX_ev = 0.917588	Observable_XZZ_ev = -0.002007
# Epoch: 462	Fidelity = 0.932060	KL_Divergence = 0.037450	Observable_XXX_ev = 0.954775	Observable_XZZ_ev = 0.000998
# Epoch: 463	Fidelity = 0.932359	KL_Divergence = 0.036934	Observable_XXX_ev = 1.003543	Observable_XZZ_ev = 0.000622
# Epoch: 464	Fidelity = 0.934251	KL_Divergence = 0.033847	Observable_XXX_ev = 0.972857	Observable_XZZ_ev = 0.001263
# Epoch: 465	Fidelity = 0.934949	KL_Divergence = 0.032690	Observable_XXX_ev = 0.874445	Observable_XZZ_ev = -0.001653
# Epoch: 466	Fidelity = 0.932837	KL_Divergence = 0.036155	Observable_XXX_ev = 1.062403	Observable_XZZ_ev = 0.000168
# Epoch: 467	Fidelity = 0.932703	KL_Divergence = 0.036341	Observable_XXX_ev = 0.980045	Observable_XZZ_ev = -0.001798
# Epoch: 468	Fidelity = 0.933276	KL_Divergence = 0.035430	Observable_XXX_ev = 0.870594	Observable_XZZ_ev = 0.000615
# Epoch: 469	Fidelity = 0.932103	KL_Divergence = 0.037395	Observable_XXX_ev = 0.938870	Observable_XZZ_ev = 0.000873
# Epoch: 470	Fidelity = 0.932829	KL_Divergence = 0.036193	Observable_XXX_ev = 0.933298	Observable_XZZ_ev = -0.001157
# Epoch: 471	Fidelity = 0.932049	KL_Divergence = 0.037473	Observable_XXX_ev = 0.948803	Observable_XZZ_ev = 0.000870
# Epoch: 472	Fidelity = 0.932273	KL_Divergence = 0.037133	Observable_XXX_ev = 1.072210	Observable_XZZ_ev = -0.000122
# Epoch: 473	Fidelity = 0.932782	KL_Divergence = 0.036311	Observable_XXX_ev = 1.101241	Observable_XZZ_ev = 0.001157
# Epoch: 474	Fidelity = 0.933136	KL_Divergence = 0.035683	Observable_XXX_ev = 0.990618	Observable_XZZ_ev = -0.000037
# Epoch: 475	Fidelity = 0.933726	KL_Divergence = 0.034692	Observable_XXX_ev = 1.024494	Observable_XZZ_ev = 0.000041
# Epoch: 476	Fidelity = 0.934159	KL_Divergence = 0.034001	Observable_XXX_ev = 0.959407	Observable_XZZ_ev = 0.000152
# Epoch: 477	Fidelity = 0.934180	KL_Divergence = 0.033919	Observable_XXX_ev = 0.943832	Observable_XZZ_ev = 0.000063
# Epoch: 478	Fidelity = 0.933644	KL_Divergence = 0.034811	Observable_XXX_ev = 0.922139	Observable_XZZ_ev = -0.000151
# Epoch: 479	Fidelity = 0.932913	KL_Divergence = 0.036032	Observable_XXX_ev = 0.956585	Observable_XZZ_ev = 0.000892
# Epoch: 480	Fidelity = 0.931104	KL_Divergence = 0.039031	Observable_XXX_ev = 0.863723	Observable_XZZ_ev = -0.001537
# Epoch: 481	Fidelity = 0.930991	KL_Divergence = 0.039196	Observable_XXX_ev = 0.995542	Observable_XZZ_ev = 0.000313
# Epoch: 482	Fidelity = 0.931540	KL_Divergence = 0.038314	Observable_XXX_ev = 1.014096	Observable_XZZ_ev = 0.000194
# Epoch: 483	Fidelity = 0.931046	KL_Divergence = 0.039116	Observable_XXX_ev = 0.817048	Observable_XZZ_ev = -0.001849
# Epoch: 484	Fidelity = 0.930721	KL_Divergence = 0.039634	Observable_XXX_ev = 0.975734	Observable_XZZ_ev = 0.000264
# Epoch: 485	Fidelity = 0.930547	KL_Divergence = 0.039895	Observable_XXX_ev = 0.857787	Observable_XZZ_ev = 0.000393
# Epoch: 486	Fidelity = 0.929902	KL_Divergence = 0.040964	Observable_XXX_ev = 0.992443	Observable_XZZ_ev = -0.003910
# Epoch: 487	Fidelity = 0.930952	KL_Divergence = 0.039269	Observable_XXX_ev = 1.008836	Observable_XZZ_ev = 0.000087
# Epoch: 488	Fidelity = 0.932425	KL_Divergence = 0.036895	Observable_XXX_ev = 1.033359	Observable_XZZ_ev = -0.002148
# Epoch: 489	Fidelity = 0.932278	KL_Divergence = 0.037132	Observable_XXX_ev = 0.983467	Observable_XZZ_ev = 0.001052
# Epoch: 490	Fidelity = 0.931636	KL_Divergence = 0.038179	Observable_XXX_ev = 0.965431	Observable_XZZ_ev = 0.000573
# Epoch: 491	Fidelity = 0.931537	KL_Divergence = 0.038362	Observable_XXX_ev = 1.061510	Observable_XZZ_ev = 0.001356
# Epoch: 492	Fidelity = 0.932629	KL_Divergence = 0.036538	Observable_XXX_ev = 1.039147	Observable_XZZ_ev = 0.000648
# Epoch: 493	Fidelity = 0.932637	KL_Divergence = 0.036487	Observable_XXX_ev = 0.934833	Observable_XZZ_ev = -0.000212
# Epoch: 494	Fidelity = 0.933098	KL_Divergence = 0.035702	Observable_XXX_ev = 0.932235	Observable_XZZ_ev = 0.000064
# Epoch: 495	Fidelity = 0.934213	KL_Divergence = 0.033907	Observable_XXX_ev = 0.987833	Observable_XZZ_ev = -0.000089
# Epoch: 496	Fidelity = 0.933853	KL_Divergence = 0.034514	Observable_XXX_ev = 0.943537	Observable_XZZ_ev = 0.001124
# Epoch: 497	Fidelity = 0.933515	KL_Divergence = 0.035049	Observable_XXX_ev = 0.930927	Observable_XZZ_ev = -0.000085
# Epoch: 498	Fidelity = 0.933855	KL_Divergence = 0.034495	Observable_XXX_ev = 1.000467	Observable_XZZ_ev = 0.000956
# Epoch: 499	Fidelity = 0.934625	KL_Divergence = 0.033248	Observable_XXX_ev = 1.018054	Observable_XZZ_ev = -0.002164
# Epoch: 500	Fidelity = 0.934612	KL_Divergence = 0.033273	Observable_XXX_ev = 0.820009	Observable_XZZ_ev = 0.000588
# Total time elapsed during training: 75773.557 s

# %%
fidelities = callbacks[0]["Fidelity"]
KLs = callbacks[0]["KL_Divergence"]
epoch_range = np.arange(period, epoch + 1, period)

fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 5))
ax = axs[0]
ax.plot(epoch_range, fidelities, "o", color = "C0", markeredgecolor = "black")
ax.set_ylabel(r"Fidelity")
ax.set_xlabel(r"Epoch")
ax.set_ylim(0.00, 1.00)

ax = axs[1]
ax.plot(epoch_range, KLs, "o", color = "C1", markeredgecolor = "black")
ax.set_ylabel(r"KL Divergence")
ax.set_xlabel(r"Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %% [markdown]
# ## save model & train log

# %%
# save model
nn_state_dm.save("./exp001/model.pt")
# save train log
train_log_df = pd.DataFrame()
train_log_df["epoch"] = np.arange(period, epoch+1, period)
train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
train_log_df["Observable_XXX_ev"] = callbacks[0]["Observable_XXX_ev"]
train_log_df["Observable_XZZ_ev"] = callbacks[0]["Observable_XZZ_ev"]
train_log_df.to_csv("./exp001/train_log.csv", index=False)
