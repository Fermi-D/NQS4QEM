# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]
# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]
# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]
# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]
# data path info
train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
ideal_state_path = f"./target_state/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## caluculate ideal state

# %%
# calculate ideal state
is_ideal_state_file = os.path.exists(ideal_state_path)
if is_ideal_state_file:
    print("ideal state data is exsisted !")
else:
    print("caluculate ideal state data ...")
    os.makedirs(ideal_state_path, exist_ok = True)
    subprocess.run("python caluculate_ideal_state.py", shell=True)
    print("ideal state data is ready !")
# Out:
# ideal state data is exsisted !

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path)
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    subprocess.run("python generate_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# train data is exsisted !

# %% [markdown]
# ## load dataset

# %%
meas_pattern_path = train_data_path + "/measurement_pattern.txt"
meas_label_path = train_data_path + "/measurement_label.txt"
meas_result_path = train_data_path + "/measurement_result.txt"
ideal_rho_re_path = ideal_state_path + "/rho_real.txt"
ideal_rho_im_path = ideal_state_path + "/rho_imag.txt"
meas_result, ideal_rho, meas_label, meas_pattern = data.load_data_DM(meas_result_path,
                                                                     ideal_rho_re_path,
                                                                     ideal_rho_im_path,
                                                                     meas_label_path,
                                                                     meas_pattern_path)

# %% [markdown]
# ## build RBM architecture

# %%
nn_state_dm = DensityMatrix(
    num_visible = n_visible_unit, 
    num_hidden = n_hidden_unit, 
    num_aux = n_aux_unit, 
    unitary_dict = unitaries.create_dict(),
    gpu = False
)

# %% [markdown]
# ## estimate observable expectation value

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XXX():
    target_list = [0, 1, 2]
    pauli_index = [1, 1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZZ():
    target_list = [0, 1, 2]
    pauli_index = [1, 3, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_XXX_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "X", 2: "X"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_XZZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "Z", 2: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

# %% [markdown]
# ## callback setting

# %%
def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "KL_Divergence": ts.KL,
        "Observable_XXX_ev": observable_XXX_ev,
        "Observable_XZZ_ev": observable_XZZ_ev,
    }

    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = ideal_rho,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    return callbacks

callbacks = create_callback_dm(nn_state_dm)

# %% [markdown]
# ## train

# %%
nn_state_dm.fit(
    data = meas_result,
    input_bases = meas_label,
    epochs = epoch,
    pos_batch_size = pbs,
    neg_batch_size = nbs,
    lr = lr,
    k = n_gibbs_step,
    bases = meas_pattern,
    callbacks = callbacks,
    time = True,
    optimizer = torch.optim.Adadelta,
    scheduler = torch.optim.lr_scheduler.StepLR,
    scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
)
# Out:
# Epoch: 1	Fidelity = 0.434052	KL_Divergence = 0.581180	Observable_XXX_ev = 0.241398	Observable_XZZ_ev = 0.068259
# Epoch: 2	Fidelity = 0.747093	KL_Divergence = 0.314015	Observable_XXX_ev = 0.233214	Observable_XZZ_ev = 0.176321
# Epoch: 3	Fidelity = 0.861113	KL_Divergence = 0.233981	Observable_XXX_ev = 0.163513	Observable_XZZ_ev = 0.150244
# Epoch: 4	Fidelity = 0.896703	KL_Divergence = 0.217067	Observable_XXX_ev = 0.129969	Observable_XZZ_ev = 0.210127
# Epoch: 5	Fidelity = 0.929577	KL_Divergence = 0.189475	Observable_XXX_ev = 0.106351	Observable_XZZ_ev = 0.084763
# Epoch: 6	Fidelity = 0.949705	KL_Divergence = 0.173936	Observable_XXX_ev = 0.085419	Observable_XZZ_ev = 0.072296
# Epoch: 7	Fidelity = 0.958091	KL_Divergence = 0.169703	Observable_XXX_ev = 0.090860	Observable_XZZ_ev = 0.040009
# Epoch: 8	Fidelity = 0.932083	KL_Divergence = 0.214457	Observable_XXX_ev = 0.048221	Observable_XZZ_ev = 0.062036
# Epoch: 9	Fidelity = 0.943937	KL_Divergence = 0.203678	Observable_XXX_ev = 0.062197	Observable_XZZ_ev = 0.017136
# Epoch: 10	Fidelity = 0.969288	KL_Divergence = 0.166578	Observable_XXX_ev = 0.058216	Observable_XZZ_ev = 0.108269
# Epoch: 11	Fidelity = 0.930851	KL_Divergence = 0.223954	Observable_XXX_ev = 0.050641	Observable_XZZ_ev = 0.033768
# Epoch: 12	Fidelity = 0.901212	KL_Divergence = 0.272735	Observable_XXX_ev = 0.042188	Observable_XZZ_ev = 0.049886
# Epoch: 13	Fidelity = 0.959055	KL_Divergence = 0.183411	Observable_XXX_ev = 0.060149	Observable_XZZ_ev = 0.165582
# Epoch: 14	Fidelity = 0.960923	KL_Divergence = 0.178022	Observable_XXX_ev = 0.059658	Observable_XZZ_ev = 0.039371
# Epoch: 15	Fidelity = 0.960410	KL_Divergence = 0.176125	Observable_XXX_ev = 0.068280	Observable_XZZ_ev = 0.031369
# Epoch: 16	Fidelity = 0.951711	KL_Divergence = 0.191009	Observable_XXX_ev = 0.069672	Observable_XZZ_ev = -0.003968
# Epoch: 17	Fidelity = 0.954296	KL_Divergence = 0.182732	Observable_XXX_ev = 0.068702	Observable_XZZ_ev = 0.031058
# Epoch: 18	Fidelity = 0.964314	KL_Divergence = 0.167758	Observable_XXX_ev = 0.076220	Observable_XZZ_ev = 0.018601
# Epoch: 19	Fidelity = 0.966331	KL_Divergence = 0.163712	Observable_XXX_ev = 0.083322	Observable_XZZ_ev = 0.019604
# Epoch: 20	Fidelity = 0.952420	KL_Divergence = 0.181720	Observable_XXX_ev = 0.092101	Observable_XZZ_ev = 0.192389
# Epoch: 21	Fidelity = 0.932070	KL_Divergence = 0.208376	Observable_XXX_ev = 0.088887	Observable_XZZ_ev = 0.089585
# Epoch: 22	Fidelity = 0.960433	KL_Divergence = 0.164217	Observable_XXX_ev = 0.131865	Observable_XZZ_ev = 0.020671
# Epoch: 23	Fidelity = 0.954511	KL_Divergence = 0.167302	Observable_XXX_ev = 0.133159	Observable_XZZ_ev = 0.077012
# Epoch: 24	Fidelity = 0.953024	KL_Divergence = 0.165699	Observable_XXX_ev = 0.133633	Observable_XZZ_ev = -0.014452
# Epoch: 25	Fidelity = 0.949384	KL_Divergence = 0.167275	Observable_XXX_ev = 0.143934	Observable_XZZ_ev = 0.017267
# Epoch: 26	Fidelity = 0.940983	KL_Divergence = 0.176196	Observable_XXX_ev = 0.161397	Observable_XZZ_ev = 0.013362
# Epoch: 27	Fidelity = 0.940811	KL_Divergence = 0.173247	Observable_XXX_ev = 0.169369	Observable_XZZ_ev = 0.009628
# Epoch: 28	Fidelity = 0.940168	KL_Divergence = 0.169978	Observable_XXX_ev = 0.186785	Observable_XZZ_ev = 0.004074
# Epoch: 29	Fidelity = 0.932514	KL_Divergence = 0.176617	Observable_XXX_ev = 0.225747	Observable_XZZ_ev = 0.119255
# Epoch: 30	Fidelity = 0.930780	KL_Divergence = 0.171426	Observable_XXX_ev = 0.216501	Observable_XZZ_ev = 0.030417
# Epoch: 31	Fidelity = 0.923342	KL_Divergence = 0.174639	Observable_XXX_ev = 0.256469	Observable_XZZ_ev = -0.034371
# Epoch: 32	Fidelity = 0.915804	KL_Divergence = 0.175729	Observable_XXX_ev = 0.297833	Observable_XZZ_ev = 0.009310
# Epoch: 33	Fidelity = 0.898754	KL_Divergence = 0.190223	Observable_XXX_ev = 0.300659	Observable_XZZ_ev = -0.004027
# Epoch: 34	Fidelity = 0.894305	KL_Divergence = 0.182956	Observable_XXX_ev = 0.384475	Observable_XZZ_ev = -0.002056
# Epoch: 35	Fidelity = 0.884353	KL_Divergence = 0.184375	Observable_XXX_ev = 0.490270	Observable_XZZ_ev = -0.029654
# Epoch: 36	Fidelity = 0.875151	KL_Divergence = 0.187027	Observable_XXX_ev = 0.491411	Observable_XZZ_ev = -0.053089
# Epoch: 37	Fidelity = 0.862197	KL_Divergence = 0.193574	Observable_XXX_ev = 0.471469	Observable_XZZ_ev = -0.039920
# Epoch: 38	Fidelity = 0.852768	KL_Divergence = 0.192265	Observable_XXX_ev = 0.592252	Observable_XZZ_ev = -0.058410
# Epoch: 39	Fidelity = 0.844823	KL_Divergence = 0.197406	Observable_XXX_ev = 0.681415	Observable_XZZ_ev = -0.060706
# Epoch: 40	Fidelity = 0.841491	KL_Divergence = 0.195562	Observable_XXX_ev = 0.784405	Observable_XZZ_ev = -0.029421
# Epoch: 41	Fidelity = 0.828139	KL_Divergence = 0.201952	Observable_XXX_ev = 0.714642	Observable_XZZ_ev = -0.044947
# Epoch: 42	Fidelity = 0.819853	KL_Divergence = 0.205324	Observable_XXX_ev = 0.768795	Observable_XZZ_ev = -0.068758
# Epoch: 43	Fidelity = 0.822680	KL_Divergence = 0.200901	Observable_XXX_ev = 0.920336	Observable_XZZ_ev = -0.064167
# Epoch: 44	Fidelity = 0.816253	KL_Divergence = 0.202896	Observable_XXX_ev = 0.787222	Observable_XZZ_ev = -0.085281
# Epoch: 45	Fidelity = 0.806340	KL_Divergence = 0.205730	Observable_XXX_ev = 0.743876	Observable_XZZ_ev = -0.066360
# Epoch: 46	Fidelity = 0.796991	KL_Divergence = 0.212189	Observable_XXX_ev = 0.911531	Observable_XZZ_ev = -0.054622
# Epoch: 47	Fidelity = 0.787769	KL_Divergence = 0.214404	Observable_XXX_ev = 0.766761	Observable_XZZ_ev = -0.040029
# Epoch: 48	Fidelity = 0.784658	KL_Divergence = 0.213419	Observable_XXX_ev = 0.865973	Observable_XZZ_ev = -0.075715
# Epoch: 49	Fidelity = 0.776187	KL_Divergence = 0.217625	Observable_XXX_ev = 0.948223	Observable_XZZ_ev = -0.080772
# Epoch: 50	Fidelity = 0.767881	KL_Divergence = 0.219791	Observable_XXX_ev = 0.890180	Observable_XZZ_ev = -0.061832
# Epoch: 51	Fidelity = 0.762355	KL_Divergence = 0.221236	Observable_XXX_ev = 0.836340	Observable_XZZ_ev = -0.044274
# Epoch: 52	Fidelity = 0.749079	KL_Divergence = 0.228071	Observable_XXX_ev = 0.926340	Observable_XZZ_ev = -0.040885
# Epoch: 53	Fidelity = 0.745724	KL_Divergence = 0.230793	Observable_XXX_ev = 1.087845	Observable_XZZ_ev = -0.033207
# Epoch: 54	Fidelity = 0.739488	KL_Divergence = 0.229249	Observable_XXX_ev = 0.984317	Observable_XZZ_ev = -0.042862
# Epoch: 55	Fidelity = 0.724725	KL_Divergence = 0.241637	Observable_XXX_ev = 1.000613	Observable_XZZ_ev = -0.044872
# Epoch: 56	Fidelity = 0.716834	KL_Divergence = 0.242784	Observable_XXX_ev = 0.920548	Observable_XZZ_ev = -0.040752
# Epoch: 57	Fidelity = 0.708380	KL_Divergence = 0.244903	Observable_XXX_ev = 1.067105	Observable_XZZ_ev = -0.022889
# Epoch: 58	Fidelity = 0.697080	KL_Divergence = 0.249708	Observable_XXX_ev = 1.055583	Observable_XZZ_ev = -0.057465
# Epoch: 59	Fidelity = 0.691108	KL_Divergence = 0.250164	Observable_XXX_ev = 0.894338	Observable_XZZ_ev = -0.032598
# Epoch: 60	Fidelity = 0.680946	KL_Divergence = 0.252785	Observable_XXX_ev = 0.935883	Observable_XZZ_ev = -0.057383
# Epoch: 61	Fidelity = 0.672823	KL_Divergence = 0.259606	Observable_XXX_ev = 0.895632	Observable_XZZ_ev = -0.057965
# Epoch: 62	Fidelity = 0.665286	KL_Divergence = 0.262707	Observable_XXX_ev = 1.029405	Observable_XZZ_ev = -0.041026
# Epoch: 63	Fidelity = 0.654383	KL_Divergence = 0.269425	Observable_XXX_ev = 1.053694	Observable_XZZ_ev = -0.029625
# Epoch: 64	Fidelity = 0.646253	KL_Divergence = 0.272519	Observable_XXX_ev = 1.055607	Observable_XZZ_ev = -0.024178
# Epoch: 65	Fidelity = 0.639724	KL_Divergence = 0.274932	Observable_XXX_ev = 0.997981	Observable_XZZ_ev = -0.050086
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 nn_state_dm.fit(
#       2     data = meas_result,
#       3     input_bases = meas_label,
#       4     epochs = epoch,
#       5     pos_batch_size = pbs,
#       6     neg_batch_size = nbs,
#       7     lr = lr,
#       8     k = n_gibbs_step,
#       9     bases = meas_pattern,
#      10     callbacks = callbacks,
#      11     time = True,
#      12     optimizer = torch.optim.Adadelta,
#      13     scheduler = torch.optim.lr_scheduler.StepLR,
#      14     scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
#      15 )
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/density_matrix.py:354, in DensityMatrix.fit(self, data, epochs, pos_batch_size, neg_batch_size, k, lr, input_bases, progbar, starting_epoch, time, callbacks, optimizer, optimizer_args, scheduler, scheduler_args, **kwargs)
#     352     raise ValueError("input_bases must be provided to train a DensityMatrix!")
#     353 else:
# --> 354     super().fit(
#     355         data=data,
#     356         epochs=epochs,
#     357         pos_batch_size=pos_batch_size,
#     358         neg_batch_size=neg_batch_size,
#     359         k=k,
#     360         lr=lr,
#     361         input_bases=input_bases,
#     362         progbar=progbar,
#     363         starting_epoch=starting_epoch,
#     364         time=time,
#     365         callbacks=callbacks,
#     366         optimizer=optimizer,
#     367         optimizer_args=optimizer_args,
#     368         scheduler=scheduler,
#     369         scheduler_args=scheduler_args,
#     370         **kwargs,
#     371     )
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/neural_state.py:614, in NeuralStateBase.fit(self, data, epochs, pos_batch_size, neg_batch_size, k, lr, input_bases, progbar, starting_epoch, time, callbacks, optimizer, optimizer_args, scheduler, scheduler_args, **kwargs)
#     611 for b, batch in enumerate(data_iterator):
#     612     callbacks.on_batch_start(self, ep, b)
# --> 614     all_grads = self.compute_batch_gradients(k, *batch)
#     616     optimizer.zero_grad()  # clear any cached gradients
#     618     # assign gradients to corresponding parameters
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/neural_state.py:439, in NeuralStateBase.compute_batch_gradients(self, k, samples_batch, neg_batch, bases_batch)
#     418 """Compute the gradients of a batch of the training data (`samples_batch`).
#     419
#     420 If measurements are taken in bases other than the reference basis,
#    (...)
#     436 :rtype: list[torch.Tensor]
#     437 """
#     438 # Positive phase: learning signal driven by the data (and bases)
# --> 439 grad = self.positive_phase_gradients(samples_batch, bases_batch=bases_batch)
#     441 # Negative phase: learning signal driven by the amplitude RBM of
#     442 # the NN state
#     443 vk = self.rbm_am.gibbs_steps(k, neg_batch)
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/neural_state.py:382, in NeuralStateBase.positive_phase_gradients(self, samples_batch, bases_batch)
#     371 def positive_phase_gradients(self, samples_batch, bases_batch=None):
#     372     r"""Computes the positive phase of the gradients of the parameters.
#     373
#     374     :param samples_batch: The measurements
#    (...)
#     380     :rtype: list[torch.Tensor]
#     381     """
# --> 382     grad = self.gradient(samples_batch, bases=bases_batch)
#     383     grad = [gr / float(samples_batch.shape[0]) for gr in grad]
#     384     return grad
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/neural_state.py:359, in NeuralStateBase.gradient(self, samples, bases)
#     356 rot_sites = np.where(basis != "Z")[0]
#     358 if rot_sites.size != 0:
# --> 359     sample_grad = self.rotated_gradient(basis, samples[indices == i, :])
#     360 else:
#     361     sample_grad = [
#     362         self.rbm_am.effective_energy_gradient(samples[indices == i, :]),
#     363         0.0,
#     364     ]
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/density_matrix.py:298, in DensityMatrix.rotated_gradient(self, basis, sample)
#     293 UrhoU, UrhoU_v, v = unitaries.rotate_rho_probs(
#     294     self, basis, sample, include_extras=True
#     295 )
#     296 inv_UrhoU = 1 / (UrhoU + 1e-8)  # avoid dividing by zero
# --> 298 raw_grads = [self.am_grads(v), self.ph_grads(v)]
#     300 rotated_grad = [
#     301     -cplx.einsum("ijb,ijbg->bg", UrhoU_v, g, imag_part=False) for g in raw_grads
#     302 ]
#     304 return [torch.einsum("b,bg->g", inv_UrhoU, g) for g in rotated_grad]
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/density_matrix.py:315, in DensityMatrix.am_grads(self, v)
#     306 def am_grads(self, v):
#     307     r"""Computes the gradients of the amplitude RBM for given input states
#     308
#     309     :param v: The first input state, :math:`\sigma`
#    (...)
#     313     :rtype: torch.Tensor
#     314     """
# --> 315     return self.rbm_am.gamma_grad(v, v, eta=+1, expand=True) + self.pi_grad(
#     316         v, v, phase=False, expand=True
#     317     )
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/nn_states/density_matrix.py:194, in DensityMatrix.pi_grad(self, v, vp, phase, expand)
#     191     arg_real = self.rbm_am.mixing_term(v + vp)
#     192     arg_imag = self.rbm_ph.mixing_term(v - vp)
# --> 194 sig = cplx.sigmoid(arg_real, arg_imag)
#     196 batch_sizes = (
#     197     (v.shape[0], vp.shape[0], *v.shape[1:-1]) if expand else (*v.shape[:-1],)
#     198 )
#     200 W_grad = torch.zeros_like(self.rbm_am.weights_W).expand(*batch_sizes, -1, -1)
#
# File /opt/conda/lib/python3.9/site-packages/qucumber/utils/cplx.py:331, in sigmoid(x, y)
#     320 r"""Returns the sigmoid function of a complex number. Acts elementwise.
#     321
#     322 :param x: The real part of the complex number
#    (...)
#     327 :rtype: torch.Tensor
#     328 """
#     329 z = (x.cpu().numpy()) + 1j * (y.cpu().numpy())
# --> 331 out = np.exp(z) / (1 + np.exp(z))
#     332 out = torch.tensor([np.real(out), np.imag(out)]).to(x)
#     334 return out
#
# KeyboardInterrupt:

# %%
fidelities = callbacks[0]["Fidelity"]
KLs = callbacks[0]["KL_Divergence"]
epoch_range = np.arange(period, epoch + 1, period)

fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 5))
ax = axs[0]
ax.plot(epoch_range, fidelities, "o", color = "C0", markeredgecolor = "black")
ax.set_ylabel(r"Fidelity")
ax.set_xlabel(r"Epoch")
ax.set_ylim(0.00, 1.00)

ax = axs[1]
ax.plot(epoch_range, KLs, "o", color = "C1", markeredgecolor = "black")
ax.set_ylabel(r"KL Divergence")
ax.set_xlabel(r"Epoch")

# %% [markdown]
# ## save model & train log

# %%
# save model
nn_state_dm.save("./exp001/model.pt")
# save train log
train_log_df = pd.DataFrame()
train_log_df["epoch"] = np.arange(period, epoch+1, period)
train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
train_log_df["Observable_XX_ev"] = callbacks[0]["Observable_XX_ev"]
train_log_df["Observable_XZ_ev"] = callbacks[0]["Observable_XZ_ev"]
train_log_df.to_csv("./exp001/train_log.csv", index=False)
