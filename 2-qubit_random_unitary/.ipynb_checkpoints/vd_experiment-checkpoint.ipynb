# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]
# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]
# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]
# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]
# data path info
environment = "local"
if environment == "local":
    train_data_path = f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = f"./target_state/"
if environment == "colab":
    from google.colab import drive
    drive.mount("/content/drive/")
    rive_path = "/content/drive/MyDrive/NQS4QEM/Bell"
    train_data_path = drive_path + f"./data/{error_model}/error_prob_{100*error_rate}%/num_of_data_{each_n_shot}/"
    ideal_state_path = drive_path + f"./target_state/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## caluculate ideal state

# %%
# calculate ideal state
is_ideal_state_file = os.path.exists(ideal_state_path)
if is_ideal_state_file:
    print("ideal state data is exsisted !")
else:
    print("caluculate ideal state data ...")
    subprocess.run("python caluculate_ideal_state.py", shell=True)
    print("ideal state data is ready !")
# Out:
# ideal state data is exsisted !

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path)
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    subprocess.run("python generate_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# generate directries & train data ...
# 0it [00:00, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#
#  77%|███████▋  | 766/1000 [00:09<00:02, 84.28it/s]
#  78%|███████▊  | 775/1000 [00:09<00:02, 84.80it/s]
#  78%|███████▊  | 784/1000 [00:09<00:02, 85.63it/s]
#  79%|███████▉  | 793/1000 [00:09<00:02, 85.99it/s]
#  80%|████████  | 802/1000 [00:09<00:02, 84.99it/s]
#  81%|████████  | 811/1000 [00:09<00:02, 78.50it/s]
#  82%|████████▏ | 819/1000 [00:09<00:02, 78.13it/s]
#  83%|████████▎ | 827/1000 [00:09<00:02, 61.14it/s]
#  84%|████████▎ | 835/1000 [00:10<00:02, 64.48it/s]
#  84%|████████▍ | 843/1000 [00:10<00:02, 66.76it/s]
#  85%|████████▌ | 852/1000 [00:10<00:02, 71.37it/s]
#  86%|████████▌ | 861/1000 [00:10<00:01, 75.31it/s]
#  87%|████████▋ | 870/1000 [00:10<00:01, 78.51it/s]
#  88%|████████▊ | 879/1000 [00:10<00:01, 80.14it/s]
#  89%|████████▉ | 888/1000 [00:10<00:01, 81.41it/s]
#  90%|████████▉ | 897/1000 [00:10<00:01, 83.33it/s]
#  91%|█████████ | 906/1000 [00:10<00:01, 78.92it/s]
#  91%|█████████▏| 914/1000 [00:11<00:01, 79.07it/s]
#  92%|█████████▏| 923/1000 [00:11<00:00, 81.28it/s]
#  93%|█████████▎| 932/1000 [00:11<00:00, 82.59it/s]
#  94%|█████████▍| 941/1000 [00:11<00:00, 83.34it/s]
#  95%|█████████▌| 950/1000 [00:11<00:00, 84.48it/s]
#  96%|█████████▌| 959/1000 [00:11<00:00, 85.06it/s]
#  97%|█████████▋| 968/1000 [00:11<00:00, 86.31it/s]
#  98%|█████████▊| 977/1000 [00:11<00:00, 86.46it/s]
#  99%|█████████▊| 986/1000 [00:11<00:00, 86.89it/s]
# 100%|██████████| 1000/1000 [00:12<00:00, 83.22it/s][A
# 7it [01:29, 12.49s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# measurement pattern 7 : ('Z', 'Y')
#   1%|          | 9/1000 [00:00<00:11, 82.93it/s]
#   2%|▏         | 18/1000 [00:00<00:11, 85.74it/s]
#   3%|▎         | 27/1000 [00:00<00:11, 86.09it/s]
#   4%|▎         | 36/1000 [00:00<00:11, 85.81it/s]
#   4%|▍         | 45/1000 [00:00<00:11, 86.42it/s]
#   5%|▌         | 54/1000 [00:00<00:11, 85.93it/s]
#   6%|▋         | 63/1000 [00:00<00:10, 85.60it/s]
#   7%|▋         | 72/1000 [00:00<00:10, 85.04it/s]
#   8%|▊         | 81/1000 [00:00<00:10, 84.23it/s]
#   9%|▉         | 90/1000 [00:01<00:10, 84.65it/s]
#  10%|▉         | 99/1000 [00:01<00:10, 84.84it/s]
#  11%|█         | 108/1000 [00:01<00:10, 85.33it/s]
#  12%|█▏        | 117/1000 [00:01<00:10, 86.18it/s]
#  13%|█▎        | 126/1000 [00:01<00:10, 80.20it/s]
#  14%|█▎        | 135/1000 [00:01<00:12, 71.10it/s]
#  14%|█▍        | 143/1000 [00:01<00:11, 72.25it/s]
#  15%|█▌        | 152/1000 [00:01<00:11, 74.51it/s]
#  70%|███████   | 703/1000 [00:09<00:03, 80.27it/s]
#  71%|███████   | 712/1000 [00:10<00:03, 81.55it/s]
#  72%|███████▏  | 721/1000 [00:10<00:03, 82.42it/s]
#  73%|███████▎  | 730/1000 [00:10<00:03, 83.12it/s]
#  74%|███████▍  | 739/1000 [00:10<00:03, 84.07it/s]
#  75%|███████▍  | 748/1000 [00:10<00:02, 84.55it/s]
#  76%|███████▌  | 757/1000 [00:10<00:02, 85.36it/s]
#  77%|███████▋  | 766/1000 [00:10<00:02, 85.65it/s]
#  78%|███████▊  | 775/1000 [00:10<00:02, 79.59it/s]
#  78%|███████▊  | 784/1000 [00:10<00:02, 76.54it/s]
#  79%|███████▉  | 793/1000 [00:11<00:02, 78.21it/s]
#  80%|████████  | 802/1000 [00:11<00:02, 80.88it/s]
#  81%|████████  | 811/1000 [00:11<00:02, 83.02it/s]
#  82%|████████▏ | 820/1000 [00:11<00:02, 83.34it/s]
#  83%|████████▎ | 829/1000 [00:11<00:02, 84.90it/s]
#  84%|████████▍ | 838/1000 [00:11<00:01, 85.17it/s]
#  85%|████████▍ | 847/1000 [00:11<00:01, 85.49it/s]
#  86%|████████▌ | 856/1000 [00:11<00:01, 84.87it/s]
#  86%|████████▋ | 865/1000 [00:11<00:01, 84.95it/s]
#  87%|████████▋ | 874/1000 [00:11<00:01, 82.02it/s]
#  88%|████████▊ | 883/1000 [00:12<00:01, 83.25it/s]
#  89%|████████▉ | 892/1000 [00:12<00:01, 84.27it/s]
#  90%|█████████ | 901/1000 [00:12<00:01, 84.84it/s]
#  91%|█████████ | 910/1000 [00:12<00:01, 84.03it/s]
#  92%|█████████▏| 919/1000 [00:12<00:00, 82.35it/s]
#  93%|█████████▎| 928/1000 [00:12<00:00, 77.37it/s]
#  94%|█████████▎| 936/1000 [00:12<00:01, 55.84it/s]
#  94%|█████████▍| 943/1000 [00:13<00:01, 52.54it/s]
#  95%|█████████▌| 951/1000 [00:13<00:00, 57.33it/s]
#  96%|█████████▌| 958/1000 [00:13<00:00, 56.01it/s]
#  96%|█████████▋| 964/1000 [00:13<00:00, 52.25it/s]
#  97%|█████████▋| 971/1000 [00:13<00:00, 56.17it/s]
#  98%|█████████▊| 980/1000 [00:13<00:00, 62.15it/s]
#  99%|█████████▉| 989/1000 [00:13<00:00, 67.52it/s]
# 100%|██████████| 1000/1000 [00:13<00:00, 71.85it/s][A
# 9it [01:55, 12.84s/it]
# train data is ready !

# %% [markdown]
# ## load dataset

# %%
meas_pattern_path = train_data_path + "/measurement_pattern.txt"
meas_label_path = train_data_path + "/measurement_label.txt"
meas_result_path = train_data_path + "/measurement_result.txt"
ideal_rho_re_path = ideal_state_path + "/rho_real.txt"
ideal_rho_im_path = ideal_state_path + "/rho_imag.txt"
meas_result, ideal_rho, meas_label, meas_pattern = data.load_data_DM(meas_result_path,
                                                                     ideal_rho_re_path,
                                                                     ideal_rho_im_path,
                                                                     meas_label_path,
                                                                     meas_pattern_path)

# %% [markdown]
# ## build RBM architecture

# %%
nn_state_dm = DensityMatrix(
    num_visible = n_visible_unit, 
    num_hidden = n_hidden_unit, 
    num_aux = n_aux_unit, 
    unitary_dict = unitaries.create_dict(),
    gpu = False
)

# %% [markdown]
# ## estimate observable expectation value

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XX():
    target_list = [0, 1]
    pauli_index = [1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZ():
    target_list = [0, 1]
    pauli_index = [1, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_XX_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "X"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_XZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "X", 1: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

# %% [markdown]
# ## callback setting

# %%
def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "KL_Divergence": ts.KL,
        "Observable_XX_ev": observable_XX_ev,
        "Observable_XZ_ev": observable_XZ_ev,
    }

    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = ideal_rho,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    return callbacks

callbacks = create_callback_dm(nn_state_dm)

# %% [markdown]
# ## train

# %%
nn_state_dm.fit(
    data = meas_result,
    input_bases = meas_label,
    epochs = epoch,
    pos_batch_size = pbs,
    neg_batch_size = nbs,
    lr = lr,
    k = n_gibbs_step,
    bases = meas_pattern,
    callbacks = callbacks,
    time = True,
    optimizer = torch.optim.Adadelta,
    scheduler = torch.optim.lr_scheduler.StepLR,
    scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
)
# Out:
# Epoch: 1	Fidelity = 0.255534	KL_Divergence = 0.516730	Observable_XX_ev = 0.349489	Observable_XZ_ev = 0.212001
# Epoch: 2	Fidelity = 0.262953	KL_Divergence = 0.458620	Observable_XX_ev = 0.514934	Observable_XZ_ev = 0.131074
# Epoch: 3	Fidelity = 0.303051	KL_Divergence = 0.384413	Observable_XX_ev = 0.570578	Observable_XZ_ev = 0.000279
# Epoch: 4	Fidelity = 0.374646	KL_Divergence = 0.306748	Observable_XX_ev = 0.776325	Observable_XZ_ev = -0.078124
# Epoch: 5	Fidelity = 0.403096	KL_Divergence = 0.254972	Observable_XX_ev = 0.372583	Observable_XZ_ev = 0.048520
# Epoch: 6	Fidelity = 0.426615	KL_Divergence = 0.221161	Observable_XX_ev = 0.585973	Observable_XZ_ev = 0.219571
# Epoch: 7	Fidelity = 0.447662	KL_Divergence = 0.198268	Observable_XX_ev = 0.455869	Observable_XZ_ev = 0.229933
# Epoch: 8	Fidelity = 0.464926	KL_Divergence = 0.181368	Observable_XX_ev = 0.653008	Observable_XZ_ev = 0.337039
# Epoch: 9	Fidelity = 0.482874	KL_Divergence = 0.177563	Observable_XX_ev = 0.519553	Observable_XZ_ev = 0.171538
# Epoch: 10	Fidelity = 0.495007	KL_Divergence = 0.161158	Observable_XX_ev = 0.404569	Observable_XZ_ev = 0.142441
# Epoch: 11	Fidelity = 0.504378	KL_Divergence = 0.156199	Observable_XX_ev = 0.516716	Observable_XZ_ev = 0.269002
# Epoch: 12	Fidelity = 0.515081	KL_Divergence = 0.151332	Observable_XX_ev = 0.513820	Observable_XZ_ev = 0.105004
# Epoch: 13	Fidelity = 0.525668	KL_Divergence = 0.146347	Observable_XX_ev = 0.752313	Observable_XZ_ev = 0.365778
# Epoch: 14	Fidelity = 0.534297	KL_Divergence = 0.148994	Observable_XX_ev = 0.518841	Observable_XZ_ev = 0.166433
# Epoch: 15	Fidelity = 0.545397	KL_Divergence = 0.135606	Observable_XX_ev = 0.773944	Observable_XZ_ev = 0.154314
# Epoch: 16	Fidelity = 0.555967	KL_Divergence = 0.128274	Observable_XX_ev = 0.906343	Observable_XZ_ev = 0.068760
# Epoch: 17	Fidelity = 0.564425	KL_Divergence = 0.127450	Observable_XX_ev = 0.612716	Observable_XZ_ev = 0.126923
# Epoch: 18	Fidelity = 0.578394	KL_Divergence = 0.119801	Observable_XX_ev = 0.788095	Observable_XZ_ev = 0.091119
# Epoch: 19	Fidelity = 0.590053	KL_Divergence = 0.117937	Observable_XX_ev = 0.704695	Observable_XZ_ev = 0.080239
# Epoch: 20	Fidelity = 0.602954	KL_Divergence = 0.114685	Observable_XX_ev = 1.346671	Observable_XZ_ev = 0.080049
# Epoch: 21	Fidelity = 0.615319	KL_Divergence = 0.105953	Observable_XX_ev = 0.992928	Observable_XZ_ev = 0.093542
# Epoch: 22	Fidelity = 0.628675	KL_Divergence = 0.102455	Observable_XX_ev = 1.014868	Observable_XZ_ev = 0.026170
# Epoch: 23	Fidelity = 0.640228	KL_Divergence = 0.099686	Observable_XX_ev = 0.991490	Observable_XZ_ev = 0.036651
# Epoch: 24	Fidelity = 0.652427	KL_Divergence = 0.094059	Observable_XX_ev = 1.027023	Observable_XZ_ev = 0.090424
# Epoch: 25	Fidelity = 0.666462	KL_Divergence = 0.090759	Observable_XX_ev = 0.593276	Observable_XZ_ev = 0.083830
# Epoch: 26	Fidelity = 0.679315	KL_Divergence = 0.085589	Observable_XX_ev = 0.895201	Observable_XZ_ev = 0.051848
# Epoch: 27	Fidelity = 0.692751	KL_Divergence = 0.083552	Observable_XX_ev = 1.241623	Observable_XZ_ev = 0.031593
# Epoch: 28	Fidelity = 0.704399	KL_Divergence = 0.081250	Observable_XX_ev = 0.853109	Observable_XZ_ev = 0.023723
# Epoch: 29	Fidelity = 0.717313	KL_Divergence = 0.074272	Observable_XX_ev = 1.008578	Observable_XZ_ev = 0.039293
# Epoch: 30	Fidelity = 0.724865	KL_Divergence = 0.082696	Observable_XX_ev = 1.188286	Observable_XZ_ev = 0.031449
# Epoch: 31	Fidelity = 0.741750	KL_Divergence = 0.067735	Observable_XX_ev = 0.632445	Observable_XZ_ev = 0.017638
# Epoch: 32	Fidelity = 0.751161	KL_Divergence = 0.067152	Observable_XX_ev = 1.056463	Observable_XZ_ev = 0.032000
# Epoch: 33	Fidelity = 0.763427	KL_Divergence = 0.063582	Observable_XX_ev = 0.925285	Observable_XZ_ev = 0.042212
# Epoch: 34	Fidelity = 0.767005	KL_Divergence = 0.063021	Observable_XX_ev = 0.790623	Observable_XZ_ev = 0.018399
# Epoch: 35	Fidelity = 0.785419	KL_Divergence = 0.055512	Observable_XX_ev = 1.052006	Observable_XZ_ev = 0.017767
# Epoch: 36	Fidelity = 0.791527	KL_Divergence = 0.061961	Observable_XX_ev = 0.735888	Observable_XZ_ev = 0.028404
# Epoch: 37	Fidelity = 0.806655	KL_Divergence = 0.049161	Observable_XX_ev = 1.172424	Observable_XZ_ev = 0.038543
# Epoch: 38	Fidelity = 0.813630	KL_Divergence = 0.049750	Observable_XX_ev = 0.988148	Observable_XZ_ev = 0.036602
# Epoch: 39	Fidelity = 0.822869	KL_Divergence = 0.045381	Observable_XX_ev = 0.903727	Observable_XZ_ev = 0.011007
# Epoch: 40	Fidelity = 0.823416	KL_Divergence = 0.056268	Observable_XX_ev = 1.139316	Observable_XZ_ev = 0.028126
# Epoch: 41	Fidelity = 0.836376	KL_Divergence = 0.042722	Observable_XX_ev = 1.556684	Observable_XZ_ev = 0.021328
# Epoch: 42	Fidelity = 0.843624	KL_Divergence = 0.040417	Observable_XX_ev = 1.084878	Observable_XZ_ev = 0.018105
# Epoch: 43	Fidelity = 0.848735	KL_Divergence = 0.038519	Observable_XX_ev = 1.076700	Observable_XZ_ev = 0.025390
# Epoch: 44	Fidelity = 0.857003	KL_Divergence = 0.035609	Observable_XX_ev = 1.004080	Observable_XZ_ev = 0.014206
# Epoch: 45	Fidelity = 0.862683	KL_Divergence = 0.034649	Observable_XX_ev = 0.830842	Observable_XZ_ev = 0.021600
# Epoch: 46	Fidelity = 0.867191	KL_Divergence = 0.033336	Observable_XX_ev = 0.894608	Observable_XZ_ev = 0.031703
# Epoch: 47	Fidelity = 0.870890	KL_Divergence = 0.033683	Observable_XX_ev = 0.921466	Observable_XZ_ev = 0.030869
# Epoch: 48	Fidelity = 0.874121	KL_Divergence = 0.034905	Observable_XX_ev = 0.925429	Observable_XZ_ev = 0.020523
# Epoch: 49	Fidelity = 0.878331	KL_Divergence = 0.032839	Observable_XX_ev = 0.886895	Observable_XZ_ev = 0.014137
# Epoch: 50	Fidelity = 0.881473	KL_Divergence = 0.032480	Observable_XX_ev = 1.022451	Observable_XZ_ev = 0.001824
# Epoch: 51	Fidelity = 0.883570	KL_Divergence = 0.034676	Observable_XX_ev = 1.007999	Observable_XZ_ev = 0.012583
# Epoch: 52	Fidelity = 0.891445	KL_Divergence = 0.027995	Observable_XX_ev = 1.257256	Observable_XZ_ev = 0.032789
# Epoch: 53	Fidelity = 0.895838	KL_Divergence = 0.026155	Observable_XX_ev = 1.429547	Observable_XZ_ev = 0.025564
# Epoch: 54	Fidelity = 0.893958	KL_Divergence = 0.029598	Observable_XX_ev = 0.846946	Observable_XZ_ev = 0.036031
# Epoch: 55	Fidelity = 0.899739	KL_Divergence = 0.025672	Observable_XX_ev = 1.116132	Observable_XZ_ev = 0.006259
# Epoch: 56	Fidelity = 0.899429	KL_Divergence = 0.027429	Observable_XX_ev = 0.943737	Observable_XZ_ev = -0.002367
# Epoch: 57	Fidelity = 0.903231	KL_Divergence = 0.027758	Observable_XX_ev = 1.005004	Observable_XZ_ev = 0.005641
# Epoch: 58	Fidelity = 0.900210	KL_Divergence = 0.029616	Observable_XX_ev = 0.852887	Observable_XZ_ev = 0.017763
# Epoch: 59	Fidelity = 0.908843	KL_Divergence = 0.023722	Observable_XX_ev = 0.917414	Observable_XZ_ev = 0.000105
# Epoch: 60	Fidelity = 0.909669	KL_Divergence = 0.025257	Observable_XX_ev = 0.936926	Observable_XZ_ev = 0.013819
# Epoch: 61	Fidelity = 0.911776	KL_Divergence = 0.022802	Observable_XX_ev = 0.875292	Observable_XZ_ev = 0.002262
# Epoch: 62	Fidelity = 0.915995	KL_Divergence = 0.020612	Observable_XX_ev = 0.958808	Observable_XZ_ev = 0.027734
# Epoch: 63	Fidelity = 0.914196	KL_Divergence = 0.022927	Observable_XX_ev = 0.917680	Observable_XZ_ev = 0.004854
# Epoch: 64	Fidelity = 0.919660	KL_Divergence = 0.019692	Observable_XX_ev = 1.155186	Observable_XZ_ev = 0.003535
# Epoch: 65	Fidelity = 0.920599	KL_Divergence = 0.020124	Observable_XX_ev = 1.180595	Observable_XZ_ev = 0.007081
# Epoch: 66	Fidelity = 0.922381	KL_Divergence = 0.019109	Observable_XX_ev = 1.034052	Observable_XZ_ev = 0.013754
# Epoch: 67	Fidelity = 0.923433	KL_Divergence = 0.018735	Observable_XX_ev = 0.894502	Observable_XZ_ev = 0.009738
# Epoch: 68	Fidelity = 0.925350	KL_Divergence = 0.018900	Observable_XX_ev = 1.063513	Observable_XZ_ev = 0.009149
# Epoch: 69	Fidelity = 0.924036	KL_Divergence = 0.022486	Observable_XX_ev = 0.844099	Observable_XZ_ev = -0.000377
# Epoch: 70	Fidelity = 0.927284	KL_Divergence = 0.019891	Observable_XX_ev = 1.015565	Observable_XZ_ev = 0.005483
# Epoch: 71	Fidelity = 0.929401	KL_Divergence = 0.017308	Observable_XX_ev = 1.225808	Observable_XZ_ev = 0.029769
# Epoch: 72	Fidelity = 0.931436	KL_Divergence = 0.016638	Observable_XX_ev = 1.159130	Observable_XZ_ev = 0.006926
# Epoch: 73	Fidelity = 0.932147	KL_Divergence = 0.016877	Observable_XX_ev = 1.063641	Observable_XZ_ev = 0.007409
# Epoch: 74	Fidelity = 0.932862	KL_Divergence = 0.017446	Observable_XX_ev = 0.771025	Observable_XZ_ev = 0.007148
# Epoch: 75	Fidelity = 0.934341	KL_Divergence = 0.016726	Observable_XX_ev = 0.966257	Observable_XZ_ev = -0.016824
# Epoch: 76	Fidelity = 0.935989	KL_Divergence = 0.015648	Observable_XX_ev = 1.035772	Observable_XZ_ev = 0.009766
# Epoch: 77	Fidelity = 0.932410	KL_Divergence = 0.020777	Observable_XX_ev = 1.012286	Observable_XZ_ev = 0.015494
# Epoch: 78	Fidelity = 0.932095	KL_Divergence = 0.021974	Observable_XX_ev = 0.934834	Observable_XZ_ev = 0.005250
# Epoch: 79	Fidelity = 0.938003	KL_Divergence = 0.015003	Observable_XX_ev = 0.919193	Observable_XZ_ev = 0.008100
# Epoch: 80	Fidelity = 0.935796	KL_Divergence = 0.018599	Observable_XX_ev = 1.158703	Observable_XZ_ev = -0.008077
# Epoch: 81	Fidelity = 0.939588	KL_Divergence = 0.014833	Observable_XX_ev = 0.935763	Observable_XZ_ev = 0.003435
# Epoch: 82	Fidelity = 0.937803	KL_Divergence = 0.017185	Observable_XX_ev = 0.925492	Observable_XZ_ev = 0.002868
# Epoch: 83	Fidelity = 0.940074	KL_Divergence = 0.016485	Observable_XX_ev = 0.872198	Observable_XZ_ev = 0.026123
# Epoch: 84	Fidelity = 0.939621	KL_Divergence = 0.015935	Observable_XX_ev = 1.122226	Observable_XZ_ev = 0.005346
# Epoch: 85	Fidelity = 0.941557	KL_Divergence = 0.015662	Observable_XX_ev = 0.940081	Observable_XZ_ev = -0.004254
# Epoch: 86	Fidelity = 0.943895	KL_Divergence = 0.013335	Observable_XX_ev = 0.930481	Observable_XZ_ev = 0.008896
# Epoch: 87	Fidelity = 0.942086	KL_Divergence = 0.016670	Observable_XX_ev = 1.064639	Observable_XZ_ev = -0.006437
# Epoch: 88	Fidelity = 0.943420	KL_Divergence = 0.015282	Observable_XX_ev = 1.165246	Observable_XZ_ev = 0.001967
# Epoch: 89	Fidelity = 0.944764	KL_Divergence = 0.013370	Observable_XX_ev = 1.162303	Observable_XZ_ev = 0.012441
# Epoch: 90	Fidelity = 0.943917	KL_Divergence = 0.016096	Observable_XX_ev = 1.081359	Observable_XZ_ev = 0.018792
# Epoch: 91	Fidelity = 0.946857	KL_Divergence = 0.012551	Observable_XX_ev = 1.012299	Observable_XZ_ev = 0.005143
# Epoch: 92	Fidelity = 0.947086	KL_Divergence = 0.012627	Observable_XX_ev = 0.816744	Observable_XZ_ev = 0.007260
# Epoch: 93	Fidelity = 0.947877	KL_Divergence = 0.012360	Observable_XX_ev = 0.987414	Observable_XZ_ev = -0.001310
# Epoch: 94	Fidelity = 0.948199	KL_Divergence = 0.012408	Observable_XX_ev = 1.001537	Observable_XZ_ev = 0.002160
# Epoch: 95	Fidelity = 0.948558	KL_Divergence = 0.012629	Observable_XX_ev = 1.082898	Observable_XZ_ev = 0.012240
# Epoch: 96	Fidelity = 0.948636	KL_Divergence = 0.013112	Observable_XX_ev = 0.918668	Observable_XZ_ev = -0.014967
# Epoch: 97	Fidelity = 0.943755	KL_Divergence = 0.017862	Observable_XX_ev = 0.960123	Observable_XZ_ev = 0.009961
# Epoch: 98	Fidelity = 0.949713	KL_Divergence = 0.011839	Observable_XX_ev = 0.966798	Observable_XZ_ev = 0.003820
# Epoch: 99	Fidelity = 0.948896	KL_Divergence = 0.013209	Observable_XX_ev = 0.778410	Observable_XZ_ev = -0.000491
# Epoch: 100	Fidelity = 0.950612	KL_Divergence = 0.011914	Observable_XX_ev = 0.996684	Observable_XZ_ev = -0.006747
# Epoch: 101	Fidelity = 0.951109	KL_Divergence = 0.011787	Observable_XX_ev = 0.831828	Observable_XZ_ev = -0.008434
# Epoch: 102	Fidelity = 0.950838	KL_Divergence = 0.012106	Observable_XX_ev = 1.009009	Observable_XZ_ev = 0.008167
# Epoch: 103	Fidelity = 0.949723	KL_Divergence = 0.013553	Observable_XX_ev = 1.123399	Observable_XZ_ev = 0.013660
# Epoch: 104	Fidelity = 0.951320	KL_Divergence = 0.011737	Observable_XX_ev = 1.034313	Observable_XZ_ev = 0.017248
# Epoch: 105	Fidelity = 0.952076	KL_Divergence = 0.011317	Observable_XX_ev = 0.824976	Observable_XZ_ev = 0.000058
# Epoch: 106	Fidelity = 0.951977	KL_Divergence = 0.011660	Observable_XX_ev = 0.903358	Observable_XZ_ev = -0.003029
# Epoch: 107	Fidelity = 0.946070	KL_Divergence = 0.020642	Observable_XX_ev = 1.092042	Observable_XZ_ev = 0.012981
# Epoch: 108	Fidelity = 0.951802	KL_Divergence = 0.012475	Observable_XX_ev = 1.066813	Observable_XZ_ev = 0.003145
# Epoch: 109	Fidelity = 0.953002	KL_Divergence = 0.011510	Observable_XX_ev = 0.884038	Observable_XZ_ev = 0.010067
# Epoch: 110	Fidelity = 0.950519	KL_Divergence = 0.014018	Observable_XX_ev = 1.113740	Observable_XZ_ev = 0.013985
# Epoch: 111	Fidelity = 0.952860	KL_Divergence = 0.011806	Observable_XX_ev = 0.969364	Observable_XZ_ev = 0.020463
# Epoch: 112	Fidelity = 0.953346	KL_Divergence = 0.011545	Observable_XX_ev = 0.966260	Observable_XZ_ev = 0.016374
# Epoch: 113	Fidelity = 0.954327	KL_Divergence = 0.010915	Observable_XX_ev = 1.098327	Observable_XZ_ev = 0.024193
# Epoch: 114	Fidelity = 0.953175	KL_Divergence = 0.013015	Observable_XX_ev = 1.011465	Observable_XZ_ev = 0.023688
# Epoch: 115	Fidelity = 0.955245	KL_Divergence = 0.010636	Observable_XX_ev = 0.998451	Observable_XZ_ev = -0.000439
# Epoch: 116	Fidelity = 0.955182	KL_Divergence = 0.010770	Observable_XX_ev = 0.930920	Observable_XZ_ev = 0.004453
# Epoch: 117	Fidelity = 0.955548	KL_Divergence = 0.010941	Observable_XX_ev = 1.039968	Observable_XZ_ev = 0.011684
# Epoch: 118	Fidelity = 0.955979	KL_Divergence = 0.010886	Observable_XX_ev = 1.056007	Observable_XZ_ev = 0.005286
# Epoch: 119	Fidelity = 0.954831	KL_Divergence = 0.012679	Observable_XX_ev = 0.928632	Observable_XZ_ev = -0.010741
# Epoch: 120	Fidelity = 0.957151	KL_Divergence = 0.010056	Observable_XX_ev = 1.032150	Observable_XZ_ev = -0.010328
# Epoch: 121	Fidelity = 0.956303	KL_Divergence = 0.010664	Observable_XX_ev = 1.506684	Observable_XZ_ev = 0.009644
# Epoch: 122	Fidelity = 0.956996	KL_Divergence = 0.010338	Observable_XX_ev = 0.918269	Observable_XZ_ev = 0.021880
# Epoch: 123	Fidelity = 0.956976	KL_Divergence = 0.011158	Observable_XX_ev = 0.966955	Observable_XZ_ev = 0.008993
# Epoch: 124	Fidelity = 0.958004	KL_Divergence = 0.009854	Observable_XX_ev = 0.883673	Observable_XZ_ev = 0.004726
# Epoch: 125	Fidelity = 0.957215	KL_Divergence = 0.010864	Observable_XX_ev = 0.940027	Observable_XZ_ev = -0.005681
# Epoch: 126	Fidelity = 0.957645	KL_Divergence = 0.010598	Observable_XX_ev = 1.176031	Observable_XZ_ev = -0.000042
# Epoch: 127	Fidelity = 0.957549	KL_Divergence = 0.010288	Observable_XX_ev = 0.935811	Observable_XZ_ev = 0.015041
# Epoch: 128	Fidelity = 0.953042	KL_Divergence = 0.017455	Observable_XX_ev = 0.992617	Observable_XZ_ev = 0.008607
# Epoch: 129	Fidelity = 0.957528	KL_Divergence = 0.010703	Observable_XX_ev = 1.033186	Observable_XZ_ev = 0.000725
# Epoch: 130	Fidelity = 0.958770	KL_Divergence = 0.010054	Observable_XX_ev = 0.960909	Observable_XZ_ev = 0.011736
# Epoch: 131	Fidelity = 0.958832	KL_Divergence = 0.009802	Observable_XX_ev = 1.143523	Observable_XZ_ev = -0.003960
# Epoch: 132	Fidelity = 0.955362	KL_Divergence = 0.014700	Observable_XX_ev = 0.925322	Observable_XZ_ev = 0.009808
# Epoch: 133	Fidelity = 0.959628	KL_Divergence = 0.009477	Observable_XX_ev = 1.061087	Observable_XZ_ev = 0.004901
# Epoch: 134	Fidelity = 0.958688	KL_Divergence = 0.010304	Observable_XX_ev = 1.020946	Observable_XZ_ev = 0.012790
# Epoch: 135	Fidelity = 0.959191	KL_Divergence = 0.009868	Observable_XX_ev = 1.143381	Observable_XZ_ev = -0.002885
# Epoch: 136	Fidelity = 0.959653	KL_Divergence = 0.009954	Observable_XX_ev = 1.066487	Observable_XZ_ev = 0.001094
# Epoch: 137	Fidelity = 0.958244	KL_Divergence = 0.011625	Observable_XX_ev = 0.969335	Observable_XZ_ev = 0.004082
# Epoch: 138	Fidelity = 0.960089	KL_Divergence = 0.009616	Observable_XX_ev = 0.958924	Observable_XZ_ev = 0.014908
# Epoch: 139	Fidelity = 0.959867	KL_Divergence = 0.009754	Observable_XX_ev = 1.098170	Observable_XZ_ev = 0.006332
# Epoch: 140	Fidelity = 0.957562	KL_Divergence = 0.013430	Observable_XX_ev = 0.970742	Observable_XZ_ev = 0.008174
# Epoch: 141	Fidelity = 0.960890	KL_Divergence = 0.009178	Observable_XX_ev = 0.904151	Observable_XZ_ev = 0.010828
# Epoch: 142	Fidelity = 0.960753	KL_Divergence = 0.009290	Observable_XX_ev = 0.930407	Observable_XZ_ev = 0.010976
# Epoch: 143	Fidelity = 0.960732	KL_Divergence = 0.009286	Observable_XX_ev = 0.937638	Observable_XZ_ev = 0.005223
# Epoch: 144	Fidelity = 0.959966	KL_Divergence = 0.010313	Observable_XX_ev = 0.985035	Observable_XZ_ev = 0.014441
# Epoch: 145	Fidelity = 0.960952	KL_Divergence = 0.009252	Observable_XX_ev = 0.879857	Observable_XZ_ev = 0.015910
# Epoch: 146	Fidelity = 0.961085	KL_Divergence = 0.009358	Observable_XX_ev = 0.997693	Observable_XZ_ev = 0.000476
# Epoch: 147	Fidelity = 0.961078	KL_Divergence = 0.009286	Observable_XX_ev = 1.118631	Observable_XZ_ev = 0.013836
# Epoch: 148	Fidelity = 0.961514	KL_Divergence = 0.009017	Observable_XX_ev = 0.965027	Observable_XZ_ev = -0.001300
# Epoch: 149	Fidelity = 0.961101	KL_Divergence = 0.009792	Observable_XX_ev = 0.935481	Observable_XZ_ev = 0.017329
# Epoch: 150	Fidelity = 0.961867	KL_Divergence = 0.008909	Observable_XX_ev = 1.044316	Observable_XZ_ev = 0.014459
# Epoch: 151	Fidelity = 0.961323	KL_Divergence = 0.009768	Observable_XX_ev = 0.886376	Observable_XZ_ev = 0.028165
# Epoch: 152	Fidelity = 0.961979	KL_Divergence = 0.009055	Observable_XX_ev = 1.035107	Observable_XZ_ev = 0.007643
# Epoch: 153	Fidelity = 0.961374	KL_Divergence = 0.009794	Observable_XX_ev = 1.206757	Observable_XZ_ev = 0.001935
# Epoch: 154	Fidelity = 0.961497	KL_Divergence = 0.009577	Observable_XX_ev = 1.050670	Observable_XZ_ev = 0.008000
# Epoch: 155	Fidelity = 0.959385	KL_Divergence = 0.012595	Observable_XX_ev = 1.015477	Observable_XZ_ev = -0.000540
# Epoch: 156	Fidelity = 0.961528	KL_Divergence = 0.009853	Observable_XX_ev = 1.073813	Observable_XZ_ev = 0.004923
# Epoch: 157	Fidelity = 0.959103	KL_Divergence = 0.013534	Observable_XX_ev = 0.764247	Observable_XZ_ev = -0.009040
# Epoch: 158	Fidelity = 0.962206	KL_Divergence = 0.009162	Observable_XX_ev = 1.035059	Observable_XZ_ev = 0.022636
# Epoch: 159	Fidelity = 0.959827	KL_Divergence = 0.012703	Observable_XX_ev = 1.015697	Observable_XZ_ev = 0.002251
# Epoch: 160	Fidelity = 0.962417	KL_Divergence = 0.009186	Observable_XX_ev = 1.112592	Observable_XZ_ev = 0.011969
# Epoch: 161	Fidelity = 0.961923	KL_Divergence = 0.009528	Observable_XX_ev = 1.187233	Observable_XZ_ev = -0.002014
# Epoch: 162	Fidelity = 0.960277	KL_Divergence = 0.012143	Observable_XX_ev = 0.890920	Observable_XZ_ev = 0.001269
# Epoch: 163	Fidelity = 0.961828	KL_Divergence = 0.010321	Observable_XX_ev = 0.910901	Observable_XZ_ev = 0.008213
# Epoch: 164	Fidelity = 0.961540	KL_Divergence = 0.010943	Observable_XX_ev = 0.940402	Observable_XZ_ev = 0.016410
# Epoch: 165	Fidelity = 0.963154	KL_Divergence = 0.008948	Observable_XX_ev = 0.934675	Observable_XZ_ev = 0.009771
# Epoch: 166	Fidelity = 0.963326	KL_Divergence = 0.008828	Observable_XX_ev = 1.072640	Observable_XZ_ev = 0.019143
# Epoch: 167	Fidelity = 0.962743	KL_Divergence = 0.009500	Observable_XX_ev = 1.002887	Observable_XZ_ev = 0.001099
# Epoch: 168	Fidelity = 0.963738	KL_Divergence = 0.008433	Observable_XX_ev = 1.066985	Observable_XZ_ev = 0.013821
# Epoch: 169	Fidelity = 0.963086	KL_Divergence = 0.009174	Observable_XX_ev = 1.026277	Observable_XZ_ev = 0.002344
# Epoch: 170	Fidelity = 0.961311	KL_Divergence = 0.011273	Observable_XX_ev = 1.070133	Observable_XZ_ev = 0.008689
# Epoch: 171	Fidelity = 0.958669	KL_Divergence = 0.015188	Observable_XX_ev = 1.091588	Observable_XZ_ev = 0.002192
# Epoch: 172	Fidelity = 0.962558	KL_Divergence = 0.010152	Observable_XX_ev = 0.954786	Observable_XZ_ev = 0.000019
# Epoch: 173	Fidelity = 0.963537	KL_Divergence = 0.008854	Observable_XX_ev = 0.933448	Observable_XZ_ev = -0.006226
# Epoch: 174	Fidelity = 0.963735	KL_Divergence = 0.008665	Observable_XX_ev = 1.060249	Observable_XZ_ev = 0.000999
# Epoch: 175	Fidelity = 0.963767	KL_Divergence = 0.008540	Observable_XX_ev = 0.835487	Observable_XZ_ev = 0.010372
# Epoch: 176	Fidelity = 0.963232	KL_Divergence = 0.009628	Observable_XX_ev = 0.941437	Observable_XZ_ev = 0.002163
# Epoch: 177	Fidelity = 0.963393	KL_Divergence = 0.009056	Observable_XX_ev = 1.116542	Observable_XZ_ev = 0.002657
# Epoch: 178	Fidelity = 0.963996	KL_Divergence = 0.008678	Observable_XX_ev = 1.061265	Observable_XZ_ev = 0.012482
# Epoch: 179	Fidelity = 0.963112	KL_Divergence = 0.009908	Observable_XX_ev = 1.013722	Observable_XZ_ev = -0.002113
# Epoch: 180	Fidelity = 0.960855	KL_Divergence = 0.013026	Observable_XX_ev = 1.146301	Observable_XZ_ev = 0.014469
# Epoch: 181	Fidelity = 0.964207	KL_Divergence = 0.008511	Observable_XX_ev = 1.066512	Observable_XZ_ev = 0.005233
# Epoch: 182	Fidelity = 0.963833	KL_Divergence = 0.009146	Observable_XX_ev = 0.933267	Observable_XZ_ev = -0.004657
# Epoch: 183	Fidelity = 0.964029	KL_Divergence = 0.009000	Observable_XX_ev = 1.033195	Observable_XZ_ev = -0.005544
# Epoch: 184	Fidelity = 0.962680	KL_Divergence = 0.010843	Observable_XX_ev = 1.032976	Observable_XZ_ev = 0.003908
# Epoch: 185	Fidelity = 0.961631	KL_Divergence = 0.012523	Observable_XX_ev = 0.936083	Observable_XZ_ev = 0.012037
# Epoch: 186	Fidelity = 0.964115	KL_Divergence = 0.009124	Observable_XX_ev = 0.971622	Observable_XZ_ev = 0.008938
# Epoch: 187	Fidelity = 0.963944	KL_Divergence = 0.009189	Observable_XX_ev = 1.059933	Observable_XZ_ev = 0.010505
# Epoch: 188	Fidelity = 0.964809	KL_Divergence = 0.008323	Observable_XX_ev = 1.010618	Observable_XZ_ev = -0.000843
# Epoch: 189	Fidelity = 0.962844	KL_Divergence = 0.011086	Observable_XX_ev = 0.882942	Observable_XZ_ev = 0.009831
# Epoch: 190	Fidelity = 0.962742	KL_Divergence = 0.011216	Observable_XX_ev = 0.961472	Observable_XZ_ev = 0.016600
# Epoch: 191	Fidelity = 0.964434	KL_Divergence = 0.008768	Observable_XX_ev = 1.032806	Observable_XZ_ev = 0.008792
# Epoch: 192	Fidelity = 0.964489	KL_Divergence = 0.008937	Observable_XX_ev = 0.908666	Observable_XZ_ev = -0.003023
# Epoch: 193	Fidelity = 0.964294	KL_Divergence = 0.009188	Observable_XX_ev = 0.966383	Observable_XZ_ev = -0.007265
# Epoch: 194	Fidelity = 0.964511	KL_Divergence = 0.009069	Observable_XX_ev = 1.051326	Observable_XZ_ev = 0.011476
# Epoch: 195	Fidelity = 0.963300	KL_Divergence = 0.010776	Observable_XX_ev = 0.963716	Observable_XZ_ev = -0.006784
# Epoch: 196	Fidelity = 0.965336	KL_Divergence = 0.008120	Observable_XX_ev = 1.032137	Observable_XZ_ev = 0.009636
# Epoch: 197	Fidelity = 0.964770	KL_Divergence = 0.008919	Observable_XX_ev = 1.070584	Observable_XZ_ev = 0.003766
# Epoch: 198	Fidelity = 0.965583	KL_Divergence = 0.008018	Observable_XX_ev = 0.905383	Observable_XZ_ev = -0.006143
# Epoch: 199	Fidelity = 0.965297	KL_Divergence = 0.008340	Observable_XX_ev = 1.060875	Observable_XZ_ev = 0.006994
# Epoch: 200	Fidelity = 0.964217	KL_Divergence = 0.009880	Observable_XX_ev = 0.993186	Observable_XZ_ev = 0.009829
# Epoch: 201	Fidelity = 0.965226	KL_Divergence = 0.008469	Observable_XX_ev = 1.058021	Observable_XZ_ev = 0.002209
# Epoch: 202	Fidelity = 0.965529	KL_Divergence = 0.008041	Observable_XX_ev = 0.917396	Observable_XZ_ev = -0.004496
# Epoch: 203	Fidelity = 0.965132	KL_Divergence = 0.008558	Observable_XX_ev = 1.054518	Observable_XZ_ev = 0.015573
# Epoch: 204	Fidelity = 0.965231	KL_Divergence = 0.008524	Observable_XX_ev = 0.972511	Observable_XZ_ev = 0.005200
# Epoch: 205	Fidelity = 0.965040	KL_Divergence = 0.008909	Observable_XX_ev = 1.032127	Observable_XZ_ev = 0.003377
# Epoch: 206	Fidelity = 0.964914	KL_Divergence = 0.009164	Observable_XX_ev = 1.088270	Observable_XZ_ev = 0.004981
# Epoch: 207	Fidelity = 0.965800	KL_Divergence = 0.008048	Observable_XX_ev = 0.909224	Observable_XZ_ev = -0.002326
# Epoch: 208	Fidelity = 0.965499	KL_Divergence = 0.008667	Observable_XX_ev = 0.966625	Observable_XZ_ev = -0.000081
# Epoch: 209	Fidelity = 0.965598	KL_Divergence = 0.008540	Observable_XX_ev = 0.966364	Observable_XZ_ev = -0.003443
# Epoch: 210	Fidelity = 0.965843	KL_Divergence = 0.008141	Observable_XX_ev = 0.890483	Observable_XZ_ev = -0.006705
# Epoch: 211	Fidelity = 0.966035	KL_Divergence = 0.008153	Observable_XX_ev = 0.990767	Observable_XZ_ev = 0.004396
# Epoch: 212	Fidelity = 0.966240	KL_Divergence = 0.007973	Observable_XX_ev = 0.971728	Observable_XZ_ev = 0.004283
# Epoch: 213	Fidelity = 0.964673	KL_Divergence = 0.010121	Observable_XX_ev = 1.006512	Observable_XZ_ev = 0.001594
# Epoch: 214	Fidelity = 0.965311	KL_Divergence = 0.009315	Observable_XX_ev = 0.863209	Observable_XZ_ev = 0.001998
# Epoch: 215	Fidelity = 0.966262	KL_Divergence = 0.008082	Observable_XX_ev = 0.938826	Observable_XZ_ev = 0.000850
# Epoch: 216	Fidelity = 0.966410	KL_Divergence = 0.007906	Observable_XX_ev = 0.969572	Observable_XZ_ev = 0.016808
# Epoch: 217	Fidelity = 0.966547	KL_Divergence = 0.007801	Observable_XX_ev = 1.023464	Observable_XZ_ev = -0.007962
# Epoch: 218	Fidelity = 0.966548	KL_Divergence = 0.007962	Observable_XX_ev = 1.093600	Observable_XZ_ev = -0.007443
# Epoch: 219	Fidelity = 0.966684	KL_Divergence = 0.007815	Observable_XX_ev = 0.967401	Observable_XZ_ev = -0.007742
# Epoch: 220	Fidelity = 0.965658	KL_Divergence = 0.009128	Observable_XX_ev = 1.008712	Observable_XZ_ev = 0.009554
# Epoch: 221	Fidelity = 0.966173	KL_Divergence = 0.008539	Observable_XX_ev = 0.979814	Observable_XZ_ev = -0.001110
# Epoch: 222	Fidelity = 0.964109	KL_Divergence = 0.011613	Observable_XX_ev = 0.889967	Observable_XZ_ev = -0.010370
# Epoch: 223	Fidelity = 0.963169	KL_Divergence = 0.012931	Observable_XX_ev = 0.901770	Observable_XZ_ev = 0.008055
# Epoch: 224	Fidelity = 0.967168	KL_Divergence = 0.007710	Observable_XX_ev = 0.891749	Observable_XZ_ev = 0.008379
# Epoch: 225	Fidelity = 0.967254	KL_Divergence = 0.007626	Observable_XX_ev = 0.988752	Observable_XZ_ev = 0.012500
# Epoch: 226	Fidelity = 0.966641	KL_Divergence = 0.008484	Observable_XX_ev = 1.049468	Observable_XZ_ev = 0.000463
# Epoch: 227	Fidelity = 0.966803	KL_Divergence = 0.008251	Observable_XX_ev = 1.031791	Observable_XZ_ev = 0.010700
# Epoch: 228	Fidelity = 0.966646	KL_Divergence = 0.008493	Observable_XX_ev = 1.123016	Observable_XZ_ev = 0.008665
# Epoch: 229	Fidelity = 0.967145	KL_Divergence = 0.007760	Observable_XX_ev = 1.028832	Observable_XZ_ev = 0.001403
# Epoch: 230	Fidelity = 0.967340	KL_Divergence = 0.007604	Observable_XX_ev = 1.030505	Observable_XZ_ev = 0.004698
# Epoch: 231	Fidelity = 0.967354	KL_Divergence = 0.007618	Observable_XX_ev = 1.102146	Observable_XZ_ev = -0.001775
# Epoch: 232	Fidelity = 0.967393	KL_Divergence = 0.007628	Observable_XX_ev = 1.032711	Observable_XZ_ev = 0.001357
# Epoch: 233	Fidelity = 0.966883	KL_Divergence = 0.008393	Observable_XX_ev = 0.997684	Observable_XZ_ev = 0.011760
# Epoch: 234	Fidelity = 0.965157	KL_Divergence = 0.010898	Observable_XX_ev = 0.943587	Observable_XZ_ev = 0.007477
# Epoch: 235	Fidelity = 0.966469	KL_Divergence = 0.009161	Observable_XX_ev = 0.889063	Observable_XZ_ev = 0.021905
# Epoch: 236	Fidelity = 0.967714	KL_Divergence = 0.007538	Observable_XX_ev = 1.021143	Observable_XZ_ev = 0.006953
# Epoch: 237	Fidelity = 0.966219	KL_Divergence = 0.009655	Observable_XX_ev = 0.998789	Observable_XZ_ev = 0.004639
# Epoch: 238	Fidelity = 0.967681	KL_Divergence = 0.007730	Observable_XX_ev = 0.851470	Observable_XZ_ev = 0.006926
# Epoch: 239	Fidelity = 0.967648	KL_Divergence = 0.007738	Observable_XX_ev = 1.109006	Observable_XZ_ev = -0.005175
# Epoch: 240	Fidelity = 0.967624	KL_Divergence = 0.007690	Observable_XX_ev = 0.940255	Observable_XZ_ev = 0.004116
# Epoch: 241	Fidelity = 0.962619	KL_Divergence = 0.014511	Observable_XX_ev = 1.012257	Observable_XZ_ev = -0.003816
# Epoch: 242	Fidelity = 0.963485	KL_Divergence = 0.013404	Observable_XX_ev = 1.038408	Observable_XZ_ev = 0.004025
# Epoch: 243	Fidelity = 0.961590	KL_Divergence = 0.016158	Observable_XX_ev = 1.153379	Observable_XZ_ev = -0.006774
# Epoch: 244	Fidelity = 0.966391	KL_Divergence = 0.009592	Observable_XX_ev = 0.987934	Observable_XZ_ev = -0.005245
# Epoch: 245	Fidelity = 0.966768	KL_Divergence = 0.009056	Observable_XX_ev = 1.008138	Observable_XZ_ev = 0.014462
# Epoch: 246	Fidelity = 0.966157	KL_Divergence = 0.009937	Observable_XX_ev = 1.064698	Observable_XZ_ev = -0.003678
# Epoch: 247	Fidelity = 0.967583	KL_Divergence = 0.008095	Observable_XX_ev = 0.900102	Observable_XZ_ev = -0.003752
# Epoch: 248	Fidelity = 0.966145	KL_Divergence = 0.010060	Observable_XX_ev = 1.155958	Observable_XZ_ev = 0.002443
# Epoch: 249	Fidelity = 0.968048	KL_Divergence = 0.007504	Observable_XX_ev = 0.972383	Observable_XZ_ev = -0.001607
# Epoch: 250	Fidelity = 0.967208	KL_Divergence = 0.008673	Observable_XX_ev = 1.013107	Observable_XZ_ev = 0.003317
# Epoch: 251	Fidelity = 0.965631	KL_Divergence = 0.010831	Observable_XX_ev = 1.058496	Observable_XZ_ev = 0.010382
# Epoch: 252	Fidelity = 0.965574	KL_Divergence = 0.010940	Observable_XX_ev = 0.994559	Observable_XZ_ev = -0.003060
# Epoch: 253	Fidelity = 0.966196	KL_Divergence = 0.010113	Observable_XX_ev = 0.917586	Observable_XZ_ev = -0.002159
# Epoch: 254	Fidelity = 0.967837	KL_Divergence = 0.007940	Observable_XX_ev = 1.006360	Observable_XZ_ev = 0.010051
# Epoch: 255	Fidelity = 0.967053	KL_Divergence = 0.008983	Observable_XX_ev = 0.926824	Observable_XZ_ev = -0.000185
# Epoch: 256	Fidelity = 0.966984	KL_Divergence = 0.009062	Observable_XX_ev = 0.962762	Observable_XZ_ev = -0.001154
# Epoch: 257	Fidelity = 0.967548	KL_Divergence = 0.008268	Observable_XX_ev = 0.873978	Observable_XZ_ev = 0.006845
# Epoch: 258	Fidelity = 0.968317	KL_Divergence = 0.007361	Observable_XX_ev = 1.154081	Observable_XZ_ev = 0.017425
# Epoch: 259	Fidelity = 0.967461	KL_Divergence = 0.008511	Observable_XX_ev = 0.944655	Observable_XZ_ev = 0.005798
# Epoch: 260	Fidelity = 0.967037	KL_Divergence = 0.009164	Observable_XX_ev = 0.861090	Observable_XZ_ev = -0.008063
# Epoch: 261	Fidelity = 0.967508	KL_Divergence = 0.008557	Observable_XX_ev = 0.988397	Observable_XZ_ev = 0.023786
# Epoch: 262	Fidelity = 0.968356	KL_Divergence = 0.007381	Observable_XX_ev = 0.968049	Observable_XZ_ev = 0.010304
# Epoch: 263	Fidelity = 0.968096	KL_Divergence = 0.007819	Observable_XX_ev = 0.993650	Observable_XZ_ev = -0.003414
# Epoch: 264	Fidelity = 0.968274	KL_Divergence = 0.007673	Observable_XX_ev = 1.075899	Observable_XZ_ev = -0.000702
# Epoch: 265	Fidelity = 0.968154	KL_Divergence = 0.007835	Observable_XX_ev = 1.012935	Observable_XZ_ev = 0.000620
# Epoch: 266	Fidelity = 0.967801	KL_Divergence = 0.008345	Observable_XX_ev = 0.976525	Observable_XZ_ev = 0.004970
# Epoch: 267	Fidelity = 0.967983	KL_Divergence = 0.008153	Observable_XX_ev = 0.853348	Observable_XZ_ev = 0.001562
# Epoch: 268	Fidelity = 0.967575	KL_Divergence = 0.008699	Observable_XX_ev = 0.989218	Observable_XZ_ev = 0.020492
# Epoch: 269	Fidelity = 0.968441	KL_Divergence = 0.007552	Observable_XX_ev = 1.097868	Observable_XZ_ev = -0.002187
# Epoch: 270	Fidelity = 0.968460	KL_Divergence = 0.007533	Observable_XX_ev = 1.033758	Observable_XZ_ev = 0.002254
# Epoch: 271	Fidelity = 0.968514	KL_Divergence = 0.007440	Observable_XX_ev = 0.982188	Observable_XZ_ev = -0.001960
# Epoch: 272	Fidelity = 0.968536	KL_Divergence = 0.007403	Observable_XX_ev = 0.909288	Observable_XZ_ev = 0.014128
# Epoch: 273	Fidelity = 0.968416	KL_Divergence = 0.007584	Observable_XX_ev = 0.922995	Observable_XZ_ev = -0.002607
# Epoch: 274	Fidelity = 0.968369	KL_Divergence = 0.007629	Observable_XX_ev = 0.955205	Observable_XZ_ev = 0.013520
# Epoch: 275	Fidelity = 0.967604	KL_Divergence = 0.008705	Observable_XX_ev = 0.975338	Observable_XZ_ev = 0.006162
# Epoch: 276	Fidelity = 0.968225	KL_Divergence = 0.007870	Observable_XX_ev = 1.071002	Observable_XZ_ev = 0.001267
# Epoch: 277	Fidelity = 0.966780	KL_Divergence = 0.009880	Observable_XX_ev = 0.945202	Observable_XZ_ev = -0.003844
# Epoch: 278	Fidelity = 0.967704	KL_Divergence = 0.008559	Observable_XX_ev = 1.006060	Observable_XZ_ev = -0.007726
# Epoch: 279	Fidelity = 0.967378	KL_Divergence = 0.009067	Observable_XX_ev = 0.954649	Observable_XZ_ev = -0.009144
# Epoch: 280	Fidelity = 0.968038	KL_Divergence = 0.008160	Observable_XX_ev = 1.026198	Observable_XZ_ev = -0.016316
# Epoch: 281	Fidelity = 0.967132	KL_Divergence = 0.009375	Observable_XX_ev = 0.942739	Observable_XZ_ev = 0.005347
# Epoch: 282	Fidelity = 0.967780	KL_Divergence = 0.008526	Observable_XX_ev = 0.956106	Observable_XZ_ev = 0.002381
# Epoch: 283	Fidelity = 0.968436	KL_Divergence = 0.007640	Observable_XX_ev = 0.983900	Observable_XZ_ev = 0.011121
# Epoch: 284	Fidelity = 0.968205	KL_Divergence = 0.007957	Observable_XX_ev = 1.130691	Observable_XZ_ev = -0.002679
# Epoch: 285	Fidelity = 0.968238	KL_Divergence = 0.007951	Observable_XX_ev = 0.974773	Observable_XZ_ev = -0.000483
# Epoch: 286	Fidelity = 0.968655	KL_Divergence = 0.007332	Observable_XX_ev = 1.009802	Observable_XZ_ev = 0.007645
# Epoch: 287	Fidelity = 0.968720	KL_Divergence = 0.007299	Observable_XX_ev = 1.000120	Observable_XZ_ev = 0.003529
# Epoch: 288	Fidelity = 0.967900	KL_Divergence = 0.008413	Observable_XX_ev = 0.998466	Observable_XZ_ev = -0.001940
# Epoch: 289	Fidelity = 0.967924	KL_Divergence = 0.008398	Observable_XX_ev = 0.946723	Observable_XZ_ev = 0.019426
# Epoch: 290	Fidelity = 0.967859	KL_Divergence = 0.008529	Observable_XX_ev = 1.051277	Observable_XZ_ev = -0.000160
# Epoch: 291	Fidelity = 0.968311	KL_Divergence = 0.007951	Observable_XX_ev = 0.922610	Observable_XZ_ev = 0.007404
# Epoch: 292	Fidelity = 0.968048	KL_Divergence = 0.008331	Observable_XX_ev = 0.961686	Observable_XZ_ev = 0.011871
# Epoch: 293	Fidelity = 0.966900	KL_Divergence = 0.009919	Observable_XX_ev = 0.977449	Observable_XZ_ev = 0.002351
# Epoch: 294	Fidelity = 0.966602	KL_Divergence = 0.010347	Observable_XX_ev = 0.971819	Observable_XZ_ev = -0.000252
# Epoch: 295	Fidelity = 0.967398	KL_Divergence = 0.009258	Observable_XX_ev = 1.020349	Observable_XZ_ev = 0.011997
# Epoch: 296	Fidelity = 0.965927	KL_Divergence = 0.011311	Observable_XX_ev = 1.066305	Observable_XZ_ev = 0.005244
# Epoch: 297	Fidelity = 0.967223	KL_Divergence = 0.009525	Observable_XX_ev = 1.024688	Observable_XZ_ev = 0.004569
# Epoch: 298	Fidelity = 0.968039	KL_Divergence = 0.008403	Observable_XX_ev = 0.971026	Observable_XZ_ev = 0.011654
# Epoch: 299	Fidelity = 0.968166	KL_Divergence = 0.008217	Observable_XX_ev = 1.002588	Observable_XZ_ev = 0.001538
# Epoch: 300	Fidelity = 0.968825	KL_Divergence = 0.007309	Observable_XX_ev = 0.999506	Observable_XZ_ev = 0.001254
# Epoch: 301	Fidelity = 0.968553	KL_Divergence = 0.007672	Observable_XX_ev = 1.004022	Observable_XZ_ev = 0.001689
# Epoch: 302	Fidelity = 0.968817	KL_Divergence = 0.007328	Observable_XX_ev = 1.137700	Observable_XZ_ev = 0.010487
# Epoch: 303	Fidelity = 0.968285	KL_Divergence = 0.008058	Observable_XX_ev = 0.845372	Observable_XZ_ev = 0.006467
# Epoch: 304	Fidelity = 0.968533	KL_Divergence = 0.007736	Observable_XX_ev = 0.897310	Observable_XZ_ev = -0.000970
# Epoch: 305	Fidelity = 0.968042	KL_Divergence = 0.008415	Observable_XX_ev = 1.108187	Observable_XZ_ev = 0.003693
# Epoch: 306	Fidelity = 0.968484	KL_Divergence = 0.007811	Observable_XX_ev = 1.029755	Observable_XZ_ev = 0.003017
# Epoch: 307	Fidelity = 0.968401	KL_Divergence = 0.007934	Observable_XX_ev = 1.006474	Observable_XZ_ev = 0.000499
# Epoch: 308	Fidelity = 0.968017	KL_Divergence = 0.008458	Observable_XX_ev = 1.087180	Observable_XZ_ev = 0.022757
# Epoch: 309	Fidelity = 0.967747	KL_Divergence = 0.008839	Observable_XX_ev = 0.983382	Observable_XZ_ev = 0.000235
# Epoch: 310	Fidelity = 0.967810	KL_Divergence = 0.008809	Observable_XX_ev = 1.004020	Observable_XZ_ev = 0.000218
# Epoch: 311	Fidelity = 0.968149	KL_Divergence = 0.008328	Observable_XX_ev = 0.832741	Observable_XZ_ev = 0.003261
# Epoch: 312	Fidelity = 0.968381	KL_Divergence = 0.008002	Observable_XX_ev = 0.941473	Observable_XZ_ev = 0.000038
# Epoch: 313	Fidelity = 0.968818	KL_Divergence = 0.007396	Observable_XX_ev = 0.996145	Observable_XZ_ev = 0.011264
# Epoch: 314	Fidelity = 0.968721	KL_Divergence = 0.007517	Observable_XX_ev = 1.031017	Observable_XZ_ev = 0.007316
# Epoch: 315	Fidelity = 0.968476	KL_Divergence = 0.007849	Observable_XX_ev = 0.940082	Observable_XZ_ev = 0.007057
# Epoch: 316	Fidelity = 0.968825	KL_Divergence = 0.007364	Observable_XX_ev = 1.063383	Observable_XZ_ev = -0.002202
# Epoch: 317	Fidelity = 0.968558	KL_Divergence = 0.007722	Observable_XX_ev = 1.114613	Observable_XZ_ev = -0.007918
# Epoch: 318	Fidelity = 0.968483	KL_Divergence = 0.007833	Observable_XX_ev = 0.926029	Observable_XZ_ev = 0.003522
# Epoch: 319	Fidelity = 0.968014	KL_Divergence = 0.008469	Observable_XX_ev = 0.935150	Observable_XZ_ev = -0.006484
# Epoch: 320	Fidelity = 0.967463	KL_Divergence = 0.009255	Observable_XX_ev = 0.866152	Observable_XZ_ev = 0.005040
# Epoch: 321	Fidelity = 0.968263	KL_Divergence = 0.008165	Observable_XX_ev = 1.000529	Observable_XZ_ev = -0.000689
# Epoch: 322	Fidelity = 0.968661	KL_Divergence = 0.007617	Observable_XX_ev = 1.064862	Observable_XZ_ev = 0.002191
# Epoch: 323	Fidelity = 0.968653	KL_Divergence = 0.007668	Observable_XX_ev = 1.032929	Observable_XZ_ev = 0.000031
# Epoch: 324	Fidelity = 0.968736	KL_Divergence = 0.007557	Observable_XX_ev = 1.001996	Observable_XZ_ev = 0.006967
# Epoch: 325	Fidelity = 0.968496	KL_Divergence = 0.007899	Observable_XX_ev = 0.966799	Observable_XZ_ev = 0.006124
# Epoch: 326	Fidelity = 0.968121	KL_Divergence = 0.008408	Observable_XX_ev = 0.912327	Observable_XZ_ev = 0.012494
# Epoch: 327	Fidelity = 0.968259	KL_Divergence = 0.008236	Observable_XX_ev = 0.898657	Observable_XZ_ev = 0.011425
# Epoch: 328	Fidelity = 0.967507	KL_Divergence = 0.009280	Observable_XX_ev = 0.963902	Observable_XZ_ev = -0.003974
# Epoch: 329	Fidelity = 0.968235	KL_Divergence = 0.008304	Observable_XX_ev = 1.030605	Observable_XZ_ev = 0.011079
# Epoch: 330	Fidelity = 0.968579	KL_Divergence = 0.007867	Observable_XX_ev = 0.878777	Observable_XZ_ev = -0.008397
# Epoch: 331	Fidelity = 0.968922	KL_Divergence = 0.007399	Observable_XX_ev = 1.012270	Observable_XZ_ev = 0.002739
# Epoch: 332	Fidelity = 0.968280	KL_Divergence = 0.008303	Observable_XX_ev = 1.008602	Observable_XZ_ev = 0.011288
# Epoch: 333	Fidelity = 0.968666	KL_Divergence = 0.007767	Observable_XX_ev = 0.943955	Observable_XZ_ev = -0.008517
# Epoch: 334	Fidelity = 0.968733	KL_Divergence = 0.007688	Observable_XX_ev = 0.958356	Observable_XZ_ev = -0.008209
# Epoch: 335	Fidelity = 0.968191	KL_Divergence = 0.008432	Observable_XX_ev = 1.135521	Observable_XZ_ev = -0.009450
# Epoch: 336	Fidelity = 0.968347	KL_Divergence = 0.008225	Observable_XX_ev = 0.970285	Observable_XZ_ev = -0.000015
# Epoch: 337	Fidelity = 0.968805	KL_Divergence = 0.007639	Observable_XX_ev = 1.181361	Observable_XZ_ev = 0.000453
# Epoch: 338	Fidelity = 0.968897	KL_Divergence = 0.007540	Observable_XX_ev = 0.909120	Observable_XZ_ev = 0.001562
# Epoch: 339	Fidelity = 0.968742	KL_Divergence = 0.007734	Observable_XX_ev = 0.859879	Observable_XZ_ev = -0.003610
# Epoch: 340	Fidelity = 0.967828	KL_Divergence = 0.008981	Observable_XX_ev = 1.040561	Observable_XZ_ev = 0.015310
# Epoch: 341	Fidelity = 0.967985	KL_Divergence = 0.008776	Observable_XX_ev = 0.975464	Observable_XZ_ev = 0.005289
# Epoch: 342	Fidelity = 0.967911	KL_Divergence = 0.008890	Observable_XX_ev = 1.054059	Observable_XZ_ev = 0.000188
# Epoch: 343	Fidelity = 0.968077	KL_Divergence = 0.008669	Observable_XX_ev = 0.953371	Observable_XZ_ev = -0.000687
# Epoch: 344	Fidelity = 0.968531	KL_Divergence = 0.008048	Observable_XX_ev = 0.978808	Observable_XZ_ev = 0.022831
# Epoch: 345	Fidelity = 0.969168	KL_Divergence = 0.007196	Observable_XX_ev = 1.023307	Observable_XZ_ev = 0.002030
# Epoch: 346	Fidelity = 0.969218	KL_Divergence = 0.007126	Observable_XX_ev = 1.010823	Observable_XZ_ev = -0.002386
# Epoch: 347	Fidelity = 0.969188	KL_Divergence = 0.007138	Observable_XX_ev = 0.989370	Observable_XZ_ev = 0.006863
# Epoch: 348	Fidelity = 0.969167	KL_Divergence = 0.007171	Observable_XX_ev = 0.956615	Observable_XZ_ev = 0.008173
# Epoch: 349	Fidelity = 0.969166	KL_Divergence = 0.007183	Observable_XX_ev = 0.934766	Observable_XZ_ev = 0.002878
# Epoch: 350	Fidelity = 0.969155	KL_Divergence = 0.007178	Observable_XX_ev = 1.066229	Observable_XZ_ev = 0.002173
# Epoch: 351	Fidelity = 0.968991	KL_Divergence = 0.007412	Observable_XX_ev = 0.946755	Observable_XZ_ev = 0.007348
# Epoch: 352	Fidelity = 0.969139	KL_Divergence = 0.007244	Observable_XX_ev = 0.939799	Observable_XZ_ev = -0.001352
# Epoch: 353	Fidelity = 0.968511	KL_Divergence = 0.008097	Observable_XX_ev = 1.346868	Observable_XZ_ev = -0.017297
# Epoch: 354	Fidelity = 0.968656	KL_Divergence = 0.007924	Observable_XX_ev = 1.070093	Observable_XZ_ev = -0.003756
# Epoch: 355	Fidelity = 0.968834	KL_Divergence = 0.007676	Observable_XX_ev = 1.086994	Observable_XZ_ev = 0.001200
# Epoch: 356	Fidelity = 0.968779	KL_Divergence = 0.007756	Observable_XX_ev = 1.010334	Observable_XZ_ev = -0.002637
# Epoch: 357	Fidelity = 0.968229	KL_Divergence = 0.008526	Observable_XX_ev = 0.980507	Observable_XZ_ev = 0.009731
# Epoch: 358	Fidelity = 0.968126	KL_Divergence = 0.008691	Observable_XX_ev = 0.957021	Observable_XZ_ev = 0.002960
# Epoch: 359	Fidelity = 0.968513	KL_Divergence = 0.008205	Observable_XX_ev = 1.002716	Observable_XZ_ev = -0.004347
# Epoch: 360	Fidelity = 0.968397	KL_Divergence = 0.008375	Observable_XX_ev = 1.209126	Observable_XZ_ev = -0.016075
# Epoch: 361	Fidelity = 0.968151	KL_Divergence = 0.008736	Observable_XX_ev = 0.957324	Observable_XZ_ev = -0.001660
# Epoch: 362	Fidelity = 0.968284	KL_Divergence = 0.008563	Observable_XX_ev = 0.966294	Observable_XZ_ev = 0.019532
# Epoch: 363	Fidelity = 0.968308	KL_Divergence = 0.008534	Observable_XX_ev = 0.870219	Observable_XZ_ev = 0.006980
# Epoch: 364	Fidelity = 0.968304	KL_Divergence = 0.008543	Observable_XX_ev = 0.978325	Observable_XZ_ev = 0.008373
# Epoch: 365	Fidelity = 0.968479	KL_Divergence = 0.008323	Observable_XX_ev = 0.902108	Observable_XZ_ev = -0.001951
# Epoch: 366	Fidelity = 0.968522	KL_Divergence = 0.008270	Observable_XX_ev = 1.000182	Observable_XZ_ev = 0.006524
# Epoch: 367	Fidelity = 0.968802	KL_Divergence = 0.007897	Observable_XX_ev = 0.972972	Observable_XZ_ev = 0.001730
# Epoch: 368	Fidelity = 0.969024	KL_Divergence = 0.007616	Observable_XX_ev = 1.111006	Observable_XZ_ev = 0.001814
# Epoch: 369	Fidelity = 0.968648	KL_Divergence = 0.008120	Observable_XX_ev = 1.041174	Observable_XZ_ev = 0.003460
# Epoch: 370	Fidelity = 0.968146	KL_Divergence = 0.008807	Observable_XX_ev = 1.101734	Observable_XZ_ev = -0.010957
# Epoch: 371	Fidelity = 0.968281	KL_Divergence = 0.008631	Observable_XX_ev = 0.986196	Observable_XZ_ev = 0.000772
# Epoch: 372	Fidelity = 0.968162	KL_Divergence = 0.008799	Observable_XX_ev = 1.000278	Observable_XZ_ev = 0.003193
# Epoch: 373	Fidelity = 0.967743	KL_Divergence = 0.009379	Observable_XX_ev = 0.925404	Observable_XZ_ev = 0.014630
# Epoch: 374	Fidelity = 0.968193	KL_Divergence = 0.008776	Observable_XX_ev = 1.185562	Observable_XZ_ev = -0.008409
# Epoch: 375	Fidelity = 0.968311	KL_Divergence = 0.008602	Observable_XX_ev = 0.926523	Observable_XZ_ev = 0.002016
# Epoch: 376	Fidelity = 0.968157	KL_Divergence = 0.008823	Observable_XX_ev = 0.958070	Observable_XZ_ev = 0.003969
# Epoch: 377	Fidelity = 0.968360	KL_Divergence = 0.008528	Observable_XX_ev = 0.951661	Observable_XZ_ev = 0.014328
# Epoch: 378	Fidelity = 0.968501	KL_Divergence = 0.008360	Observable_XX_ev = 0.908443	Observable_XZ_ev = -0.020685
# Epoch: 379	Fidelity = 0.968202	KL_Divergence = 0.008775	Observable_XX_ev = 1.020467	Observable_XZ_ev = 0.007377
# Epoch: 380	Fidelity = 0.968567	KL_Divergence = 0.008291	Observable_XX_ev = 1.097316	Observable_XZ_ev = 0.005422
# Epoch: 381	Fidelity = 0.968708	KL_Divergence = 0.008096	Observable_XX_ev = 0.958543	Observable_XZ_ev = -0.003738
# Epoch: 382	Fidelity = 0.968746	KL_Divergence = 0.008055	Observable_XX_ev = 1.111574	Observable_XZ_ev = 0.021586
# Epoch: 383	Fidelity = 0.968667	KL_Divergence = 0.008160	Observable_XX_ev = 1.189066	Observable_XZ_ev = 0.011185
# Epoch: 384	Fidelity = 0.968836	KL_Divergence = 0.007944	Observable_XX_ev = 0.941240	Observable_XZ_ev = -0.003729
# Epoch: 385	Fidelity = 0.968724	KL_Divergence = 0.008111	Observable_XX_ev = 0.992915	Observable_XZ_ev = -0.004797
# Epoch: 386	Fidelity = 0.968510	KL_Divergence = 0.008392	Observable_XX_ev = 0.976386	Observable_XZ_ev = -0.004257
# Epoch: 387	Fidelity = 0.968601	KL_Divergence = 0.008260	Observable_XX_ev = 1.032126	Observable_XZ_ev = 0.020008
# Epoch: 388	Fidelity = 0.968393	KL_Divergence = 0.008550	Observable_XX_ev = 0.811264	Observable_XZ_ev = -0.002451
# Epoch: 389	Fidelity = 0.968352	KL_Divergence = 0.008612	Observable_XX_ev = 1.049781	Observable_XZ_ev = -0.002258
# Epoch: 390	Fidelity = 0.967870	KL_Divergence = 0.009273	Observable_XX_ev = 0.998703	Observable_XZ_ev = -0.001389
# Epoch: 391	Fidelity = 0.968057	KL_Divergence = 0.009032	Observable_XX_ev = 1.075823	Observable_XZ_ev = -0.003278
# Epoch: 392	Fidelity = 0.968257	KL_Divergence = 0.008750	Observable_XX_ev = 1.016768	Observable_XZ_ev = -0.001769
# Epoch: 393	Fidelity = 0.968617	KL_Divergence = 0.008271	Observable_XX_ev = 0.998723	Observable_XZ_ev = -0.002047
# Epoch: 394	Fidelity = 0.968297	KL_Divergence = 0.008719	Observable_XX_ev = 0.965219	Observable_XZ_ev = 0.002205
# Epoch: 395	Fidelity = 0.968304	KL_Divergence = 0.008730	Observable_XX_ev = 0.947953	Observable_XZ_ev = -0.002250
# Epoch: 396	Fidelity = 0.968085	KL_Divergence = 0.009033	Observable_XX_ev = 1.070501	Observable_XZ_ev = 0.015813
# Epoch: 397	Fidelity = 0.968213	KL_Divergence = 0.008859	Observable_XX_ev = 0.844781	Observable_XZ_ev = 0.004423
# Epoch: 398	Fidelity = 0.967975	KL_Divergence = 0.009191	Observable_XX_ev = 0.932575	Observable_XZ_ev = 0.002208
# Epoch: 399	Fidelity = 0.968303	KL_Divergence = 0.008749	Observable_XX_ev = 0.877602	Observable_XZ_ev = 0.000795
# Epoch: 400	Fidelity = 0.968465	KL_Divergence = 0.008542	Observable_XX_ev = 1.027365	Observable_XZ_ev = -0.001185
# Epoch: 401	Fidelity = 0.968389	KL_Divergence = 0.008662	Observable_XX_ev = 0.938250	Observable_XZ_ev = 0.012957
# Epoch: 402	Fidelity = 0.968454	KL_Divergence = 0.008573	Observable_XX_ev = 0.967531	Observable_XZ_ev = 0.009993
# Epoch: 403	Fidelity = 0.968266	KL_Divergence = 0.008824	Observable_XX_ev = 0.912885	Observable_XZ_ev = 0.009899
# Epoch: 404	Fidelity = 0.968208	KL_Divergence = 0.008906	Observable_XX_ev = 0.923085	Observable_XZ_ev = -0.004124
# Epoch: 405	Fidelity = 0.968204	KL_Divergence = 0.008919	Observable_XX_ev = 1.022933	Observable_XZ_ev = 0.005278
# Epoch: 406	Fidelity = 0.968370	KL_Divergence = 0.008680	Observable_XX_ev = 1.018387	Observable_XZ_ev = 0.007349
# Epoch: 407	Fidelity = 0.968743	KL_Divergence = 0.008171	Observable_XX_ev = 1.004224	Observable_XZ_ev = -0.011454
# Epoch: 408	Fidelity = 0.968709	KL_Divergence = 0.008233	Observable_XX_ev = 0.934072	Observable_XZ_ev = 0.001899
# Epoch: 409	Fidelity = 0.968941	KL_Divergence = 0.007913	Observable_XX_ev = 0.901520	Observable_XZ_ev = -0.012506
# Epoch: 410	Fidelity = 0.968923	KL_Divergence = 0.007943	Observable_XX_ev = 0.948685	Observable_XZ_ev = -0.001490
# Epoch: 411	Fidelity = 0.969026	KL_Divergence = 0.007811	Observable_XX_ev = 0.974725	Observable_XZ_ev = -0.008236
# Epoch: 412	Fidelity = 0.968665	KL_Divergence = 0.008308	Observable_XX_ev = 1.067913	Observable_XZ_ev = 0.010221
# Epoch: 413	Fidelity = 0.968490	KL_Divergence = 0.008543	Observable_XX_ev = 0.964370	Observable_XZ_ev = 0.006485
# Epoch: 414	Fidelity = 0.968751	KL_Divergence = 0.008194	Observable_XX_ev = 1.095128	Observable_XZ_ev = 0.000959
# Epoch: 415	Fidelity = 0.968701	KL_Divergence = 0.008260	Observable_XX_ev = 1.032791	Observable_XZ_ev = 0.011412
# Epoch: 416	Fidelity = 0.968409	KL_Divergence = 0.008664	Observable_XX_ev = 0.948149	Observable_XZ_ev = 0.005786
# Epoch: 417	Fidelity = 0.968534	KL_Divergence = 0.008502	Observable_XX_ev = 0.978777	Observable_XZ_ev = 0.004835
# Epoch: 418	Fidelity = 0.968748	KL_Divergence = 0.008196	Observable_XX_ev = 0.906593	Observable_XZ_ev = -0.008713
# Epoch: 419	Fidelity = 0.968938	KL_Divergence = 0.007949	Observable_XX_ev = 1.031267	Observable_XZ_ev = 0.006352
# Epoch: 420	Fidelity = 0.968987	KL_Divergence = 0.007883	Observable_XX_ev = 0.968103	Observable_XZ_ev = 0.000625
# Epoch: 421	Fidelity = 0.969030	KL_Divergence = 0.007833	Observable_XX_ev = 1.064106	Observable_XZ_ev = -0.003979
# Epoch: 422	Fidelity = 0.968920	KL_Divergence = 0.007993	Observable_XX_ev = 1.033398	Observable_XZ_ev = 0.002108
# Epoch: 423	Fidelity = 0.968889	KL_Divergence = 0.008027	Observable_XX_ev = 1.059953	Observable_XZ_ev = -0.001923
# Epoch: 424	Fidelity = 0.968938	KL_Divergence = 0.007956	Observable_XX_ev = 1.119604	Observable_XZ_ev = 0.010706
# Epoch: 425	Fidelity = 0.968973	KL_Divergence = 0.007911	Observable_XX_ev = 1.037405	Observable_XZ_ev = -0.007937
# Epoch: 426	Fidelity = 0.968964	KL_Divergence = 0.007920	Observable_XX_ev = 1.028862	Observable_XZ_ev = 0.004601
# Epoch: 427	Fidelity = 0.969164	KL_Divergence = 0.007652	Observable_XX_ev = 1.019885	Observable_XZ_ev = 0.009989
# Epoch: 428	Fidelity = 0.969296	KL_Divergence = 0.007475	Observable_XX_ev = 0.960859	Observable_XZ_ev = 0.005376
# Epoch: 429	Fidelity = 0.969338	KL_Divergence = 0.007426	Observable_XX_ev = 0.885981	Observable_XZ_ev = -0.008347
# Epoch: 430	Fidelity = 0.969379	KL_Divergence = 0.007369	Observable_XX_ev = 1.065357	Observable_XZ_ev = -0.004947
# Epoch: 431	Fidelity = 0.969378	KL_Divergence = 0.007375	Observable_XX_ev = 1.009965	Observable_XZ_ev = 0.012263
# Epoch: 432	Fidelity = 0.969208	KL_Divergence = 0.007607	Observable_XX_ev = 1.146876	Observable_XZ_ev = 0.021544
# Epoch: 433	Fidelity = 0.969038	KL_Divergence = 0.007827	Observable_XX_ev = 0.971516	Observable_XZ_ev = -0.011816
# Epoch: 434	Fidelity = 0.969144	KL_Divergence = 0.007678	Observable_XX_ev = 1.037424	Observable_XZ_ev = 0.002428
# Epoch: 435	Fidelity = 0.968998	KL_Divergence = 0.007876	Observable_XX_ev = 1.002736	Observable_XZ_ev = 0.022463
# Epoch: 436	Fidelity = 0.968901	KL_Divergence = 0.008015	Observable_XX_ev = 0.878946	Observable_XZ_ev = 0.002511
# Epoch: 437	Fidelity = 0.969018	KL_Divergence = 0.007861	Observable_XX_ev = 1.077308	Observable_XZ_ev = 0.012543
# Epoch: 438	Fidelity = 0.969034	KL_Divergence = 0.007839	Observable_XX_ev = 1.066299	Observable_XZ_ev = -0.004236
# Epoch: 439	Fidelity = 0.968892	KL_Divergence = 0.008029	Observable_XX_ev = 0.963498	Observable_XZ_ev = 0.013995
# Epoch: 440	Fidelity = 0.969119	KL_Divergence = 0.007726	Observable_XX_ev = 1.026112	Observable_XZ_ev = 0.010636
# Epoch: 441	Fidelity = 0.969117	KL_Divergence = 0.007732	Observable_XX_ev = 1.185786	Observable_XZ_ev = 0.003625
# Epoch: 442	Fidelity = 0.969055	KL_Divergence = 0.007811	Observable_XX_ev = 0.973835	Observable_XZ_ev = 0.006736
# Epoch: 443	Fidelity = 0.968851	KL_Divergence = 0.008083	Observable_XX_ev = 1.099445	Observable_XZ_ev = 0.005140
# Epoch: 444	Fidelity = 0.968661	KL_Divergence = 0.008338	Observable_XX_ev = 1.133865	Observable_XZ_ev = -0.009720
# Epoch: 445	Fidelity = 0.968614	KL_Divergence = 0.008411	Observable_XX_ev = 0.988280	Observable_XZ_ev = 0.014974
# Epoch: 446	Fidelity = 0.968676	KL_Divergence = 0.008330	Observable_XX_ev = 1.039488	Observable_XZ_ev = -0.002999
# Epoch: 447	Fidelity = 0.968816	KL_Divergence = 0.008137	Observable_XX_ev = 0.993335	Observable_XZ_ev = -0.001648
# Epoch: 448	Fidelity = 0.969047	KL_Divergence = 0.007818	Observable_XX_ev = 1.085098	Observable_XZ_ev = -0.005447
# Epoch: 449	Fidelity = 0.969000	KL_Divergence = 0.007887	Observable_XX_ev = 1.045224	Observable_XZ_ev = -0.002580
# Epoch: 450	Fidelity = 0.968773	KL_Divergence = 0.008201	Observable_XX_ev = 1.063763	Observable_XZ_ev = -0.004223
# Epoch: 451	Fidelity = 0.968617	KL_Divergence = 0.008414	Observable_XX_ev = 0.995803	Observable_XZ_ev = 0.000701
# Epoch: 452	Fidelity = 0.968746	KL_Divergence = 0.008236	Observable_XX_ev = 0.985089	Observable_XZ_ev = 0.012448
# Epoch: 453	Fidelity = 0.968611	KL_Divergence = 0.008426	Observable_XX_ev = 0.974368	Observable_XZ_ev = 0.007191
# Epoch: 454	Fidelity = 0.968684	KL_Divergence = 0.008332	Observable_XX_ev = 0.992607	Observable_XZ_ev = 0.001242
# Epoch: 455	Fidelity = 0.968856	KL_Divergence = 0.008099	Observable_XX_ev = 1.054901	Observable_XZ_ev = 0.000608
# Epoch: 456	Fidelity = 0.968646	KL_Divergence = 0.008385	Observable_XX_ev = 0.992408	Observable_XZ_ev = -0.002543
# Epoch: 457	Fidelity = 0.968757	KL_Divergence = 0.008247	Observable_XX_ev = 1.066397	Observable_XZ_ev = 0.008873
# Epoch: 458	Fidelity = 0.968789	KL_Divergence = 0.008205	Observable_XX_ev = 0.948604	Observable_XZ_ev = 0.006450
# Epoch: 459	Fidelity = 0.968686	KL_Divergence = 0.008341	Observable_XX_ev = 0.961878	Observable_XZ_ev = 0.009657
# Epoch: 460	Fidelity = 0.968654	KL_Divergence = 0.008385	Observable_XX_ev = 1.019354	Observable_XZ_ev = -0.005381
# Epoch: 461	Fidelity = 0.968766	KL_Divergence = 0.008226	Observable_XX_ev = 1.175043	Observable_XZ_ev = -0.003735
# Epoch: 462	Fidelity = 0.968516	KL_Divergence = 0.008564	Observable_XX_ev = 1.068418	Observable_XZ_ev = 0.015323
# Epoch: 463	Fidelity = 0.968610	KL_Divergence = 0.008435	Observable_XX_ev = 0.860430	Observable_XZ_ev = 0.005155
# Epoch: 464	Fidelity = 0.968701	KL_Divergence = 0.008308	Observable_XX_ev = 0.937394	Observable_XZ_ev = 0.005776
# Epoch: 465	Fidelity = 0.968538	KL_Divergence = 0.008519	Observable_XX_ev = 0.900961	Observable_XZ_ev = 0.012075
# Epoch: 466	Fidelity = 0.968463	KL_Divergence = 0.008619	Observable_XX_ev = 0.908580	Observable_XZ_ev = -0.002834
# Epoch: 467	Fidelity = 0.968319	KL_Divergence = 0.008818	Observable_XX_ev = 0.865994	Observable_XZ_ev = -0.003823
# Epoch: 468	Fidelity = 0.968403	KL_Divergence = 0.008706	Observable_XX_ev = 0.997696	Observable_XZ_ev = -0.003533
# Epoch: 469	Fidelity = 0.968404	KL_Divergence = 0.008711	Observable_XX_ev = 1.000164	Observable_XZ_ev = -0.008643
# Epoch: 470	Fidelity = 0.968597	KL_Divergence = 0.008449	Observable_XX_ev = 0.994845	Observable_XZ_ev = 0.003776
# Epoch: 471	Fidelity = 0.968597	KL_Divergence = 0.008460	Observable_XX_ev = 0.985795	Observable_XZ_ev = 0.007042
# Epoch: 472	Fidelity = 0.968571	KL_Divergence = 0.008499	Observable_XX_ev = 0.959464	Observable_XZ_ev = -0.000627
# Epoch: 473	Fidelity = 0.968670	KL_Divergence = 0.008368	Observable_XX_ev = 0.964515	Observable_XZ_ev = 0.019700
# Epoch: 474	Fidelity = 0.968932	KL_Divergence = 0.008009	Observable_XX_ev = 1.064320	Observable_XZ_ev = -0.008006
# Epoch: 475	Fidelity = 0.968846	KL_Divergence = 0.008130	Observable_XX_ev = 1.048767	Observable_XZ_ev = 0.006335
# Epoch: 476	Fidelity = 0.968681	KL_Divergence = 0.008357	Observable_XX_ev = 0.962949	Observable_XZ_ev = 0.016043
# Epoch: 477	Fidelity = 0.968742	KL_Divergence = 0.008281	Observable_XX_ev = 0.928810	Observable_XZ_ev = -0.003476
# Epoch: 478	Fidelity = 0.968629	KL_Divergence = 0.008428	Observable_XX_ev = 0.945701	Observable_XZ_ev = 0.017036
# Epoch: 479	Fidelity = 0.968728	KL_Divergence = 0.008295	Observable_XX_ev = 0.912486	Observable_XZ_ev = 0.000719
# Epoch: 480	Fidelity = 0.968656	KL_Divergence = 0.008391	Observable_XX_ev = 1.058743	Observable_XZ_ev = -0.002626
# Epoch: 481	Fidelity = 0.968624	KL_Divergence = 0.008435	Observable_XX_ev = 0.954823	Observable_XZ_ev = 0.014390
# Epoch: 482	Fidelity = 0.968590	KL_Divergence = 0.008482	Observable_XX_ev = 1.093444	Observable_XZ_ev = 0.011752
# Epoch: 483	Fidelity = 0.968578	KL_Divergence = 0.008494	Observable_XX_ev = 0.847494	Observable_XZ_ev = -0.002151
# Epoch: 484	Fidelity = 0.968577	KL_Divergence = 0.008499	Observable_XX_ev = 1.035885	Observable_XZ_ev = -0.003803
# Epoch: 485	Fidelity = 0.968607	KL_Divergence = 0.008464	Observable_XX_ev = 1.034879	Observable_XZ_ev = 0.001211
# Epoch: 486	Fidelity = 0.968653	KL_Divergence = 0.008405	Observable_XX_ev = 1.106587	Observable_XZ_ev = 0.001374
# Epoch: 487	Fidelity = 0.968612	KL_Divergence = 0.008462	Observable_XX_ev = 1.043757	Observable_XZ_ev = 0.010670
# Epoch: 488	Fidelity = 0.968803	KL_Divergence = 0.008198	Observable_XX_ev = 0.937811	Observable_XZ_ev = 0.003815
# Epoch: 489	Fidelity = 0.968810	KL_Divergence = 0.008190	Observable_XX_ev = 0.998201	Observable_XZ_ev = 0.001306
# Epoch: 490	Fidelity = 0.968799	KL_Divergence = 0.008214	Observable_XX_ev = 1.020718	Observable_XZ_ev = 0.006075
# Epoch: 491	Fidelity = 0.968769	KL_Divergence = 0.008252	Observable_XX_ev = 1.049208	Observable_XZ_ev = 0.002027
# Epoch: 492	Fidelity = 0.968709	KL_Divergence = 0.008335	Observable_XX_ev = 1.020577	Observable_XZ_ev = -0.002295
# Epoch: 493	Fidelity = 0.968812	KL_Divergence = 0.008196	Observable_XX_ev = 1.011922	Observable_XZ_ev = -0.002278
# Epoch: 494	Fidelity = 0.968750	KL_Divergence = 0.008283	Observable_XX_ev = 0.959140	Observable_XZ_ev = 0.004075
# Epoch: 495	Fidelity = 0.968883	KL_Divergence = 0.008100	Observable_XX_ev = 0.916834	Observable_XZ_ev = 0.012845
# Epoch: 496	Fidelity = 0.968863	KL_Divergence = 0.008129	Observable_XX_ev = 1.139480	Observable_XZ_ev = 0.014233
# Epoch: 497	Fidelity = 0.968885	KL_Divergence = 0.008098	Observable_XX_ev = 0.909083	Observable_XZ_ev = 0.015889
# Epoch: 498	Fidelity = 0.969000	KL_Divergence = 0.007945	Observable_XX_ev = 1.065070	Observable_XZ_ev = 0.001372
# Epoch: 499	Fidelity = 0.969043	KL_Divergence = 0.007886	Observable_XX_ev = 0.988808	Observable_XZ_ev = 0.017724
# Epoch: 500	Fidelity = 0.969015	KL_Divergence = 0.007924	Observable_XX_ev = 0.878370	Observable_XZ_ev = -0.007753
# Total time elapsed during training: 10145.489 s

# %%
fidelities = callbacks[0]["Fidelity"]
KLs = callbacks[0]["KL_Divergence"]
epoch_range = np.arange(period, epoch + 1, period)

fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 5))
ax = axs[0]
ax.plot(epoch_range, fidelities, "o", color = "C0", markeredgecolor = "black")
ax.set_ylabel(r"Fidelity")
ax.set_xlabel(r"Epoch")
ax.set_ylim(0.00, 1.00)

ax = axs[1]
ax.plot(epoch_range, KLs, "o", color = "C1", markeredgecolor = "black")
ax.set_ylabel(r"KL Divergence")
ax.set_xlabel(r"Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %% [markdown]
# ## save model & train log

# %%
# save model
nn_state_dm.save("./exp003/model.pt")
# save train log
train_log_df = pd.DataFrame()
train_log_df["epoch"] = np.arange(period, epoch+1, period)
train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
train_log_df["Observable_XX_ev"] = callbacks[0]["Observable_XX_ev"]
train_log_df["Observable_XZ_ev"] = callbacks[0]["Observable_XZ_ev"]
train_log_df.to_csv("./exp003/train_log.csv", index=False)
