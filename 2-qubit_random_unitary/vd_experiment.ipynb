# %% [markdown]
# ## Import library

# %%
import os
import subprocess
import random
import warnings
import numpy as np
from scipy.linalg import sqrtm
from scipy.stats import unitary_group
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import yaml
from tqdm.notebook import tqdm
import itertools

import torch
from qucumber.nn_states import DensityMatrix
from qucumber.nn_states import ComplexWaveFunction
from qucumber.callbacks import MetricEvaluator
import qucumber.utils.unitaries as unitaries
import qucumber.utils.training_statistics as ts
import qucumber.utils.cplx as cplx
import qucumber.utils.data as data
from qucumber.observables import ObservableBase, to_pm1
from qucumber.observables.pauli import flip_spin
import qucumber

from qulacs.gate import Pauli

# %% [markdown]
# ## settings

# %%
with open('./params_setting.yaml', 'r') as yml:
    params = yaml.safe_load(yml)
    
# quantum circuit parameter
n_qubit = params["circuit_info"]["n_qubit"]
each_n_shot = params["circuit_info"]["each_n_shot"]
state_name = params["circuit_info"]["state_name"]
error_model = params["circuit_info"]["error_model"]
error_rate = params["circuit_info"]["error_rate"]

# RBM architecture parameter
n_visible_unit = params["architecture_info"]["n_visible_unit"]
n_hidden_unit = params["architecture_info"]["n_hidden_unit"] 
n_aux_unit = params["architecture_info"]["n_aux_unit"]

# train parameter
lr = params["train_info"]["lr"]
pbs = params["train_info"]["positive_batch_size"]
nbs = params["train_info"]["negative_batch_size"]
n_gibbs_step = params["train_info"]["n_gibbs_step"]
period = 1
epoch = params["train_info"]["n_epoch"]
lr_drop_epoch = params["train_info"]["lr_drop_epoch"]
lr_drop_factor = params["train_info"]["lr_drop_factor"]
seed = params["train_info"]["seed"]

# sampling parameter
n_sampling = params["sampling_info"]["n_sample"]
n_copy = params["sampling_info"]["n_copy"]

# data path info
environment = "local"
if environment == "local":
    train_data_path = f"./data/{error_model}/error_rate_{100*error_rate}%/num_of_data_{each_n_shot}/"
    target_state_path = f"./target_state/{error_model}/error_rate_{100*error_rate}%/"
if environment == "colab":
    from google.colab import drive
    drive.mount("/content/drive/")
    drive_path = "/content/drive/MyDrive/NQS4QEM/Bell"
    train_data_path = drive_path + f"./data/{error_model}/error_rate_{100*error_rate}%/num_of_data_{each_n_shot}/"
    target_state_path = drive_path + f"./target_state/{error_model}/error_rate_{100*error_rate}%/"

# settings
## warnings
warnings.simplefilter('ignore')

## seaborn layout
sns.set()
sns.set_style("white")

## seed
def seed_settings(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    qucumber.set_random_seed(seed, cpu=True, gpu=False)

seed_settings(seed=seed)

# %% [markdown]
# ## utility

# %%
def get_density_matrix(nn_state):
    space = nn_state.generate_hilbert_space()
    Z = nn_state.normalization(space)
    tensor = nn_state.rho(space, space)/Z
    matrix = cplx.numpy(tensor)
    return matrix

def get_max_eigvec(matrix):
    e_val, e_vec = np.linalg.eigh(matrix)
    me_val = e_val[-1]
    me_vec = e_vec[:,-1]
    return me_vec

def get_eigvec(nn_state, obs, space, **kwargs):
    dm = get_density_matrix(nn_state)
    ev = get_max_eigvec(dm)
    ev = np.atleast_2d(ev)
    val = ev@obs@ev.T.conj()
    val = val[0,0].real
    return val

def observable_XX():
    target_list = [0, 1]
    pauli_index = [1, 1] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 X_2
    return gate.get_matrix()

def observable_XZ():
    target_list = [0, 1]
    pauli_index = [1, 3] # 1:X , 2:Y, 3:Z
    gate = Pauli(target_list, pauli_index) # = X_1 Z_2
    return gate.get_matrix()

def observable_ZZ_ev(nn_state, **kwargs):
    obs_stat = calculate_distilled_expectation_value({0: "Z", 1: "Z"}, n_sampling, n_copy)
    return obs_stat["mean"]

def observable_1dtfi_ev(nn_state, **kwargs):
    obs_stat_term_1 = calculate_distilled_expectation_value({0: "Z", 1: "Z"}, n_sampling, n_copy)
    obs_stat_term_2 = calculate_distilled_expectation_value({0: "X", 1: "I"}, n_sampling, n_copy)
    obs_stat_term_3 = calculate_distilled_expectation_value({0: "I", 1: "X"}, n_sampling, n_copy)
    
    return obs_stat_term_1["mean"] + obs_stat_term_2["mean"] + obs_stat_term_3["mean"]

# %% [markdown]
# ## quantum circuit

# %%
def Rz(n_qubit, target_qubit_idx, theta):
    I = np.eye(2)
    local_Rz = np.array([[np.exp(-1j*theta/2),0], [0,np.cos(1j*theta/2)]])
    if target_qubit_idx==0:
        mat = local_Rz
    else:
        mat = I
    for i in range(n_qubit-1):
        if i+1==target_qubit_idx:
            mat = np.kron(mat, local_Rz)
        else:
            mat = np.kron(mat, I)
            
    return mat

def global_depolarizing(state, n_qubit, error_rate):
    return (1-error_rate)*state + error_rate*np.trace(state)*np.eye(2**n_qubit)/(2**n_qubit)
    
def unitary(state, n_qubit, theta, target_qubit_idx):
    return Rz(n_qubit, target_qubit_idx, theta) @ state @ Rz(n_qubit, target_qubit_idx, theta).T.conjugate()

def init_state(n_qubit, state_name):
    ket_0 = np.array([[1],[0]]) 
    init_state = ket_0
    
    for i in range(2**(n_qubit-1)-1):
        init_state = np.append(init_state, np.array([[0],[0]]), axis=0) # |00...0>
    
    if state_name == "density_matrix":
        init_state_vec = init_state
        init_state = init_state_vec @ init_state_vec.T.conjugate() # |00...0><00...0|
    
    return init_state

def Random_unitary(n_qubit, state_name, error_model, error_rate):
    from scipy.stats import unitary_group
    U = unitary_group.rvs(dim = 2**n_qubit, random_state = seed)
    
    if state_name == "state_vector":
        if error_model == "ideal":
            state = init_state(n_qubit, state_name)
            state = U @ state
            
    if state_name == "density_matrix":
        if error_model == "ideal":
            state = init_state(n_qubit, state_name)
            state = U @ state @ U.T.conjugate()
        
        if error_model == "depolarizing":
            state = init_state(n_qubit, state_name)
            state = U @ state @ U.T.conjugate()
            state = global_depolarizing(state, n_qubit, error_rate)
        
        if error_model == "unitary":
            state = init_state(n_qubit, state_name)
            state = U @ state @ U.T.conjugate()
            for i in range(n_qubit):
                state = unitary(state, n_qubit, np.sqrt(error_rate), i)
            
        if error_model == "depolarizing&unitary":
            state = init_state(n_qubit, state_name)
            state = U @ state @ U.T.conjugate()
            state = global_depolarizing(state, n_qubit, error_rate)
            for i in range(n_qubit):
                state = unitary(state, n_qubit, np.sqrt(error_rate), i)
    
    return state

# %% [markdown]
# ## generate dataset

# %%
# generate train data
is_train_data_file = os.path.exists(train_data_path + "*.txt")
if is_train_data_file:
    print("train data is exsisted !")
else:
    print("generate directries & train data ...")
    os.makedirs(train_data_path, exist_ok = True)
    os.makedirs(target_state_path, exist_ok = True)
    subprocess.run("python gen_dataset.py", shell=True)
    print("train data is ready !")
# Out:
# generate directries & train data ...
# 0it [00:00, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   2%|▎         | 25/1000 [00:00<00:03, 245.74it/s]
# measurement pattern 1 : ('X', 'X')
#   5%|▌         | 54/1000 [00:00<00:03, 265.78it/s]
#   8%|▊         | 81/1000 [00:00<00:03, 257.91it/s]
#  11%|█         | 110/1000 [00:00<00:03, 266.62it/s]
#  14%|█▎        | 137/1000 [00:00<00:03, 267.39it/s]
#  16%|█▋        | 165/1000 [00:00<00:03, 271.07it/s]
#  19%|█▉        | 193/1000 [00:00<00:03, 267.38it/s]
#  22%|██▏       | 222/1000 [00:00<00:02, 272.14it/s]
#  25%|██▌       | 250/1000 [00:00<00:02, 273.49it/s]
#  28%|██▊       | 278/1000 [00:01<00:02, 271.09it/s]
#  31%|███       | 308/1000 [00:01<00:02, 277.05it/s]
#  34%|███▎      | 336/1000 [00:01<00:02, 274.88it/s]
#  36%|███▋      | 364/1000 [00:01<00:02, 275.92it/s]
#  39%|███▉      | 392/1000 [00:01<00:02, 273.53it/s]
#  42%|████▏     | 421/1000 [00:01<00:02, 277.39it/s]
#  45%|████▍     | 449/1000 [00:01<00:02, 271.67it/s]
#  48%|████▊     | 477/1000 [00:01<00:01, 266.82it/s]
#  50%|█████     | 505/1000 [00:01<00:01, 268.54it/s]
#  53%|█████▎    | 534/1000 [00:01<00:01, 272.90it/s]
#  56%|█████▌    | 562/1000 [00:02<00:01, 271.18it/s]
#  59%|█████▉    | 590/1000 [00:02<00:01, 265.18it/s]
#  62%|██████▏   | 617/1000 [00:02<00:01, 266.56it/s]
#  64%|██████▍   | 645/1000 [00:02<00:01, 270.32it/s]
#  67%|██████▋   | 673/1000 [00:02<00:01, 269.51it/s]
#  70%|███████   | 702/1000 [00:02<00:01, 272.78it/s]
#  73%|███████▎  | 730/1000 [00:02<00:01, 263.88it/s]
#  76%|███████▌  | 758/1000 [00:02<00:00, 267.63it/s]
#  79%|███████▊  | 787/1000 [00:02<00:00, 271.99it/s]
#  82%|████████▏ | 816/1000 [00:03<00:00, 275.00it/s]
#  84%|████████▍ | 844/1000 [00:03<00:00, 271.40it/s]
#  87%|████████▋ | 872/1000 [00:03<00:00, 260.76it/s]
#  90%|████████▉ | 899/1000 [00:03<00:00, 257.55it/s]
#  93%|█████████▎| 926/1000 [00:03<00:00, 259.45it/s]
#  96%|█████████▌| 955/1000 [00:03<00:00, 265.65it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 268.55it/s][A
# 1it [00:03,  3.73s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   3%|▎         | 28/1000 [00:00<00:03, 279.26it/s]
# measurement pattern 2 : ('X', 'Y')
#   6%|▌         | 56/1000 [00:00<00:03, 271.73it/s]
#   8%|▊         | 84/1000 [00:00<00:03, 262.32it/s]
#  11%|█         | 111/1000 [00:00<00:04, 213.83it/s]
#  14%|█▎        | 137/1000 [00:00<00:03, 227.29it/s]
#  16%|█▋        | 163/1000 [00:00<00:03, 236.18it/s]
#  19%|█▉        | 190/1000 [00:00<00:03, 246.21it/s]
#  22%|██▏       | 218/1000 [00:00<00:03, 253.97it/s]
#  24%|██▍       | 245/1000 [00:00<00:02, 256.85it/s]
#  27%|██▋       | 272/1000 [00:01<00:02, 258.25it/s]
#  30%|███       | 300/1000 [00:01<00:02, 263.93it/s]
#  33%|███▎      | 328/1000 [00:01<00:02, 267.50it/s]
#  36%|███▌      | 356/1000 [00:01<00:02, 269.96it/s]
#  38%|███▊      | 384/1000 [00:01<00:02, 270.07it/s]
#  41%|████      | 412/1000 [00:01<00:02, 271.95it/s]
#  44%|████▍     | 440/1000 [00:01<00:02, 271.21it/s]
#  47%|████▋     | 468/1000 [00:01<00:01, 273.02it/s]
#  50%|████▉     | 496/1000 [00:01<00:01, 273.18it/s]
#  52%|█████▏    | 524/1000 [00:02<00:01, 269.65it/s]
#  55%|█████▌    | 552/1000 [00:02<00:01, 271.69it/s]
#  58%|█████▊    | 581/1000 [00:02<00:01, 276.37it/s]
#  61%|██████    | 609/1000 [00:02<00:01, 271.75it/s]
#  64%|██████▍   | 638/1000 [00:02<00:01, 273.25it/s]
#  67%|██████▋   | 666/1000 [00:02<00:01, 274.42it/s]
#  70%|██████▉   | 695/1000 [00:02<00:01, 276.40it/s]
#  72%|███████▏  | 723/1000 [00:02<00:01, 275.02it/s]
#  75%|███████▌  | 751/1000 [00:02<00:01, 243.77it/s]
#  78%|███████▊  | 777/1000 [00:02<00:00, 248.06it/s]
#  80%|████████  | 804/1000 [00:03<00:00, 253.03it/s]
#  83%|████████▎ | 831/1000 [00:03<00:00, 257.12it/s]
#  86%|████████▌ | 857/1000 [00:03<00:00, 245.27it/s]
#  88%|████████▊ | 885/1000 [00:03<00:00, 252.69it/s]
#  91%|█████████▏| 914/1000 [00:03<00:00, 260.06it/s]
#  94%|█████████▍| 941/1000 [00:03<00:00, 253.04it/s]
#  97%|█████████▋| 967/1000 [00:03<00:00, 245.62it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 258.60it/s][A
# 2it [00:07,  3.81s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# measurement pattern 3 : ('X', 'Z')
#   2%|▏         | 24/1000 [00:00<00:04, 239.43it/s]
#   5%|▌         | 53/1000 [00:00<00:03, 264.96it/s]
#   8%|▊         | 81/1000 [00:00<00:03, 269.29it/s]
#  11%|█         | 109/1000 [00:00<00:03, 272.06it/s]
#  14%|█▍        | 138/1000 [00:00<00:03, 277.09it/s]
#  17%|█▋        | 166/1000 [00:00<00:03, 275.59it/s]
#  20%|█▉        | 195/1000 [00:00<00:02, 278.30it/s]
#  22%|██▏       | 223/1000 [00:00<00:02, 277.32it/s]
#  25%|██▌       | 252/1000 [00:00<00:02, 280.32it/s]
#  28%|██▊       | 281/1000 [00:01<00:02, 277.46it/s]
#  31%|███       | 309/1000 [00:01<00:02, 274.67it/s]
#  34%|███▍      | 338/1000 [00:01<00:02, 278.52it/s]
#  37%|███▋      | 366/1000 [00:01<00:02, 278.56it/s]
#  40%|███▉      | 395/1000 [00:01<00:02, 279.98it/s]
#  42%|████▏     | 424/1000 [00:01<00:02, 274.68it/s]
#  45%|████▌     | 452/1000 [00:01<00:02, 209.16it/s]
#  48%|████▊     | 476/1000 [00:01<00:02, 212.79it/s]
#  50%|█████     | 502/1000 [00:01<00:02, 223.73it/s]
#  53%|█████▎    | 528/1000 [00:02<00:02, 232.27it/s]
#  56%|█████▌    | 556/1000 [00:02<00:01, 244.94it/s]
#  58%|█████▊    | 582/1000 [00:02<00:01, 238.92it/s]
#  61%|██████    | 608/1000 [00:02<00:01, 243.11it/s]
#  64%|██████▎   | 635/1000 [00:02<00:01, 248.41it/s]
#  66%|██████▋   | 663/1000 [00:02<00:01, 256.12it/s]
#  69%|██████▉   | 692/1000 [00:02<00:01, 264.84it/s]
#  72%|███████▏  | 720/1000 [00:02<00:01, 267.22it/s]
#  75%|███████▍  | 749/1000 [00:02<00:00, 272.97it/s]
#  78%|███████▊  | 777/1000 [00:02<00:00, 274.69it/s]
#  80%|████████  | 805/1000 [00:03<00:00, 273.94it/s]
#  83%|████████▎ | 833/1000 [00:03<00:00, 271.79it/s]
#  86%|████████▌ | 862/1000 [00:03<00:00, 275.02it/s]
#  89%|████████▉ | 890/1000 [00:03<00:00, 274.21it/s]
#  92%|█████████▏| 918/1000 [00:03<00:00, 275.03it/s]
#  95%|█████████▍| 946/1000 [00:03<00:00, 275.91it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 263.22it/s][A
# 3it [00:11,  3.81s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   3%|▎         | 29/1000 [00:00<00:03, 281.09it/s]
# measurement pattern 4 : ('Y', 'X')
#   6%|▌         | 58/1000 [00:00<00:03, 282.17it/s]
#   9%|▊         | 87/1000 [00:00<00:03, 268.60it/s]
#  11%|█▏        | 114/1000 [00:00<00:03, 264.97it/s]
#  14%|█▍        | 142/1000 [00:00<00:03, 267.60it/s]
#  17%|█▋        | 170/1000 [00:00<00:03, 271.37it/s]
#  20%|█▉        | 198/1000 [00:00<00:02, 270.60it/s]
#  23%|██▎       | 226/1000 [00:00<00:02, 268.77it/s]
#  26%|██▌       | 255/1000 [00:00<00:02, 271.49it/s]
#  28%|██▊       | 283/1000 [00:01<00:02, 267.90it/s]
#  31%|███       | 310/1000 [00:01<00:02, 267.19it/s]
#  34%|███▎      | 337/1000 [00:01<00:02, 266.42it/s]
#  36%|███▋      | 364/1000 [00:01<00:02, 266.85it/s]
#  39%|███▉      | 392/1000 [00:01<00:02, 267.89it/s]
#  42%|████▏     | 420/1000 [00:01<00:02, 270.13it/s]
#  45%|████▍     | 448/1000 [00:01<00:02, 271.70it/s]
#  48%|████▊     | 476/1000 [00:01<00:01, 272.17it/s]
#  50%|█████     | 504/1000 [00:01<00:01, 253.64it/s]
#  53%|█████▎    | 530/1000 [00:01<00:01, 253.30it/s]
#  56%|█████▌    | 557/1000 [00:02<00:01, 255.19it/s]
#  58%|█████▊    | 584/1000 [00:02<00:01, 259.18it/s]
#  61%|██████    | 611/1000 [00:02<00:01, 259.24it/s]
#  64%|██████▍   | 639/1000 [00:02<00:01, 263.19it/s]
#  67%|██████▋   | 668/1000 [00:02<00:01, 269.08it/s]
#  70%|██████▉   | 695/1000 [00:02<00:01, 269.04it/s]
#  72%|███████▏  | 722/1000 [00:02<00:01, 243.46it/s]
#  75%|███████▍  | 748/1000 [00:02<00:01, 246.12it/s]
#  78%|███████▊  | 775/1000 [00:02<00:00, 251.12it/s]
#  80%|████████  | 803/1000 [00:03<00:00, 256.98it/s]
#  83%|████████▎ | 830/1000 [00:03<00:00, 259.61it/s]
#  86%|████████▌ | 857/1000 [00:03<00:00, 259.20it/s]
#  88%|████████▊ | 885/1000 [00:03<00:00, 264.97it/s]
#  91%|█████████ | 912/1000 [00:03<00:00, 261.09it/s]
#  94%|█████████▍| 940/1000 [00:03<00:00, 266.00it/s]
#  97%|█████████▋| 968/1000 [00:03<00:00, 269.85it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 264.05it/s][A
# 4it [00:15,  3.80s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# measurement pattern 5 : ('Y', 'Y')
#   3%|▎         | 28/1000 [00:00<00:03, 275.51it/s]
#   6%|▌         | 56/1000 [00:00<00:03, 275.67it/s]
#   8%|▊         | 84/1000 [00:00<00:03, 275.54it/s]
#  11%|█         | 112/1000 [00:00<00:03, 273.92it/s]
#  14%|█▍        | 140/1000 [00:00<00:03, 274.17it/s]
#  17%|█▋        | 168/1000 [00:00<00:03, 271.37it/s]
#  20%|█▉        | 196/1000 [00:00<00:02, 273.49it/s]
#  22%|██▏       | 224/1000 [00:00<00:02, 273.09it/s]
#  25%|██▌       | 252/1000 [00:00<00:02, 273.95it/s]
#  28%|██▊       | 280/1000 [00:01<00:02, 272.17it/s]
#  31%|███       | 309/1000 [00:01<00:02, 275.74it/s]
#  34%|███▎      | 337/1000 [00:01<00:02, 274.17it/s]
#  36%|███▋      | 365/1000 [00:01<00:02, 274.34it/s]
#  39%|███▉      | 393/1000 [00:01<00:02, 273.94it/s]
#  42%|████▏     | 421/1000 [00:01<00:02, 271.49it/s]
#  45%|████▍     | 449/1000 [00:01<00:02, 268.76it/s]
#  48%|████▊     | 476/1000 [00:01<00:01, 267.51it/s]
#  50%|█████     | 503/1000 [00:01<00:01, 254.15it/s]
#  53%|█████▎    | 530/1000 [00:01<00:01, 257.60it/s]
#  56%|█████▌    | 556/1000 [00:02<00:02, 212.36it/s]
#  58%|█████▊    | 580/1000 [00:02<00:01, 218.87it/s]
#  60%|██████    | 605/1000 [00:02<00:01, 225.25it/s]
#  63%|██████▎   | 631/1000 [00:02<00:01, 231.09it/s]
#  66%|██████▌   | 658/1000 [00:02<00:01, 239.84it/s]
#  69%|██████▊   | 686/1000 [00:02<00:01, 249.79it/s]
#  71%|███████▏  | 713/1000 [00:02<00:01, 253.55it/s]
#  74%|███████▍  | 742/1000 [00:02<00:00, 261.99it/s]
#  77%|███████▋  | 769/1000 [00:02<00:00, 263.05it/s]
#  80%|███████▉  | 797/1000 [00:03<00:00, 267.34it/s]
#  82%|████████▏ | 824/1000 [00:03<00:00, 267.71it/s]
#  85%|████████▌ | 852/1000 [00:03<00:00, 270.15it/s]
#  88%|████████▊ | 880/1000 [00:03<00:00, 252.07it/s]
#  91%|█████████ | 906/1000 [00:03<00:00, 247.15it/s]
#  93%|█████████▎| 933/1000 [00:03<00:00, 252.19it/s]
#  96%|█████████▌| 961/1000 [00:03<00:00, 258.35it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 259.16it/s][A
# 5it [00:19,  3.82s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   3%|▎         | 29/1000 [00:00<00:03, 282.67it/s]
# measurement pattern 6 : ('Y', 'Z')
#   6%|▌         | 58/1000 [00:00<00:03, 272.98it/s]
#   9%|▊         | 86/1000 [00:00<00:03, 274.16it/s]
#  12%|█▏        | 115/1000 [00:00<00:03, 278.35it/s]
#  14%|█▍        | 143/1000 [00:00<00:03, 256.79it/s]
#  17%|█▋        | 169/1000 [00:00<00:03, 252.61it/s]
#  20%|█▉        | 197/1000 [00:00<00:03, 259.85it/s]
#  23%|██▎       | 226/1000 [00:00<00:02, 266.47it/s]
#  25%|██▌       | 253/1000 [00:00<00:02, 256.40it/s]
#  28%|██▊       | 279/1000 [00:01<00:02, 249.80it/s]
#  31%|███       | 306/1000 [00:01<00:02, 253.93it/s]
#  34%|███▎      | 335/1000 [00:01<00:02, 261.99it/s]
#  36%|███▌      | 362/1000 [00:01<00:02, 262.74it/s]
#  39%|███▉      | 390/1000 [00:01<00:02, 267.38it/s]
#  42%|████▏     | 417/1000 [00:01<00:02, 267.12it/s]
#  44%|████▍     | 445/1000 [00:01<00:02, 268.36it/s]
#  47%|████▋     | 473/1000 [00:01<00:01, 269.90it/s]
#  50%|█████     | 501/1000 [00:01<00:01, 269.47it/s]
#  53%|█████▎    | 530/1000 [00:01<00:01, 273.70it/s]
#  56%|█████▌    | 558/1000 [00:02<00:01, 272.09it/s]
#  59%|█████▊    | 587/1000 [00:02<00:01, 274.98it/s]
#  62%|██████▏   | 615/1000 [00:02<00:01, 274.00it/s]
#  64%|██████▍   | 644/1000 [00:02<00:01, 276.18it/s]
#  67%|██████▋   | 672/1000 [00:02<00:01, 273.87it/s]
#  70%|███████   | 700/1000 [00:02<00:01, 250.77it/s]
#  73%|███████▎  | 726/1000 [00:02<00:01, 246.20it/s]
#  75%|███████▌  | 751/1000 [00:02<00:01, 246.84it/s]
#  78%|███████▊  | 778/1000 [00:02<00:00, 253.17it/s]
#  81%|████████  | 807/1000 [00:03<00:00, 261.00it/s]
#  83%|████████▎ | 834/1000 [00:03<00:00, 263.02it/s]
#  86%|████████▌ | 862/1000 [00:03<00:00, 266.11it/s]
#  89%|████████▉ | 890/1000 [00:03<00:00, 267.92it/s]
#  92%|█████████▏| 917/1000 [00:03<00:00, 267.28it/s]
#  94%|█████████▍| 944/1000 [00:03<00:00, 256.20it/s]
#  97%|█████████▋| 970/1000 [00:03<00:00, 255.85it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 262.48it/s][A
# 6it [00:22,  3.82s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   3%|▎         | 27/1000 [00:00<00:03, 263.21it/s]
# measurement pattern 7 : ('Z', 'X')
#   5%|▌         | 54/1000 [00:00<00:03, 253.15it/s]
#   8%|▊         | 80/1000 [00:00<00:03, 253.50it/s]
#  11%|█         | 106/1000 [00:00<00:03, 253.59it/s]
#  13%|█▎        | 132/1000 [00:00<00:03, 254.04it/s]
#  16%|█▌        | 158/1000 [00:00<00:03, 255.88it/s]
#  18%|█▊        | 184/1000 [00:00<00:03, 255.57it/s]
#  21%|██        | 212/1000 [00:00<00:03, 260.27it/s]
#  24%|██▍       | 240/1000 [00:00<00:02, 265.80it/s]
#  27%|██▋       | 268/1000 [00:01<00:02, 269.54it/s]
#  30%|██▉       | 297/1000 [00:01<00:02, 275.35it/s]
#  32%|███▎      | 325/1000 [00:01<00:02, 265.20it/s]
#  35%|███▌      | 354/1000 [00:01<00:02, 271.55it/s]
#  38%|███▊      | 383/1000 [00:01<00:02, 275.35it/s]
#  41%|████      | 411/1000 [00:01<00:02, 274.81it/s]
#  44%|████▍     | 440/1000 [00:01<00:02, 276.60it/s]
#  47%|████▋     | 468/1000 [00:01<00:01, 275.35it/s]
#  50%|████▉     | 496/1000 [00:01<00:01, 275.55it/s]
#  52%|█████▏    | 524/1000 [00:01<00:01, 269.53it/s]
#  55%|█████▌    | 553/1000 [00:02<00:01, 273.78it/s]
#  58%|█████▊    | 581/1000 [00:02<00:01, 274.34it/s]
#  61%|██████    | 609/1000 [00:02<00:01, 274.47it/s]
#  64%|██████▎   | 637/1000 [00:02<00:01, 273.48it/s]
#  66%|██████▋   | 665/1000 [00:02<00:01, 256.60it/s]
#  69%|██████▉   | 691/1000 [00:02<00:01, 223.30it/s]
#  72%|███████▏  | 716/1000 [00:02<00:01, 229.91it/s]
#  74%|███████▍  | 742/1000 [00:02<00:01, 235.82it/s]
#  77%|███████▋  | 770/1000 [00:02<00:00, 247.46it/s]
#  80%|███████▉  | 798/1000 [00:03<00:00, 254.70it/s]
#  83%|████████▎ | 827/1000 [00:03<00:00, 263.76it/s]
#  86%|████████▌ | 855/1000 [00:03<00:00, 267.46it/s]
#  88%|████████▊ | 883/1000 [00:03<00:00, 269.48it/s]
#  91%|█████████▏| 913/1000 [00:03<00:00, 276.04it/s]
#  94%|█████████▍| 941/1000 [00:03<00:00, 266.82it/s]
#  97%|█████████▋| 968/1000 [00:03<00:00, 257.97it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 261.98it/s][A
# 7it [00:26,  3.82s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# measurement pattern 8 : ('Z', 'Y')
#   3%|▎         | 28/1000 [00:00<00:03, 270.97it/s]
#   6%|▌         | 56/1000 [00:00<00:03, 270.38it/s]
#   8%|▊         | 84/1000 [00:00<00:03, 262.88it/s]
#  11%|█         | 111/1000 [00:00<00:03, 245.51it/s]
#  14%|█▍        | 139/1000 [00:00<00:03, 256.58it/s]
#  17%|█▋        | 167/1000 [00:00<00:03, 261.67it/s]
#  20%|█▉        | 196/1000 [00:00<00:02, 268.20it/s]
#  22%|██▏       | 224/1000 [00:00<00:02, 270.07it/s]
#  25%|██▌       | 252/1000 [00:00<00:02, 264.17it/s]
#  28%|██▊       | 280/1000 [00:01<00:02, 266.71it/s]
#  31%|███       | 309/1000 [00:01<00:02, 272.80it/s]
#  34%|███▎      | 337/1000 [00:01<00:02, 271.89it/s]
#  36%|███▋      | 365/1000 [00:01<00:02, 273.43it/s]
#  39%|███▉      | 393/1000 [00:01<00:02, 272.29it/s]
#  42%|████▏     | 422/1000 [00:01<00:02, 275.62it/s]
#  45%|████▌     | 450/1000 [00:01<00:02, 273.68it/s]
#  48%|████▊     | 478/1000 [00:01<00:01, 275.21it/s]
#  51%|█████     | 506/1000 [00:01<00:01, 274.28it/s]
#  53%|█████▎    | 534/1000 [00:01<00:01, 270.29it/s]
#  56%|█████▌    | 562/1000 [00:02<00:01, 269.69it/s]
#  59%|█████▉    | 590/1000 [00:02<00:01, 271.74it/s]
#  62%|██████▏   | 619/1000 [00:02<00:01, 274.70it/s]
#  65%|██████▍   | 647/1000 [00:02<00:01, 273.56it/s]
#  68%|██████▊   | 675/1000 [00:02<00:01, 275.40it/s]
#  70%|███████   | 703/1000 [00:02<00:01, 272.17it/s]
#  73%|███████▎  | 732/1000 [00:02<00:00, 275.88it/s]
#  76%|███████▌  | 760/1000 [00:02<00:00, 274.25it/s]
#  79%|███████▉  | 789/1000 [00:02<00:00, 277.68it/s]
#  82%|████████▏ | 817/1000 [00:03<00:00, 272.85it/s]
#  84%|████████▍ | 845/1000 [00:03<00:00, 274.43it/s]
#  87%|████████▋ | 874/1000 [00:03<00:00, 276.24it/s]
#  90%|█████████ | 902/1000 [00:03<00:00, 274.14it/s]
#  93%|█████████▎| 930/1000 [00:03<00:00, 275.64it/s]
#  96%|█████████▌| 958/1000 [00:03<00:00, 272.56it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 271.23it/s][A
# 8it [00:30,  3.78s/it]
#   0%|          | 0/1000 [00:00<?, ?it/s]
#   3%|▎         | 29/1000 [00:00<00:03, 284.10it/s]
# measurement pattern 9 : ('Z', 'Z')
#   6%|▌         | 58/1000 [00:00<00:03, 278.43it/s]
#   9%|▊         | 86/1000 [00:00<00:03, 266.63it/s]
#  11%|█▏        | 113/1000 [00:00<00:03, 244.91it/s]
#  14%|█▍        | 139/1000 [00:00<00:03, 249.22it/s]
#  17%|█▋        | 168/1000 [00:00<00:03, 259.38it/s]
#  20%|█▉        | 196/1000 [00:00<00:03, 265.59it/s]
#  22%|██▎       | 225/1000 [00:00<00:02, 273.06it/s]
#  25%|██▌       | 253/1000 [00:00<00:02, 271.48it/s]
#  28%|██▊       | 282/1000 [00:01<00:02, 275.90it/s]
#  31%|███       | 311/1000 [00:01<00:02, 278.84it/s]
#  34%|███▍      | 339/1000 [00:01<00:02, 276.46it/s]
#  37%|███▋      | 367/1000 [00:01<00:02, 275.80it/s]
#  40%|███▉      | 395/1000 [00:01<00:02, 275.45it/s]
#  42%|████▏     | 423/1000 [00:01<00:02, 276.07it/s]
#  45%|████▌     | 451/1000 [00:01<00:02, 273.48it/s]
#  48%|████▊     | 480/1000 [00:01<00:01, 277.84it/s]
#  51%|█████     | 508/1000 [00:01<00:01, 277.74it/s]
#  54%|█████▎    | 536/1000 [00:01<00:01, 273.32it/s]
#  56%|█████▋    | 564/1000 [00:02<00:01, 272.95it/s]
#  59%|█████▉    | 592/1000 [00:02<00:01, 273.57it/s]
#  62%|██████▏   | 620/1000 [00:02<00:01, 270.46it/s]
#  65%|██████▍   | 648/1000 [00:02<00:01, 268.34it/s]
#  68%|██████▊   | 675/1000 [00:02<00:01, 266.76it/s]
#  70%|███████   | 702/1000 [00:02<00:01, 264.64it/s]
#  73%|███████▎  | 729/1000 [00:02<00:01, 261.82it/s]
#  76%|███████▌  | 756/1000 [00:02<00:00, 258.27it/s]
#  78%|███████▊  | 783/1000 [00:02<00:00, 261.03it/s]
#  81%|████████  | 810/1000 [00:03<00:00, 257.86it/s]
#  84%|████████▎ | 836/1000 [00:03<00:00, 246.40it/s]
#  86%|████████▌ | 861/1000 [00:03<00:00, 244.41it/s]
#  89%|████████▊ | 887/1000 [00:03<00:00, 247.34it/s]
#  92%|█████████▏| 915/1000 [00:03<00:00, 255.39it/s]
#  94%|█████████▍| 943/1000 [00:03<00:00, 261.28it/s]
#  97%|█████████▋| 972/1000 [00:03<00:00, 269.20it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 265.48it/s][A
# 9it [00:34,  3.79s/it]
# train data is ready !

# %% [markdown]
# ## load dataset

# %%
meas_pattern_path = train_data_path + "/measurement_pattern.txt"
meas_label_path = train_data_path + "/measurement_label.txt"
meas_result_path = train_data_path + "/measurement_result.txt"
target_rho_re_path = target_state_path + "/rho_real.txt"
target_rho_im_path = target_state_path + "/rho_imag.txt"
meas_result, target_rho, meas_label, meas_pattern = data.load_data_DM(meas_result_path,
                                                                      target_rho_re_path,
                                                                      target_rho_im_path,
                                                                      meas_label_path,
                                                                      meas_pattern_path)

# %% [markdown]
# ## build RBM architecture

# %%
nn_state_dm = DensityMatrix(
    num_visible = n_visible_unit, 
    num_hidden = n_hidden_unit, 
    num_aux = n_aux_unit, 
    unitary_dict = unitaries.create_dict(),
    gpu = False
)

# %% [markdown]
# ## NQS for VD

# %%
class GeneralPauliDistill(ObservableBase):
    def __init__(self, pauli_dict: dict, m: int) -> None:
        self.name = "distilled_pauli"
        self.symbol = "distilled_general_pauli"
        self.pauli_dict = pauli_dict
        self.num_copy = m
        
    def apply(self, nn_state, samples):
        """
        This function calcualte <x1 x2 ... xm | rho^{\otimes m} O | xm x1 x2 ... xm-1> / <x1 x2 ... xm | rho^{\otimes m} | x1 x2 ... xm>
        where O acts only on the first register.
        """
        
        # [num_sample, num_visible_node]
        # samples = [s1, s2, s3 ... sN]
        #  where num_sample = N, and si is num_visible_node-bits
        samples = samples.to(device=nn_state.device)
        
        num_sample, num_visible_node = samples.shape
        
        # [num_sample, num_visible_node * num_copy]
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        #  each row is num_copy*num_visible_node bits the above example is for num_copy=3
        samples_array = []
        for copy_index in range(self.num_copy):
            rolled_samples = torch.roll(samples, shifts=copy_index, dims=0)
            samples_array.append(rolled_samples)
        samples_array = torch.hstack(samples_array)
        assert(samples_array.shape[0] == num_sample)
        assert(samples_array.shape[1] == num_visible_node * self.num_copy)
        
        # roll second dim of [num_sample, num_visible_node * num_copy] by num_visible_node
        # swapped_samples_array = [[sN-1 s1 sN], [sN s2 s1], [s1 s3 s2],.. [sN-2 sN sN-1]]
        swapped_samples_array = torch.roll(samples_array, shifts = num_visible_node, dims=1)

        # pick copy of first block
        #  first_block_sample = [sN-1, sN, s1, s2, ... sN-2]
        first_block_sample = swapped_samples_array[:, :num_visible_node].clone()

        # calculate coefficient for first block [num_samples, 0:num_visible_node]
        total_prod = cplx.make_complex(torch.ones_like(samples[:,0]), torch.zeros_like(samples[:,0]))
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            coeff = to_pm1(first_block_sample[:, index])
            if pauli == "Z":
                coeff = cplx.make_complex(coeff, torch.zeros_like(coeff))
                total_prod = cplx.elementwise_mult(coeff, total_prod)
            elif pauli == "Y":
                coeff = cplx.make_complex(torch.zeros_like(coeff), coeff)
                total_prod = cplx.elementwise_mult(coeff, total_prod)
        
        # flip samples for for first block [num_samples, 0:num_visible_node]
        # first_block_sample -> [OsN-1, OsN, Os1, Os2, ... OsN-2]
        #  where Osi is bit array after Pauli bit-flips 
        for index, pauli in self.pauli_dict.items():
            assert(index < num_visible_node)
            if pauli in ["X", "Y"]:
                first_block_sample = flip_spin(index, first_block_sample)


        # store flipped first block
        swapped_samples_array[:, :num_visible_node] = first_block_sample

        # calculate product of coefficients
        # samples_array = [[s1 sN sN-1], [s2 s1 sN], [s3 s2 s1],.. [sN sN-1 sN-2]]
        # swapped_samples_array = [[OsN-1 s1 sN], [OsN s2 s1], [Os1 s3 s2],.. [OsN-2 sN sN-1]]
        """
        total_prod = [
            <s1 sN sN-1 | rho^{\otimes 3} | OsN-1 s1 sN> / <s1 sN sN-1 | rho^{\otimes 3} | s1 sN sN-1> , 
            <s2 s1 sN   | rho^{\otimes 3} | OsN s2 s1>   / <s2 s1 sN   | rho^{\otimes 3} | s2 s1 sN> , 
            <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1> , 

        e.g. 
        <s3 s2 s1   | rho^{\otimes 3} | Os1 s3 s2>   / <s3 s2 s1   | rho^{\otimes 3} | s3 s2 s1>
         = <s3 | rho | Os1> <s2 | rho | s3> < s1| rho | s2> / (<s3 | rho | s3> <s2 | rho | s2> < s1| rho | s1>)
         =  (<s3 | rho | Os1> / <s3 | rho | s3>)
          * (<s2 | rho | s3> / <s2 | rho | s2> )
          * (< s1| rho | s2> / < s1| rho | s1>)
         
        importance_sampling_numerator(s3, Os1)  provides <s3 | rho | Os1>
        importance_sampling_denominator(s3)     provides <s3 | rho | s3>
        """
        for copy_index in range(self.num_copy):
            st = copy_index * samples.shape[1]
            en = (copy_index+1) * samples.shape[1]
            # numerator is []
            numerator = nn_state.importance_sampling_numerator(swapped_samples_array[:, st:en], samples_array[:, st:en])
            denominator = nn_state.importance_sampling_denominator(samples_array[:, st:en])
            values = cplx.elementwise_division(numerator, denominator)
            total_prod = cplx.elementwise_mult(total_prod, values)

        value = cplx.real(total_prod)
        return value

def calculate_distilled_expectation_value(pauli_dict: dict, num_samples: int, num_copies: int):
    obs_num = GeneralPauliDistill(pauli_dict, num_copies)
    obs_div = GeneralPauliDistill({}, num_copies)
    num_stat = obs_num.statistics(nn_state_dm, num_samples=num_samples)
    div_stat = obs_div.statistics(nn_state_dm, num_samples=num_samples)

    from uncertainties import ufloat
    num = ufloat(num_stat["mean"], num_stat["std_error"])
    div = ufloat(div_stat["mean"], div_stat["std_error"])
    val = num/div
    result_dict = {"mean": val.n , "std_error": val.s, "num_samples": num_samples, "num_copies": num_copies}
    return result_dict

# %% [markdown]
# ## callback setting

# %%
def ideal_fidelity(nn_state, **kwargs):
    ideal_state = Random_unitary(n_qubit, state_name, "ideal", error_rate)
    train_state = get_density_matrix(nn_state)
    F = np.trace(sqrtm(sqrtm(ideal_state)@train_state@sqrtm(ideal_state)))
    
    return (F.real)**2

def noisy_fidelity(nn_state, **kwargs):
    noisy_state = Random_unitary(n_qubit, state_name, error_model, error_rate)
    train_state = get_density_matrix(nn_state)
    F = np.trace(sqrtm(sqrtm(noisy_state)@train_state@sqrtm(noisy_state)))
    
    return (F.real)**2
    
def max_eigen_fidelity(nn_state, **kwargs):
    ideal_state = Random_unitary(n_qubit, state_name, "ideal", error_rate)
    train_state = get_density_matrix(nn_state)
    max_eigen_state = get_max_eigvec(train_state)
    F = max_eigen_state.T.conjugate()@ideal_state@max_eigen_state
    
    return F.real

def create_callback_dm(nn_state):
    metric_dict = {
        "Fidelity": ts.fidelity,
        "Ideal_fidelity": ideal_fidelity,
        "Noisy_fidelity": noisy_fidelity,
        "Max_eigen_fidelity": max_eigen_fidelity,
        "KL_Divergence": ts.KL,
        #"ObservableZZ_ev": observable_ZZ_ev,
    }
    space = nn_state.generate_hilbert_space()
    callbacks = [
        MetricEvaluator(
            period,
            metric_dict,
            target = target_rho,
            bases = meas_pattern,
            verbose = True,
            space = space,
        )
    ]
    
    return callbacks

callbacks = create_callback_dm(nn_state_dm)

# %% [markdown]
# ## train

# %%
nn_state_dm.fit(
    data = meas_result,
    input_bases = meas_label,
    epochs = epoch,
    pos_batch_size = pbs,
    neg_batch_size = nbs,
    lr = lr,
    k = n_gibbs_step,
    bases = meas_pattern,
    callbacks = callbacks,
    time = True,
    optimizer = torch.optim.Adadelta,
    scheduler = torch.optim.lr_scheduler.StepLR,
    scheduler_args = {"step_size": lr_drop_epoch, "gamma": lr_drop_factor},
)
# Out:
# Epoch: 1	Fidelity = 0.809501	Ideal_fidelity = 0.872215	Noisy_fidelity = 0.899723	Max_eigen_fidelity = 0.899401	KL_Divergence = 0.434793
# Epoch: 2	Fidelity = 0.826246	Ideal_fidelity = 0.880780	Noisy_fidelity = 0.908981	Max_eigen_fidelity = 0.930734	KL_Divergence = 0.353533
# Epoch: 3	Fidelity = 0.843348	Ideal_fidelity = 0.891173	Noisy_fidelity = 0.918340	Max_eigen_fidelity = 0.942341	KL_Divergence = 0.340485
# Epoch: 4	Fidelity = 0.852896	Ideal_fidelity = 0.896139	Noisy_fidelity = 0.923524	Max_eigen_fidelity = 0.958826	KL_Divergence = 0.346220
# Epoch: 5	Fidelity = 0.870808	Ideal_fidelity = 0.907264	Noisy_fidelity = 0.933171	Max_eigen_fidelity = 0.968091	KL_Divergence = 0.323714
# Epoch: 6	Fidelity = 0.886323	Ideal_fidelity = 0.917532	Noisy_fidelity = 0.941447	Max_eigen_fidelity = 0.968738	KL_Divergence = 0.304103
# Epoch: 7	Fidelity = 0.904868	Ideal_fidelity = 0.928429	Noisy_fidelity = 0.951246	Max_eigen_fidelity = 0.985463	KL_Divergence = 0.316082
# Epoch: 8	Fidelity = 0.918352	Ideal_fidelity = 0.937788	Noisy_fidelity = 0.958307	Max_eigen_fidelity = 0.983122	KL_Divergence = 0.313503
# Epoch: 9	Fidelity = 0.930353	Ideal_fidelity = 0.945148	Noisy_fidelity = 0.964548	Max_eigen_fidelity = 0.990860	KL_Divergence = 0.344964
# Epoch: 10	Fidelity = 0.931838	Ideal_fidelity = 0.947725	Noisy_fidelity = 0.965318	Max_eigen_fidelity = 0.979038	KL_Divergence = 0.353357
# Epoch: 11	Fidelity = 0.955389	Ideal_fidelity = 0.962458	Noisy_fidelity = 0.977440	Max_eigen_fidelity = 0.990599	KL_Divergence = 0.290277
# Epoch: 12	Fidelity = 0.959460	Ideal_fidelity = 0.965057	Noisy_fidelity = 0.979520	Max_eigen_fidelity = 0.992881	KL_Divergence = 0.287699
# Epoch: 13	Fidelity = 0.962399	Ideal_fidelity = 0.967896	Noisy_fidelity = 0.981020	Max_eigen_fidelity = 0.989888	KL_Divergence = 0.300037
# Epoch: 14	Fidelity = 0.969695	Ideal_fidelity = 0.971999	Noisy_fidelity = 0.984731	Max_eigen_fidelity = 0.996505	KL_Divergence = 0.295022
# Epoch: 15	Fidelity = 0.971843	Ideal_fidelity = 0.974215	Noisy_fidelity = 0.985821	Max_eigen_fidelity = 0.994628	KL_Divergence = 0.300389
# Epoch: 16	Fidelity = 0.964235	Ideal_fidelity = 0.970493	Noisy_fidelity = 0.981955	Max_eigen_fidelity = 0.986004	KL_Divergence = 0.351169
# Epoch: 17	Fidelity = 0.975831	Ideal_fidelity = 0.977128	Noisy_fidelity = 0.987841	Max_eigen_fidelity = 0.995355	KL_Divergence = 0.311381
# Epoch: 18	Fidelity = 0.973785	Ideal_fidelity = 0.977337	Noisy_fidelity = 0.986806	Max_eigen_fidelity = 0.988793	KL_Divergence = 0.297490
# Epoch: 19	Fidelity = 0.980799	Ideal_fidelity = 0.980963	Noisy_fidelity = 0.990353	Max_eigen_fidelity = 0.996750	KL_Divergence = 0.328491
# Epoch: 20	Fidelity = 0.984289	Ideal_fidelity = 0.983415	Noisy_fidelity = 0.992113	Max_eigen_fidelity = 0.998224	KL_Divergence = 0.320376
# Epoch: 21	Fidelity = 0.980089	Ideal_fidelity = 0.981295	Noisy_fidelity = 0.989994	Max_eigen_fidelity = 0.993822	KL_Divergence = 0.341074
# Epoch: 22	Fidelity = 0.983735	Ideal_fidelity = 0.983488	Noisy_fidelity = 0.991834	Max_eigen_fidelity = 0.996163	KL_Divergence = 0.303859
# Epoch: 23	Fidelity = 0.986234	Ideal_fidelity = 0.984917	Noisy_fidelity = 0.993093	Max_eigen_fidelity = 0.998850	KL_Divergence = 0.316920
# Epoch: 24	Fidelity = 0.988119	Ideal_fidelity = 0.986572	Noisy_fidelity = 0.994042	Max_eigen_fidelity = 0.999067	KL_Divergence = 0.303912
# Epoch: 25	Fidelity = 0.984918	Ideal_fidelity = 0.985343	Noisy_fidelity = 0.992430	Max_eigen_fidelity = 0.994924	KL_Divergence = 0.316517
# Epoch: 26	Fidelity = 0.986661	Ideal_fidelity = 0.986479	Noisy_fidelity = 0.993308	Max_eigen_fidelity = 0.996213	KL_Divergence = 0.302687
# Epoch: 27	Fidelity = 0.980958	Ideal_fidelity = 0.984066	Noisy_fidelity = 0.990433	Max_eigen_fidelity = 0.989317	KL_Divergence = 0.308344
# Epoch: 28	Fidelity = 0.989754	Ideal_fidelity = 0.988373	Noisy_fidelity = 0.994864	Max_eigen_fidelity = 0.998516	KL_Divergence = 0.301340
# Epoch: 29	Fidelity = 0.987944	Ideal_fidelity = 0.987503	Noisy_fidelity = 0.993954	Max_eigen_fidelity = 0.996795	KL_Divergence = 0.325329
# Epoch: 30	Fidelity = 0.987047	Ideal_fidelity = 0.987012	Noisy_fidelity = 0.993502	Max_eigen_fidelity = 0.995696	KL_Divergence = 0.334987
# Epoch: 31	Fidelity = 0.989602	Ideal_fidelity = 0.988816	Noisy_fidelity = 0.994787	Max_eigen_fidelity = 0.997651	KL_Divergence = 0.334853
# Epoch: 32	Fidelity = 0.990557	Ideal_fidelity = 0.989366	Noisy_fidelity = 0.995267	Max_eigen_fidelity = 0.998247	KL_Divergence = 0.305323
# Epoch: 33	Fidelity = 0.987848	Ideal_fidelity = 0.988419	Noisy_fidelity = 0.993906	Max_eigen_fidelity = 0.995164	KL_Divergence = 0.315146
# Epoch: 34	Fidelity = 0.991285	Ideal_fidelity = 0.990007	Noisy_fidelity = 0.995633	Max_eigen_fidelity = 0.998551	KL_Divergence = 0.316346
# Epoch: 35	Fidelity = 0.992420	Ideal_fidelity = 0.991090	Noisy_fidelity = 0.996203	Max_eigen_fidelity = 0.999069	KL_Divergence = 0.320464
# Epoch: 36	Fidelity = 0.992486	Ideal_fidelity = 0.991030	Noisy_fidelity = 0.996236	Max_eigen_fidelity = 0.998999	KL_Divergence = 0.313907
# Epoch: 37	Fidelity = 0.990130	Ideal_fidelity = 0.990110	Noisy_fidelity = 0.995053	Max_eigen_fidelity = 0.996578	KL_Divergence = 0.329650
# Epoch: 38	Fidelity = 0.991758	Ideal_fidelity = 0.991344	Noisy_fidelity = 0.995871	Max_eigen_fidelity = 0.997587	KL_Divergence = 0.310325
# Epoch: 39	Fidelity = 0.989813	Ideal_fidelity = 0.990544	Noisy_fidelity = 0.994893	Max_eigen_fidelity = 0.995650	KL_Divergence = 0.333393
# Epoch: 40	Fidelity = 0.991849	Ideal_fidelity = 0.991579	Noisy_fidelity = 0.995916	Max_eigen_fidelity = 0.997208	KL_Divergence = 0.310514
# Epoch: 41	Fidelity = 0.993328	Ideal_fidelity = 0.992568	Noisy_fidelity = 0.996658	Max_eigen_fidelity = 0.998637	KL_Divergence = 0.319005
# Epoch: 42	Fidelity = 0.993393	Ideal_fidelity = 0.992551	Noisy_fidelity = 0.996691	Max_eigen_fidelity = 0.998842	KL_Divergence = 0.330668
# Epoch: 43	Fidelity = 0.994183	Ideal_fidelity = 0.992965	Noisy_fidelity = 0.997087	Max_eigen_fidelity = 0.999655	KL_Divergence = 0.319084
# Epoch: 44	Fidelity = 0.993843	Ideal_fidelity = 0.992977	Noisy_fidelity = 0.996917	Max_eigen_fidelity = 0.999208	KL_Divergence = 0.317293
# Epoch: 45	Fidelity = 0.992511	Ideal_fidelity = 0.992303	Noisy_fidelity = 0.996248	Max_eigen_fidelity = 0.997565	KL_Divergence = 0.304243
# Epoch: 46	Fidelity = 0.993751	Ideal_fidelity = 0.992987	Noisy_fidelity = 0.996870	Max_eigen_fidelity = 0.998746	KL_Divergence = 0.305040
# Epoch: 47	Fidelity = 0.993607	Ideal_fidelity = 0.993117	Noisy_fidelity = 0.996798	Max_eigen_fidelity = 0.998309	KL_Divergence = 0.315188
# Epoch: 48	Fidelity = 0.993505	Ideal_fidelity = 0.993059	Noisy_fidelity = 0.996747	Max_eigen_fidelity = 0.998405	KL_Divergence = 0.328624
# Epoch: 49	Fidelity = 0.994167	Ideal_fidelity = 0.993548	Noisy_fidelity = 0.997079	Max_eigen_fidelity = 0.998865	KL_Divergence = 0.304910
# Epoch: 50	Fidelity = 0.994376	Ideal_fidelity = 0.993886	Noisy_fidelity = 0.997184	Max_eigen_fidelity = 0.999035	KL_Divergence = 0.308620
# Epoch: 51	Fidelity = 0.994324	Ideal_fidelity = 0.993831	Noisy_fidelity = 0.997158	Max_eigen_fidelity = 0.999009	KL_Divergence = 0.312415
# Epoch: 52	Fidelity = 0.991179	Ideal_fidelity = 0.992220	Noisy_fidelity = 0.995580	Max_eigen_fidelity = 0.995796	KL_Divergence = 0.316854
# Epoch: 53	Fidelity = 0.995066	Ideal_fidelity = 0.994247	Noisy_fidelity = 0.997530	Max_eigen_fidelity = 0.999874	KL_Divergence = 0.317133
# Epoch: 54	Fidelity = 0.993711	Ideal_fidelity = 0.993630	Noisy_fidelity = 0.996850	Max_eigen_fidelity = 0.998526	KL_Divergence = 0.321979
# Epoch: 55	Fidelity = 0.993250	Ideal_fidelity = 0.993537	Noisy_fidelity = 0.996619	Max_eigen_fidelity = 0.998042	KL_Divergence = 0.328823
# Epoch: 56	Fidelity = 0.994984	Ideal_fidelity = 0.994456	Noisy_fidelity = 0.997489	Max_eigen_fidelity = 0.999539	KL_Divergence = 0.310126
# Epoch: 57	Fidelity = 0.992442	Ideal_fidelity = 0.993420	Noisy_fidelity = 0.996214	Max_eigen_fidelity = 0.996983	KL_Divergence = 0.320602
# Epoch: 58	Fidelity = 0.994566	Ideal_fidelity = 0.994363	Noisy_fidelity = 0.997279	Max_eigen_fidelity = 0.998892	KL_Divergence = 0.322145
# Epoch: 59	Fidelity = 0.993578	Ideal_fidelity = 0.994113	Noisy_fidelity = 0.996784	Max_eigen_fidelity = 0.997990	KL_Divergence = 0.322844
# Epoch: 60	Fidelity = 0.993599	Ideal_fidelity = 0.994121	Noisy_fidelity = 0.996794	Max_eigen_fidelity = 0.997904	KL_Divergence = 0.339199
# Epoch: 61	Fidelity = 0.990261	Ideal_fidelity = 0.992580	Noisy_fidelity = 0.995119	Max_eigen_fidelity = 0.994606	KL_Divergence = 0.347647
# Epoch: 62	Fidelity = 0.995278	Ideal_fidelity = 0.995121	Noisy_fidelity = 0.997636	Max_eigen_fidelity = 0.999546	KL_Divergence = 0.324113
# Epoch: 63	Fidelity = 0.994768	Ideal_fidelity = 0.994832	Noisy_fidelity = 0.997380	Max_eigen_fidelity = 0.999014	KL_Divergence = 0.310272
# Epoch: 64	Fidelity = 0.992333	Ideal_fidelity = 0.993645	Noisy_fidelity = 0.996159	Max_eigen_fidelity = 0.996525	KL_Divergence = 0.341801
# Epoch: 65	Fidelity = 0.993186	Ideal_fidelity = 0.994050	Noisy_fidelity = 0.996587	Max_eigen_fidelity = 0.997426	KL_Divergence = 0.311169
# Epoch: 66	Fidelity = 0.995508	Ideal_fidelity = 0.995362	Noisy_fidelity = 0.997752	Max_eigen_fidelity = 0.999744	KL_Divergence = 0.317195
# Epoch: 67	Fidelity = 0.994820	Ideal_fidelity = 0.995001	Noisy_fidelity = 0.997406	Max_eigen_fidelity = 0.999068	KL_Divergence = 0.320538
# Epoch: 68	Fidelity = 0.995357	Ideal_fidelity = 0.995227	Noisy_fidelity = 0.997676	Max_eigen_fidelity = 0.999470	KL_Divergence = 0.319504
# Epoch: 69	Fidelity = 0.994414	Ideal_fidelity = 0.994901	Noisy_fidelity = 0.997203	Max_eigen_fidelity = 0.998546	KL_Divergence = 0.310927
# Epoch: 70	Fidelity = 0.995091	Ideal_fidelity = 0.995205	Noisy_fidelity = 0.997543	Max_eigen_fidelity = 0.999020	KL_Divergence = 0.313545
# Epoch: 71	Fidelity = 0.994927	Ideal_fidelity = 0.995139	Noisy_fidelity = 0.997460	Max_eigen_fidelity = 0.998957	KL_Divergence = 0.320173
# Epoch: 72	Fidelity = 0.994293	Ideal_fidelity = 0.994955	Noisy_fidelity = 0.997143	Max_eigen_fidelity = 0.998439	KL_Divergence = 0.327337
# Epoch: 73	Fidelity = 0.994670	Ideal_fidelity = 0.995083	Noisy_fidelity = 0.997331	Max_eigen_fidelity = 0.998720	KL_Divergence = 0.320175
# Epoch: 74	Fidelity = 0.994872	Ideal_fidelity = 0.995324	Noisy_fidelity = 0.997433	Max_eigen_fidelity = 0.999008	KL_Divergence = 0.316727
# Epoch: 75	Fidelity = 0.993816	Ideal_fidelity = 0.994917	Noisy_fidelity = 0.996903	Max_eigen_fidelity = 0.997819	KL_Divergence = 0.338002
# Epoch: 76	Fidelity = 0.993168	Ideal_fidelity = 0.994531	Noisy_fidelity = 0.996578	Max_eigen_fidelity = 0.997143	KL_Divergence = 0.326492
# Epoch: 77	Fidelity = 0.995097	Ideal_fidelity = 0.995693	Noisy_fidelity = 0.997546	Max_eigen_fidelity = 0.999214	KL_Divergence = 0.312810
# Epoch: 78	Fidelity = 0.995077	Ideal_fidelity = 0.995514	Noisy_fidelity = 0.997535	Max_eigen_fidelity = 0.999088	KL_Divergence = 0.315767
# Epoch: 79	Fidelity = 0.995330	Ideal_fidelity = 0.995757	Noisy_fidelity = 0.997662	Max_eigen_fidelity = 0.999335	KL_Divergence = 0.314951
# Epoch: 80	Fidelity = 0.995070	Ideal_fidelity = 0.995547	Noisy_fidelity = 0.997532	Max_eigen_fidelity = 0.999079	KL_Divergence = 0.315048
# Epoch: 81	Fidelity = 0.995639	Ideal_fidelity = 0.995926	Noisy_fidelity = 0.997817	Max_eigen_fidelity = 0.999654	KL_Divergence = 0.321013
# Epoch: 82	Fidelity = 0.995214	Ideal_fidelity = 0.995842	Noisy_fidelity = 0.997604	Max_eigen_fidelity = 0.999264	KL_Divergence = 0.321677
# Epoch: 83	Fidelity = 0.995276	Ideal_fidelity = 0.995798	Noisy_fidelity = 0.997635	Max_eigen_fidelity = 0.999303	KL_Divergence = 0.319548
# Epoch: 84	Fidelity = 0.994340	Ideal_fidelity = 0.995358	Noisy_fidelity = 0.997166	Max_eigen_fidelity = 0.998354	KL_Divergence = 0.331316
# Epoch: 85	Fidelity = 0.994600	Ideal_fidelity = 0.995470	Noisy_fidelity = 0.997296	Max_eigen_fidelity = 0.998687	KL_Divergence = 0.306481
# Epoch: 86	Fidelity = 0.991960	Ideal_fidelity = 0.994247	Noisy_fidelity = 0.995972	Max_eigen_fidelity = 0.996166	KL_Divergence = 0.311306
# Epoch: 87	Fidelity = 0.994597	Ideal_fidelity = 0.995475	Noisy_fidelity = 0.997295	Max_eigen_fidelity = 0.998515	KL_Divergence = 0.305624
# Epoch: 88	Fidelity = 0.995260	Ideal_fidelity = 0.995943	Noisy_fidelity = 0.997627	Max_eigen_fidelity = 0.999363	KL_Divergence = 0.313598
# Epoch: 89	Fidelity = 0.995053	Ideal_fidelity = 0.995936	Noisy_fidelity = 0.997523	Max_eigen_fidelity = 0.999161	KL_Divergence = 0.312912
# Epoch: 90	Fidelity = 0.992137	Ideal_fidelity = 0.994475	Noisy_fidelity = 0.996061	Max_eigen_fidelity = 0.996281	KL_Divergence = 0.335929
# Epoch: 91	Fidelity = 0.992174	Ideal_fidelity = 0.994482	Noisy_fidelity = 0.996079	Max_eigen_fidelity = 0.996237	KL_Divergence = 0.313662
# Epoch: 92	Fidelity = 0.995422	Ideal_fidelity = 0.996262	Noisy_fidelity = 0.997708	Max_eigen_fidelity = 0.999419	KL_Divergence = 0.325606
# Epoch: 93	Fidelity = 0.993888	Ideal_fidelity = 0.995509	Noisy_fidelity = 0.996940	Max_eigen_fidelity = 0.997935	KL_Divergence = 0.334748
# Epoch: 94	Fidelity = 0.995693	Ideal_fidelity = 0.996401	Noisy_fidelity = 0.997844	Max_eigen_fidelity = 0.999646	KL_Divergence = 0.318810
# Epoch: 95	Fidelity = 0.994997	Ideal_fidelity = 0.996059	Noisy_fidelity = 0.997495	Max_eigen_fidelity = 0.998979	KL_Divergence = 0.325933
# Epoch: 96	Fidelity = 0.995473	Ideal_fidelity = 0.996252	Noisy_fidelity = 0.997734	Max_eigen_fidelity = 0.999452	KL_Divergence = 0.318170
# Epoch: 97	Fidelity = 0.994059	Ideal_fidelity = 0.995531	Noisy_fidelity = 0.997025	Max_eigen_fidelity = 0.997983	KL_Divergence = 0.328201
# Epoch: 98	Fidelity = 0.995455	Ideal_fidelity = 0.996280	Noisy_fidelity = 0.997725	Max_eigen_fidelity = 0.999277	KL_Divergence = 0.314779
# Epoch: 99	Fidelity = 0.994826	Ideal_fidelity = 0.996072	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.998782	KL_Divergence = 0.310271
# Epoch: 100	Fidelity = 0.994723	Ideal_fidelity = 0.996082	Noisy_fidelity = 0.997358	Max_eigen_fidelity = 0.998719	KL_Divergence = 0.318012
# Epoch: 101	Fidelity = 0.995395	Ideal_fidelity = 0.996503	Noisy_fidelity = 0.997695	Max_eigen_fidelity = 0.999444	KL_Divergence = 0.322496
# Epoch: 102	Fidelity = 0.992963	Ideal_fidelity = 0.995197	Noisy_fidelity = 0.996475	Max_eigen_fidelity = 0.997063	KL_Divergence = 0.313020
# Epoch: 103	Fidelity = 0.994223	Ideal_fidelity = 0.995842	Noisy_fidelity = 0.997107	Max_eigen_fidelity = 0.998273	KL_Divergence = 0.315480
# Epoch: 104	Fidelity = 0.995366	Ideal_fidelity = 0.996430	Noisy_fidelity = 0.997680	Max_eigen_fidelity = 0.999266	KL_Divergence = 0.325258
# Epoch: 105	Fidelity = 0.994935	Ideal_fidelity = 0.996232	Noisy_fidelity = 0.997464	Max_eigen_fidelity = 0.998962	KL_Divergence = 0.327464
# Epoch: 106	Fidelity = 0.994186	Ideal_fidelity = 0.995898	Noisy_fidelity = 0.997089	Max_eigen_fidelity = 0.998341	KL_Divergence = 0.331397
# Epoch: 107	Fidelity = 0.994208	Ideal_fidelity = 0.995711	Noisy_fidelity = 0.997100	Max_eigen_fidelity = 0.998191	KL_Divergence = 0.324915
# Epoch: 108	Fidelity = 0.994108	Ideal_fidelity = 0.995665	Noisy_fidelity = 0.997050	Max_eigen_fidelity = 0.998057	KL_Divergence = 0.304898
# Epoch: 109	Fidelity = 0.993427	Ideal_fidelity = 0.995372	Noisy_fidelity = 0.996708	Max_eigen_fidelity = 0.997316	KL_Divergence = 0.335488
# Epoch: 110	Fidelity = 0.995436	Ideal_fidelity = 0.996385	Noisy_fidelity = 0.997715	Max_eigen_fidelity = 0.999448	KL_Divergence = 0.321996
# Epoch: 111	Fidelity = 0.992710	Ideal_fidelity = 0.995050	Noisy_fidelity = 0.996348	Max_eigen_fidelity = 0.996887	KL_Divergence = 0.317352
# Epoch: 112	Fidelity = 0.995518	Ideal_fidelity = 0.996403	Noisy_fidelity = 0.997756	Max_eigen_fidelity = 0.999561	KL_Divergence = 0.312757
# Epoch: 113	Fidelity = 0.995168	Ideal_fidelity = 0.996349	Noisy_fidelity = 0.997581	Max_eigen_fidelity = 0.999354	KL_Divergence = 0.325717
# Epoch: 114	Fidelity = 0.993760	Ideal_fidelity = 0.995581	Noisy_fidelity = 0.996875	Max_eigen_fidelity = 0.997973	KL_Divergence = 0.315906
# Epoch: 115	Fidelity = 0.994965	Ideal_fidelity = 0.996146	Noisy_fidelity = 0.997479	Max_eigen_fidelity = 0.999073	KL_Divergence = 0.324895
# Epoch: 116	Fidelity = 0.995606	Ideal_fidelity = 0.996477	Noisy_fidelity = 0.997801	Max_eigen_fidelity = 0.999770	KL_Divergence = 0.315990
# Epoch: 117	Fidelity = 0.995561	Ideal_fidelity = 0.996432	Noisy_fidelity = 0.997778	Max_eigen_fidelity = 0.999625	KL_Divergence = 0.317279
# Epoch: 118	Fidelity = 0.994280	Ideal_fidelity = 0.995822	Noisy_fidelity = 0.997136	Max_eigen_fidelity = 0.998312	KL_Divergence = 0.304237
# Epoch: 119	Fidelity = 0.994763	Ideal_fidelity = 0.996224	Noisy_fidelity = 0.997378	Max_eigen_fidelity = 0.998978	KL_Divergence = 0.314560
# Epoch: 120	Fidelity = 0.994617	Ideal_fidelity = 0.996172	Noisy_fidelity = 0.997305	Max_eigen_fidelity = 0.998947	KL_Divergence = 0.320097
# Epoch: 121	Fidelity = 0.994698	Ideal_fidelity = 0.996167	Noisy_fidelity = 0.997345	Max_eigen_fidelity = 0.998892	KL_Divergence = 0.327426
# Epoch: 122	Fidelity = 0.995239	Ideal_fidelity = 0.996427	Noisy_fidelity = 0.997617	Max_eigen_fidelity = 0.999262	KL_Divergence = 0.315502
# Epoch: 123	Fidelity = 0.994539	Ideal_fidelity = 0.996142	Noisy_fidelity = 0.997266	Max_eigen_fidelity = 0.998814	KL_Divergence = 0.316833
# Epoch: 124	Fidelity = 0.994836	Ideal_fidelity = 0.996279	Noisy_fidelity = 0.997415	Max_eigen_fidelity = 0.999052	KL_Divergence = 0.323815
# Epoch: 125	Fidelity = 0.994177	Ideal_fidelity = 0.995928	Noisy_fidelity = 0.997084	Max_eigen_fidelity = 0.998382	KL_Divergence = 0.321359
# Epoch: 126	Fidelity = 0.995669	Ideal_fidelity = 0.996714	Noisy_fidelity = 0.997832	Max_eigen_fidelity = 0.999799	KL_Divergence = 0.314521
# Epoch: 127	Fidelity = 0.994067	Ideal_fidelity = 0.995935	Noisy_fidelity = 0.997029	Max_eigen_fidelity = 0.998319	KL_Divergence = 0.319141
# Epoch: 128	Fidelity = 0.994563	Ideal_fidelity = 0.996170	Noisy_fidelity = 0.997278	Max_eigen_fidelity = 0.998809	KL_Divergence = 0.315324
# Epoch: 129	Fidelity = 0.994561	Ideal_fidelity = 0.996230	Noisy_fidelity = 0.997277	Max_eigen_fidelity = 0.998881	KL_Divergence = 0.316876
# Epoch: 130	Fidelity = 0.994424	Ideal_fidelity = 0.996153	Noisy_fidelity = 0.997208	Max_eigen_fidelity = 0.998775	KL_Divergence = 0.328137
# Epoch: 131	Fidelity = 0.993932	Ideal_fidelity = 0.995823	Noisy_fidelity = 0.996961	Max_eigen_fidelity = 0.998208	KL_Divergence = 0.306966
# Epoch: 132	Fidelity = 0.994970	Ideal_fidelity = 0.996420	Noisy_fidelity = 0.997482	Max_eigen_fidelity = 0.999296	KL_Divergence = 0.328900
# Epoch: 133	Fidelity = 0.993261	Ideal_fidelity = 0.995571	Noisy_fidelity = 0.996625	Max_eigen_fidelity = 0.997597	KL_Divergence = 0.338179
# Epoch: 134	Fidelity = 0.994310	Ideal_fidelity = 0.996050	Noisy_fidelity = 0.997151	Max_eigen_fidelity = 0.998601	KL_Divergence = 0.311046
# Epoch: 135	Fidelity = 0.995603	Ideal_fidelity = 0.996808	Noisy_fidelity = 0.997799	Max_eigen_fidelity = 0.999837	KL_Divergence = 0.318294
# Epoch: 136	Fidelity = 0.994609	Ideal_fidelity = 0.996352	Noisy_fidelity = 0.997301	Max_eigen_fidelity = 0.998961	KL_Divergence = 0.329758
# Epoch: 137	Fidelity = 0.995085	Ideal_fidelity = 0.996599	Noisy_fidelity = 0.997539	Max_eigen_fidelity = 0.999424	KL_Divergence = 0.324650
# Epoch: 138	Fidelity = 0.995247	Ideal_fidelity = 0.996624	Noisy_fidelity = 0.997621	Max_eigen_fidelity = 0.999526	KL_Divergence = 0.318213
# Epoch: 139	Fidelity = 0.993715	Ideal_fidelity = 0.995812	Noisy_fidelity = 0.996852	Max_eigen_fidelity = 0.997978	KL_Divergence = 0.311914
# Epoch: 140	Fidelity = 0.995318	Ideal_fidelity = 0.996724	Noisy_fidelity = 0.997656	Max_eigen_fidelity = 0.999601	KL_Divergence = 0.324722
# Epoch: 141	Fidelity = 0.995383	Ideal_fidelity = 0.996738	Noisy_fidelity = 0.997689	Max_eigen_fidelity = 0.999701	KL_Divergence = 0.320465
# Epoch: 142	Fidelity = 0.994118	Ideal_fidelity = 0.996065	Noisy_fidelity = 0.997055	Max_eigen_fidelity = 0.998419	KL_Divergence = 0.331330
# Epoch: 143	Fidelity = 0.995079	Ideal_fidelity = 0.996614	Noisy_fidelity = 0.997536	Max_eigen_fidelity = 0.999499	KL_Divergence = 0.323124
# Epoch: 144	Fidelity = 0.994849	Ideal_fidelity = 0.996399	Noisy_fidelity = 0.997421	Max_eigen_fidelity = 0.999086	KL_Divergence = 0.329623
# Epoch: 145	Fidelity = 0.995084	Ideal_fidelity = 0.996564	Noisy_fidelity = 0.997539	Max_eigen_fidelity = 0.999437	KL_Divergence = 0.316406
# Epoch: 146	Fidelity = 0.995324	Ideal_fidelity = 0.996650	Noisy_fidelity = 0.997659	Max_eigen_fidelity = 0.999613	KL_Divergence = 0.316510
# Epoch: 147	Fidelity = 0.995077	Ideal_fidelity = 0.996567	Noisy_fidelity = 0.997536	Max_eigen_fidelity = 0.999431	KL_Divergence = 0.318729
# Epoch: 148	Fidelity = 0.995262	Ideal_fidelity = 0.996690	Noisy_fidelity = 0.997628	Max_eigen_fidelity = 0.999629	KL_Divergence = 0.322257
# Epoch: 149	Fidelity = 0.995137	Ideal_fidelity = 0.996593	Noisy_fidelity = 0.997566	Max_eigen_fidelity = 0.999457	KL_Divergence = 0.318994
# Epoch: 150	Fidelity = 0.995055	Ideal_fidelity = 0.996601	Noisy_fidelity = 0.997524	Max_eigen_fidelity = 0.999417	KL_Divergence = 0.322807
# Epoch: 151	Fidelity = 0.994699	Ideal_fidelity = 0.996406	Noisy_fidelity = 0.997346	Max_eigen_fidelity = 0.999062	KL_Divergence = 0.322273
# Epoch: 152	Fidelity = 0.995267	Ideal_fidelity = 0.996749	Noisy_fidelity = 0.997631	Max_eigen_fidelity = 0.999584	KL_Divergence = 0.327733
# Epoch: 153	Fidelity = 0.995293	Ideal_fidelity = 0.996746	Noisy_fidelity = 0.997644	Max_eigen_fidelity = 0.999661	KL_Divergence = 0.325344
# Epoch: 154	Fidelity = 0.994456	Ideal_fidelity = 0.996323	Noisy_fidelity = 0.997224	Max_eigen_fidelity = 0.998895	KL_Divergence = 0.323350
# Epoch: 155	Fidelity = 0.993289	Ideal_fidelity = 0.995665	Noisy_fidelity = 0.996639	Max_eigen_fidelity = 0.997700	KL_Divergence = 0.315770
# Epoch: 156	Fidelity = 0.994956	Ideal_fidelity = 0.996621	Noisy_fidelity = 0.997475	Max_eigen_fidelity = 0.999405	KL_Divergence = 0.323627
# Epoch: 157	Fidelity = 0.994368	Ideal_fidelity = 0.996305	Noisy_fidelity = 0.997180	Max_eigen_fidelity = 0.998786	KL_Divergence = 0.328039
# Epoch: 158	Fidelity = 0.995446	Ideal_fidelity = 0.996847	Noisy_fidelity = 0.997720	Max_eigen_fidelity = 0.999808	KL_Divergence = 0.321127
# Epoch: 159	Fidelity = 0.995481	Ideal_fidelity = 0.996855	Noisy_fidelity = 0.997738	Max_eigen_fidelity = 0.999800	KL_Divergence = 0.321272
# Epoch: 160	Fidelity = 0.993914	Ideal_fidelity = 0.996058	Noisy_fidelity = 0.996952	Max_eigen_fidelity = 0.998414	KL_Divergence = 0.323082
# Epoch: 161	Fidelity = 0.994748	Ideal_fidelity = 0.996458	Noisy_fidelity = 0.997370	Max_eigen_fidelity = 0.999128	KL_Divergence = 0.313716
# Epoch: 162	Fidelity = 0.994777	Ideal_fidelity = 0.996549	Noisy_fidelity = 0.997385	Max_eigen_fidelity = 0.999241	KL_Divergence = 0.321552
# Epoch: 163	Fidelity = 0.993079	Ideal_fidelity = 0.995716	Noisy_fidelity = 0.996534	Max_eigen_fidelity = 0.997640	KL_Divergence = 0.322842
# Epoch: 164	Fidelity = 0.995055	Ideal_fidelity = 0.996634	Noisy_fidelity = 0.997524	Max_eigen_fidelity = 0.999437	KL_Divergence = 0.317231
# Epoch: 165	Fidelity = 0.995019	Ideal_fidelity = 0.996727	Noisy_fidelity = 0.997506	Max_eigen_fidelity = 0.999435	KL_Divergence = 0.324888
# Epoch: 166	Fidelity = 0.993022	Ideal_fidelity = 0.995667	Noisy_fidelity = 0.996505	Max_eigen_fidelity = 0.997533	KL_Divergence = 0.315359
# Epoch: 167	Fidelity = 0.995306	Ideal_fidelity = 0.996833	Noisy_fidelity = 0.997650	Max_eigen_fidelity = 0.999692	KL_Divergence = 0.316552
# Epoch: 168	Fidelity = 0.993164	Ideal_fidelity = 0.995786	Noisy_fidelity = 0.996576	Max_eigen_fidelity = 0.997691	KL_Divergence = 0.328484
# Epoch: 169	Fidelity = 0.995023	Ideal_fidelity = 0.996779	Noisy_fidelity = 0.997509	Max_eigen_fidelity = 0.999491	KL_Divergence = 0.326624
# Epoch: 170	Fidelity = 0.994769	Ideal_fidelity = 0.996626	Noisy_fidelity = 0.997381	Max_eigen_fidelity = 0.999324	KL_Divergence = 0.318490
# Epoch: 171	Fidelity = 0.993699	Ideal_fidelity = 0.996109	Noisy_fidelity = 0.996845	Max_eigen_fidelity = 0.998311	KL_Divergence = 0.329002
# Epoch: 172	Fidelity = 0.994767	Ideal_fidelity = 0.996595	Noisy_fidelity = 0.997380	Max_eigen_fidelity = 0.999268	KL_Divergence = 0.315028
# Epoch: 173	Fidelity = 0.994642	Ideal_fidelity = 0.996590	Noisy_fidelity = 0.997317	Max_eigen_fidelity = 0.999194	KL_Divergence = 0.327103
# Epoch: 174	Fidelity = 0.995051	Ideal_fidelity = 0.996730	Noisy_fidelity = 0.997523	Max_eigen_fidelity = 0.999554	KL_Divergence = 0.320240
# Epoch: 175	Fidelity = 0.994925	Ideal_fidelity = 0.996730	Noisy_fidelity = 0.997459	Max_eigen_fidelity = 0.999518	KL_Divergence = 0.323930
# Epoch: 176	Fidelity = 0.995382	Ideal_fidelity = 0.996914	Noisy_fidelity = 0.997688	Max_eigen_fidelity = 0.999846	KL_Divergence = 0.320342
# Epoch: 177	Fidelity = 0.995262	Ideal_fidelity = 0.996865	Noisy_fidelity = 0.997628	Max_eigen_fidelity = 0.999711	KL_Divergence = 0.315448
# Epoch: 178	Fidelity = 0.994847	Ideal_fidelity = 0.996647	Noisy_fidelity = 0.997420	Max_eigen_fidelity = 0.999380	KL_Divergence = 0.323235
# Epoch: 179	Fidelity = 0.994725	Ideal_fidelity = 0.996628	Noisy_fidelity = 0.997359	Max_eigen_fidelity = 0.999279	KL_Divergence = 0.326249
# Epoch: 180	Fidelity = 0.994875	Ideal_fidelity = 0.996657	Noisy_fidelity = 0.997434	Max_eigen_fidelity = 0.999389	KL_Divergence = 0.319181
# Epoch: 181	Fidelity = 0.994826	Ideal_fidelity = 0.996636	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999307	KL_Divergence = 0.312348
# Epoch: 182	Fidelity = 0.994689	Ideal_fidelity = 0.996594	Noisy_fidelity = 0.997341	Max_eigen_fidelity = 0.999162	KL_Divergence = 0.322372
# Epoch: 183	Fidelity = 0.994687	Ideal_fidelity = 0.996607	Noisy_fidelity = 0.997340	Max_eigen_fidelity = 0.999136	KL_Divergence = 0.327303
# Epoch: 184	Fidelity = 0.995191	Ideal_fidelity = 0.996866	Noisy_fidelity = 0.997593	Max_eigen_fidelity = 0.999622	KL_Divergence = 0.317246
# Epoch: 185	Fidelity = 0.994496	Ideal_fidelity = 0.996568	Noisy_fidelity = 0.997244	Max_eigen_fidelity = 0.999051	KL_Divergence = 0.328142
# Epoch: 186	Fidelity = 0.993864	Ideal_fidelity = 0.996294	Noisy_fidelity = 0.996927	Max_eigen_fidelity = 0.998527	KL_Divergence = 0.322690
# Epoch: 187	Fidelity = 0.995181	Ideal_fidelity = 0.996965	Noisy_fidelity = 0.997588	Max_eigen_fidelity = 0.999727	KL_Divergence = 0.320149
# Epoch: 188	Fidelity = 0.994617	Ideal_fidelity = 0.996655	Noisy_fidelity = 0.997305	Max_eigen_fidelity = 0.999207	KL_Divergence = 0.319927
# Epoch: 189	Fidelity = 0.994437	Ideal_fidelity = 0.996550	Noisy_fidelity = 0.997214	Max_eigen_fidelity = 0.998938	KL_Divergence = 0.328964
# Epoch: 190	Fidelity = 0.994669	Ideal_fidelity = 0.996704	Noisy_fidelity = 0.997331	Max_eigen_fidelity = 0.999246	KL_Divergence = 0.323145
# Epoch: 191	Fidelity = 0.994585	Ideal_fidelity = 0.996668	Noisy_fidelity = 0.997289	Max_eigen_fidelity = 0.999163	KL_Divergence = 0.319961
# Epoch: 192	Fidelity = 0.994500	Ideal_fidelity = 0.996611	Noisy_fidelity = 0.997246	Max_eigen_fidelity = 0.999065	KL_Divergence = 0.323416
# Epoch: 193	Fidelity = 0.994429	Ideal_fidelity = 0.996554	Noisy_fidelity = 0.997210	Max_eigen_fidelity = 0.998979	KL_Divergence = 0.323921
# Epoch: 194	Fidelity = 0.994941	Ideal_fidelity = 0.996772	Noisy_fidelity = 0.997467	Max_eigen_fidelity = 0.999368	KL_Divergence = 0.321831
# Epoch: 195	Fidelity = 0.994666	Ideal_fidelity = 0.996719	Noisy_fidelity = 0.997330	Max_eigen_fidelity = 0.999261	KL_Divergence = 0.321012
# Epoch: 196	Fidelity = 0.994874	Ideal_fidelity = 0.996797	Noisy_fidelity = 0.997434	Max_eigen_fidelity = 0.999395	KL_Divergence = 0.319134
# Epoch: 197	Fidelity = 0.994160	Ideal_fidelity = 0.996468	Noisy_fidelity = 0.997076	Max_eigen_fidelity = 0.998763	KL_Divergence = 0.323897
# Epoch: 198	Fidelity = 0.995155	Ideal_fidelity = 0.996955	Noisy_fidelity = 0.997574	Max_eigen_fidelity = 0.999691	KL_Divergence = 0.320011
# Epoch: 199	Fidelity = 0.995021	Ideal_fidelity = 0.996857	Noisy_fidelity = 0.997508	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.318608
# Epoch: 200	Fidelity = 0.994930	Ideal_fidelity = 0.996834	Noisy_fidelity = 0.997462	Max_eigen_fidelity = 0.999463	KL_Divergence = 0.317191
# Epoch: 201	Fidelity = 0.994589	Ideal_fidelity = 0.996648	Noisy_fidelity = 0.997291	Max_eigen_fidelity = 0.999112	KL_Divergence = 0.316198
# Epoch: 202	Fidelity = 0.994703	Ideal_fidelity = 0.996717	Noisy_fidelity = 0.997348	Max_eigen_fidelity = 0.999201	KL_Divergence = 0.313573
# Epoch: 203	Fidelity = 0.994455	Ideal_fidelity = 0.996647	Noisy_fidelity = 0.997223	Max_eigen_fidelity = 0.998942	KL_Divergence = 0.330676
# Epoch: 204	Fidelity = 0.994981	Ideal_fidelity = 0.996832	Noisy_fidelity = 0.997487	Max_eigen_fidelity = 0.999373	KL_Divergence = 0.322526
# Epoch: 205	Fidelity = 0.994332	Ideal_fidelity = 0.996574	Noisy_fidelity = 0.997162	Max_eigen_fidelity = 0.998929	KL_Divergence = 0.323838
# Epoch: 206	Fidelity = 0.994834	Ideal_fidelity = 0.996812	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999380	KL_Divergence = 0.318964
# Epoch: 207	Fidelity = 0.995033	Ideal_fidelity = 0.996987	Noisy_fidelity = 0.997514	Max_eigen_fidelity = 0.999637	KL_Divergence = 0.322955
# Epoch: 208	Fidelity = 0.995111	Ideal_fidelity = 0.996979	Noisy_fidelity = 0.997552	Max_eigen_fidelity = 0.999642	KL_Divergence = 0.320669
# Epoch: 209	Fidelity = 0.995179	Ideal_fidelity = 0.997011	Noisy_fidelity = 0.997586	Max_eigen_fidelity = 0.999735	KL_Divergence = 0.318454
# Epoch: 210	Fidelity = 0.994483	Ideal_fidelity = 0.996631	Noisy_fidelity = 0.997238	Max_eigen_fidelity = 0.998982	KL_Divergence = 0.328722
# Epoch: 211	Fidelity = 0.995029	Ideal_fidelity = 0.996914	Noisy_fidelity = 0.997511	Max_eigen_fidelity = 0.999503	KL_Divergence = 0.324703
# Epoch: 212	Fidelity = 0.994676	Ideal_fidelity = 0.996810	Noisy_fidelity = 0.997334	Max_eigen_fidelity = 0.999313	KL_Divergence = 0.324698
# Epoch: 213	Fidelity = 0.994574	Ideal_fidelity = 0.996746	Noisy_fidelity = 0.997283	Max_eigen_fidelity = 0.999180	KL_Divergence = 0.325977
# Epoch: 214	Fidelity = 0.994940	Ideal_fidelity = 0.996916	Noisy_fidelity = 0.997467	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.319608
# Epoch: 215	Fidelity = 0.994646	Ideal_fidelity = 0.996740	Noisy_fidelity = 0.997319	Max_eigen_fidelity = 0.999215	KL_Divergence = 0.316693
# Epoch: 216	Fidelity = 0.995229	Ideal_fidelity = 0.997085	Noisy_fidelity = 0.997611	Max_eigen_fidelity = 0.999785	KL_Divergence = 0.320702
# Epoch: 217	Fidelity = 0.995048	Ideal_fidelity = 0.996956	Noisy_fidelity = 0.997521	Max_eigen_fidelity = 0.999571	KL_Divergence = 0.314398
# Epoch: 218	Fidelity = 0.994094	Ideal_fidelity = 0.996586	Noisy_fidelity = 0.997043	Max_eigen_fidelity = 0.998750	KL_Divergence = 0.332042
# Epoch: 219	Fidelity = 0.994998	Ideal_fidelity = 0.996956	Noisy_fidelity = 0.997496	Max_eigen_fidelity = 0.999558	KL_Divergence = 0.320091
# Epoch: 220	Fidelity = 0.995176	Ideal_fidelity = 0.997061	Noisy_fidelity = 0.997585	Max_eigen_fidelity = 0.999717	KL_Divergence = 0.320969
# Epoch: 221	Fidelity = 0.994987	Ideal_fidelity = 0.996988	Noisy_fidelity = 0.997490	Max_eigen_fidelity = 0.999588	KL_Divergence = 0.317237
# Epoch: 222	Fidelity = 0.993996	Ideal_fidelity = 0.996463	Noisy_fidelity = 0.996993	Max_eigen_fidelity = 0.998652	KL_Divergence = 0.322450
# Epoch: 223	Fidelity = 0.993932	Ideal_fidelity = 0.996439	Noisy_fidelity = 0.996961	Max_eigen_fidelity = 0.998593	KL_Divergence = 0.322895
# Epoch: 224	Fidelity = 0.994085	Ideal_fidelity = 0.996533	Noisy_fidelity = 0.997038	Max_eigen_fidelity = 0.998749	KL_Divergence = 0.322297
# Epoch: 225	Fidelity = 0.994734	Ideal_fidelity = 0.996850	Noisy_fidelity = 0.997364	Max_eigen_fidelity = 0.999310	KL_Divergence = 0.323382
# Epoch: 226	Fidelity = 0.994593	Ideal_fidelity = 0.996826	Noisy_fidelity = 0.997293	Max_eigen_fidelity = 0.999254	KL_Divergence = 0.321085
# Epoch: 227	Fidelity = 0.994560	Ideal_fidelity = 0.996762	Noisy_fidelity = 0.997276	Max_eigen_fidelity = 0.999173	KL_Divergence = 0.315369
# Epoch: 228	Fidelity = 0.994628	Ideal_fidelity = 0.996845	Noisy_fidelity = 0.997310	Max_eigen_fidelity = 0.999278	KL_Divergence = 0.322398
# Epoch: 229	Fidelity = 0.995186	Ideal_fidelity = 0.997081	Noisy_fidelity = 0.997590	Max_eigen_fidelity = 0.999734	KL_Divergence = 0.317246
# Epoch: 230	Fidelity = 0.994954	Ideal_fidelity = 0.996973	Noisy_fidelity = 0.997474	Max_eigen_fidelity = 0.999507	KL_Divergence = 0.322296
# Epoch: 231	Fidelity = 0.995056	Ideal_fidelity = 0.997051	Noisy_fidelity = 0.997525	Max_eigen_fidelity = 0.999633	KL_Divergence = 0.320544
# Epoch: 232	Fidelity = 0.994826	Ideal_fidelity = 0.996933	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999436	KL_Divergence = 0.318315
# Epoch: 233	Fidelity = 0.994548	Ideal_fidelity = 0.996835	Noisy_fidelity = 0.997270	Max_eigen_fidelity = 0.999195	KL_Divergence = 0.323552
# Epoch: 234	Fidelity = 0.995018	Ideal_fidelity = 0.997033	Noisy_fidelity = 0.997506	Max_eigen_fidelity = 0.999564	KL_Divergence = 0.322824
# Epoch: 235	Fidelity = 0.994769	Ideal_fidelity = 0.996853	Noisy_fidelity = 0.997381	Max_eigen_fidelity = 0.999260	KL_Divergence = 0.322265
# Epoch: 236	Fidelity = 0.994793	Ideal_fidelity = 0.996864	Noisy_fidelity = 0.997393	Max_eigen_fidelity = 0.999283	KL_Divergence = 0.321272
# Epoch: 237	Fidelity = 0.994725	Ideal_fidelity = 0.996857	Noisy_fidelity = 0.997359	Max_eigen_fidelity = 0.999177	KL_Divergence = 0.326187
# Epoch: 238	Fidelity = 0.994884	Ideal_fidelity = 0.996991	Noisy_fidelity = 0.997439	Max_eigen_fidelity = 0.999477	KL_Divergence = 0.319357
# Epoch: 239	Fidelity = 0.995118	Ideal_fidelity = 0.997111	Noisy_fidelity = 0.997556	Max_eigen_fidelity = 0.999663	KL_Divergence = 0.320418
# Epoch: 240	Fidelity = 0.994783	Ideal_fidelity = 0.996964	Noisy_fidelity = 0.997388	Max_eigen_fidelity = 0.999390	KL_Divergence = 0.322030
# Epoch: 241	Fidelity = 0.994875	Ideal_fidelity = 0.996964	Noisy_fidelity = 0.997434	Max_eigen_fidelity = 0.999405	KL_Divergence = 0.320969
# Epoch: 242	Fidelity = 0.995014	Ideal_fidelity = 0.997075	Noisy_fidelity = 0.997504	Max_eigen_fidelity = 0.999575	KL_Divergence = 0.321341
# Epoch: 243	Fidelity = 0.994937	Ideal_fidelity = 0.997040	Noisy_fidelity = 0.997465	Max_eigen_fidelity = 0.999520	KL_Divergence = 0.319835
# Epoch: 244	Fidelity = 0.994862	Ideal_fidelity = 0.997061	Noisy_fidelity = 0.997427	Max_eigen_fidelity = 0.999509	KL_Divergence = 0.323285
# Epoch: 245	Fidelity = 0.994952	Ideal_fidelity = 0.997111	Noisy_fidelity = 0.997473	Max_eigen_fidelity = 0.999579	KL_Divergence = 0.323016
# Epoch: 246	Fidelity = 0.994627	Ideal_fidelity = 0.996916	Noisy_fidelity = 0.997310	Max_eigen_fidelity = 0.999233	KL_Divergence = 0.325547
# Epoch: 247	Fidelity = 0.994710	Ideal_fidelity = 0.996950	Noisy_fidelity = 0.997352	Max_eigen_fidelity = 0.999304	KL_Divergence = 0.325027
# Epoch: 248	Fidelity = 0.994863	Ideal_fidelity = 0.997035	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999485	KL_Divergence = 0.322999
# Epoch: 249	Fidelity = 0.994836	Ideal_fidelity = 0.997038	Noisy_fidelity = 0.997415	Max_eigen_fidelity = 0.999462	KL_Divergence = 0.324057
# Epoch: 250	Fidelity = 0.995108	Ideal_fidelity = 0.997123	Noisy_fidelity = 0.997551	Max_eigen_fidelity = 0.999650	KL_Divergence = 0.318889
# Epoch: 251	Fidelity = 0.995063	Ideal_fidelity = 0.997092	Noisy_fidelity = 0.997528	Max_eigen_fidelity = 0.999587	KL_Divergence = 0.319965
# Epoch: 252	Fidelity = 0.994533	Ideal_fidelity = 0.996885	Noisy_fidelity = 0.997263	Max_eigen_fidelity = 0.999202	KL_Divergence = 0.319661
# Epoch: 253	Fidelity = 0.994888	Ideal_fidelity = 0.997031	Noisy_fidelity = 0.997441	Max_eigen_fidelity = 0.999494	KL_Divergence = 0.315831
# Epoch: 254	Fidelity = 0.995036	Ideal_fidelity = 0.997111	Noisy_fidelity = 0.997515	Max_eigen_fidelity = 0.999635	KL_Divergence = 0.317335
# Epoch: 255	Fidelity = 0.994371	Ideal_fidelity = 0.996813	Noisy_fidelity = 0.997182	Max_eigen_fidelity = 0.999062	KL_Divergence = 0.322052
# Epoch: 256	Fidelity = 0.995004	Ideal_fidelity = 0.997126	Noisy_fidelity = 0.997499	Max_eigen_fidelity = 0.999615	KL_Divergence = 0.321350
# Epoch: 257	Fidelity = 0.994812	Ideal_fidelity = 0.996988	Noisy_fidelity = 0.997403	Max_eigen_fidelity = 0.999408	KL_Divergence = 0.316431
# Epoch: 258	Fidelity = 0.994820	Ideal_fidelity = 0.997033	Noisy_fidelity = 0.997407	Max_eigen_fidelity = 0.999434	KL_Divergence = 0.322125
# Epoch: 259	Fidelity = 0.995058	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997526	Max_eigen_fidelity = 0.999657	KL_Divergence = 0.320894
# Epoch: 260	Fidelity = 0.994859	Ideal_fidelity = 0.997052	Noisy_fidelity = 0.997426	Max_eigen_fidelity = 0.999488	KL_Divergence = 0.317426
# Epoch: 261	Fidelity = 0.994519	Ideal_fidelity = 0.996909	Noisy_fidelity = 0.997256	Max_eigen_fidelity = 0.999176	KL_Divergence = 0.323854
# Epoch: 262	Fidelity = 0.994781	Ideal_fidelity = 0.997058	Noisy_fidelity = 0.997387	Max_eigen_fidelity = 0.999441	KL_Divergence = 0.321970
# Epoch: 263	Fidelity = 0.994864	Ideal_fidelity = 0.997098	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999488	KL_Divergence = 0.325473
# Epoch: 264	Fidelity = 0.995126	Ideal_fidelity = 0.997237	Noisy_fidelity = 0.997560	Max_eigen_fidelity = 0.999754	KL_Divergence = 0.320845
# Epoch: 265	Fidelity = 0.995022	Ideal_fidelity = 0.997131	Noisy_fidelity = 0.997508	Max_eigen_fidelity = 0.999587	KL_Divergence = 0.321014
# Epoch: 266	Fidelity = 0.994807	Ideal_fidelity = 0.997030	Noisy_fidelity = 0.997400	Max_eigen_fidelity = 0.999422	KL_Divergence = 0.321041
# Epoch: 267	Fidelity = 0.995115	Ideal_fidelity = 0.997205	Noisy_fidelity = 0.997555	Max_eigen_fidelity = 0.999696	KL_Divergence = 0.321448
# Epoch: 268	Fidelity = 0.994946	Ideal_fidelity = 0.997104	Noisy_fidelity = 0.997470	Max_eigen_fidelity = 0.999558	KL_Divergence = 0.319360
# Epoch: 269	Fidelity = 0.995010	Ideal_fidelity = 0.997127	Noisy_fidelity = 0.997502	Max_eigen_fidelity = 0.999596	KL_Divergence = 0.318225
# Epoch: 270	Fidelity = 0.994735	Ideal_fidelity = 0.996996	Noisy_fidelity = 0.997364	Max_eigen_fidelity = 0.999355	KL_Divergence = 0.320625
# Epoch: 271	Fidelity = 0.994992	Ideal_fidelity = 0.997135	Noisy_fidelity = 0.997493	Max_eigen_fidelity = 0.999620	KL_Divergence = 0.318395
# Epoch: 272	Fidelity = 0.994965	Ideal_fidelity = 0.997140	Noisy_fidelity = 0.997479	Max_eigen_fidelity = 0.999610	KL_Divergence = 0.319282
# Epoch: 273	Fidelity = 0.994983	Ideal_fidelity = 0.997139	Noisy_fidelity = 0.997488	Max_eigen_fidelity = 0.999624	KL_Divergence = 0.317269
# Epoch: 274	Fidelity = 0.994913	Ideal_fidelity = 0.997083	Noisy_fidelity = 0.997453	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.316075
# Epoch: 275	Fidelity = 0.994800	Ideal_fidelity = 0.997054	Noisy_fidelity = 0.997397	Max_eigen_fidelity = 0.999461	KL_Divergence = 0.318618
# Epoch: 276	Fidelity = 0.994871	Ideal_fidelity = 0.997085	Noisy_fidelity = 0.997432	Max_eigen_fidelity = 0.999495	KL_Divergence = 0.322727
# Epoch: 277	Fidelity = 0.994833	Ideal_fidelity = 0.997054	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999451	KL_Divergence = 0.322026
# Epoch: 278	Fidelity = 0.994894	Ideal_fidelity = 0.997112	Noisy_fidelity = 0.997444	Max_eigen_fidelity = 0.999520	KL_Divergence = 0.323632
# Epoch: 279	Fidelity = 0.994978	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997486	Max_eigen_fidelity = 0.999624	KL_Divergence = 0.321017
# Epoch: 280	Fidelity = 0.995008	Ideal_fidelity = 0.997202	Noisy_fidelity = 0.997501	Max_eigen_fidelity = 0.999669	KL_Divergence = 0.321892
# Epoch: 281	Fidelity = 0.994933	Ideal_fidelity = 0.997172	Noisy_fidelity = 0.997463	Max_eigen_fidelity = 0.999592	KL_Divergence = 0.323397
# Epoch: 282	Fidelity = 0.994999	Ideal_fidelity = 0.997197	Noisy_fidelity = 0.997496	Max_eigen_fidelity = 0.999641	KL_Divergence = 0.322234
# Epoch: 283	Fidelity = 0.994978	Ideal_fidelity = 0.997175	Noisy_fidelity = 0.997486	Max_eigen_fidelity = 0.999632	KL_Divergence = 0.320583
# Epoch: 284	Fidelity = 0.995032	Ideal_fidelity = 0.997187	Noisy_fidelity = 0.997513	Max_eigen_fidelity = 0.999660	KL_Divergence = 0.320388
# Epoch: 285	Fidelity = 0.994853	Ideal_fidelity = 0.997101	Noisy_fidelity = 0.997423	Max_eigen_fidelity = 0.999516	KL_Divergence = 0.318008
# Epoch: 286	Fidelity = 0.994978	Ideal_fidelity = 0.997161	Noisy_fidelity = 0.997486	Max_eigen_fidelity = 0.999613	KL_Divergence = 0.320164
# Epoch: 287	Fidelity = 0.994813	Ideal_fidelity = 0.997067	Noisy_fidelity = 0.997403	Max_eigen_fidelity = 0.999461	KL_Divergence = 0.317167
# Epoch: 288	Fidelity = 0.994855	Ideal_fidelity = 0.997129	Noisy_fidelity = 0.997424	Max_eigen_fidelity = 0.999527	KL_Divergence = 0.321156
# Epoch: 289	Fidelity = 0.994823	Ideal_fidelity = 0.997122	Noisy_fidelity = 0.997408	Max_eigen_fidelity = 0.999488	KL_Divergence = 0.324885
# Epoch: 290	Fidelity = 0.994616	Ideal_fidelity = 0.997019	Noisy_fidelity = 0.997305	Max_eigen_fidelity = 0.999331	KL_Divergence = 0.321300
# Epoch: 291	Fidelity = 0.994822	Ideal_fidelity = 0.997108	Noisy_fidelity = 0.997407	Max_eigen_fidelity = 0.999501	KL_Divergence = 0.320770
# Epoch: 292	Fidelity = 0.994892	Ideal_fidelity = 0.997143	Noisy_fidelity = 0.997443	Max_eigen_fidelity = 0.999568	KL_Divergence = 0.320673
# Epoch: 293	Fidelity = 0.994919	Ideal_fidelity = 0.997151	Noisy_fidelity = 0.997456	Max_eigen_fidelity = 0.999584	KL_Divergence = 0.321969
# Epoch: 294	Fidelity = 0.994974	Ideal_fidelity = 0.997164	Noisy_fidelity = 0.997484	Max_eigen_fidelity = 0.999613	KL_Divergence = 0.322107
# Epoch: 295	Fidelity = 0.994977	Ideal_fidelity = 0.997151	Noisy_fidelity = 0.997485	Max_eigen_fidelity = 0.999616	KL_Divergence = 0.319208
# Epoch: 296	Fidelity = 0.994699	Ideal_fidelity = 0.997014	Noisy_fidelity = 0.997346	Max_eigen_fidelity = 0.999370	KL_Divergence = 0.319197
# Epoch: 297	Fidelity = 0.994854	Ideal_fidelity = 0.997081	Noisy_fidelity = 0.997424	Max_eigen_fidelity = 0.999494	KL_Divergence = 0.318296
# Epoch: 298	Fidelity = 0.994682	Ideal_fidelity = 0.996983	Noisy_fidelity = 0.997338	Max_eigen_fidelity = 0.999324	KL_Divergence = 0.319988
# Epoch: 299	Fidelity = 0.994850	Ideal_fidelity = 0.997045	Noisy_fidelity = 0.997422	Max_eigen_fidelity = 0.999444	KL_Divergence = 0.320634
# Epoch: 300	Fidelity = 0.994659	Ideal_fidelity = 0.996955	Noisy_fidelity = 0.997326	Max_eigen_fidelity = 0.999257	KL_Divergence = 0.323147
# Epoch: 301	Fidelity = 0.994776	Ideal_fidelity = 0.997011	Noisy_fidelity = 0.997385	Max_eigen_fidelity = 0.999364	KL_Divergence = 0.322937
# Epoch: 302	Fidelity = 0.994797	Ideal_fidelity = 0.997052	Noisy_fidelity = 0.997395	Max_eigen_fidelity = 0.999427	KL_Divergence = 0.323301
# Epoch: 303	Fidelity = 0.994887	Ideal_fidelity = 0.997101	Noisy_fidelity = 0.997440	Max_eigen_fidelity = 0.999522	KL_Divergence = 0.321594
# Epoch: 304	Fidelity = 0.994658	Ideal_fidelity = 0.996995	Noisy_fidelity = 0.997325	Max_eigen_fidelity = 0.999322	KL_Divergence = 0.322743
# Epoch: 305	Fidelity = 0.994811	Ideal_fidelity = 0.997071	Noisy_fidelity = 0.997402	Max_eigen_fidelity = 0.999473	KL_Divergence = 0.319096
# Epoch: 306	Fidelity = 0.994888	Ideal_fidelity = 0.997090	Noisy_fidelity = 0.997441	Max_eigen_fidelity = 0.999505	KL_Divergence = 0.321069
# Epoch: 307	Fidelity = 0.994945	Ideal_fidelity = 0.997131	Noisy_fidelity = 0.997469	Max_eigen_fidelity = 0.999583	KL_Divergence = 0.320115
# Epoch: 308	Fidelity = 0.994931	Ideal_fidelity = 0.997122	Noisy_fidelity = 0.997462	Max_eigen_fidelity = 0.999573	KL_Divergence = 0.319205
# Epoch: 309	Fidelity = 0.994775	Ideal_fidelity = 0.997037	Noisy_fidelity = 0.997384	Max_eigen_fidelity = 0.999410	KL_Divergence = 0.322788
# Epoch: 310	Fidelity = 0.994824	Ideal_fidelity = 0.997063	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999455	KL_Divergence = 0.322763
# Epoch: 311	Fidelity = 0.994780	Ideal_fidelity = 0.997045	Noisy_fidelity = 0.997387	Max_eigen_fidelity = 0.999426	KL_Divergence = 0.321144
# Epoch: 312	Fidelity = 0.994669	Ideal_fidelity = 0.996982	Noisy_fidelity = 0.997331	Max_eigen_fidelity = 0.999325	KL_Divergence = 0.319101
# Epoch: 313	Fidelity = 0.994698	Ideal_fidelity = 0.996996	Noisy_fidelity = 0.997346	Max_eigen_fidelity = 0.999341	KL_Divergence = 0.321048
# Epoch: 314	Fidelity = 0.994853	Ideal_fidelity = 0.997077	Noisy_fidelity = 0.997423	Max_eigen_fidelity = 0.999479	KL_Divergence = 0.320816
# Epoch: 315	Fidelity = 0.994914	Ideal_fidelity = 0.997112	Noisy_fidelity = 0.997454	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.320617
# Epoch: 316	Fidelity = 0.994657	Ideal_fidelity = 0.996976	Noisy_fidelity = 0.997325	Max_eigen_fidelity = 0.999307	KL_Divergence = 0.317881
# Epoch: 317	Fidelity = 0.994687	Ideal_fidelity = 0.997002	Noisy_fidelity = 0.997340	Max_eigen_fidelity = 0.999329	KL_Divergence = 0.321998
# Epoch: 318	Fidelity = 0.994900	Ideal_fidelity = 0.997112	Noisy_fidelity = 0.997447	Max_eigen_fidelity = 0.999530	KL_Divergence = 0.320878
# Epoch: 319	Fidelity = 0.994939	Ideal_fidelity = 0.997143	Noisy_fidelity = 0.997466	Max_eigen_fidelity = 0.999581	KL_Divergence = 0.320295
# Epoch: 320	Fidelity = 0.994957	Ideal_fidelity = 0.997175	Noisy_fidelity = 0.997475	Max_eigen_fidelity = 0.999627	KL_Divergence = 0.320145
# Epoch: 321	Fidelity = 0.994977	Ideal_fidelity = 0.997172	Noisy_fidelity = 0.997485	Max_eigen_fidelity = 0.999620	KL_Divergence = 0.320042
# Epoch: 322	Fidelity = 0.994700	Ideal_fidelity = 0.997040	Noisy_fidelity = 0.997347	Max_eigen_fidelity = 0.999386	KL_Divergence = 0.319065
# Epoch: 323	Fidelity = 0.994792	Ideal_fidelity = 0.997097	Noisy_fidelity = 0.997393	Max_eigen_fidelity = 0.999476	KL_Divergence = 0.320412
# Epoch: 324	Fidelity = 0.994789	Ideal_fidelity = 0.997107	Noisy_fidelity = 0.997391	Max_eigen_fidelity = 0.999474	KL_Divergence = 0.322235
# Epoch: 325	Fidelity = 0.994888	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997441	Max_eigen_fidelity = 0.999565	KL_Divergence = 0.321429
# Epoch: 326	Fidelity = 0.994805	Ideal_fidelity = 0.997130	Noisy_fidelity = 0.997399	Max_eigen_fidelity = 0.999488	KL_Divergence = 0.324053
# Epoch: 327	Fidelity = 0.994760	Ideal_fidelity = 0.997095	Noisy_fidelity = 0.997377	Max_eigen_fidelity = 0.999433	KL_Divergence = 0.324040
# Epoch: 328	Fidelity = 0.994832	Ideal_fidelity = 0.997119	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999507	KL_Divergence = 0.320729
# Epoch: 329	Fidelity = 0.994898	Ideal_fidelity = 0.997154	Noisy_fidelity = 0.997446	Max_eigen_fidelity = 0.999562	KL_Divergence = 0.322119
# Epoch: 330	Fidelity = 0.994884	Ideal_fidelity = 0.997148	Noisy_fidelity = 0.997439	Max_eigen_fidelity = 0.999545	KL_Divergence = 0.322556
# Epoch: 331	Fidelity = 0.994901	Ideal_fidelity = 0.997139	Noisy_fidelity = 0.997447	Max_eigen_fidelity = 0.999539	KL_Divergence = 0.321727
# Epoch: 332	Fidelity = 0.994816	Ideal_fidelity = 0.997108	Noisy_fidelity = 0.997404	Max_eigen_fidelity = 0.999474	KL_Divergence = 0.322330
# Epoch: 333	Fidelity = 0.994842	Ideal_fidelity = 0.997125	Noisy_fidelity = 0.997418	Max_eigen_fidelity = 0.999511	KL_Divergence = 0.321501
# Epoch: 334	Fidelity = 0.994879	Ideal_fidelity = 0.997130	Noisy_fidelity = 0.997436	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.320299
# Epoch: 335	Fidelity = 0.994868	Ideal_fidelity = 0.997138	Noisy_fidelity = 0.997431	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.321701
# Epoch: 336	Fidelity = 0.994726	Ideal_fidelity = 0.997059	Noisy_fidelity = 0.997360	Max_eigen_fidelity = 0.999411	KL_Divergence = 0.318856
# Epoch: 337	Fidelity = 0.994872	Ideal_fidelity = 0.997136	Noisy_fidelity = 0.997433	Max_eigen_fidelity = 0.999546	KL_Divergence = 0.319712
# Epoch: 338	Fidelity = 0.994863	Ideal_fidelity = 0.997138	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999543	KL_Divergence = 0.319112
# Epoch: 339	Fidelity = 0.994800	Ideal_fidelity = 0.997090	Noisy_fidelity = 0.997397	Max_eigen_fidelity = 0.999471	KL_Divergence = 0.317728
# Epoch: 340	Fidelity = 0.994816	Ideal_fidelity = 0.997096	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999475	KL_Divergence = 0.319275
# Epoch: 341	Fidelity = 0.994768	Ideal_fidelity = 0.997084	Noisy_fidelity = 0.997381	Max_eigen_fidelity = 0.999439	KL_Divergence = 0.320951
# Epoch: 342	Fidelity = 0.994834	Ideal_fidelity = 0.997119	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999502	KL_Divergence = 0.321031
# Epoch: 343	Fidelity = 0.994776	Ideal_fidelity = 0.997105	Noisy_fidelity = 0.997384	Max_eigen_fidelity = 0.999467	KL_Divergence = 0.321084
# Epoch: 344	Fidelity = 0.994835	Ideal_fidelity = 0.997126	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999513	KL_Divergence = 0.320627
# Epoch: 345	Fidelity = 0.994777	Ideal_fidelity = 0.997072	Noisy_fidelity = 0.997385	Max_eigen_fidelity = 0.999426	KL_Divergence = 0.321826
# Epoch: 346	Fidelity = 0.994758	Ideal_fidelity = 0.997059	Noisy_fidelity = 0.997376	Max_eigen_fidelity = 0.999409	KL_Divergence = 0.321017
# Epoch: 347	Fidelity = 0.994756	Ideal_fidelity = 0.997081	Noisy_fidelity = 0.997375	Max_eigen_fidelity = 0.999437	KL_Divergence = 0.321265
# Epoch: 348	Fidelity = 0.994812	Ideal_fidelity = 0.997114	Noisy_fidelity = 0.997403	Max_eigen_fidelity = 0.999479	KL_Divergence = 0.322721
# ...
# Epoch: 386	Fidelity = 0.994853	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997423	Max_eigen_fidelity = 0.999542	KL_Divergence = 0.321540
# Epoch: 387	Fidelity = 0.994877	Ideal_fidelity = 0.997158	Noisy_fidelity = 0.997435	Max_eigen_fidelity = 0.999547	KL_Divergence = 0.321278
# Epoch: 388	Fidelity = 0.994881	Ideal_fidelity = 0.997158	Noisy_fidelity = 0.997437	Max_eigen_fidelity = 0.999550	KL_Divergence = 0.320928
# Epoch: 389	Fidelity = 0.994862	Ideal_fidelity = 0.997147	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999520	KL_Divergence = 0.322295
# Epoch: 390	Fidelity = 0.994866	Ideal_fidelity = 0.997148	Noisy_fidelity = 0.997430	Max_eigen_fidelity = 0.999536	KL_Divergence = 0.320862
# Epoch: 391	Fidelity = 0.994858	Ideal_fidelity = 0.997137	Noisy_fidelity = 0.997426	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.320396
# Epoch: 392	Fidelity = 0.994884	Ideal_fidelity = 0.997147	Noisy_fidelity = 0.997439	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.320987
# Epoch: 393	Fidelity = 0.994893	Ideal_fidelity = 0.997155	Noisy_fidelity = 0.997443	Max_eigen_fidelity = 0.999547	KL_Divergence = 0.321232
# Epoch: 394	Fidelity = 0.994878	Ideal_fidelity = 0.997143	Noisy_fidelity = 0.997436	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.320517
# Epoch: 395	Fidelity = 0.994852	Ideal_fidelity = 0.997143	Noisy_fidelity = 0.997423	Max_eigen_fidelity = 0.999521	KL_Divergence = 0.321885
# Epoch: 396	Fidelity = 0.994807	Ideal_fidelity = 0.997130	Noisy_fidelity = 0.997400	Max_eigen_fidelity = 0.999492	KL_Divergence = 0.322399
# Epoch: 397	Fidelity = 0.994842	Ideal_fidelity = 0.997148	Noisy_fidelity = 0.997418	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.322324
# Epoch: 398	Fidelity = 0.994875	Ideal_fidelity = 0.997157	Noisy_fidelity = 0.997434	Max_eigen_fidelity = 0.999549	KL_Divergence = 0.321191
# Epoch: 399	Fidelity = 0.994841	Ideal_fidelity = 0.997142	Noisy_fidelity = 0.997417	Max_eigen_fidelity = 0.999517	KL_Divergence = 0.321571
# Epoch: 400	Fidelity = 0.994850	Ideal_fidelity = 0.997155	Noisy_fidelity = 0.997422	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.322096
# Epoch: 401	Fidelity = 0.994877	Ideal_fidelity = 0.997168	Noisy_fidelity = 0.997435	Max_eigen_fidelity = 0.999564	KL_Divergence = 0.320442
# Epoch: 402	Fidelity = 0.994872	Ideal_fidelity = 0.997161	Noisy_fidelity = 0.997433	Max_eigen_fidelity = 0.999553	KL_Divergence = 0.320422
# Epoch: 403	Fidelity = 0.994854	Ideal_fidelity = 0.997151	Noisy_fidelity = 0.997424	Max_eigen_fidelity = 0.999540	KL_Divergence = 0.319915
# Epoch: 404	Fidelity = 0.994871	Ideal_fidelity = 0.997170	Noisy_fidelity = 0.997432	Max_eigen_fidelity = 0.999565	KL_Divergence = 0.320380
# Epoch: 405	Fidelity = 0.994851	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997422	Max_eigen_fidelity = 0.999539	KL_Divergence = 0.321455
# Epoch: 406	Fidelity = 0.994875	Ideal_fidelity = 0.997171	Noisy_fidelity = 0.997434	Max_eigen_fidelity = 0.999565	KL_Divergence = 0.320451
# Epoch: 407	Fidelity = 0.994815	Ideal_fidelity = 0.997129	Noisy_fidelity = 0.997404	Max_eigen_fidelity = 0.999507	KL_Divergence = 0.318793
# Epoch: 408	Fidelity = 0.994806	Ideal_fidelity = 0.997125	Noisy_fidelity = 0.997400	Max_eigen_fidelity = 0.999499	KL_Divergence = 0.317834
# Epoch: 409	Fidelity = 0.994844	Ideal_fidelity = 0.997147	Noisy_fidelity = 0.997418	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.319270
# Epoch: 410	Fidelity = 0.994827	Ideal_fidelity = 0.997138	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999520	KL_Divergence = 0.319588
# Epoch: 411	Fidelity = 0.994839	Ideal_fidelity = 0.997146	Noisy_fidelity = 0.997416	Max_eigen_fidelity = 0.999530	KL_Divergence = 0.320050
# Epoch: 412	Fidelity = 0.994845	Ideal_fidelity = 0.997152	Noisy_fidelity = 0.997419	Max_eigen_fidelity = 0.999542	KL_Divergence = 0.319796
# Epoch: 413	Fidelity = 0.994839	Ideal_fidelity = 0.997143	Noisy_fidelity = 0.997416	Max_eigen_fidelity = 0.999531	KL_Divergence = 0.319107
# Epoch: 414	Fidelity = 0.994827	Ideal_fidelity = 0.997128	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999510	KL_Divergence = 0.319090
# Epoch: 415	Fidelity = 0.994812	Ideal_fidelity = 0.997125	Noisy_fidelity = 0.997402	Max_eigen_fidelity = 0.999500	KL_Divergence = 0.319463
# Epoch: 416	Fidelity = 0.994831	Ideal_fidelity = 0.997135	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999516	KL_Divergence = 0.319915
# Epoch: 417	Fidelity = 0.994837	Ideal_fidelity = 0.997142	Noisy_fidelity = 0.997415	Max_eigen_fidelity = 0.999525	KL_Divergence = 0.319640
# Epoch: 418	Fidelity = 0.994835	Ideal_fidelity = 0.997149	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999528	KL_Divergence = 0.320546
# Epoch: 419	Fidelity = 0.994860	Ideal_fidelity = 0.997169	Noisy_fidelity = 0.997427	Max_eigen_fidelity = 0.999557	KL_Divergence = 0.320637
# Epoch: 420	Fidelity = 0.994846	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997420	Max_eigen_fidelity = 0.999548	KL_Divergence = 0.320837
# Epoch: 421	Fidelity = 0.994845	Ideal_fidelity = 0.997161	Noisy_fidelity = 0.997419	Max_eigen_fidelity = 0.999542	KL_Divergence = 0.320739
# Epoch: 422	Fidelity = 0.994862	Ideal_fidelity = 0.997170	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999560	KL_Divergence = 0.320441
# Epoch: 423	Fidelity = 0.994859	Ideal_fidelity = 0.997173	Noisy_fidelity = 0.997426	Max_eigen_fidelity = 0.999560	KL_Divergence = 0.320833
# Epoch: 424	Fidelity = 0.994856	Ideal_fidelity = 0.997173	Noisy_fidelity = 0.997425	Max_eigen_fidelity = 0.999559	KL_Divergence = 0.320939
# Epoch: 425	Fidelity = 0.994834	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.321939
# Epoch: 426	Fidelity = 0.994849	Ideal_fidelity = 0.997174	Noisy_fidelity = 0.997421	Max_eigen_fidelity = 0.999548	KL_Divergence = 0.322046
# Epoch: 427	Fidelity = 0.994841	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997417	Max_eigen_fidelity = 0.999539	KL_Divergence = 0.321610
# Epoch: 428	Fidelity = 0.994830	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999524	KL_Divergence = 0.321953
# Epoch: 429	Fidelity = 0.994831	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.321741
# Epoch: 430	Fidelity = 0.994824	Ideal_fidelity = 0.997158	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999519	KL_Divergence = 0.322124
# Epoch: 431	Fidelity = 0.994834	Ideal_fidelity = 0.997164	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999531	KL_Divergence = 0.322059
# Epoch: 432	Fidelity = 0.994842	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997418	Max_eigen_fidelity = 0.999536	KL_Divergence = 0.322000
# Epoch: 433	Fidelity = 0.994841	Ideal_fidelity = 0.997161	Noisy_fidelity = 0.997417	Max_eigen_fidelity = 0.999529	KL_Divergence = 0.321964
# Epoch: 434	Fidelity = 0.994844	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997419	Max_eigen_fidelity = 0.999542	KL_Divergence = 0.321508
# Epoch: 435	Fidelity = 0.994837	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997415	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.322487
# Epoch: 436	Fidelity = 0.994826	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999537	KL_Divergence = 0.321810
# Epoch: 437	Fidelity = 0.994827	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999537	KL_Divergence = 0.322029
# Epoch: 438	Fidelity = 0.994832	Ideal_fidelity = 0.997170	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999541	KL_Divergence = 0.322129
# Epoch: 439	Fidelity = 0.994831	Ideal_fidelity = 0.997171	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999541	KL_Divergence = 0.322377
# Epoch: 440	Fidelity = 0.994810	Ideal_fidelity = 0.997156	Noisy_fidelity = 0.997401	Max_eigen_fidelity = 0.999511	KL_Divergence = 0.323286
# Epoch: 441	Fidelity = 0.994802	Ideal_fidelity = 0.997149	Noisy_fidelity = 0.997398	Max_eigen_fidelity = 0.999498	KL_Divergence = 0.323544
# Epoch: 442	Fidelity = 0.994828	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997411	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.322825
# Epoch: 443	Fidelity = 0.994846	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997420	Max_eigen_fidelity = 0.999544	KL_Divergence = 0.322063
# Epoch: 444	Fidelity = 0.994850	Ideal_fidelity = 0.997169	Noisy_fidelity = 0.997422	Max_eigen_fidelity = 0.999546	KL_Divergence = 0.322105
# Epoch: 445	Fidelity = 0.994859	Ideal_fidelity = 0.997177	Noisy_fidelity = 0.997426	Max_eigen_fidelity = 0.999564	KL_Divergence = 0.321387
# Epoch: 446	Fidelity = 0.994869	Ideal_fidelity = 0.997183	Noisy_fidelity = 0.997431	Max_eigen_fidelity = 0.999573	KL_Divergence = 0.321495
# Epoch: 447	Fidelity = 0.994878	Ideal_fidelity = 0.997189	Noisy_fidelity = 0.997436	Max_eigen_fidelity = 0.999584	KL_Divergence = 0.321194
# Epoch: 448	Fidelity = 0.994870	Ideal_fidelity = 0.997179	Noisy_fidelity = 0.997432	Max_eigen_fidelity = 0.999570	KL_Divergence = 0.320873
# Epoch: 449	Fidelity = 0.994869	Ideal_fidelity = 0.997181	Noisy_fidelity = 0.997431	Max_eigen_fidelity = 0.999566	KL_Divergence = 0.321618
# Epoch: 450	Fidelity = 0.994854	Ideal_fidelity = 0.997180	Noisy_fidelity = 0.997424	Max_eigen_fidelity = 0.999560	KL_Divergence = 0.321740
# Epoch: 451	Fidelity = 0.994854	Ideal_fidelity = 0.997178	Noisy_fidelity = 0.997424	Max_eigen_fidelity = 0.999560	KL_Divergence = 0.321320
# Epoch: 452	Fidelity = 0.994863	Ideal_fidelity = 0.997180	Noisy_fidelity = 0.997428	Max_eigen_fidelity = 0.999564	KL_Divergence = 0.321197
# Epoch: 453	Fidelity = 0.994848	Ideal_fidelity = 0.997171	Noisy_fidelity = 0.997421	Max_eigen_fidelity = 0.999551	KL_Divergence = 0.321027
# Epoch: 454	Fidelity = 0.994836	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997415	Max_eigen_fidelity = 0.999540	KL_Divergence = 0.321128
# Epoch: 455	Fidelity = 0.994835	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999540	KL_Divergence = 0.321431
# Epoch: 456	Fidelity = 0.994826	Ideal_fidelity = 0.997168	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999540	KL_Divergence = 0.321480
# Epoch: 457	Fidelity = 0.994831	Ideal_fidelity = 0.997170	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999543	KL_Divergence = 0.321180
# Epoch: 458	Fidelity = 0.994833	Ideal_fidelity = 0.997175	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999550	KL_Divergence = 0.321146
# Epoch: 459	Fidelity = 0.994829	Ideal_fidelity = 0.997172	Noisy_fidelity = 0.997411	Max_eigen_fidelity = 0.999543	KL_Divergence = 0.321412
# Epoch: 460	Fidelity = 0.994802	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997398	Max_eigen_fidelity = 0.999521	KL_Divergence = 0.321193
# Epoch: 461	Fidelity = 0.994817	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.320750
# Epoch: 462	Fidelity = 0.994813	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997403	Max_eigen_fidelity = 0.999531	KL_Divergence = 0.321119
# Epoch: 463	Fidelity = 0.994806	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997399	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.321527
# Epoch: 464	Fidelity = 0.994811	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997402	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.322037
# Epoch: 465	Fidelity = 0.994820	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997407	Max_eigen_fidelity = 0.999529	KL_Divergence = 0.321690
# Epoch: 466	Fidelity = 0.994825	Ideal_fidelity = 0.997168	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.321332
# Epoch: 467	Fidelity = 0.994816	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999531	KL_Divergence = 0.321492
# Epoch: 468	Fidelity = 0.994817	Ideal_fidelity = 0.997166	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.321500
# Epoch: 469	Fidelity = 0.994829	Ideal_fidelity = 0.997170	Noisy_fidelity = 0.997411	Max_eigen_fidelity = 0.999543	KL_Divergence = 0.321056
# Epoch: 470	Fidelity = 0.994826	Ideal_fidelity = 0.997169	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999543	KL_Divergence = 0.320783
# Epoch: 471	Fidelity = 0.994817	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.320507
# Epoch: 472	Fidelity = 0.994820	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997406	Max_eigen_fidelity = 0.999536	KL_Divergence = 0.321020
# Epoch: 473	Fidelity = 0.994815	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997404	Max_eigen_fidelity = 0.999530	KL_Divergence = 0.321440
# Epoch: 474	Fidelity = 0.994826	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997410	Max_eigen_fidelity = 0.999534	KL_Divergence = 0.321005
# Epoch: 475	Fidelity = 0.994835	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999542	KL_Divergence = 0.320715
# Epoch: 476	Fidelity = 0.994833	Ideal_fidelity = 0.997169	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999544	KL_Divergence = 0.320791
# Epoch: 477	Fidelity = 0.994829	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997411	Max_eigen_fidelity = 0.999538	KL_Divergence = 0.320530
# Epoch: 478	Fidelity = 0.994834	Ideal_fidelity = 0.997161	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.320530
# Epoch: 479	Fidelity = 0.994825	Ideal_fidelity = 0.997159	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999528	KL_Divergence = 0.320851
# Epoch: 480	Fidelity = 0.994816	Ideal_fidelity = 0.997156	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999520	KL_Divergence = 0.320983
# Epoch: 481	Fidelity = 0.994808	Ideal_fidelity = 0.997149	Noisy_fidelity = 0.997400	Max_eigen_fidelity = 0.999509	KL_Divergence = 0.321102
# Epoch: 482	Fidelity = 0.994810	Ideal_fidelity = 0.997148	Noisy_fidelity = 0.997402	Max_eigen_fidelity = 0.999509	KL_Divergence = 0.320803
# Epoch: 483	Fidelity = 0.994810	Ideal_fidelity = 0.997150	Noisy_fidelity = 0.997401	Max_eigen_fidelity = 0.999508	KL_Divergence = 0.321277
# Epoch: 484	Fidelity = 0.994814	Ideal_fidelity = 0.997153	Noisy_fidelity = 0.997403	Max_eigen_fidelity = 0.999515	KL_Divergence = 0.320985
# Epoch: 485	Fidelity = 0.994818	Ideal_fidelity = 0.997155	Noisy_fidelity = 0.997405	Max_eigen_fidelity = 0.999516	KL_Divergence = 0.321214
# Epoch: 486	Fidelity = 0.994819	Ideal_fidelity = 0.997155	Noisy_fidelity = 0.997406	Max_eigen_fidelity = 0.999514	KL_Divergence = 0.321620
# Epoch: 487	Fidelity = 0.994825	Ideal_fidelity = 0.997158	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999517	KL_Divergence = 0.321828
# Epoch: 488	Fidelity = 0.994831	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997412	Max_eigen_fidelity = 0.999528	KL_Divergence = 0.321468
# Epoch: 489	Fidelity = 0.994835	Ideal_fidelity = 0.997167	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999533	KL_Divergence = 0.321583
# Epoch: 490	Fidelity = 0.994832	Ideal_fidelity = 0.997163	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999530	KL_Divergence = 0.321138
# Epoch: 491	Fidelity = 0.994834	Ideal_fidelity = 0.997165	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999531	KL_Divergence = 0.321055
# Epoch: 492	Fidelity = 0.994834	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999525	KL_Divergence = 0.321009
# Epoch: 493	Fidelity = 0.994833	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999524	KL_Divergence = 0.321160
# Epoch: 494	Fidelity = 0.994834	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997413	Max_eigen_fidelity = 0.999522	KL_Divergence = 0.321252
# Epoch: 495	Fidelity = 0.994841	Ideal_fidelity = 0.997160	Noisy_fidelity = 0.997417	Max_eigen_fidelity = 0.999526	KL_Divergence = 0.320927
# Epoch: 496	Fidelity = 0.994841	Ideal_fidelity = 0.997157	Noisy_fidelity = 0.997417	Max_eigen_fidelity = 0.999523	KL_Divergence = 0.320575
# Epoch: 497	Fidelity = 0.994834	Ideal_fidelity = 0.997153	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999518	KL_Divergence = 0.320271
# Epoch: 498	Fidelity = 0.994834	Ideal_fidelity = 0.997156	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999522	KL_Divergence = 0.320284
# Epoch: 499	Fidelity = 0.994836	Ideal_fidelity = 0.997158	Noisy_fidelity = 0.997414	Max_eigen_fidelity = 0.999522	KL_Divergence = 0.320607
# Epoch: 500	Fidelity = 0.994825	Ideal_fidelity = 0.997150	Noisy_fidelity = 0.997409	Max_eigen_fidelity = 0.999511	KL_Divergence = 0.320558
# Total time elapsed during training: 10097.819 s

# %%
fidelities = callbacks[0]["Fidelity"]
KLs = callbacks[0]["KL_Divergence"]
epoch_range = np.arange(period, epoch + 1, period)

fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (16, 5))
ax = axs[0]
ax.plot(epoch_range, fidelities, "o", color = "C0", markeredgecolor = "black")
ax.set_ylabel(r"Fidelity")
ax.set_xlabel(r"Epoch")
ax.set_ylim(0.00, 1.00)

ax = axs[1]
ax.plot(epoch_range, KLs, "o", color = "C1", markeredgecolor = "black")
ax.set_ylabel(r"KL Divergence")
ax.set_xlabel(r"Epoch")

# %% [markdown]
# ## save model & train log

# %% [markdown]
# # save model
# nn_state_dm.save("./exp003/model.pt")
# # save train log
# train_log_df = pd.DataFrame()
# train_log_df["epoch"] = np.arange(period, epoch+1, period)
# train_log_df["Fidelity"] = callbacks[0]["Fidelity"]
# train_log_df["KL_Divergence"] = callbacks[0]["KL_Divergence"]
# #train_log_df["Observable_ZZ_ev"] = callbacks[0]["Observable_ZZ_ev"]
# #train_log_df["Observable_XZ_ev"] = callbacks[0]["Observable_XZ_ev"]
# #train_log_df.to_csv("./exp003/train_log.csv", index=False)
